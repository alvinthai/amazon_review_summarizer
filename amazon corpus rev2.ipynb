# %%
# 2016/08/03 6:17PM
# No filters for amod score in this notebook

# %% [markdown]
# # My Code

# %%
from __future__ import division
from bs4 import BeautifulSoup
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from pprint import pprint
from spacy.en import English
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
import datetime
import numpy as np
import pandas as pd
import os
import re
import requests
import string
import time

parser = English()

# %%
# list of dependencies not likely to be words found in features
com_dep = set(['det', 'aux', 'cc', 'punct', 'mark', '', 'neg', 'nummod',
               'prt', 'auxpass', 'case', 'expl', 'preconj', 'intj',
               'predet', 'meta', 'quantmod', 'agent'])

# list of POS tags not likely to be words found in features
com_tag = set(['IN', 'PRP', 'PRP$', 'DT', 'HYPH', 'TO', ',', '.', 'CC',
               'SP', 'CD', 'MD', 'WDT', 'RP', 'WRB', '-LRB-', '-RRB-',
               ':', 'WP', 'POS', '``', "''", 'SYM', 'EX', 'PDT', 'UH',
               'NFP', 'XX'])

# list of POS tag belonging to nouns
noun_tag = set(['NN', 'NNP', 'NNS'])

# %%
# stopword aspects to filter out
nonaspects = set(['product', 'price', 'problem', 'device', 'review',
                 'item', 'amazon', 'everything', 'company', 'brand',
                 'buy', 'purchase', 'cost'])

# stopword adjectives to filter out
nonadj = set(['other', 'first', 'second', 'third', 'much'])

# %%
class SentCustomProperties(object):
    '''
    adds properties to spacy sentence that tracks:
        index of review where sentence originated
        spacy Span object
        index of sentence within review corpus
        index of first token in sentence within review
        num of words in sentences
    '''
    
    def __init__(self, review_idx, sent_idx, sent):
        '''
        INPUT: int, int, spacy sentence (spacy.tokens.span.Span)
        OUTPUT: None
        '''
        self.review_idx = review_idx
        self.sent = sent
        self.sent_idx = sent_idx
        self.start_idx = sent[0].i
        self.words = len(sent)

# %%
class ReviewSents(object):
    '''
    Takes a list of unicode reviews and stores the sentences
    (with additional properties) in the returned object
    '''
    
    def __init__(self, reviews):
        '''
        INPUT: list(unicode)
        OUTPUT: None
        '''
        self.reviews = reviews
        self.n_reviews, self.n_sent, self.sentences = self._parse_sentences()
        
    def _parse_sentences(self):
        '''
        INPUT: None
        OUTPUT: int, int, list(SentCustomProperties)
        
        Uses spacy to parse and split the sentences
        Return number of reviews, sentences, and list of spacy objects
        '''
        n_sent, n_reviews = 0, 0
        sentences = []
        
        for i, review in enumerate(self.reviews):
            try:
                review = parser(review)
                n_reviews += 1
            except AssertionError:
                print 'parser for review #{} failed'.format(i)
                continue
            
            for sent in review.sents:
                if sent.string:
                    sentences.append(SentCustomProperties(i, n_sent, sent))
                    n_sent += 1
                
        return n_reviews, n_sent, sentences

# %%
def _iter_nps(sent):
    '''
    INPUT: spacy sentence (spacy.tokens.span.Span)
    OUTPUT: set
    
    Iterates through each token of spacy sentence and collects
    lemmas of all nouns into a set
    
    this function requires parser to be defined as:
        from spacy.en import English
        parser = English()
    '''
    wordset = set()
    
    for token in sent:
        root = parser.vocab[token.lemma].prob
        # filter to only consider nouns
        if token.tag_ in noun_tag and (root < -7.5 and
                                       token.lemma_ not in nonaspects):
            wordset.add(token.lemma_)
    
    return " ".join(wordset)

def candidate_unigrams(corpus, min_pct=0.01):
    '''
    INPUT: ReviewSents, float
    OUTPUT: set
    
    obtains a set of candidate unigrams
    each candidate unigram must be a noun and must appear in at least
        a percentage of the sentences specified by min_pct
    '''
    count_X = []

    for sent in corpus.sentences:
        count_X.append(_iter_nps(sent.sent))
        
    cnt_vec = CountVectorizer()
    freq = cnt_vec.fit_transform(count_X)
    
    total_count = freq.toarray().sum(axis=0)
    filter_ = total_count >= min_pct * corpus.n_sent

    features = np.array(cnt_vec.get_feature_names())
    return set(features[filter_])

# %%
def _get_compactness_feat(corpus):
    '''
    INPUT: ReviewSents
    OUTPUT: generator(tuples(unicode))
    
    outputs generator of tuples consisting of:
        at least one noun
        a second word within +/- 3 words of noun
    excludes dependencies and tags not likely to be a feature word
    
    this function requires parser to be defined as:
        from spacy.en import English
        parser = English()
    '''

    for sent in corpus.sentences:
        output = set()

        for i, token in enumerate(sent.sent):
            # one word in bigram must be noun
            if token.tag_ not in noun_tag or token.lemma_ in nonaspects:
                continue
            else:
                arr = sent.sent[max(0, i-3):min(i+4, sent.words)]
                arr = np.array(arr)
                arr = arr[arr != token]

                for item in arr:
                    root = parser.vocab[item.lemma].prob
                    # filter out unlikely features
                    if root > -7.5 or (item.dep_ in com_dep or
                                       item.tag_ in com_tag or
                                       item.lemma_ in nonaspects):
                        continue
                    else:
                        tup = tuple(sorted([item.lemma_, token.lemma_]))
                        output.add(tup)

        if output:
            for element in output:
                yield element
                            
def candidate_bigrams(corpus, min_pct=0.005):
    '''
    INPUT: ReviewSents, float
    OUTPUT: set(tuples), set(str)
    
    outputs set of tuples and set of words within tuples from 
        _get_compactness_feat function appearing at least 
        min_cnt times
    '''
    bigrams = set()
    bigram_words = set()
    
    feats = Counter(_get_compactness_feat(corpus))
    
    for (key, val) in feats.iteritems():
        if val >= max(2, min_pct * corpus.n_sent):
            bigrams.add(key)
            bigram_words.update(set(key))
            
    return bigrams, bigram_words

# %%
def _check_bigram(adj, token, sent, bigrams, bigram_words):
    '''
    INPUT: spacy token (spacy.tokens.token.Token),
           spacy token (spacy.tokens.token.Token),
           SentCustomProperties,
           set(tuples),
           set(str)
    OUTPUT: generator(tuples)
    
    Given an adjective token, dependency word token, a sentence, and 
        token index within sentence, check if the token has any 
        associated bigram within +/- 3 words and yield all bigrams. 
    
    If no bigrams, yield unigram.
    '''
    yielded = False
    seen_words = []
    t_idx = token.i - sent.start_idx
    a_idx = adj.i - sent.start_idx
    
    arr = sent.sent[max(0, t_idx-3):min(t_idx+4, sent.words)]
    
    for item in arr:
        if item == token or (item.lemma_ in seen_words or
                             item.lemma_ in nonaspects):
            continue
        elif item.lemma_ in bigram_words:
            tup = tuple(sorted([item.lemma_, token.lemma_]))
            adjectives = [adj]
            
            if adj.lemma_ in tup:
                # try finding first adjective around aspect if
                #     bigram includes adjective
                # return nothing if no other adjectives found
                left = max(0, min(a_idx-3, t_idx-3))
                right = min(sent.words, max(a_idx+4, t_idx+4))
                bi_arr = sent.sent[left:right]

                adjectives = [word for word in bi_arr 
                              if word.tag_ in ['JJ', 'JJR', 'JJS']
                              and word.lemma_ not in tup
                              and word.lemma_ not in nonadj]
                
            if tup in bigrams and adjectives:
                yielded = True
                seen_words.append(item.lemma_)
                # for checking which word in bigram is likely to appear first
                ordering = [1, 0] if item.lemma_ == tup[0] else [0, 1]
                a_idx = adjectives[0].i - sent.start_idx
                
                yield (adjectives[0].lemma_, tup, 
                       np.array(ordering), t_idx, a_idx)
                
    if not yielded:
        yield (adj.lemma_, token.lemma_, np.array([1, 0]), t_idx, a_idx)

def extract_aspects(corpus, unigrams, bigrams, bigram_words):
    '''
    INPUT: ReviewSents, set(str), set(tuple), set(str)
    OUTPUT: dictionary
    
    Extracts all aspects modified by an 'amod' dependency and returns
    dictionary of all aspects within candidate unigram and bigram aspects
    
    relation_from: list of words that aspect has dependency relation from
    relation_dep: list of dependencies types aspect has relationship from
    
    adjectives: word modifying the aspect
    adj_idx: list of where adjective can be found within sentence
    aspect_idx: list of where aspect can be found within sentence
    ordering: if bigram, count of which word appears first
    review_idx: list of which reviews contain aspct
    sentence_idx: list of which sentences contain aspect
    
    amod_pct: percentage of time aspect has 'amod' dependency relation
    review_count: how many reviews aspects are found in
    sentence_count: how many sentences aspects are found in
    '''
    props = defaultdict(lambda:
                    {'adjectives': [],
                     'adj_idx': [],
                     'aspect_idx': [],
                     'ordering': np.array([0, 0]),
                     'relation_from': [],
                     'relation_dep': [],
                     'review_idx': [],
                     'sentence_idx': []})
    
    for sent in corpus.sentences:
        
        for token in sent.sent:
            # code to check frequency of adjective for aspect
            if token.head.lemma_ in unigrams:
                props[token.head.lemma_]['relation_from'].append(token.lemma_)
                props[token.head.lemma_]['relation_dep'].append(token.dep_)
            
            if token.head.lemma_ not in unigrams or token.lemma_ in nonadj:
                continue
            
            elif token.dep_ == 'amod':
                aspects = _check_bigram(token, token.head, sent, 
                                        bigrams, bigram_words)
                
                for adj, aspect, ordering, asp_i, adj_i in aspects:
                    props[aspect]['adjectives'].append(adj)
                    props[aspect]['adj_idx'].append(adj_i)
                    props[aspect]['aspect_idx'].append(asp_i)
                    props[aspect]['review_idx'].append(sent.review_idx)
                    props[aspect]['sentence_idx'].append(sent.sent_idx)
                    props[aspect]['ordering'] += ordering
    
    for key in props:
        props[key]['review_count'] = len(set(props[key]['review_idx']))
        props[key]['sent_count'] = len(set(props[key]['sentence_idx']))
        
        if isinstance(key, unicode):
            arr = np.array(props[key]['relation_dep']) == 'amod'
            props[key]['amod_pct'] = np.sum(arr)/len(arr)
    
    # determining bigram amod percentage requires knowing unigram amod
    for key in props:        
        if isinstance(key, tuple):
            reverse = props[key]['ordering'][1] > props[key]['ordering'][0]
            word1 = key[reverse]
            word2_key = key[not reverse]
            
            arr = np.array(props[word2_key]['relation_from']) == word1
            props[key]['amod_pct'] = np.sum(arr)/len(arr)
        
    return props

# %%
def sort_aspect_frequency(aspect_dict, n=3):
    '''
    INPUT: dict, int
    OUTPUT: list([aspect, freq])
    
    Outputs a list of the most common aspect occuring at least n times in descending order.
    Dictionary returned from extract_aspects is the input of this function.
    '''
    counts = []

    for key in aspect_dict:

        freq = aspect_dict[key]['review_count']
        amod = round(aspect_dict[key]['amod_pct'], 3)

        if freq < n:
            continue

        if isinstance(key, tuple):
            # check which word of bigram appears first more often
            reverse = aspect_dict[key]['ordering'][1] > aspect_dict[key]['ordering'][0]
            ordered_key = " ".join(sorted(key, reverse=reverse))
            counts.append([ordered_key, freq, amod])
        else:
            counts.append([key, freq, amod])

    return sorted(counts, key=lambda x: x[1], reverse=True)

# %%
def print_sentence_frag(corpus, aspect_dict, aspect, adjective=None):
    '''
    INPUT: ReviewSents, dict, string, str(optional)
    OUTPUT: None
    
    Script that prints out sentence fragment containing adjective
        describing specified aspect.
    
    Dictionary returned from extract_aspects is the second input 
        of this function.
    
    If no adjective specified, prints all adjectives in descending
        order of occurance.
    '''
    print '-'*40
    print aspect
    print '-'*40
    print

    aspect_list = aspect.split(" ")
    
    if len(aspect_list) == 2:
        aspect = tuple(sorted(aspect_list))
    
    if not adjective:
        adjectives = Counter(aspect_dict[aspect]['adjectives']).most_common()
        
        for (word, freq) in adjectives:
            # toss out adjectives that with non-alphabetic characters
            if not word.isalpha():
                continue
            
            print freq, "\t", word
            print '-'*40
            
            mask = np.array(aspect_dict[aspect]['adjectives']) == word
            aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
            sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]
            
            for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
                sent = corpus.sentences[s_idx]
                print i, sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)]
                
            print
            
    else:
        print adjective
        print '-'*40

        mask = np.array(aspect_dict[aspect]['adjectives']) == adjective
        aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
        sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]

        for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
            sent = corpus.sentences[s_idx]
            print i, sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)]

        print

# %%
def pipeline(df, asin_list):
    '''
    INPUT: df, list(str)
    OUTPUT: dict
    
    runs pipeline specified in functions above for list of asin
        on loaded data frame containing reviews
    outputs asin callable dictionary with attributes:
        aspect_dict: dictionary of aspects
        sorted_aspects: list of descending aspect frequencies
    '''
    print 'start time:', datetime.datetime.now().time().isoformat()
    print
    
    asin_dict = defaultdict(dict)
    
    for asin in asin_list:
        print 'working on ASIN {}'.format(asin)
        print '-'*40
        
        reviews = df[df.asin == asin].reviewText.tolist()
        corpus = ReviewSents(reviews)
        
        unigrams = candidate_unigrams(corpus)
        bigrams, bigram_words = candidate_bigrams(corpus)
        
        results = extract_aspects(corpus, unigrams, bigrams, bigram_words)
        freq = sort_aspect_frequency(results)
        
        asin_dict[asin]['corpus'] = corpus
        asin_dict[asin]['aspect_dict'] = results
        asin_dict[asin]['sorted_aspects'] = freq
        
        print '-'*40
        print
    
    print 'end time:', datetime.datetime.now().time().isoformat()
    return asin_dict

# %%
def print_sentence_frag_multiprod(multiprod_corpus,
                                  aspect, adjective=None):
    '''
    INPUT: dict, string, str(optional)
    OUTPUT: None
    
    Script that prints out sentence fragment containing adjective
        describing specified aspect.
    
    Dictionary returned from pipeline function is the first input 
        of this function.
    
    If no adjective specified, prints all adjectives in descending
        order of occurance.
    '''
    print '-'*60
    print aspect
    print '-'*60
    print

    for asin in multiprod_corpus:
        if aspect not in multiprod_corpus[asin]['aspect_dict']:
            continue
        
        print '-'*50
        print asin
        print '-'*50
        print
        
        corpus = multiprod_corpus[asin]['corpus']
        aspect_dict = multiprod_corpus[asin]['aspect_dict']
    
        aspect_list = aspect.split(" ")

        if len(aspect_list) == 2:
            aspect = tuple(sorted(aspect_list))

        if not adjective:
            adjectives = Counter(aspect_dict[aspect]['adjectives']).most_common()

            for (word, freq) in adjectives:
                # toss out adjectives that with non-alphabetic characters
                if not word.isalpha():
                    continue

                print freq, "\t", word
                print '-'*40

                mask = np.array(aspect_dict[aspect]['adjectives']) == word
                aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
                sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]

                for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
                    sent = corpus.sentences[s_idx]
                    print i, sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)]

                print

        else:
            print adjective
            print '-'*40

            mask = np.array(aspect_dict[aspect]['adjectives']) == adjective
            aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
            sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]

            for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
                sent = corpus.sentences[s_idx]
                print i, sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)]

            print

# %%
def get_item_name(asin_list):
    '''
    INPUT: list
    OUTPUT: dict
    
    Script that returns a list of product names given an ASIN list
    '''
    output = dict()
    
    for asin in asin_list:
        url = 'https://www.amazon.com/dp/{}/'.format(asin)
        user_agent = ['Mozilla/5.0 (X11; Linux i686) AppleWebKit/534.30',
                      '(KHTML, like Gecko) Ubuntu/11.04',
                      'Chromium/12.0.742.91 Chrome/12.0.742.91',
                      'Safari/534.30']
        headers = {'User-Agent': np.random.choice(user_agent)}
        html = requests.get(url, headers=headers).content
        soup = BeautifulSoup(html, 'html.parser')
        try:
            name = soup.select('#productTitle')[0].text.strip()
        except IndexError:
            name = ''
            
        output[asin] = name
        time.sleep(5 + np.random.random()*10)
    
    return output

# %%
def print_sorted_aspects_multiprod(multiprod_corpus, product_names):
    '''
    INPUT: dict
    OUTPUT: None
    
    Script that prints out top occuring aspects for each product
    '''

    for asin in multiprod_corpus:

        print '-'*50
        print asin, product_names[asin]
        print '-'*50
        print
        pprint(multiprod_corpus[asin]['sorted_aspects'])
        print

# %% [markdown]
# # Amazon Electronics Review Corpus

# %%
with open('reviews/Electronics_5-2.json', 'r') as f:
    data = f.readlines()

# %%
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"

# %%
df = pd.read_json(data_json_str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689188 entries, 0 to 1689187
# Data columns (total 9 columns):
# asin              1689188 non-null object
# helpful           1689188 non-null object
# overall           1689188 non-null int64
# reviewText        1689188 non-null object
# reviewTime        1689188 non-null object
# reviewerID        1689188 non-null object
# reviewerName      1664458 non-null object
# summary           1689188 non-null object
# unixReviewTime    1689188 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 128.9+ MB

# %%
group = df.groupby('asin').size()

# %%
len(group[df.groupby('asin').size() >= 1000])
# Out:
# 52

# %%
asin_1000 = group[df.groupby('asin').size() >= 1000].index.tolist()
asin_1000
# Out:
# [u'B00004ZCJE',
#  u'B00007E7JU',
#  u'B0002L5R78',
#  u'B000BQ7GW8',
#  u'B000I68BD4',
#  u'B000LRMS66',
#  u'B000QUUFRW',
#  u'B000S5Q9CA',
#  u'B000VX6XL6',
#  u'B0012S4APK',
#  u'B0015DYMVO',
#  u'B0019EHU8G',
#  u'B001TH7GSW',
#  u'B001TH7GUU',
#  u'B001XURP7W',
#  u'B0027VT6V4',
#  u'B002MAPRYU',
#  u'B002QEBMAK',
#  u'B002SZEOLG',
#  u'B002V88HFE',
#  u'B002WE6D44',
#  u'B00316263Y',
#  u'B003ELYQGG',
#  u'B003ES5ZUU',
#  u'B0041Q38NU',
#  u'B0043T7FXE',
#  u'B0044YU60M',
#  u'B004G6002M',
#  u'B004GF8TIK',
#  u'B004QK7HI8',
#  u'B004W2JKWG',
#  u'B004XC6GJ0',
#  u'B0052SCU8U',
#  u'B005CLPP84',
#  u'B005CT56F8',
#  u'B005DKZTMG',
#  u'B005FYNSPK',
#  u'B005HMKKH4',
#  u'B00622AG6S',
#  u'B006GWO5WK',
#  u'B006W8U2MU',
#  u'B0074BW614',
#  u'B007I5JT4S',
#  u'B007R5YDYA',
#  u'B007WTAJTO',
#  u'B008OHNZI0',
#  u'B009A5204K',
#  u'B009SYZ8OC',
#  u'B00B46XUQU',
#  u'B00BGGDVOO',
#  u'B00DR0PDNE',
#  u'B00E3W15P0']

# %%
product_names = get_item_name(asin_1000)

# %%
group[df.groupby('asin').size() >= 1000].sum()
# Out:
# 89054

# %%
asin_dict = pipeline(df, asin_1000)
# Out:
# start time: 17:37:42.429110
#
# working on ASIN B00004ZCJE
# ----------------------------------------
# parser for review #18 failed
# parser for review #493 failed
# parser for review #1081 failed
# ----------------------------------------
#
# working on ASIN B00007E7JU
# ----------------------------------------
# parser for review #312 failed
# parser for review #602 failed
# parser for review #643 failed
# ----------------------------------------
#
# working on ASIN B0002L5R78
# ----------------------------------------
# parser for review #446 failed
# parser for review #1291 failed
# parser for review #1624 failed
# parser for review #1867 failed
# parser for review #2009 failed
# parser for review #2581 failed
# ----------------------------------------
#
# working on ASIN B000BQ7GW8
# ----------------------------------------
# parser for review #648 failed
# parser for review #939 failed
# parser for review #1028 failed
# parser for review #1122 failed
# ----------------------------------------
#
# working on ASIN B000I68BD4
# ----------------------------------------
# parser for review #24 failed
# parser for review #867 failed
# ----------------------------------------
#
# working on ASIN B000LRMS66
# ----------------------------------------
# parser for review #418 failed
# parser for review #649 failed
# parser for review #756 failed
# parser for review #827 failed
# parser for review #1311 failed
# ----------------------------------------
#
# working on ASIN B000QUUFRW
# ----------------------------------------
# parser for review #384 failed
# ----------------------------------------
#
# working on ASIN B000S5Q9CA
# ----------------------------------------
# parser for review #366 failed
# parser for review #975 failed
# ----------------------------------------
#
# working on ASIN B000VX6XL6
# ----------------------------------------
# parser for review #572 failed
# parser for review #1026 failed
# parser for review #1359 failed
# ----------------------------------------
#
# working on ASIN B0012S4APK
# ----------------------------------------
# parser for review #420 failed
# ----------------------------------------
#
# working on ASIN B0015DYMVO
# ----------------------------------------
# parser for review #1191 failed
# parser for review #1209 failed
# ----------------------------------------
#
# working on ASIN B0019EHU8G
# ----------------------------------------
# parser for review #224 failed
# parser for review #2108 failed
# parser for review #2277 failed
# parser for review #2573 failed
# parser for review #2972 failed
# parser for review #2973 failed
# parser for review #3069 failed
# ----------------------------------------
#
# working on ASIN B001TH7GSW
# ----------------------------------------
# parser for review #419 failed
# parser for review #966 failed
# parser for review #1035 failed
# ----------------------------------------
#
# working on ASIN B001TH7GUU
# ----------------------------------------
# parser for review #174 failed
# parser for review #430 failed
# parser for review #805 failed
# ----------------------------------------
#
# working on ASIN B001XURP7W
# ----------------------------------------
# parser for review #623 failed
# parser for review #627 failed
# parser for review #856 failed
# parser for review #928 failed
# parser for review #1104 failed
# parser for review #1320 failed
# ----------------------------------------
#
# working on ASIN B0027VT6V4
# ----------------------------------------
# parser for review #160 failed
# parser for review #328 failed
# parser for review #372 failed
# parser for review #476 failed
# parser for review #517 failed
# parser for review #525 failed
# parser for review #986 failed
# ----------------------------------------
#
# working on ASIN B002MAPRYU
# ----------------------------------------
# parser for review #9 failed
# parser for review #84 failed
# parser for review #430 failed
# parser for review #738 failed
# parser for review #817 failed
# parser for review #933 failed
# ----------------------------------------
#
# working on ASIN B002QEBMAK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002SZEOLG
# ----------------------------------------
# parser for review #690 failed
# ----------------------------------------
#
# working on ASIN B002V88HFE
# ----------------------------------------
# parser for review #359 failed
# parser for review #737 failed
# parser for review #1325 failed
# ----------------------------------------
#
# working on ASIN B002WE6D44
# ----------------------------------------
# parser for review #932 failed
# parser for review #973 failed
# parser for review #1364 failed
# parser for review #1755 failed
# parser for review #1777 failed
# parser for review #2647 failed
# ----------------------------------------
#
# working on ASIN B00316263Y
# ----------------------------------------
# parser for review #829 failed
# parser for review #1139 failed
# ----------------------------------------
#
# working on ASIN B003ELYQGG
# ----------------------------------------
# parser for review #1281 failed
# parser for review #1357 failed
# parser for review #2090 failed
# parser for review #2269 failed
# ----------------------------------------
#
# working on ASIN B003ES5ZUU
# ----------------------------------------
# parser for review #1231 failed
# parser for review #1504 failed
# parser for review #2183 failed
# parser for review #2742 failed
# parser for review #2918 failed
# parser for review #3002 failed
# parser for review #3053 failed
# parser for review #3489 failed
# ----------------------------------------
#
# working on ASIN B0041Q38NU
# ----------------------------------------
# parser for review #413 failed
# parser for review #1534 failed
# ----------------------------------------
#
# working on ASIN B0043T7FXE
# ----------------------------------------
# parser for review #528 failed
# ----------------------------------------
#
# working on ASIN B0044YU60M
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004G6002M
# ----------------------------------------
# parser for review #547 failed
# ----------------------------------------
#
# working on ASIN B004GF8TIK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004QK7HI8
# ----------------------------------------
# parser for review #983 failed
# ----------------------------------------
#
# working on ASIN B004W2JKWG
# ----------------------------------------
# parser for review #144 failed
# ----------------------------------------
#
# working on ASIN B004XC6GJ0
# ----------------------------------------
# parser for review #137 failed
# parser for review #1205 failed
# parser for review #1449 failed
# ----------------------------------------
#
# working on ASIN B0052SCU8U
# ----------------------------------------
# parser for review #831 failed
# ----------------------------------------
#
# working on ASIN B005CLPP84
# ----------------------------------------
# parser for review #2 failed
# parser for review #91 failed
# parser for review #217 failed
# parser for review #256 failed
# parser for review #299 failed
# parser for review #300 failed
# parser for review #616 failed
# ----------------------------------------
#
# working on ASIN B005CT56F8
# ----------------------------------------
# parser for review #427 failed
# parser for review #578 failed
# parser for review #1079 failed
# ----------------------------------------
#
# working on ASIN B005DKZTMG
# ----------------------------------------
# parser for review #423 failed
# parser for review #895 failed
# parser for review #1067 failed
# ----------------------------------------
#
# working on ASIN B005FYNSPK
# ----------------------------------------
# parser for review #899 failed
# parser for review #1618 failed
# ----------------------------------------
#
# working on ASIN B005HMKKH4
# ----------------------------------------
# parser for review #1048 failed
# parser for review #1177 failed
# parser for review #1250 failed
# parser for review #1591 failed
# parser for review #1654 failed
# ----------------------------------------
#
# working on ASIN B00622AG6S
# ----------------------------------------
# parser for review #518 failed
# parser for review #678 failed
# parser for review #1293 failed
# ----------------------------------------
#
# working on ASIN B006GWO5WK
# ----------------------------------------
# parser for review #94 failed
# parser for review #278 failed
# parser for review #534 failed
# parser for review #716 failed
# parser for review #773 failed
# ----------------------------------------
#
# working on ASIN B006W8U2MU
# ----------------------------------------
# parser for review #103 failed
# parser for review #429 failed
# parser for review #483 failed
# parser for review #1191 failed
# ----------------------------------------
#
# working on ASIN B0074BW614
# ----------------------------------------
# parser for review #486 failed
# parser for review #487 failed
# parser for review #492 failed
# parser for review #569 failed
# parser for review #596 failed
# parser for review #702 failed
# parser for review #1379 failed
# parser for review #1434 failed
# parser for review #1440 failed
# parser for review #1488 failed
# parser for review #1646 failed
# parser for review #1680 failed
# parser for review #1835 failed
# parser for review #1981 failed
# ----------------------------------------
#
# working on ASIN B007I5JT4S
# ----------------------------------------
# parser for review #24 failed
# parser for review #669 failed
# parser for review #1044 failed
# parser for review #1057 failed
# parser for review #1112 failed
# ----------------------------------------
#
# working on ASIN B007R5YDYA
# ----------------------------------------
# parser for review #973 failed
# ----------------------------------------
#
# working on ASIN B007WTAJTO
# ----------------------------------------
# parser for review #1271 failed
# parser for review #2653 failed
# parser for review #2934 failed
# parser for review #3059 failed
# parser for review #3329 failed
# parser for review #3494 failed
# parser for review #3701 failed
# ----------------------------------------
#
# working on ASIN B008OHNZI0
# ----------------------------------------
# parser for review #985 failed
# ----------------------------------------
#
# working on ASIN B009A5204K
# ----------------------------------------
# parser for review #165 failed
# parser for review #626 failed
# parser for review #738 failed
# parser for review #920 failed
# ----------------------------------------
#
# working on ASIN B009SYZ8OC
# ----------------------------------------
# parser for review #344 failed
# parser for review #410 failed
# parser for review #431 failed
# parser for review #1007 failed
# parser for review #2416 failed
# parser for review #2535 failed
# ----------------------------------------
#
# working on ASIN B00B46XUQU
# ----------------------------------------
# parser for review #38 failed
# ----------------------------------------
#
# working on ASIN B00BGGDVOO
# ----------------------------------------
# parser for review #59 failed
# parser for review #569 failed
# parser for review #933 failed
# parser for review #989 failed
# parser for review #1038 failed
# parser for review #1641 failed
# ----------------------------------------
#
# working on ASIN B00DR0PDNE
# ----------------------------------------
# parser for review #195 failed
# parser for review #517 failed
# parser for review #752 failed
# parser for review #868 failed
# parser for review #1091 failed
# parser for review #1190 failed
# parser for review #1332 failed
# parser for review #1378 failed
# parser for review #1387 failed
# parser for review #1409 failed
# parser for review #1485 failed
# parser for review #1498 failed
# parser for review #2435 failed
# parser for review #2605 failed
# parser for review #2629 failed
# parser for review #2657 failed
# parser for review #2796 failed
# parser for review #2928 failed
# parser for review #3005 failed
# ----------------------------------------
#
# working on ASIN B00E3W15P0
# ----------------------------------------
# parser for review #26 failed
# parser for review #258 failed
# parser for review #940 failed
# parser for review #1000 failed
# parser for review #1089 failed
# ----------------------------------------
#
# end time: 17:52:04.432925

# %%
print_sorted_aspects_multiprod(asin_dict, product_names)
# Out:
# --------------------------------------------------
# B00007E7JU Canon EF 50mm f/1.8 II Camera Lens - Fixed (Discontinued by Manufacturer)
# --------------------------------------------------
#
# [[u'lens', 653, 0.202],
#  [u'picture', 168, 0.337],
#  [u'shot', 165, 0.326],
#  [u'light', 155, 0.459],
#  [u'low light', 114, 0.323],
#  [u'photo', 102, 0.291],
#  [u'aperture', 96, 0.354],
#  [u'photographer', 86, 0.301],
#  [u'image', 79, 0.319],
#  [u'field depth', 76, 0.0],
#  [u'bokeh', 70, 0.281],
#  [u'focus', 67, 0.116],
#  [u'quality', 65, 0.148],
#  [u'50mm lens', 60, 0.014],
#  [u'prime lens', 58, 0.016],
#  [u'portrait lens', 57, 0.006],
#  [u'camera', 53, 0.114],
#  [u'canon lens', 51, 0.01],
#  [u'focal length', 51, 0.257],
#  [u'portrait', 47, 0.247],
#  [u'photography', 44, 0.374],
#  [u'light situation', 42, 0.27],
#  [u'length', 41, 0.385],
#  [u'image quality', 32, 0.089],
#  [u'focus ring', 31, 0.247],
#  [u'background', 31, 0.278],
#  [u'quality build', 28, 0.058],
#  [u'body', 28, 0.123],
#  [u'lens picture', 26, 0.001],
#  [u'bit', 25, 0.122],
#  [u'quality lens', 24, 0.003],
#  [u'plastic', 23, 0.181],
#  [u'money', 23, 0.146],
#  [u'50mm', 23, 0.087],
#  [u'glass', 23, 0.196],
#  [u'sensor', 23, 0.187],
#  [u'color', 21, 0.282],
#  [u'zoom lens', 21, 0.009],
#  [u'situation', 21, 0.572],
#  [u'cheap lens', 20, 0.007],
#  [u'light lens', 20, 0.002],
#  [u'kit lens', 20, 0.026],
#  [u'fast lens', 19, 0.006],
#  [u'zoom', 19, 0.082],
#  [u'manual focus', 18, 0.044],
#  [u'year', 18, 0.132],
#  [u'issue', 18, 0.14],
#  [u'sharp lens', 17, 0.003],
#  [u'auto focus', 17, 0.078],
#  [u'wide aperture', 16, 0.086],
#  [u'ring', 16, 0.218],
#  [u'depth', 16, 0.251],
#  [u'build', 15, 0.094],
#  [u'picture quality', 15, 0.035],
#  [u'subject', 13, 0.103],
#  [u'come lens', 11, 0.004],
#  [u'l lens', 9, 0.005],
#  [u'field', 9, 0.203],
#  [u'dslr', 8, 0.138],
#  [u'bag', 8, 0.055],
#  [u'camera lens', 7, 0.002],
#  [u'canon', 6, 0.063],
#  [u'flash', 6, 0.049],
#  [u'canon 50mm', 3, 0.033],
#  [u'auto', 3, 0.364],
#  [u'recommend lens', 3, 0.0]]
#
# --------------------------------------------------
# B0027VT6V4 Cyber Acoustics 30 Watt Powered Speakers with Subwoofer for PC and Gaming Systems in Standard Packaging, (CA-3602a)
# --------------------------------------------------
#
# [[u'speaker', 311, 0.202],
#  [u'sound', 276, 0.125],
#  [u'system', 141, 0.195],
#  [u'bass', 132, 0.233],
#  [u'sound quality', 125, 0.225],
#  [u'quality', 123, 0.393],
#  [u'volume', 99, 0.194],
#  [u'speaker set', 69, 0.022],
#  [u'room', 63, 0.269],
#  [u'range', 56, 0.254],
#  [u'speaker system', 51, 0.078],
#  [u'set', 50, 0.104],
#  [u'volume control', 49, 0.199],
#  [u'input', 48, 0.269],
#  [u'sound system', 48, 0.047],
#  [u'level', 47, 0.238],
#  [u'computer speaker', 42, 0.032],
#  [u'sound speaker', 41, 0.005],
#  [u'control', 37, 0.096],
#  [u'unit', 29, 0.163],
#  [u'setup', 28, 0.208],
#  [u'music', 26, 0.164],
#  [u'computer', 24, 0.087],
#  [u'base', 24, 0.19],
#  [u'bass sound', 22, 0.007],
#  [u'cable', 20, 0.136],
#  [u'controller', 18, 0.158],
#  [u'money', 17, 0.189],
#  [u'clear sound', 17, 0.008],
#  [u'small speaker', 17, 0.008],
#  [u'jack', 17, 0.097],
#  [u'bit', 16, 0.117],
#  [u'subwoofer', 14, 0.053],
#  [u'audio', 13, 0.194],
#  [u'year', 12, 0.089],
#  [u'pod', 12, 0.097],
#  [u'wire', 12, 0.155],
#  [u'sub', 12, 0.067],
#  [u'power', 11, 0.116],
#  [u'bass control', 11, 0.056],
#  [u'volume knob', 10, 0.16],
#  [u'headphone jack', 10, 0.2],
#  [u'old speaker', 10, 0.011],
#  [u'tv', 9, 0.052],
#  [u'pc', 9, 0.083],
#  [u'bass volume', 9, 0.064],
#  [u'puck', 9, 0.121],
#  [u'office', 7, 0.104],
#  [u'desk', 7, 0.05],
#  [u'pod control', 7, 0.005],
#  [u'listen music', 6, 0.017],
#  [u'satellite', 6, 0.109],
#  [u'knob', 5, 0.086],
#  [u'play music', 5, 0.014],
#  [u'sub woofer', 5, 0.261],
#  [u'logitech', 4, 0.052],
#  [u'headphone', 3, 0.046],
#  [u'desktop', 3, 0.065],
#  [u'star', 3, 0.021],
#  [u'woofer', 3, 0.045],
#  [u'acoustics', 3, 0.032],
#  [u'satellite speaker', 3, 0.015]]
#
# --------------------------------------------------
# B004G6002M SanDisk 16GB Mobile MicroSDHC Class 4 Flash Memory Card- SDSDQM-016G-B35N
# --------------------------------------------------
#
# [[u'card', 105, 0.126],
#  [u'memory', 72, 0.293],
#  [u'sd card', 69, 0.066],
#  [u'space', 61, 0.367],
#  [u'memory card', 55, 0.079],
#  [u'storage', 53, 0.284],
#  [u'phone', 49, 0.092],
#  [u'speed', 40, 0.252],
#  [u'deal', 37, 0.264],
#  [u'packaging', 37, 0.404],
#  [u'micro card', 31, 0.029],
#  [u'quality', 28, 0.283],
#  [u'sandisk card', 25, 0.027],
#  [u'capacity', 24, 0.182],
#  [u'camera', 24, 0.164],
#  [u'year', 20, 0.167],
#  [u'size', 20, 0.19],
#  [u'file', 17, 0.227],
#  [u'flash card', 13, 0.022],
#  [u'month', 12, 0.114],
#  [u'tablet', 12, 0.033],
#  [u'android phone', 11, 0.034],
#  [u'smart phone', 11, 0.033],
#  [u'32gb card', 11, 0.019],
#  [u'music', 11, 0.061],
#  [u'issue', 10, 0.049],
#  [u'class card', 10, 0.026],
#  [u'micro sd', 10, 0.264],
#  [u'data', 10, 0.126],
#  [u'class', 10, 0.066],
#  [u'sd', 10, 0.236],
#  [u'photo', 9, 0.089],
#  [u'write speed', 9, 0.069],
#  [u'movie', 8, 0.101],
#  [u'microsd card', 8, 0.018],
#  [u'adapter', 8, 0.052],
#  [u'retail packaging', 7, 0.213],
#  [u'video', 7, 0.072],
#  [u'sandisk', 7, 0.09],
#  [u'cell phone', 6, 0.048],
#  [u'gb', 6, 0.06],
#  [u'picture', 6, 0.051],
#  [u'gb card', 6, 0.013],
#  [u'player', 5, 0.037],
#  [u'32gb', 5, 0.069],
#  [u'phone card', 5, 0.0],
#  [u'music video', 4, 0.078],
#  [u'computer', 3, 0.031],
#  [u'video picture', 3, 0.114],
#  [u'android tablet', 3, 0.048],
#  [u'microsd', 3, 0.067],
#  [u'tablet phone', 3, 0.026],
#  [u'galaxy tab', 3, 0.228]]
#
# --------------------------------------------------
# B001TH7GSW AmazonBasics Digital Optical Audio Toslink Cable - 6 Feet (1.8 Meters)
# --------------------------------------------------
#
# [[u'cable', 269, 0.24],
#  [u'quality', 118, 0.384],
#  [u'optical cable', 95, 0.071],
#  [u'audio cable', 69, 0.035],
#  [u'sound', 50, 0.163],
#  [u'connection', 41, 0.308],
#  [u'sound quality', 39, 0.103],
#  [u'quality cable', 38, 0.015],
#  [u'digital cable', 32, 0.017],
#  [u'store', 30, 0.304],
#  [u'packaging', 26, 0.364],
#  [u'toslink cable', 24, 0.028],
#  [u'end', 24, 0.142],
#  [u'tv', 24, 0.058],
#  [u'system', 24, 0.186],
#  [u'bar', 23, 0.154],
#  [u'cost', 21, 0.136],
#  [u'audio', 21, 0.199],
#  [u'high quality', 20, 0.096],
#  [u'plastic cap', 20, 0.155],
#  [u'signal', 19, 0.368],
#  [u'receiver', 19, 0.086],
#  [u'end cap', 18, 0.018],
#  [u'cord', 16, 0.278],
#  [u'surround system', 16, 0.059],
#  [u'cap', 16, 0.347],
#  [u'sound system', 16, 0.147],
#  [u'cheap cable', 14, 0.011],
#  [u'audio quality', 13, 0.024],
#  [u'expensive cable', 13, 0.012],
#  [u'box', 13, 0.136],
#  [u'sound bar', 13, 0.364],
#  [u'connector', 12, 0.17],
#  [u'job', 12, 0.144],
#  [u'difference', 12, 0.118],
#  [u'excellent quality', 12, 0.014],
#  [u'hdmi cable', 11, 0.008],
#  [u'high cable', 11, 0.002],
#  [u'money', 10, 0.185],
#  [u'come cable', 10, 0.004],
#  [u'speaker', 10, 0.158],
#  [u'digital audio', 9, 0.183],
#  [u'digital signal', 8, 0.218],
#  [u'year', 8, 0.154],
#  [u'player', 8, 0.071],
#  [u'build quality', 8, 0.022],
#  [u'sound surround', 8, 0.075],
#  [u'amazonbasics cable', 8, 0.012],
#  [u'cable end', 7, 0.013],
#  [u'optical audio', 7, 0.183],
#  [u'connect cable', 6, 0.003],
#  [u'issue', 6, 0.075],
#  [u'optic cable', 6, 0.006],
#  [u'monster cable', 6, 0.008],
#  [u'plastic', 5, 0.273],
#  [u'rubber', 5, 0.24],
#  [u'cable fiber', 5, 0.0],
#  [u'soundbar', 5, 0.055],
#  [u'theater system', 4, 0.077],
#  [u'home system', 4, 0.015],
#  [u'name', 4, 0.114],
#  [u'fiber', 3, 0.345],
#  [u'optical', 3, 0.098]]
#
# --------------------------------------------------
# B006W8U2MU Kingston Digital DataTraveler SE9 8GB USB 2.0 DTSE9H/8GBZ
# --------------------------------------------------
#
# [[u'flash drive', 136, 0.152],
#  [u'drive', 117, 0.172],
#  [u'chain', 101, 0.32],
#  [u'design', 88, 0.22],
#  [u'size', 85, 0.231],
#  [u'ring', 81, 0.286],
#  [u'usb drive', 75, 0.071],
#  [u'file', 63, 0.317],
#  [u'speed', 58, 0.296],
#  [u'thumb drive', 41, 0.032],
#  [u'capacity', 39, 0.353],
#  [u'part', 38, 0.262],
#  [u'hole', 33, 0.26],
#  [u'key ring', 27, 0.324],
#  [u'key chain', 27, 0.44],
#  [u'usb', 24, 0.141],
#  [u'storage', 23, 0.222],
#  [u'metal', 23, 0.233],
#  [u'quality', 22, 0.241],
#  [u'key', 22, 0.119],
#  [u'space', 21, 0.393],
#  [u'end', 20, 0.119],
#  [u'data', 20, 0.208],
#  [u'small size', 19, 0.077],
#  [u'computer', 18, 0.151],
#  [u'usb stick', 18, 0.117],
#  [u'usb port', 18, 0.349],
#  [u'month', 17, 0.191],
#  [u'transfer file', 16, 0.003],
#  [u'issue', 15, 0.11],
#  [u'transfer speed', 14, 0.096],
#  [u'year', 13, 0.153],
#  [u'bit', 13, 0.157],
#  [u'small drive', 13, 0.012],
#  [u'stick', 13, 0.11],
#  [u'case', 13, 0.143],
#  [u'port', 12, 0.094],
#  [u'aluminum', 12, 0.357],
#  [u'memory', 11, 0.232],
#  [u'metal casing', 10, 0.252],
#  [u'transfer', 10, 0.039],
#  [u'metal case', 10, 0.122],
#  [u'casing', 10, 0.191],
#  [u'keychain', 8, 0.028],
#  [u'plastic', 7, 0.163],
#  [u'large file', 6, 0.087],
#  [u'write speed', 6, 0.063],
#  [u'cap', 6, 0.033],
#  [u'gb', 5, 0.044],
#  [u'pocket', 5, 0.05],
#  [u'move part', 5, 0.145],
#  [u'kingston', 4, 0.093],
#  [u'thumb', 4, 0.483],
#  [u'solid metal', 4, 0.096],
#  [u'keyring', 3, 0.04],
#  [u'star', 3, 0.038]]
#
# --------------------------------------------------
# B009SYZ8OC AmazonBasics Apple Certified Lightning to USB Cable - 3 Feet (0.9 Meters) - Black
# --------------------------------------------------
#
# [[u'cable', 455, 0.185],
#  [u'apple cable', 249, 0.076],
#  [u'quality', 186, 0.349],
#  [u'cord', 141, 0.18],
#  [u'length', 135, 0.261],
#  [u'case', 107, 0.091],
#  [u'lightning cable', 104, 0.04],
#  [u'charger', 78, 0.149],
#  [u'month', 65, 0.215],
#  [u'connector', 56, 0.117],
#  [u'apple cord', 51, 0.091],
#  [u'quality cable', 51, 0.008],
#  [u'iphone cable', 40, 0.006],
#  [u'plug', 40, 0.034],
#  [u'issue', 35, 0.071],
#  [u'wire', 34, 0.191],
#  [u'original cable', 34, 0.017],
#  [u'cheap cable', 32, 0.011],
#  [u'end', 31, 0.058],
#  [u'charge cable', 30, 0.006],
#  [u'high quality', 30, 0.1],
#  [u'come cable', 25, 0.008],
#  [u'connection', 25, 0.19],
#  [u'iphone case', 22, 0.028],
#  [u'money', 20, 0.237],
#  [u'apple version', 20, 0.197],
#  [u'version', 20, 0.13],
#  [u'plastic', 19, 0.122],
#  [u'charge', 19, 0.015],
#  [u'bit', 19, 0.09],
#  [u'usb cable', 18, 0.006],
#  [u'port', 16, 0.109],
#  [u'cable end', 15, 0.015],
#  [u'iphone', 15, 0.032],
#  [u'apple', 14, 0.076],
#  [u'fit case', 14, 0.004],
#  [u'iphone 5s', 12, 0.395],
#  [u'5 iphone', 11, 0.252],
#  [u'fit cable', 10, 0.001],
#  [u'car charger', 10, 0.058],
#  [u'oem cable', 9, 0.011],
#  [u'one apple', 8, 0.015],
#  [u'amazonbasics cable', 7, 0.009],
#  [u'usb', 7, 0.097],
#  [u'lightning connector', 7, 0.17],
#  [u'phone', 7, 0.016],
#  [u'lightning usb', 7, 0.011],
#  [u'ipad', 6, 0.028],
#  [u'lightning end', 6, 0.125],
#  [u'original apple', 5, 0.017],
#  [u'charge iphone', 4, 0.003],
#  [u'car', 4, 0.022],
#  [u'lifeproof case', 4, 0.024],
#  [u'foot', 4, 0.035],
#  [u'amazonbasics', 3, 0.129],
#  [u'phone case', 3, 0.012],
#  [u'oem', 3, 0.083]]
#
# --------------------------------------------------
# B001TH7GUU AmazonBasics USB 2.0 Extension Cable - A-Male to A-Female - 9.8 Feet (3 Meters)
# --------------------------------------------------
#
# [[u'cable', 170, 0.154],
#  [u'quality', 89, 0.334],
#  [u'cord', 68, 0.161],
#  [u'length', 59, 0.283],
#  [u'usb cable', 56, 0.073],
#  [u'cable quality', 41, 0.016],
#  [u'connector', 30, 0.333],
#  [u'extension cable', 30, 0.078],
#  [u'end', 28, 0.222],
#  [u'connection', 28, 0.243],
#  [u'foot', 16, 0.133],
#  [u'charger', 16, 0.093],
#  [u'computer', 14, 0.074],
#  [u'hard drive', 14, 0.141],
#  [u'extension cord', 14, 0.089],
#  [u'extension', 14, 0.106],
#  [u'keyboard', 13, 0.126],
#  [u'box', 13, 0.182],
#  [u'controller', 13, 0.155],
#  [u'room', 11, 0.156],
#  [u'usb cord', 11, 0.041],
#  [u'signal', 11, 0.254],
#  [u'job', 10, 0.128],
#  [u'usb extension', 10, 0.135],
#  [u'drive', 10, 0.26],
#  [u'short cable', 10, 0.011],
#  [u'usb hub', 10, 0.224],
#  [u'port', 9, 0.07],
#  [u'long cable', 9, 0.009],
#  [u'usb', 9, 0.101],
#  [u'female end', 8, 0.08],
#  [u'high quality', 8, 0.104],
#  [u'build quality', 8, 0.032],
#  [u'adapter', 8, 0.125],
#  [u'nice cable', 8, 0.007],
#  [u'come cable', 7, 0.008],
#  [u'mouse', 7, 0.085],
#  [u'extend cable', 6, 0.001],
#  [u'camera', 6, 0.108],
#  [u'foot cable', 6, 0.006],
#  [u'keyboard mouse', 6, 0.099],
#  [u'charge cable', 5, 0.005],
#  [u'hub', 5, 0.088],
#  [u'pc', 5, 0.076],
#  [u'iphone', 5, 0.049],
#  [u'tv', 4, 0.109],
#  [u'issue', 4, 0.048],
#  [u'power', 4, 0.083],
#  [u'desk', 4, 0.051],
#  [u'usb port', 4, 0.303],
#  [u'printer', 3, 0.076],
#  [u'phone', 3, 0.021]]
#
# --------------------------------------------------
# B006GWO5WK Amazon Kindle 9W PowerFast Adapter for Accelerated Charging
# --------------------------------------------------
#
# [[u'charger', 261, 0.196],
#  [u'charge', 93, 0.025],
#  [u'adapter', 46, 0.143],
#  [u'kindle', 45, 0.053],
#  [u'kindle fire', 43, 0.358],
#  [u'kindle charger', 41, 0.015],
#  [u'plug', 31, 0.032],
#  [u'job', 29, 0.208],
#  [u'charging', 26, 0.409],
#  [u'cord', 25, 0.12],
#  [u'hour', 25, 0.094],
#  [u'cable', 22, 0.115],
#  [u'usb cable', 21, 0.199],
#  [u'usb charger', 21, 0.019],
#  [u'fire hd', 19, 0.29],
#  [u'kindle charge', 18, 0.046],
#  [u'kindles', 18, 0.156],
#  [u'outlet', 18, 0.148],
#  [u'unit', 17, 0.169],
#  [u'power', 17, 0.103],
#  [u'battery', 16, 0.138],
#  [u'money', 16, 0.284],
#  [u'fire', 16, 0.063],
#  [u'phone charger', 15, 0.018],
#  [u'fast charger', 14, 0.016],
#  [u'charge hour', 14, 0.006],
#  [u'charge charger', 12, 0.004],
#  [u'kindle hd', 12, 0.235],
#  [u'wall charger', 12, 0.022],
#  [u'fast charge', 10, 0.029],
#  [u'fold prong', 10, 0.05],
#  [u'phone', 9, 0.05],
#  [u'charge fire', 8, 0.001],
#  [u'include charger', 7, 0.004],
#  [u'tablet', 7, 0.077],
#  [u'usb cord', 7, 0.165],
#  [u'usb', 6, 0.165],
#  [u'wall', 6, 0.141],
#  [u'charge usb', 6, 0.032],
#  [u'usb port', 6, 0.359],
#  [u'original charger', 5, 0.009],
#  [u'port', 5, 0.044],
#  [u'prong', 5, 0.1],
#  [u'micro usb', 5, 0.101],
#  [u'full charge', 5, 0.006],
#  [u'come charger', 5, 0.006],
#  [u'charge hd', 5, 0.0],
#  [u'kindle plug', 5, 0.016],
#  [u'hd. fire', 4, 0.003],
#  [u'charge phone', 4, 0.006],
#  [u'usb plug', 4, 0.012],
#  [u'computer', 3, 0.014],
#  [u'hd', 3, 0.019]]
#
# --------------------------------------------------
# B002QEBMAK WD Elements 500 GB USB 2.0 Desktop External Hard Drive
# --------------------------------------------------
#
# [[u'drive', 354, 0.288],
#  [u'hard drive', 254, 0.115],
#  [u'external drive', 198, 0.062],
#  [u'file', 74, 0.183],
#  [u'software', 61, 0.232],
#  [u'year', 60, 0.152],
#  [u'wd drive', 59, 0.02],
#  [u'space', 54, 0.37],
#  [u'backup', 53, 0.147],
#  [u'storage', 49, 0.311],
#  [u'computer', 39, 0.108],
#  [u'light', 39, 0.203],
#  [u'digital drive', 37, 0.007],
#  [u'month', 36, 0.151],
#  [u'speed', 36, 0.239],
#  [u'backup drive', 33, 0.01],
#  [u'internal drive', 32, 0.01],
#  [u'size', 31, 0.196],
#  [u'usb drive', 30, 0.011],
#  [u'hd', 29, 0.238],
#  [u'system', 28, 0.179],
#  [u'data', 27, 0.16],
#  [u'issue', 25, 0.095],
#  [u'case', 24, 0.22],
#  [u'disk', 20, 0.315],
#  [u'unit', 20, 0.131],
#  [u'western drive', 20, 0.006],
#  [u'digital', 19, 0.164],
#  [u'power', 18, 0.06],
#  [u'tb drive', 16, 0.008],
#  [u'fail drive', 14, 0.001],
#  [u'box', 13, 0.132],
#  [u'hdd', 13, 0.195],
#  [u'western digital', 12, 0.69],
#  [u'external', 11, 0.222],
#  [u'plug', 11, 0.008],
#  [u'element', 11, 0.088],
#  [u'usb cable', 10, 0.219],
#  [u'warranty', 8, 0.068],
#  [u'medium', 8, 0.191],
#  [u'elements drive', 8, 0.009],
#  [u'cable', 8, 0.104],
#  [u'movie', 7, 0.051],
#  [u'photo', 6, 0.051],
#  [u'usb', 6, 0.05],
#  [u'pc', 6, 0.062],
#  [u'video', 6, 0.069],
#  [u'gb', 5, 0.048],
#  [u'wd', 5, 0.12],
#  [u'format drive', 5, 0.0],
#  [u'laptop', 4, 0.045],
#  [u'transfer', 4, 0.009],
#  [u'external usb', 4, 0.015],
#  [u'machine', 4, 0.06],
#  [u'tb', 3, 0.029],
#  [u'music', 3, 0.037],
#  [u'hard wd', 3, 0.0]]
#
# --------------------------------------------------
# B007I5JT4S
# --------------------------------------------------
#
# [[u'apps', 74, 0.275],
#  [u'feature', 74, 0.226],
#  [u'content', 63, 0.232],
#  [u'screen', 63, 0.242],
#  [u'channel', 60, 0.313],
#  [u'tv', 57, 0.048],
#  [u'box', 56, 0.244],
#  [u'service', 49, 0.312],
#  [u'quality', 47, 0.186],
#  [u'interface', 42, 0.171],
#  [u'apple tv', 41, 0.363],
#  [u'option', 39, 0.252],
#  [u'video', 38, 0.09],
#  [u'app', 38, 0.124],
#  [u'reason', 34, 0.183],
#  [u'system', 33, 0.158],
#  [u'remote', 33, 0.109],
#  [u'issue', 31, 0.19],
#  [u'year', 29, 0.253],
#  [u'movie', 28, 0.109],
#  [u'library', 27, 0.155],
#  [u'network', 27, 0.151],
#  [u'connection', 26, 0.176],
#  [u'cable', 24, 0.125],
#  [u'unit', 23, 0.171],
#  [u'room', 23, 0.16],
#  [u'tv screen', 22, 0.071],
#  [u'picture', 22, 0.149],
#  [u'medium', 20, 0.231],
#  [u'music', 19, 0.052],
#  [u'access', 16, 0.033],
#  [u'player', 15, 0.101],
#  [u'show', 14, 0.051],
#  [u'streaming', 13, 0.152],
#  [u'computer', 13, 0.062],
#  [u'store', 13, 0.059],
#  [u'movie show', 13, 0.025],
#  [u'hd', 12, 0.172],
#  [u'tv show', 12, 0.095],
#  [u'apple', 12, 0.058],
#  [u'itunes library', 11, 0.201],
#  [u'user interface', 11, 0.1],
#  [u'remote app', 10, 0.091],
#  [u'audio', 10, 0.13],
#  [u'airplay', 9, 0.031],
#  [u'user', 9, 0.115],
#  [u'big screen', 8, 0.093],
#  [u'roku', 8, 0.019],
#  [u'itunes', 8, 0.038],
#  [u'watch movie', 8, 0.0],
#  [u'tv movie', 7, 0.008],
#  [u'house', 7, 0.097],
#  [u'stream content', 7, 0.012],
#  [u'itunes movie', 6, 0.023],
#  [u'ray player', 6, 0.131],
#  [u'stream movie', 6, 0.007],
#  [u'pc', 6, 0.058],
#  [u'photo', 5, 0.059],
#  [u'watch tv', 5, 0.001],
#  [u'smart tv', 5, 0.012],
#  [u'mac', 5, 0.035],
#  [u'internet', 4, 0.093],
#  [u'appletv', 4, 0.029],
#  [u'air', 4, 0.06],
#  [u'wifi', 4, 0.098],
#  [u'instant video', 3, 0.062],
#  [u'ipad', 3, 0.008],
#  [u'macbook', 3, 0.052],
#  [u'stream video', 3, 0.02]]
#
# --------------------------------------------------
# B002SZEOLG TP-LINK TL-WN722N Wireless N150 High Gain USB Adapter, 150Mbps, 4dBi External Antenna, WPS Button, Support Windows XP/Vista/7/8
# --------------------------------------------------
#
# [[u'adapter', 132, 0.142],
#  [u'signal', 126, 0.289],
#  [u'speed', 105, 0.231],
#  [u'connection', 96, 0.252],
#  [u'wireless adapter', 67, 0.077],
#  [u'antenna', 63, 0.258],
#  [u'range', 62, 0.304],
#  [u'usb adapter', 59, 0.083],
#  [u'computer', 56, 0.117],
#  [u'router', 55, 0.073],
#  [u'laptop', 53, 0.126],
#  [u'driver', 52, 0.131],
#  [u'network', 47, 0.176],
#  [u'card', 43, 0.215],
#  [u'reception', 43, 0.445],
#  [u'cd', 41, 0.178],
#  [u'band', 39, 0.289],
#  [u'desktop', 37, 0.155],
#  [u'software', 37, 0.133],
#  [u'size', 32, 0.235],
#  [u'performance', 32, 0.288],
#  [u'issue', 31, 0.134],
#  [u'signal strength', 31, 0.375],
#  [u'wifi adapter', 30, 0.026],
#  [u'wireless card', 30, 0.14],
#  [u'usb port', 25, 0.382],
#  [u'pc', 25, 0.15],
#  [u'room', 25, 0.171],
#  [u'bar', 24, 0.105],
#  [u'support', 21, 0.075],
#  [u'wall', 19, 0.213],
#  [u'unit', 19, 0.18],
#  [u'system', 19, 0.107],
#  [u'bit', 18, 0.118],
#  [u'box', 18, 0.182],
#  [u'wifi', 18, 0.139],
#  [u'setup', 17, 0.102],
#  [u'download driver', 15, 0.003],
#  [u'wireless', 15, 0.106],
#  [u'usb cable', 15, 0.138],
#  [u'wireless network', 15, 0.125],
#  [u'utility', 14, 0.098],
#  [u'installation', 14, 0.139],
#  [u'machine', 14, 0.114],
#  [u'wireless band', 13, 0.025],
#  [u'dual band', 13, 0.225],
#  [u'extension cable', 12, 0.104],
#  [u'strong signal', 12, 0.066],
#  [u'cable', 11, 0.09],
#  [u'year', 11, 0.124],
#  [u'wireless signal', 11, 0.047],
#  [u'old laptop', 10, 0.078],
#  [u'strength', 10, 0.165],
#  [u'minute', 9, 0.068],
#  [u'old adapter', 8, 0.013],
#  [u'mini cd', 8, 0.118],
#  [u'port', 8, 0.124],
#  [u'access', 8, 0.144],
#  [u'internet', 8, 0.073],
#  [u'usb', 8, 0.07],
#  [u'wi fi', 8, 0.393],
#  [u'house', 7, 0.063],
#  [u'fi', 7, 0.109],
#  [u'install driver', 6, 0.005],
#  [u'instal driver', 6, 0.004],
#  [u'link', 6, 0.013],
#  [u'window', 5, 0.074],
#  [u'point access', 5, 0.0],
#  [u'pick signal', 5, 0.0],
#  [u'mbps', 5, 0.05],
#  [u'link adapter', 4, 0.031],
#  [u'foot', 4, 0.035],
#  [u'home', 4, 0.056],
#  [u'old desktop', 4, 0.087],
#  [u'star', 4, 0.04],
#  [u'windows', 4, 0.014],
#  [u'wireless router', 3, 0.078]]
#
# --------------------------------------------------
# B000S5Q9CA Motorola Vehicle Power Adapter micro-USB Charger
# --------------------------------------------------
#
# [[u'charger', 229, 0.181],
#  [u'blue light', 146, 0.192],
#  [u'light', 124, 0.26],
#  [u'car charger', 115, 0.085],
#  [u'phone', 67, 0.09],
#  [u'quality', 61, 0.302],
#  [u'usb', 42, 0.287],
#  [u'charge', 42, 0.02],
#  [u'usb charger', 40, 0.022],
#  [u'cool light', 37, 0.017],
#  [u'cord', 34, 0.24],
#  [u'power', 28, 0.167],
#  [u'motorola charger', 28, 0.026],
#  [u'bright light', 26, 0.011],
#  [u'month', 25, 0.154],
#  [u'micro charger', 24, 0.004],
#  [u'cable', 24, 0.224],
#  [u'year', 23, 0.121],
#  [u'job', 23, 0.211],
#  [u'plug', 23, 0.029],
#  [u'store', 21, 0.144],
#  [u'rate', 20, 0.248],
#  [u'car', 20, 0.076],
#  [u'usb port', 19, 0.228],
#  [u'micro usb', 17, 0.38],
#  [u'adapter', 17, 0.15],
#  [u'charge phone', 16, 0.005],
#  [u'issue', 15, 0.1],
#  [u'cheap charger', 15, 0.009],
#  [u'motorola', 15, 0.149],
#  [u'phone charger', 14, 0.006],
#  [u'logo', 13, 0.216],
#  [u'motorola logo', 13, 0.178],
#  [u'port', 12, 0.195],
#  [u'battery', 10, 0.088],
#  [u'droid', 9, 0.08],
#  [u'long cord', 8, 0.057],
#  [u'charge charger', 8, 0.002],
#  [u'fast charge', 7, 0.025],
#  [u'oem charger', 7, 0.007],
#  [u'cell phone', 6, 0.046],
#  [u'rapid charger', 6, 0.007],
#  [u'vehicle', 6, 0.122],
#  [u'high quality', 5, 0.111],
#  [u'power adapter', 4, 0.092],
#  [u'wall charger', 4, 0.009],
#  [u'gp', 3, 0.045],
#  [u'verizon', 3, 0.235],
#  [u'rapid rate', 3, 0.287]]
#
# --------------------------------------------------
# B000VX6XL6 Kingston 4 GB microSDHC Class 4 Flash Memory Card SDC4/4GBET
# --------------------------------------------------
#
# [[u'card', 127, 0.137],
#  [u'sd card', 100, 0.083],
#  [u'memory', 73, 0.278],
#  [u'phone', 65, 0.104],
#  [u'speed', 49, 0.275],
#  [u'space', 46, 0.357],
#  [u'micro card', 45, 0.047],
#  [u'size', 38, 0.336],
#  [u'camera', 38, 0.153],
#  [u'memory card', 38, 0.059],
#  [u'adapter', 34, 0.097],
#  [u'quality', 32, 0.277],
#  [u'storage', 32, 0.245],
#  [u'capacity', 29, 0.287],
#  [u'flash card', 18, 0.03],
#  [u'adapter card', 17, 0.008],
#  [u'sd', 17, 0.184],
#  [u'sd adapter', 15, 0.099],
#  [u'card reader', 14, 0.243],
#  [u'file', 13, 0.134],
#  [u'data', 13, 0.174],
#  [u'picture', 12, 0.073],
#  [u'issue', 12, 0.055],
#  [u'chip', 11, 0.15],
#  [u'class card', 11, 0.02],
#  [u'cell phone', 10, 0.094],
#  [u'computer', 10, 0.06],
#  [u'year', 10, 0.126],
#  [u'month', 9, 0.111],
#  [u'reader', 9, 0.133],
#  [u'microsd card', 9, 0.018],
#  [u'phone card', 9, 0.001],
#  [u'sdhc card', 8, 0.009],
#  [u'micro sd', 8, 0.305],
#  [u'video', 7, 0.083],
#  [u'kingston card', 6, 0.016],
#  [u'music', 6, 0.032],
#  [u'class', 6, 0.048],
#  [u'digital camera', 6, 0.088],
#  [u'photo', 5, 0.062],
#  [u'tablet', 5, 0.026],
#  [u'microsd', 5, 0.12],
#  [u'gb', 5, 0.055],
#  [u'smart phone', 4, 0.031],
#  [u'player', 4, 0.037],
#  [u'flash memory', 4, 0.058],
#  [u'kingston', 3, 0.058],
#  [u'transfer file', 3, 0.016],
#  [u'microsdhc card', 3, 0.017],
#  [u'transfer', 3, 0.014]]
#
# --------------------------------------------------
# B0041Q38NU Kingston Datatraveler 101 Gen 2 With urDrive 8GB USB 2.0 (Red)
# --------------------------------------------------
#
# [[u'flash drive', 146, 0.174],
#  [u'drive', 138, 0.133],
#  [u'file', 97, 0.223],
#  [u'speed', 76, 0.251],
#  [u'size', 69, 0.276],
#  [u'cover', 61, 0.168],
#  [u'usb drive', 56, 0.047],
#  [u'design', 52, 0.208],
#  [u'capacity', 48, 0.279],
#  [u'storage', 44, 0.279],
#  [u'space', 43, 0.368],
#  [u'software', 37, 0.252],
#  [u'computer', 34, 0.13],
#  [u'cap', 34, 0.137],
#  [u'year', 32, 0.167],
#  [u'quality', 31, 0.333],
#  [u'color', 30, 0.325],
#  [u'thumb drive', 30, 0.029],
#  [u'memory', 29, 0.258],
#  [u'data', 25, 0.22],
#  [u'transfer file', 24, 0.011],
#  [u'hard drive', 22, 0.015],
#  [u'stick', 22, 0.121],
#  [u'large file', 21, 0.081],
#  [u'month', 21, 0.191],
#  [u'usb', 18, 0.099],
#  [u'kingston drive', 17, 0.021],
#  [u'transfer speed', 15, 0.086],
#  [u'pc', 13, 0.167],
#  [u'issue', 13, 0.07],
#  [u'data transfer', 12, 0.078],
#  [u'transfer', 10, 0.036],
#  [u'gb', 8, 0.029],
#  [u'write speed', 8, 0.045],
#  [u'usb port', 8, 0.361],
#  [u'gb drive', 8, 0.011],
#  [u'photo', 7, 0.078],
#  [u'picture', 7, 0.056],
#  [u'music', 6, 0.051],
#  [u'metal', 6, 0.231],
#  [u'kingston', 4, 0.029],
#  [u'video', 4, 0.067],
#  [u'port', 3, 0.073],
#  [u'flash', 3, 0.064],
#  [u'xbox', 3, 0.04]]
#
# --------------------------------------------------
# B0002L5R78 DVI Gear HDMI-2M 2M/6' HDMI Cable
# --------------------------------------------------
#
# [[u'cable', 495, 0.157],
#  [u'hdmi cable', 248, 0.148],
#  [u'quality', 184, 0.281],
#  [u'store', 144, 0.302],
#  [u'signal', 82, 0.246],
#  [u'cable quality', 82, 0.013],
#  [u'deal', 81, 0.287],
#  [u'picture', 75, 0.203],
#  [u'tv', 61, 0.076],
#  [u'shipping', 57, 0.309],
#  [u'expensive cable', 53, 0.024],
#  [u'length', 47, 0.26],
#  [u'difference', 46, 0.095],
#  [u'picture quality', 43, 0.072],
#  [u'connection', 39, 0.249],
#  [u'cord', 38, 0.19],
#  [u'money', 36, 0.195],
#  [u'cheap cable', 34, 0.011],
#  [u'dollar', 32, 0.178],
#  [u'end', 32, 0.161],
#  [u'buck', 31, 0.171],
#  [u'job', 28, 0.146],
#  [u'high cable', 27, 0.003],
#  [u'year', 26, 0.128],
#  [u'high quality', 24, 0.056],
#  [u'video quality', 23, 0.019],
#  [u'box', 22, 0.062],
#  [u'monster cable', 20, 0.015],
#  [u'cost', 19, 0.045],
#  [u'cable cost', 18, 0.038],
#  [u'dvd player', 18, 0.159],
#  [u'sound picture', 18, 0.058],
#  [u'issue', 16, 0.061],
#  [u'player', 14, 0.062],
#  [u'hdmi cord', 14, 0.128],
#  [u'hdtv', 12, 0.082],
#  [u'ray', 11, 0.059],
#  [u'sound', 11, 0.107],
#  [u'ray player', 11, 0.1],
#  [u'digital cable', 11, 0.004],
#  [u'hdmi', 10, 0.045],
#  [u'audio video', 9, 0.116],
#  [u'hd', 8, 0.116],
#  [u'digital signal', 7, 0.175],
#  [u'connect cable', 6, 0.001],
#  [u'dvd', 6, 0.071],
#  [u'blu player', 6, 0.013],
#  [u'laptop', 5, 0.03],
#  [u'video', 5, 0.074],
#  [u'cable box', 5, 0.184],
#  [u'audio', 5, 0.082],
#  [u'plat gold', 4, 0.0],
#  [u'blu ray', 3, 0.337],
#  [u'foot', 3, 0.02],
#  [u'fine cable', 3, 0.0]]
#
# --------------------------------------------------
# B0043T7FXE Logitech M570 Wireless Trackball, Computer Wireless Mouse, Long Range Wireless Mouse
# --------------------------------------------------
#
# [[u'mouse', 268, 0.201],
#  [u'button', 141, 0.259],
#  [u'trackball', 138, 0.175],
#  [u'version', 108, 0.363],
#  [u'hand', 74, 0.22],
#  [u'model', 74, 0.361],
#  [u'receiver', 66, 0.253],
#  [u'year', 65, 0.197],
#  [u'ball', 63, 0.145],
#  [u'space', 47, 0.35],
#  [u'logitech trackball', 46, 0.058],
#  [u'click', 37, 0.166],
#  [u'battery', 36, 0.152],
#  [u'trackball mouse', 34, 0.044],
#  [u'keyboard', 33, 0.223],
#  [u'side', 33, 0.258],
#  [u'battery life', 32, 0.417],
#  [u'design', 32, 0.128],
#  [u'year trackball', 31, 0.0],
#  [u'trackman', 30, 0.189],
#  [u'unit', 30, 0.274],
#  [u'movement', 30, 0.245],
#  [u'month', 29, 0.139],
#  [u'issue', 28, 0.172],
#  [u'forward button', 27, 0.019],
#  [u'user', 27, 0.187],
#  [u'finger', 25, 0.156],
#  [u'button click', 24, 0.04],
#  [u'wireless mouse', 22, 0.021],
#  [u'usb receiver', 22, 0.085],
#  [u'logitech keyboard', 22, 0.093],
#  [u'logitech mouse', 21, 0.016],
#  [u'software', 21, 0.121],
#  [u'wireless trackball', 19, 0.036],
#  [u'week', 18, 0.151],
#  [u'old trackball', 17, 0.023],
#  [u'wireless version', 17, 0.072],
#  [u'wire version', 17, 0.106],
#  [u'computer', 16, 0.091],
#  [u'wheel', 15, 0.086],
#  [u'unifying receiver', 15, 0.071],
#  [u'bit', 15, 0.082],
#  [u'regular mouse', 15, 0.029],
#  [u'red ball', 15, 0.04],
#  [u'track ball', 15, 0.096],
#  [u'thumb', 13, 0.049],
#  [u'ago year', 13, 0.0],
#  [u'life', 13, 0.217],
#  [u'wire trackball', 13, 0.018],
#  [u'arm', 12, 0.089],
#  [u'pain', 12, 0.12],
#  [u'usb port', 12, 0.361],
#  [u'move mouse', 12, 0.0],
#  [u'laptop', 10, 0.049],
#  [u'trackman wheel', 10, 0.071],
#  [u'index finger', 10, 0.124],
#  [u'left button', 10, 0.027],
#  [u'wrist', 10, 0.064],
#  [u'pad', 9, 0.077],
#  [u'wireless keyboard', 8, 0.124],
#  [u'desk', 8, 0.076],
#  [u'm570', 8, 0.051],
#  [u'logitech', 7, 0.054],
#  [u'scroll wheel', 7, 0.256],
#  [u'wireless', 7, 0.076],
#  [u'usb', 7, 0.234],
#  [u'pad mouse', 6, 0.002],
#  [u'thumb ball', 5, 0.024],
#  [u'logitech software', 5, 0.089],
#  [u'scroll', 5, 0.049],
#  [u'last battery', 4, 0.003]]
#
# --------------------------------------------------
# B004XC6GJ0 ARRIS SURFboard SB6121 DOCSIS 3.0 Cable Modem  (Black,Retail Packaging)
# --------------------------------------------------
#
# [[u'modem', 369, 0.162],
#  [u'speed', 193, 0.27],
#  [u'cable modem', 92, 0.064],
#  [u'router', 79, 0.122],
#  [u'fee', 77, 0.319],
#  [u'year', 65, 0.166],
#  [u'connection', 65, 0.164],
#  [u'model', 56, 0.255],
#  [u'month', 54, 0.122],
#  [u'docsis modem', 49, 0.024],
#  [u'issue', 47, 0.106],
#  [u'comcast modem', 46, 0.01],
#  [u'service', 43, 0.121],
#  [u'old modem', 43, 0.036],
#  [u'number', 42, 0.131],
#  [u'internet speed', 41, 0.047],
#  [u'rental fee', 31, 0.189],
#  [u'motorola modem', 31, 0.012],
#  [u'unit', 29, 0.149],
#  [u'light', 29, 0.226],
#  [u'modem fee', 25, 0.021],
#  [u'setup', 25, 0.144],
#  [u'download speed', 23, 0.062],
#  [u'box', 23, 0.132],
#  [u'surfboard', 22, 0.217],
#  [u'minute', 20, 0.069],
#  [u'replace modem', 20, 0.003],
#  [u'cable', 19, 0.055],
#  [u'high speed', 19, 0.057],
#  [u'network', 19, 0.142],
#  [u'wireless router', 19, 0.09],
#  [u'week', 18, 0.147],
#  [u'internet', 17, 0.078],
#  [u'support', 17, 0.052],
#  [u'money', 16, 0.247],
#  [u'call', 16, 0.02],
#  [u'hour', 16, 0.143],
#  [u'signal', 15, 0.127],
#  [u'monthly fee', 15, 0.151],
#  [u'download', 13, 0.059],
#  [u'connect modem', 12, 0.002],
#  [u'computer', 12, 0.092],
#  [u'internet service', 12, 0.132],
#  [u'docsis', 11, 0.063],
#  [u'fast speed', 11, 0.025],
#  [u'customer', 11, 0.132],
#  [u'rent modem', 11, 0.006],
#  [u'comcast call', 10, 0.063],
#  [u'address', 10, 0.064],
#  [u'provider', 10, 0.055],
#  [u'time modem', 10, 0.0],
#  [u'lease modem', 9, 0.007],
#  [u'mbps', 9, 0.035],
#  [u'upload speed', 9, 0.024],
#  [u'activate modem', 8, 0.0],
#  [u'rental modem', 8, 0.004],
#  [u'installation', 8, 0.098],
#  [u'tech', 8, 0.089],
#  [u'mac address', 8, 0.258],
#  [u'own modem', 7, 0.014],
#  [u'rental', 6, 0.051],
#  [u'motorola', 6, 0.086],
#  [u'test speed', 6, 0.002],
#  [u'comcast service', 6, 0.075],
#  [u'rend modem', 5, 0.0],
#  [u'comcast internet', 5, 0.101],
#  [u'increase speed', 5, 0.002],
#  [u'isp', 5, 0.035],
#  [u'internet provider', 5, 0.108],
#  [u'cable service', 5, 0.055],
#  [u'sb6121', 5, 0.044],
#  [u'pay modem', 4, 0.0],
#  [u'comcast', 4, 0.026],
#  [u'wireless', 4, 0.075],
#  [u'phone', 4, 0.025],
#  [u'time warner', 3, 0.824],
#  [u'cable provider', 3, 0.17],
#  [u'internet cable', 3, 0.007]]
#
# --------------------------------------------------
# B00E3W15P0 [DISCONTINUED] Samsung 840 EVO 120GB 2.5-Inch SATA III Internal SSD (MZ-7TE120BW)
# --------------------------------------------------
#
# [[u'drive', 322, 0.244],
#  [u'hard drive', 156, 0.087],
#  [u'ssd', 119, 0.114],
#  [u'speed', 107, 0.183],
#  [u'computer', 81, 0.161],
#  [u'laptop', 76, 0.155],
#  [u'performance', 76, 0.24],
#  [u'software', 72, 0.126],
#  [u'old drive', 59, 0.028],
#  [u'hdd', 59, 0.214],
#  [u'install', 56, 0.08],
#  [u'upgrade', 50, 0.075],
#  [u'system', 46, 0.139],
#  [u'difference', 46, 0.182],
#  [u'disk', 45, 0.25],
#  [u'version', 44, 0.184],
#  [u'ssd drive', 38, 0.022],
#  [u'file', 37, 0.224],
#  [u'boot', 37, 0.05],
#  [u'clone drive', 36, 0.001],
#  [u'space', 35, 0.343],
#  [u'program', 34, 0.153],
#  [u'machine', 32, 0.217],
#  [u'life', 32, 0.275],
#  [u'state drive', 28, 0.01],
#  [u'year', 27, 0.145],
#  [u'mode', 27, 0.218],
#  [u'replace drive', 25, 0.001],
#  [u'pc', 24, 0.116],
#  [u'boot drive', 22, 0.012],
#  [u'mechanical drive', 22, 0.01],
#  [u'ssds', 21, 0.245],
#  [u'storage', 19, 0.253],
#  [u'samsung drive', 19, 0.009],
#  [u'instal drive', 19, 0.002],
#  [u'issue', 19, 0.104],
#  [u'samsung software', 19, 0.085],
#  [u'installation', 19, 0.139],
#  [u'window', 18, 0.18],
#  [u'data', 18, 0.141],
#  [u'minute', 17, 0.081],
#  [u'second', 16, 0.04],
#  [u'case', 16, 0.129],
#  [u'external drive', 16, 0.007],
#  [u'solid drive', 15, 0.008],
#  [u'include software', 15, 0.031],
#  [u'desktop', 14, 0.08],
#  [u'magician software', 14, 0.071],
#  [u'hour', 13, 0.107],
#  [u'application', 12, 0.133],
#  [u'fast drive', 12, 0.005],
#  [u'time boot', 12, 0.013],
#  [u'bit', 12, 0.09],
#  [u'power', 11, 0.11],
#  [u'macbook pro', 11, 0.165],
#  [u'ram', 10, 0.144],
#  [u'migration software', 9, 0.063],
#  [u'pro', 9, 0.039],
#  [u'old laptop', 8, 0.054],
#  [u'macbook', 8, 0.098],
#  [u'samsung ssd', 8, 0.048],
#  [u'cable', 8, 0.052],
#  [u'sata', 7, 0.071],
#  [u'second boot', 7, 0.006],
#  [u'mac', 7, 0.163],
#  [u'fast boot', 6, 0.022],
#  [u'windows', 6, 0.023],
#  [u'clone', 5, 0.009],
#  [u'gb', 5, 0.034],
#  [u'migration', 4, 0.036],
#  [u'windows boot', 4, 0.014],
#  [u'samsung evo', 4, 0.138],
#  [u'samsung', 4, 0.061],
#  [u'usb sata', 3, 0.027],
#  [u'come software', 3, 0.026],
#  [u'usb', 3, 0.023]]
#
# --------------------------------------------------
# B005DKZTMG Logitech Wireless Touch Keyboard K400 with Built-In Multi-Touch Touchpad, Black
# --------------------------------------------------
#
# [[u'keyboard', 448, 0.21],
#  [u'key', 137, 0.123],
#  [u'size', 136, 0.302],
#  [u'wireless keyboard', 109, 0.04],
#  [u'key shift', 104, 0.019],
#  [u'range', 102, 0.294],
#  [u'button', 86, 0.172],
#  [u'side', 71, 0.337],
#  [u'button click', 71, 0.016],
#  [u'hand', 71, 0.347],
#  [u'feature', 63, 0.241],
#  [u'mouse', 62, 0.15],
#  [u'mouse keyboard', 60, 0.018],
#  [u'touch', 54, 0.178],
#  [u'control', 51, 0.102],
#  [u'keyboard size', 48, 0.018],
#  [u'function', 48, 0.18],
#  [u'click', 48, 0.216],
#  [u'issue', 48, 0.158],
#  [u'room', 48, 0.151],
#  [u'mouse button', 48, 0.064],
#  [u'screen', 44, 0.236],
#  [u'battery', 44, 0.162],
#  [u'computer', 41, 0.082],
#  [u'receiver', 41, 0.192],
#  [u'quality', 39, 0.183],
#  [u'full keyboard', 35, 0.005],
#  [u'arrow', 35, 0.311],
#  [u'logitech keyboard', 34, 0.009],
#  [u'battery life', 34, 0.401],
#  [u'touchpad', 33, 0.082],
#  [u'pc', 32, 0.082],
#  [u'tv', 31, 0.076],
#  [u'left button', 30, 0.032],
#  [u'typing', 29, 0.365],
#  [u'laptop', 28, 0.085],
#  [u'bit', 28, 0.121],
#  [u'shift', 27, 0.385],
#  [u'key arrow', 26, 0.019],
#  [u'finger', 26, 0.118],
#  [u'setup', 25, 0.126],
#  [u'top button', 25, 0.002],
#  [u'touch pad', 24, 0.208],
#  [u'htpc keyboard', 24, 0.007],
#  [u'laptop keyboard', 23, 0.006],
#  [u'pad', 23, 0.058],
#  [u'full size', 23, 0.079],
#  [u'dongle', 22, 0.122],
#  [u'touchpad keyboard', 22, 0.004],
#  [u'left click', 20, 0.104],
#  [u'software', 20, 0.109],
#  [u'small keyboard', 20, 0.006],
#  [u'year', 17, 0.146],
#  [u'life', 15, 0.221],
#  [u'function key', 14, 0.022],
#  [u'trackpad', 13, 0.077],
#  [u'usb receiver', 12, 0.103],
#  [u'smart tv', 11, 0.099],
#  [u'usb dongle', 10, 0.159],
#  [u'living room', 10, 0.238],
#  [u'box', 9, 0.048],
#  [u'multi touch', 9, 0.147],
#  [u'center', 9, 0.055],
#  [u'mouse pad', 8, 0.075],
#  [u'usb', 8, 0.167],
#  [u'k400', 8, 0.05],
#  [u'track pad', 8, 0.096],
#  [u'star', 7, 0.049],
#  [u'small key', 6, 0.006],
#  [u'htpc', 6, 0.052],
#  [u'logitech', 6, 0.065],
#  [u'foot', 5, 0.038],
#  [u'home', 5, 0.063],
#  [u'left mouse', 5, 0.021],
#  [u'medium', 5, 0.172],
#  [u'windows', 5, 0.032],
#  [u'android', 5, 0.082],
#  [u'wireless mouse', 4, 0.04],
#  [u'medium center', 4, 0.307],
#  [u'home theater', 4, 0.66],
#  [u'away foot', 4, 0.0],
#  [u'wireless', 3, 0.07]]
#
# --------------------------------------------------
# B003ELYQGG Panasonic ErgoFit Best in Class In-Ear Earbud Headphones RP-HJE120-D (Orange) Dynamic Crystal Clear Sound, Ergonomic Comfort-Fit, iPhone, Android Compatible, Noise Isolating Headphones
# --------------------------------------------------
#
# [[u'sound', 442, 0.115],
#  [u'sound quality', 349, 0.265],
#  [u'headphone', 325, 0.231],
#  [u'quality', 296, 0.411],
#  [u'pair', 245, 0.186],
#  [u'earbuds', 181, 0.195],
#  [u'bass', 173, 0.254],
#  [u'set', 138, 0.173],
#  [u'ear bud', 131, 0.258],
#  [u'fit', 130, 0.052],
#  [u'earphone', 115, 0.232],
#  [u'noise', 104, 0.325],
#  [u'color', 94, 0.306],
#  [u'bud', 92, 0.179],
#  [u'size', 90, 0.293],
#  [u'ear', 87, 0.087],
#  [u'cord', 54, 0.201],
#  [u'design', 53, 0.14],
#  [u'month', 47, 0.156],
#  [u'headphone pair', 46, 0.003],
#  [u'volume', 43, 0.327],
#  [u'phone', 39, 0.154],
#  [u'year', 35, 0.137],
#  [u'ear fit', 35, 0.019],
#  [u'cheap headphone', 34, 0.024],
#  [u'music', 32, 0.142],
#  [u'ear size', 31, 0.025],
#  [u'ear headphone', 30, 0.03],
#  [u'sound headphone', 27, 0.006],
#  [u'wire', 24, 0.183],
#  [u'different size', 21, 0.144],
#  [u'money', 20, 0.175],
#  [u'ear phone', 20, 0.114],
#  [u'bit', 20, 0.084],
#  [u'case', 19, 0.121],
#  [u'small ear', 12, 0.024],
#  [u'star', 10, 0.041],
#  [u'listen music', 7, 0.015],
#  [u'ipod', 6, 0.067],
#  [u'panasonic', 5, 0.06],
#  [u'sony', 4, 0.051]]
#
# --------------------------------------------------
# B0012S4APK Cheetah Mounts APTMM2B TV Wall Mount for 20-75-Inch TVs Bundle with 10-feet Braided HDMI Cable and a 6-Inch 3-Axis Magnetic Bubble
# --------------------------------------------------
#
# [[u'mount', 214, 0.08],
#  [u'level', 142, 0.213],
#  [u'screw', 112, 0.119],
#  [u'tv', 97, 0.075],
#  [u'quality', 88, 0.317],
#  [u'hdmi cable', 78, 0.268],
#  [u'piece', 64, 0.199],
#  [u'deal', 63, 0.289],
#  [u'mount wall', 60, 0.003],
#  [u'part', 59, 0.22],
#  [u'bracket', 56, 0.127],
#  [u'screen', 54, 0.407],
#  [u'hardware', 53, 0.267],
#  [u'store', 50, 0.287],
#  [u'tv mount', 50, 0.047],
#  [u'hole', 46, 0.247],
#  [u'size', 43, 0.296],
#  [u'bolt', 42, 0.128],
#  [u'room', 37, 0.252],
#  [u'cable', 35, 0.121],
#  [u'bit', 34, 0.132],
#  [u'design', 32, 0.161],
#  [u'box', 32, 0.195],
#  [u'instruction', 32, 0.112],
#  [u'issue', 29, 0.14],
#  [u'angle', 28, 0.129],
#  [u'tilt', 25, 0.059],
#  [u'job', 24, 0.137],
#  [u'metal', 24, 0.33],
#  [u'wall', 22, 0.073],
#  [u'frame', 19, 0.14],
#  [u'plasma', 19, 0.096],
#  [u'side', 19, 0.176],
#  [u'include level', 18, 0.028],
#  [u'lag bolt', 16, 0.079],
#  [u'installation', 16, 0.193],
#  [u'bubble level', 15, 0.038],
#  [u'unit', 15, 0.153],
#  [u'flat screen', 14, 0.366],
#  [u'tv wall', 13, 0.02],
#  [u'mount screw', 13, 0.018],
#  [u'drill hole', 13, 0.021],
#  [u'cheetah mount', 13, 0.013],
#  [u'mount bracket', 12, 0.071],
#  [u'include cable', 12, 0.029],
#  [u'tilt mount', 12, 0.004],
#  [u'money', 11, 0.146],
#  [u'stud', 11, 0.041],
#  [u'bottom screw', 10, 0.015],
#  [u'tighten screw', 10, 0.0],
#  [u'inch', 9, 0.037],
#  [u'tv bracket', 9, 0.022],
#  [u'samsung', 7, 0.104],
#  [u'wall bracket', 7, 0.038],
#  [u'come level', 7, 0.016],
#  [u'hang tv', 6, 0.001],
#  [u'inch tv', 5, 0.018],
#  [u'minute', 5, 0.042],
#  [u'lcd', 5, 0.036],
#  [u'hold tv', 4, 0.001],
#  [u'build level', 4, 0.02],
#  [u'easy mount', 4, 0.002],
#  [u'come mount', 4, 0.001],
#  [u'wall stud', 3, 0.108],
#  [u'led tv', 3, 0.015],
#  [u'bottom', 3, 0.016],
#  [u'safety screw', 3, 0.026]]
#
# --------------------------------------------------
# B00622AG6S PowerGen 2.4Amps / 12W Dual USB Car charger Designed for Apple and Android Devices - White
# --------------------------------------------------
#
# [[u'charger', 167, 0.182],
#  [u'car charger', 92, 0.111],
#  [u'light', 83, 0.268],
#  [u'port', 56, 0.128],
#  [u'blue light', 50, 0.173],
#  [u'cable', 48, 0.18],
#  [u'power', 45, 0.14],
#  [u'car', 43, 0.095],
#  [u'quality', 41, 0.326],
#  [u'charge', 41, 0.016],
#  [u'trip', 38, 0.261],
#  [u'usb port', 38, 0.137],
#  [u'usb charger', 37, 0.041],
#  [u'adapter', 33, 0.187],
#  [u'phone', 28, 0.056],
#  [u'month', 27, 0.214],
#  [u'outlet', 26, 0.15],
#  [u'job', 25, 0.198],
#  [u'socket', 23, 0.17],
#  [u'cord', 22, 0.179],
#  [u'unit', 21, 0.195],
#  [u'dual port', 16, 0.033],
#  [u'amp', 16, 0.105],
#  [u'plug', 16, 0.02],
#  [u'road trip', 15, 0.177],
#  [u'slot', 15, 0.114],
#  [u'usb cable', 14, 0.142],
#  [u'usb', 13, 0.193],
#  [u'charge phone', 13, 0.007],
#  [u'iphone', 13, 0.02],
#  [u'issue', 13, 0.066],
#  [u'complaint', 13, 0.082],
#  [u'charge port', 11, 0.017],
#  [u'charge charger', 11, 0.003],
#  [u'dual charger', 11, 0.012],
#  [u'iphone charge', 9, 0.026],
#  [u'usb charge', 9, 0.003],
#  [u'dual usb', 7, 0.198],
#  [u'long trip', 7, 0.195],
#  [u'battery', 6, 0.078],
#  [u'usb plug', 6, 0.018],
#  [u'fast charge', 5, 0.013],
#  [u'apple', 5, 0.039],
#  [u'gp', 5, 0.061],
#  [u'android phone', 5, 0.047],
#  [u'car usb', 5, 0.01],
#  [u'tablet', 4, 0.071],
#  [u'iphones', 4, 0.051],
#  [u'ipad', 4, 0.017],
#  [u'car charge', 4, 0.001],
#  [u'cell phone', 3, 0.036],
#  [u'ipad charge', 3, 0.015],
#  [u'android', 3, 0.082]]
#
# --------------------------------------------------
# B005FYNSPK SanDisk Cruzer Fit 4GB USB 2.0 Low-Profile Flash Drive- SDCZ33-004G-B35
# --------------------------------------------------
#
# [[u'flash drive', 197, 0.157],
#  [u'size', 186, 0.265],
#  [u'drive', 178, 0.174],
#  [u'storage', 103, 0.409],
#  [u'profile', 101, 0.472],
#  [u'usb drive', 101, 0.061],
#  [u'file', 73, 0.235],
#  [u'speed', 67, 0.277],
#  [u'space', 63, 0.403],
#  [u'capacity', 61, 0.292],
#  [u'loop', 52, 0.17],
#  [u'small size', 47, 0.107],
#  [u'ring', 45, 0.25],
#  [u'low profile', 41, 0.385],
#  [u'thumb drive', 40, 0.021],
#  [u'hard drive', 38, 0.017],
#  [u'system', 36, 0.158],
#  [u'music', 31, 0.122],
#  [u'small drive', 30, 0.018],
#  [u'usb', 29, 0.13],
#  [u'usb port', 29, 0.388],
#  [u'issue', 28, 0.134],
#  [u'lanyard', 28, 0.125],
#  [u'memory', 27, 0.308],
#  [u'stick drive', 25, 0.005],
#  [u'stick', 25, 0.041],
#  [u'laptop', 24, 0.057],
#  [u'usb stick', 24, 0.03],
#  [u'fit', 21, 0.023],
#  [u'write speed', 19, 0.086],
#  [u'data', 18, 0.236],
#  [u'car stereo', 18, 0.345],
#  [u'bit', 16, 0.13],
#  [u'transfer speed', 15, 0.086],
#  [u'transfer', 15, 0.05],
#  [u'transfer file', 15, 0.007],
#  [u'song', 15, 0.179],
#  [u'tiny drive', 14, 0.007],
#  [u'car', 14, 0.057],
#  [u'computer', 13, 0.073],
#  [u'port', 8, 0.048],
#  [u'key', 8, 0.134],
#  [u'gb', 7, 0.043],
#  [u'radio', 6, 0.05],
#  [u'slot', 6, 0.044],
#  [u'flash usb', 6, 0.003],
#  [u'usb car', 6, 0.002],
#  [u'cruzer', 5, 0.073],
#  [u'flash', 5, 0.09],
#  [u'thumb', 4, 0.25],
#  [u'cruzer fit', 3, 0.067],
#  [u'usb slot', 3, 0.32]]
#
# --------------------------------------------------
# B000I68BD4 JLab Audio JBuds Hi-Fi Noise-Reducing Ear Buds, GUARANTEED FOR LIFE - White
# --------------------------------------------------
#
# [[u'sound', 163, 0.129],
#  [u'sound quality', 147, 0.278],
#  [u'quality', 111, 0.409],
#  [u'pair', 106, 0.216],
#  [u'headphone', 96, 0.247],
#  [u'ear bud', 92, 0.279],
#  [u'earbuds', 73, 0.197],
#  [u'noise', 56, 0.287],
#  [u'size', 55, 0.262],
#  [u'set', 50, 0.196],
#  [u'bud', 46, 0.153],
#  [u'fit', 45, 0.054],
#  [u'ear', 42, 0.112],
#  [u'earphone', 38, 0.228],
#  [u'bass', 32, 0.2],
#  [u'volume', 26, 0.243],
#  [u'cord', 24, 0.197],
#  [u'month', 22, 0.119],
#  [u'year', 18, 0.138],
#  [u'week', 16, 0.168],
#  [u'phone', 15, 0.101],
#  [u'piece', 15, 0.2],
#  [u'ear piece', 14, 0.188],
#  [u'noise reduction', 14, 0.438],
#  [u'music', 13, 0.141],
#  [u'cancel noise', 11, 0.036],
#  [u'reduce noise', 10, 0.022],
#  [u'money', 9, 0.119],
#  [u'come bud', 9, 0.019],
#  [u'wire', 8, 0.112],
#  [u'mp3 player', 8, 0.326],
#  [u'outside noise', 7, 0.091],
#  [u'jbuds', 7, 0.049],
#  [u'ear fit', 7, 0.033],
#  [u'listen music', 6, 0.012],
#  [u'bit', 6, 0.077],
#  [u'replacement', 6, 0.095],
#  [u'player', 5, 0.083],
#  [u'ear phone', 5, 0.144],
#  [u'rubber', 3, 0.25],
#  [u'ipod', 3, 0.032]]
#
# --------------------------------------------------
# B000BQ7GW8 SanDisk 2GB Class 4 SD Flash Memory Card- SDSDB-002G-B35 (Label May Change)
# --------------------------------------------------
#
# [[u'card', 123, 0.114],
#  [u'camera', 111, 0.173],
#  [u'sd card', 61, 0.091],
#  [u'memory card', 55, 0.104],
#  [u'picture', 41, 0.153],
#  [u'quality', 36, 0.319],
#  [u'speed', 33, 0.331],
#  [u'storage', 32, 0.305],
#  [u'capacity', 31, 0.208],
#  [u'memory', 31, 0.269],
#  [u'space', 28, 0.32],
#  [u'digital camera', 28, 0.068],
#  [u'size', 25, 0.235],
#  [u'photo', 22, 0.12],
#  [u'store', 22, 0.076],
#  [u'year', 20, 0.226],
#  [u'drive', 20, 0.233],
#  [u'camera card', 16, 0.002],
#  [u'disk', 15, 0.155],
#  [u'flash card', 14, 0.018],
#  [u'video', 14, 0.125],
#  [u'file', 14, 0.242],
#  [u'computer', 13, 0.1],
#  [u'sdhc card', 11, 0.023],
#  [u'gb card', 10, 0.018],
#  [u'class', 10, 0.062],
#  [u'old camera', 10, 0.02],
#  [u'sandisk card', 9, 0.02],
#  [u'class card', 8, 0.014],
#  [u'data', 7, 0.216],
#  [u'video picture', 6, 0.061],
#  [u'video camera', 5, 0.015],
#  [u'canon camera', 4, 0.016],
#  [u'hd video', 4, 0.138],
#  [u'pic', 3, 0.043],
#  [u'gb', 3, 0.049],
#  [u'issue', 3, 0.024],
#  [u'fine card', 3, 0.0],
#  [u'sd', 3, 0.104]]
#
# --------------------------------------------------
# B00BGGDVOO Roku 3 Streaming Media Player (2014 model)
# --------------------------------------------------
#
# [[u'channel', 332, 0.264],
#  [u'feature', 158, 0.238],
#  [u'tv', 140, 0.098],
#  [u'roku', 133, 0.057],
#  [u'interface', 123, 0.217],
#  [u'connection', 118, 0.217],
#  [u'box', 115, 0.18],
#  [u'content', 112, 0.274],
#  [u'quality', 104, 0.207],
#  [u'remote', 100, 0.105],
#  [u'service', 98, 0.219],
#  [u'model', 93, 0.303],
#  [u'unit', 89, 0.197],
#  [u'option', 89, 0.231],
#  [u'issue', 88, 0.193],
#  [u'player', 80, 0.134],
#  [u'video', 77, 0.137],
#  [u'movie', 77, 0.152],
#  [u'control', 71, 0.183],
#  [u'app', 70, 0.124],
#  [u'speed', 69, 0.212],
#  [u'screen', 67, 0.224],
#  [u'apps', 66, 0.277],
#  [u'year', 62, 0.221],
#  [u'medium', 55, 0.364],
#  [u'network', 53, 0.199],
#  [u'support', 50, 0.067],
#  [u'picture', 48, 0.232],
#  [u'show', 48, 0.087],
#  [u'roku channel', 48, 0.022],
#  [u'room', 43, 0.158],
#  [u'free channel', 41, 0.032],
#  [u'remote control', 39, 0.153],
#  [u'headphone', 36, 0.167],
#  [u'streaming', 35, 0.192],
#  [u'cable', 34, 0.065],
#  [u'setup', 33, 0.11],
#  [u'show movie', 27, 0.04],
#  [u'account', 25, 0.087],
#  [u'phone', 24, 0.09],
#  [u'month', 20, 0.108],
#  [u'jack', 20, 0.05],
#  [u'audio', 20, 0.126],
#  [u'computer', 19, 0.074],
#  [u'internet', 18, 0.114],
#  [u'hd', 18, 0.092],
#  [u'roku box', 18, 0.079],
#  [u'ray player', 17, 0.074],
#  [u'watch movie', 15, 0.006],
#  [u'tv movie', 15, 0.009],
#  [u'smart tv', 14, 0.043],
#  [u'tv show', 14, 0.081],
#  [u'wifi', 14, 0.099],
#  [u'headphone jack', 13, 0.249],
#  [u'hdmi cable', 13, 0.123],
#  [u'roku player', 13, 0.068],
#  [u'roku remote', 13, 0.033],
#  [u'star', 13, 0.059],
#  [u'watch tv', 12, 0.001],
#  [u'stream video', 11, 0.012],
#  [u'sound', 11, 0.04],
#  [u'old roku', 10, 0.013],
#  [u'cable tv', 9, 0.03],
#  [u'roku tv', 8, 0.009],
#  [u'remote jack', 8, 0.007],
#  [u'home', 8, 0.108],
#  [u'netflix', 8, 0.011],
#  [u'hulu', 7, 0.031],
#  [u'remote headphone', 7, 0.026],
#  [u'youtube', 4, 0.034],
#  [u'apple tv', 4, 0.118],
#  [u'netflix prime', 3, 0.044],
#  [u'hdmi', 3, 0.028],
#  [u'prime', 3, 0.008]]
#
# --------------------------------------------------
# B000QUUFRW SanDisk 4GB Extreme SDHC Class 10 Memory Card
# --------------------------------------------------
#
# [[u'card', 252, 0.129],
#  [u'speed', 136, 0.27],
#  [u'camera', 117, 0.136],
#  [u'memory card', 79, 0.069],
#  [u'sd card', 75, 0.059],
#  [u'quality', 65, 0.323],
#  [u'shot', 49, 0.254],
#  [u'capacity', 49, 0.28],
#  [u'photo', 47, 0.129],
#  [u'file', 47, 0.267],
#  [u'picture', 44, 0.155],
#  [u'video', 36, 0.125],
#  [u'fast card', 33, 0.017],
#  [u'sandisk card', 31, 0.021],
#  [u'storage', 31, 0.437],
#  [u'card class', 30, 0.02],
#  [u'size', 29, 0.162],
#  [u'performance', 29, 0.25],
#  [u'memory', 26, 0.262],
#  [u'card speed', 26, 0.008],
#  [u'image', 25, 0.191],
#  [u'year', 24, 0.197],
#  [u'space', 24, 0.282],
#  [u'write speed', 23, 0.064],
#  [u'mode', 22, 0.193],
#  [u'flash card', 19, 0.012],
#  [u'sdhc card', 18, 0.013],
#  [u'digital camera', 18, 0.041],
#  [u'camera card', 17, 0.001],
#  [u'extreme card', 17, 0.012],
#  [u'issue', 16, 0.05],
#  [u'transfer speed', 14, 0.039],
#  [u'fast speed', 14, 0.015],
#  [u'hd video', 14, 0.187],
#  [u'transfer', 14, 0.04],
#  [u'high speed', 13, 0.043],
#  [u'card reader', 13, 0.234],
#  [u'video camera', 12, 0.025],
#  [u'data', 10, 0.19],
#  [u'reader', 9, 0.092],
#  [u'class', 9, 0.07],
#  [u'nikon camera', 8, 0.014],
#  [u'hd', 8, 0.18],
#  [u'dslr camera', 8, 0.025],
#  [u'canon camera', 7, 0.016],
#  [u'gb', 6, 0.063],
#  [u'video photo', 6, 0.08],
#  [u'sandisk', 6, 0.078],
#  [u'sd', 6, 0.112],
#  [u'video picture', 5, 0.097],
#  [u'dslr', 5, 0.06],
#  [u'flash memory', 5, 0.123],
#  [u'sdhc class', 4, 0.04],
#  [u'read speed', 4, 0.016],
#  [u'recommend card', 4, 0.001],
#  [u'second', 3, 0.037],
#  [u'flash', 3, 0.229]]
#
# --------------------------------------------------
# B008OHNZI0 Tech Armor Ultimate 4-Way 360 Degree Privacy Screen Protector for Apple New iPhone 5, Latest Generation, 1-Pack
# --------------------------------------------------
#
# [[u'screen protector', 229, 0.308],
#  [u'glare', 67, 0.241],
#  [u'protector', 65, 0.112],
#  [u'bubble', 59, 0.1],
#  [u'quality', 54, 0.244],
#  [u'screen', 52, 0.117],
#  [u'cloth', 47, 0.181],
#  [u'scratch', 31, 0.066],
#  [u'instruction', 29, 0.152],
#  [u'side', 29, 0.196],
#  [u'finish', 28, 0.25],
#  [u'cover', 28, 0.087],
#  [u'film', 26, 0.191],
#  [u'matte finish', 25, 0.254],
#  [u'tape', 25, 0.167],
#  [u'iphone', 24, 0.088],
#  [u'phone', 24, 0.072],
#  [u'protection', 24, 0.294],
#  [u'anti glare', 23, 0.225],
#  [u'installation', 23, 0.263],
#  [u'fingerprint', 21, 0.187],
#  [u'case', 21, 0.084],
#  [u'piece', 20, 0.134],
#  [u'bit', 19, 0.145],
#  [u'video', 17, 0.186],
#  [u'glass', 16, 0.186],
#  [u'dust', 15, 0.096],
#  [u'issue', 15, 0.168],
# ...
#  [u'dashboard', 45, 0.094],
#  [u'road', 42, 0.32],
#  [u'windshield mount', 41, 0.026],
#  [u'unit', 40, 0.092],
#  [u'windshield cup', 40, 0.012],
#  [u'vehicle', 38, 0.196],
#  [u'year', 33, 0.207],
#  [u'suction mount', 33, 0.032],
#  [u'base', 30, 0.135],
#  [u'trip', 27, 0.162],
#  [u'holder', 24, 0.166],
#  [u'garmin mount', 24, 0.023],
#  [u'windshield mark', 23, 0.004],
#  [u'mount gp', 22, 0.003],
#  [u'place', 22, 0.035],
#  [u'garmin', 20, 0.06],
#  [u'gp unit', 20, 0.14],
#  [u'seat', 19, 0.076],
#  [u'mount dashboard', 18, 0.001],
#  [u'bit', 18, 0.102],
#  [u'bag', 18, 0.156],
#  [u'garmin friction', 14, 0.039],
#  [u'sharp turn', 14, 0.097],
#  [u'windshield', 14, 0.057],
#  [u'bottom', 14, 0.097],
#  [u'window mount', 14, 0.017],
#  [u'bean bag', 13, 0.289],
#  [u'thief', 13, 0.217],
#  [u'mark', 11, 0.161],
#  [u'portable mount', 11, 0.013],
#  [u'mount dash', 11, 0.003],
#  [u'garmin unit', 11, 0.027],
#  [u'suction windshield', 10, 0.011],
#  [u'nuvi', 9, 0.024],
#  [u'friction', 9, 0.222],
#  [u'window', 9, 0.07],
#  [u'portable friction', 8, 0.104],
#  [u'rental car', 8, 0.055],
#  [u'come mount', 7, 0.012],
#  [u'garmin gp', 7, 0.038],
#  [u'console', 7, 0.063],
#  [u'gps unit', 7, 0.065],
#  [u'ball', 7, 0.065],
#  [u'leave mark', 6, 0.018],
#  [u'garmin nuvi', 6, 0.201],
#  [u'car gp', 5, 0.001],
#  [u'garmin gps', 5, 0.239],
#  [u'suction window', 5, 0.016],
#  [u'nuvi mount', 3, 0.002],
#  [u'fall windshield', 3, 0.0]]
#
# --------------------------------------------------
# B003ES5ZUU AmazonBasics High-Speed HDMI Cable with Ethernet - Braided 6.5 feet/2.0 meters (Discontinued by Manufacturer)
# --------------------------------------------------
#
# [[u'cable', 866, 0.176],
#  [u'hdmi cable', 436, 0.15],
#  [u'quality', 401, 0.316],
#  [u'cable quality', 175, 0.015],
#  [u'length', 148, 0.269],
#  [u'value', 117, 0.351],
#  [u'store', 113, 0.307],
#  [u'tv', 97, 0.068],
#  [u'packaging', 80, 0.339],
#  [u'signal', 79, 0.262],
#  [u'box store', 68, 0.126],
#  [u'picture quality', 67, 0.047],
#  [u'cord', 66, 0.187],
#  [u'end', 64, 0.196],
#  [u'connection', 64, 0.226],
#  [u'picture', 63, 0.206],
#  [u'high quality', 62, 0.093],
#  [u'connector', 58, 0.263],
#  [u'high cable', 56, 0.003],
#  [u'money', 54, 0.225],
#  [u'box', 51, 0.153],
#  [u'expensive cable', 50, 0.018],
#  [u'hdmi quality', 48, 0.002],
#  [u'cheap cable', 44, 0.01],
#  [u'year', 43, 0.222],
#  [u'job', 38, 0.134],
#  [u'cable speed', 38, 0.0],
#  [u'ray player', 37, 0.177],
#  [u'sound picture', 34, 0.068],
#  [u'issue', 33, 0.059],
#  [u'difference', 33, 0.085],
#  [u'hdmi speed', 32, 0.01],
#  [u'basic cable', 32, 0.007],
#  [u'monitor', 28, 0.109],
#  [u'monster cable', 25, 0.01],
#  [u'player', 23, 0.056],
#  [u'hdmi', 23, 0.058],
#  [u'speed', 20, 0.262],
#  [u'high speed', 20, 0.445],
#  [u'audio video', 19, 0.138],
#  [u'video', 19, 0.125],
#  [u'hdmi cord', 19, 0.118],
#  [u'amazonbasics cable', 18, 0.008],
#  [u'connect cable', 17, 0.002],
#  [u'blu player', 17, 0.032],
#  [u'big store', 16, 0.069],
#  [u'roku', 16, 0.078],
#  [u'sound', 14, 0.114],
#  [u'name', 14, 0.118],
#  [u'foot', 12, 0.054],
#  [u'ray', 11, 0.072],
#  [u'cable box', 9, 0.096],
#  [u'big box', 9, 0.066],
#  [u'hd', 9, 0.175],
#  [u'blu ray', 7, 0.342],
#  [u'computer', 5, 0.025],
#  [u'audio', 5, 0.052],
#  [u'3d', 4, 0.022],
#  [u'monster', 4, 0.063],
#  [u'laptop', 3, 0.014]]
#
# --------------------------------------------------
# B00DR0PDNE
# --------------------------------------------------
#
# [[u'apps', 435, 0.327],
#  [u'tv', 294, 0.095],
#  [u'screen', 234, 0.282],
#  [u'network', 148, 0.197],
#  [u'video', 134, 0.129],
#  [u'feature', 129, 0.252],
#  [u'quality', 123, 0.195],
#  [u'app', 116, 0.092],
#  [u'service', 105, 0.31],
#  [u'connection', 105, 0.185],
#  [u'content', 103, 0.233],
#  [u'issue', 101, 0.171],
#  [u'medium', 85, 0.343],
#  [u'option', 85, 0.225],
#  [u'support', 84, 0.05],
#  [u'support apps', 83, 0.033],
#  [u'router', 83, 0.135],
#  [u'player', 76, 0.103],
#  [u'setup', 75, 0.11],
#  [u'phone', 70, 0.053],
#  [u'box', 70, 0.167],
#  [u'cable', 57, 0.112],
#  [u'room', 55, 0.128],
#  [u'smart tv', 50, 0.046],
#  [u'picture', 47, 0.151],
#  [u'hdmi port', 47, 0.19],
#  [u'movie', 44, 0.07],
#  [u'youtube video', 44, 0.103],
#  [u'laptop', 43, 0.05],
#  [u'tv screen', 41, 0.053],
#  [u'stream content', 41, 0.019],
#  [u'computer', 40, 0.051],
#  [u'streaming', 33, 0.153],
#  [u'usb port', 32, 0.159],
#  [u'tablet phone', 32, 0.104],
#  [u'chromecast', 31, 0.02],
#  [u'power', 31, 0.045],
#  [u'wifi', 31, 0.116],
#  [u'stream video', 30, 0.011],
#  [u'play video', 27, 0.007],
#  [u'hdmi cable', 27, 0.135],
#  [u'pc', 27, 0.062],
#  [u'browser', 25, 0.03],
#  [u'music', 24, 0.049],
#  [u'watch video', 23, 0.003],
#  [u'netflix', 23, 0.017],
#  [u'internet', 22, 0.104],
#  [u'chromecast app', 20, 0.064],
#  [u'star', 20, 0.052],
#  [u'turn tv', 17, 0.0],
#  [u'roku', 15, 0.017],
#  [u'android', 15, 0.074],
#  [u'chrome tab', 15, 0.172],
#  [u'tablet', 14, 0.021],
#  [u'port', 13, 0.086],
#  [u'youtube netflix', 13, 0.17],
#  [u'big screen', 13, 0.099],
#  [u'chrome browser', 11, 0.336],
#  [u'usb', 10, 0.087],
#  [u'hdmi', 9, 0.053],
#  [u'android phone', 9, 0.059],
#  [u'easy setup', 9, 0.061],
#  [u'tab', 8, 0.049],
#  [u'youtube', 8, 0.02],
#  [u'chrome', 8, 0.022],
#  [u'home', 7, 0.102],
#  [u'google', 6, 0.018],
#  [u'web', 6, 0.08],
#  [u'play', 6, 0.004],
#  [u'cast tab', 6, 0.025],
#  [u'apple tv', 6, 0.068],
#  [u'stream youtube', 4, 0.006],
#  [u'google play', 3, 0.052],
#  [u'hulu', 3, 0.007],
#  [u'ipad', 3, 0.009],
#  [u'hulu netflix', 3, 0.054]]
#
# --------------------------------------------------
# B005HMKKH4 WD My Passport 2TB Portable External USB 3.0 Hard Drive Storage Black (WDBY8L0020BBK-NESN)
# --------------------------------------------------
#
# [[u'drive', 419, 0.309],
#  [u'hard drive', 312, 0.119],
#  [u'external drive', 209, 0.057],
#  [u'file', 102, 0.188],
#  [u'storage', 100, 0.375],
#  [u'size', 94, 0.204],
#  [u'software', 90, 0.187],
#  [u'portable drive', 85, 0.022],
#  [u'space', 79, 0.347],
#  [u'backup', 76, 0.122],
#  [u'computer', 74, 0.14],
#  [u'capacity', 61, 0.316],
#  [u'case', 55, 0.153],
#  [u'wd drive', 49, 0.017],
#  [u'usb drive', 47, 0.012],
#  [u'speed', 45, 0.189],
#  [u'backup drive', 41, 0.012],
#  [u'year', 39, 0.155],
#  [u'data', 37, 0.156],
#  [u'cable', 34, 0.125],
#  [u'month', 31, 0.162],
#  [u'unit', 31, 0.219],
#  [u'power', 28, 0.111],
#  [u'small drive', 28, 0.005],
#  [u'system', 27, 0.131],
#  [u'issue', 27, 0.098],
#  [u'hd', 25, 0.187],
#  [u'digital', 25, 0.17],
#  [u'passport drive', 24, 0.01],
#  [u'usb', 23, 0.065],
#  [u'backup software', 22, 0.077],
#  [u'usb cable', 22, 0.144],
#  [u'passport', 21, 0.082],
#  [u'pc', 20, 0.12],
#  [u'transfer speed', 19, 0.103],
#  [u'disk', 19, 0.215],
#  [u'laptop', 18, 0.07],
#  [u'usb port', 16, 0.304],
#  [u'usb speed', 15, 0.043],
#  [u'machine', 13, 0.096],
#  [u'photo', 12, 0.063],
#  [u'wd passport', 12, 0.103],
#  [u'transfer', 12, 0.05],
#  [u'transfer file', 12, 0.004],
#  [u'data transfer', 10, 0.06],
#  [u'port', 9, 0.064],
#  [u'picture', 9, 0.048],
#  [u'star', 8, 0.05],
#  [u'western digital', 8, 0.688],
#  [u'video', 7, 0.056],
#  [u'tb', 6, 0.051],
#  [u'wd', 6, 0.105],
#  [u'movie', 6, 0.037],
#  [u'usb power', 5, 0.054],
#  [u'external power', 3, 0.04],
#  [u'music', 3, 0.016]]
#
# --------------------------------------------------
# B002V88HFE eneloop SEC-CSPACER4PK C Size Spacers for use with AA battery cells
# --------------------------------------------------
#
# [[u'battery', 586, 0.27],
#  [u'rechargeable battery', 241, 0.08],
#  [u'charger', 137, 0.165],
#  [u'charge', 99, 0.045],
#  [u'year', 81, 0.182],
#  [u'capacity', 66, 0.356],
#  [u'set', 62, 0.142],
#  [u'camera', 60, 0.189],
#  [u'quality', 58, 0.427],
#  [u'eneloop battery', 58, 0.043],
#  [u'life', 52, 0.262],
#  [u'month', 51, 0.168],
#  [u'alkaline battery', 50, 0.02],
#  [u'power', 49, 0.147],
#  [u'eneloops', 43, 0.165],
#  [u'rechargeables', 43, 0.247],
#  [u'aa battery', 43, 0.031],
#  [u'cell', 38, 0.225],
#  [u'charge battery', 37, 0.006],
#  [u'nimh battery', 33, 0.01],
#  [u'pack', 33, 0.106],
#  [u'case', 31, 0.16],
#  [u'light', 31, 0.182],
#  [u'hold charge', 30, 0.005],
#  [u'week', 30, 0.168],
#  [u'battery charger', 30, 0.049],
#  [u'year battery', 29, 0.0],
#  [u'last battery', 29, 0.002],
#  [u'cycle', 28, 0.101],
#  [u'regular battery', 27, 0.013],
#  [u'self discharge', 26, 0.152],
#  [u'hour', 25, 0.096],
#  [u'battery life', 24, 0.112],
#  [u'long battery', 24, 0.0],
#  [u'mouse', 24, 0.113],
#  [u'phone', 23, 0.115],
#  [u'flashlight', 22, 0.096],
#  [u'battery pack', 22, 0.045],
#  [u'high capacity', 22, 0.153],
#  [u'aa', 20, 0.054],
#  [u'size', 19, 0.151],
#  [u'digital camera', 19, 0.132],
#  [u'sanyo battery', 18, 0.006],
#  [u'flash', 18, 0.073],
#  [u'come battery', 18, 0.002],
#  [u'aaa battery', 17, 0.014],
#  [u'old battery', 17, 0.006],
#  [u'discharge', 16, 0.125],
#  [u'long life', 16, 0.124],
#  [u'money', 14, 0.215],
#  [u'camera flash', 13, 0.1],
#  [u'replace battery', 12, 0.0],
#  [u'eneloop', 12, 0.069],
#  [u'd battery', 12, 0.006],
#  [u'hold battery', 11, 0.001],
#  [u'full charge', 10, 0.011],
#  [u'last charge', 10, 0.004],
#  [u'remote', 10, 0.061],
#  [u'ago year', 10, 0.0],
#  [u'aaa aa', 9, 0.119],
#  [u'long charge', 9, 0.003],
#  [u'aaa', 8, 0.053],
#  [u'mah', 8, 0.054],
#  [u'nimh', 8, 0.194],
#  [u'power battery', 8, 0.001],
#  [u'time battery', 8, 0.0],
#  [u'controller', 7, 0.045],
#  [u'keep charge', 5, 0.001],
#  [u'xbox controller', 5, 0.164],
#  [u'xx', 4, 0.045],
#  [u'save money', 3, 0.028],
#  [u'cordless phone', 3, 0.181],
#  [u'longer charge', 3, 0.002],
#  [u'energizer', 3, 0.05]]
#
# --------------------------------------------------
# B001XURP7W SanDisk Cruzer 4GB USB 2.0 Flash Drive- SDCZ36-004G-B35
# --------------------------------------------------
#
# [[u'flash drive', 137, 0.198],
#  [u'drive', 118, 0.134],
#  [u'file', 97, 0.251],
#  [u'storage', 56, 0.332],
#  [u'speed', 54, 0.268],
#  [u'capacity', 51, 0.328],
#  [u'deal', 50, 0.255],
#  [u'usb drive', 42, 0.047],
#  [u'size', 36, 0.282],
#  [u'space', 36, 0.351],
#  [u'thumb drive', 31, 0.029],
#  [u'hard drive', 30, 0.021],
#  [u'year', 28, 0.246],
#  [u'quality', 27, 0.218],
#  [u'computer', 25, 0.126],
#  [u'transfer file', 23, 0.012],
#  [u'software', 19, 0.145],
#  [u'laptop', 15, 0.183],
#  [u'memory', 14, 0.24],
#  [u'sandisk drive', 14, 0.012],
#  [u'data', 14, 0.173],
#  [u'transfer', 14, 0.03],
#  [u'system', 13, 0.2],
#  [u'disk', 12, 0.161],
#  [u'backup', 12, 0.099],
#  [u'issue', 11, 0.091],
#  [u'write speed', 11, 0.1],
#  [u'document', 10, 0.11],
#  [u'usb', 9, 0.066],
#  [u'movie', 9, 0.171],
#  [u'picture', 7, 0.065],
#  [u'cruzer', 6, 0.051],
#  [u'large file', 6, 0.069],
#  [u'gb drive', 6, 0.01],
#  [u'photo', 5, 0.048],
#  [u'music', 5, 0.06],
#  [u'transfer data', 5, 0.043],
#  [u'usb port', 5, 0.359],
#  [u'gb', 3, 0.029],
#  [u'port', 3, 0.084],
#  [u'flash', 3, 0.042],
#  [u'pc', 3, 0.051],
#  [u'sandisk cruzer', 3, 0.292]]
#
# --------------------------------------------------
# B004W2JKWG Crucial m4 64GB 2.5-Inch (9.5mm) SATA 6Gb/s Solid State Drive CT064M4SSD2
# --------------------------------------------------
#
# [[u'drive', 325, 0.228],
#  [u'hard drive', 134, 0.07],
#  [u'ssd', 93, 0.106],
#  [u'speed', 73, 0.173],
#  [u'laptop', 70, 0.186],
#  [u'performance', 70, 0.238],
#  [u'system', 61, 0.143],
#  [u'computer', 59, 0.139],
#  [u'upgrade', 55, 0.082],
#  [u'firmware', 52, 0.189],
#  [u'machine', 47, 0.261],
#  [u'install', 45, 0.086],
#  [u'issue', 44, 0.132],
#  [u'disk', 41, 0.304],
#  [u'state drive', 41, 0.015],
#  [u'hdd', 41, 0.191],
#  [u'difference', 40, 0.177],
#  [u'program', 37, 0.201],
#  [u'file', 36, 0.219],
#  [u'space', 34, 0.393],
#  [u'boot', 34, 0.04],
#  [u'old drive', 34, 0.019],
#  [u'life', 29, 0.284],
#  [u'second', 29, 0.057],
#  [u'version', 29, 0.164],
#  [u'ssd drive', 29, 0.021],
#  [u'month', 27, 0.131],
#  [u'support', 26, 0.156],
#  [u'year', 25, 0.1],
#  [u'screen', 25, 0.176],
#  [u'pc', 24, 0.147],
#  [u'application', 23, 0.193],
#  [u'storage', 23, 0.312],
#  [u'ssds', 23, 0.279],
#  [u'solid drive', 22, 0.011],
#  [u'software', 20, 0.122],
#  [u'm4', 19, 0.102],
#  [u'hour', 19, 0.102],
#  [u'experience', 17, 0.097],
#  [u'desktop', 15, 0.118],
#  [u'window', 15, 0.164],
#  [u'minute', 15, 0.082],
#  [u'macbook pro', 15, 0.233],
#  [u'update', 14, 0.036],
#  [u'instal drive', 13, 0.002],
#  [u'data', 13, 0.103],
#  [u'state', 12, 0.232],
#  [u'ram', 11, 0.082],
#  [u'boot drive', 11, 0.016],
#  [u'macbook', 11, 0.156],
#  [u'case', 11, 0.11],
#  [u'crucial drive', 11, 0.009],
#  [u'fast drive', 10, 0.005],
#  [u'firmware update', 10, 0.137],
#  [u'installation', 10, 0.183],
#  [u'm4 ssd', 10, 0.022],
#  [u'pro', 7, 0.046],
#  [u'power', 7, 0.045],
#  [u'crucial m4', 7, 0.208],
#  [u'time boot', 6, 0.007],
#  [u'sata', 5, 0.054],
#  [u'mac', 5, 0.063],
#  [u'windows', 5, 0.024],
#  [u'gb', 4, 0.036],
#  [u'solid state', 4, 0.366],
#  [u'crucial ssd', 4, 0.045],
#  [u'crucial', 3, 0.052],
#  [u'bios', 3, 0.07]]
#
# --------------------------------------------------
# B0044YU60M Wireless Router w/ WiFi Range Extender Mode (300 Mbps) by Medialink - Easy YouTube Setup Video (Part# MWNWAPR300N )
# --------------------------------------------------
#
# [[u'router', 329, 0.175],
#  [u'signal', 90, 0.259],
#  [u'connection', 84, 0.233],
#  [u'range', 75, 0.276],
#  [u'speed', 73, 0.26],
#  [u'wireless router', 73, 0.04],
#  [u'issue', 51, 0.132],
#  [u'network', 48, 0.193],
#  [u'antenna', 44, 0.317],
#  [u'house', 41, 0.138],
#  [u'instruction', 41, 0.146],
#  [u'support', 39, 0.156],
#  [u'month', 39, 0.176],
#  [u'setup', 39, 0.14],
#  [u'room', 37, 0.185],
#  [u'linksys router', 35, 0.012],
#  [u'year', 35, 0.138],
#  [u'old router', 32, 0.031],
#  [u'customer service', 30, 0.361],
#  [u'week', 29, 0.181],
#  [u'light', 29, 0.224],
#  [u'setting', 28, 0.167],
#  [u'computer', 27, 0.086],
#  [u'unit', 27, 0.175],
#  [u'modem', 27, 0.086],
#  [u'signal strength', 25, 0.322],
#  [u'g router', 23, 0.01],
#  [u'netgear router', 23, 0.009],
#  [u'home', 22, 0.208],
#  [u'blue light', 20, 0.135],
#  [u'laptop', 19, 0.07],
#  [u'customer', 18, 0.256],
#  [u'address', 18, 0.131],
#  [u'cable', 18, 0.095],
#  [u'service', 17, 0.159],
#  [u'replace router', 16, 0.001],
#  [u'email', 15, 0.077],
#  [u'strong signal', 15, 0.074],
#  [u'medialink router', 14, 0.029],
#  [u'linksys', 14, 0.123],
#  [u'password', 14, 0.107],
#  [u'tech support', 13, 0.196],
#  [u'minute', 13, 0.053],
#  [u'n router', 12, 0.018],
#  [u'cd', 10, 0.078],
#  [u'ip address', 10, 0.172],
#  [u'wireless', 10, 0.059],
#  [u'strength', 9, 0.153],
#  [u'internet', 9, 0.063],
#  [u'link', 9, 0.036],
#  [u'phone', 8, 0.064],
#  [u'installation', 8, 0.128],
#  [u'customer support', 7, 0.094],
#  [u'drop connection', 7, 0.015],
#  [u'netgear', 7, 0.093],
#  [u'easy setup', 7, 0.05],
#  [u'old linksys', 6, 0.088],
#  [u'ip', 6, 0.178],
#  [u'star', 6, 0.031],
#  [u'power', 6, 0.057],
#  [u'medialink', 5, 0.024],
#  [u'cable modem', 5, 0.121],
#  [u'drop signal', 5, 0.01],
#  [u'wireless network', 5, 0.103],
#  [u'tech', 5, 0.128],
#  [u'wifi', 4, 0.08],
#  [u'set router', 4, 0.001],
#  [u'box', 4, 0.041],
#  [u'easy router', 3, 0.002]]
#
# --------------------------------------------------
# B0074BW614 Kindle Fire HD 7", Dolby Audio, Dual-Band Wi-Fi, 16 GB (Previous Generation - 2nd),-R
# --------------------------------------------------
#
# [[u'tablet', 252, 0.219],
#  [u'apps', 198, 0.243],
#  [u'screen', 178, 0.163],
#  [u'kindle', 163, 0.125],
#  [u'book', 152, 0.148],
#  [u'kindle fire', 123, 0.285],
#  [u'quality', 105, 0.195],
#  [u'feature', 92, 0.195],
#  [u'version', 92, 0.205],
#  [u'size', 81, 0.176],
#  [u'reader', 81, 0.152],
#  [u'sound', 73, 0.111],
#  [u'fire', 72, 0.124],
#  [u'speaker', 67, 0.252],
#  [u'year', 62, 0.197],
#  [u'issue', 58, 0.136],
#  [u'camera', 57, 0.207],
#  [u'battery life', 57, 0.414],
#  [u'fire hd', 56, 0.284],
#  [u'app', 55, 0.077],
#  [u'picture', 54, 0.176],
#  [u'charger', 54, 0.152],
#  [u'case', 50, 0.112],
#  [u'video', 50, 0.135],
#  [u'movie', 47, 0.109],
#  [u'kindle hd', 43, 0.203],
#  [u'content', 42, 0.207],
#  [u'button', 39, 0.111],
#  [u'original fire', 34, 0.068],
#  [u'month', 33, 0.128],
#  [u'read book', 33, 0.017],
#  [u'reading', 29, 0.186],
#  [u'service', 28, 0.17],
#  [u'ipad', 25, 0.031],
#  [u'store', 24, 0.038],
#  [u'battery', 22, 0.152],
#  [u'watch movie', 21, 0.013],
#  [u'customer service', 20, 0.305],
#  [u'music', 19, 0.074],
#  [u'customer', 19, 0.223],
#  [u'hd', 19, 0.026],
#  [u'computer', 18, 0.092],
#  [u'tv', 18, 0.107],
#  [u'ad', 16, 0.064],
#  [u'life', 16, 0.204],
#  [u'android', 16, 0.214],
#  [u'wifi', 15, 0.103],
#  [u'watch video', 14, 0.007],
#  [u'email', 8, 0.03],
#  [u'original kindle', 4, 0.021],
#  [u'hd. fire', 4, 0.003],
#  [u'web', 4, 0.02],
#  [u'wife', 3, 0.008]]

# %%
reverse = asin_dict['B00007E7JU']['aspect_dict'][(u'depth', u'field')]['ordering'][1] > asin_dict['B00007E7JU']['aspect_dict'][(u'depth', u'field')]['ordering'][0]
word1 = (u'depth', u'field')[reverse]
word2_key = (u'depth', u'field')[not reverse]

arr = np.array(asin_dict['B00007E7JU']['aspect_dict'][word2_key]['relation_from']) == word1
np.sum(arr)/len(arr)

print word2_key
asin_dict['B00007E7JU']['aspect_dict'][word2_key]['relation_from']
# Out:
# depth
# [u'good',
#  u'shallow',
#  u'of',
#  u'good',
#  u'the',
#  u'narrow',
#  u'-',
#  u'of',
#  u'at',
#  u'that',
#  u'shallow',
#  u'of',
#  u'of',
#  u'the',
#  u'narrow',
#  u'of',
#  u'some',
#  u'intense',
#  u'of',
#  u'its',
#  u'shallow',
#  u'of',
#  u'of',
#  u'and',
#  u'shot',
#  u'of',
#  u'some',
#  u'of',
#  u'great',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'think',
#  u'a',
#  u'satisfy',
#  u'shallow',
#  u'of',
#  u'of',
#  u'a',
#  u'narrow',
#  u'of',
#  u'great',
#  u'len',
#  u'shallow',
#  u'of',
#  u'the',
#  u'deep',
#  u'of',
#  u'its',
#  u'great',
#  u'of',
#  u'of',
#  u'some',
#  u'great',
#  u'of',
#  u'the',
#  u'right',
#  u'of',
#  u'a',
#  u'of',
#  u'shallow',
#  u'a',
#  u'shallow',
#  u'of',
#  u'at',
#  u'of',
#  u'a',
#  u'great',
#  u'shallow',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'narrow',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'some',
#  u'nice',
#  u'of',
#  u'(',
#  u'background',
#  u',',
#  u'improve',
#  u'the',
#  u'of',
#  u'of',
#  u'a',
#  u'huge',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'a',
#  u'of',
#  u'of',
#  u'excellent',
#  u'of',
#  u'photo',
#  u'narrow',
#  u'of',
#  u'create',
#  u'the',
#  u'narrow',
#  u'of',
#  u'the',
#  u'of',
#  u'of',
#  u'the',
#  u'of',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u',',
#  u'confuse',
#  u'the',
#  u'shallow',
#  u'of',
#  u'create',
#  u'the',
#  u'of',
#  u'on',
#  u'the',
#  u'of',
#  u'any',
#  u'photographer!the',
#  u'of',
#  u'shallow',
#  u'shallow',
#  u'of',
#  u'great',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'the',
#  u'the',
#  u'narrow',
#  u'of',
#  u'at',
#  u'of',
#  u'shallow',
#  u'-',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'a',
#  u'shallow',
#  u'-',
#  u'of',
#  u'a',
#  u'great',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'much',
#  u'a',
#  u'of',
#  u'a',
#  u'narrow',
#  u'of',
#  u'of',
#  u'of',
#  u'the',
#  u'of',
#  u'fantasticly',
#  u'shallow',
#  u'of',
#  u',',
#  u'color',
#  u'the',
#  u'of',
#  u'good',
#  u'of',
#  u'of',
#  u'the',
#  u'of',
#  u'get',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'the',
#  u'low',
#  u'of',
#  u'(',
#  u'-',
#  u'of',
#  u')',
#  u'from',
#  u'-',
#  u'of',
#  u'shallow',
#  u'-',
#  u'of',
#  u'great',
#  u'shallow',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'the',
#  u'the',
#  u'focal',
#  u'the',
#  u'of',
#  u'the',
#  u'the',
#  u'of',
#  u'of',
#  u'narrow',
#  u'depth',
#  u'of',
#  u'expect',
#  u'.',
#  u'a',
#  u'small',
#  u'of',
#  u'make',
#  u'of',
#  u'nice',
#  u'-',
#  u'of',
#  u'enough',
#  u'of',
#  u'set',
#  u'great',
#  u'depth',
#  u'of',
#  u',',
#  u'great',
#  u'.',
#  u'less',
#  u'of',
#  u'the',
#  u'of',
#  u'a',
#  u'narrow',
#  u'of',
#  u'an',
#  u'unusable',
#  u'of',
#  u'a',
#  u'great',
#  u'of',
#  u'color',
#  u'a',
#  u'little',
#  u'deep',
#  u'of',
#  u'put',
#  u'the',
#  u'narrow',
#  u'of',
#  u'the',
#  u'shallow',
#  u'-',
#  u'of',
#  u'afford',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'(',
#  u'of',
#  u'the',
#  u'of',
#  u'allow',
#  u'an',
#  u'amazing',
#  u'of',
#  u'-',
#  u'of',
#  u'clear',
#  u',',
#  u'shallow',
#  u'of',
#  u'a',
#  u'thin',
#  u'of',
#  u'-',
#  u'of',
#  u'a',
#  u'great',
#  u'of',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'in',
#  u'a',
#  u'of',
#  u'be',
#  u'such',
#  u'a',
#  u'narrow',
#  u'of',
#  u'such',
#  u'a',
#  u'narrow',
#  u'of',
#  u'a',
#  u'great',
#  u'of',
#  u'and',
#  u'of',
#  u'great',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'the',
#  u'narrow',
#  u'of',
#  u'the',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'the',
#  u'narrow',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'a',
#  u'shallow',
#  u'of',
#  u'small',
#  u'of',
#  u'the',
#  u'of',
#  u'and',
#  u'bokeh',
#  u'shallow',
#  u'of',
#  u'-',
#  u'of',
#  u'the',
#  u'necessary',
#  u'of',
#  u'for',
#  u'the',
#  u'shallow',
#  u'of',
#  u'at',
#  u'some',
#  u'beautiful',
#  u'of',
#  u'reflection',
#  u'great',
#  u'of',
#  u'...',
#  u'shallow',
#  u'of',
#  u'shallow',
#  u'of',
#  u'incredible',
#  u'the',
#  u'of',
#  u'the',
#  u'of',
#  u'of',
#  u'a',
#  u'great',
#  u'narrow',
#  u'of',
#  u'of',
#  u'that',
#  u'shallow',
#  u'of',
#  u'the',
#  u'of',
#  u'a',
#  u'good',
#  u'of',
#  u'great',
#  u'of',
#  u'.',
#  u'good',
#  u'of',
#  u'the',
#  u'shallow',
#  u'of',
#  u'a',
#  u'nice',
#  u'of']

# %%
aspects = []

for key in asin_dict:
    for aspect, freq in asin_dict[key]['sorted_aspects']:
        aspects.append(aspect)
        
aspects_cnt = Counter(aspects)

# %%
aspects_cnt.most_common()
# Out:
# [(u'product', 51),
#  (u'price', 51),
#  (u'problem', 50),
#  (u'issue', 43),
#  (u'year', 42),
#  (u'quality', 39),
#  (u'device', 38),
#  (u'review', 37),
#  (u'computer', 31),
#  (u'month', 27),
#  (u'cable', 27),
#  (u'picture', 23),
#  (u'speed', 22),
#  (u'video', 22),
#  (u'size', 21),
#  (u'brand', 21),
#  (u'box', 20),
#  (u'usb', 20),
#  (u'phone', 19),
#  (u'item', 19),
#  (u'unit', 18),
#  (u'connection', 18),
#  (u'space', 17),
#  (u'money', 17),
#  (u'tv', 17),
#  (u'bit', 17),
#  (u'music', 16),
#  (u'cord', 16),
#  (u'port', 16),
#  (u'file', 16),
#  (u'power', 16),
#  (u'player', 15),
#  (u'laptop', 15),
#  (u'data', 15),
#  (u'storage', 15),
#  (u'hd', 15),
#  (u'pc', 14),
#  (u'gb', 14),
#  (u'capacity', 13),
#  (u'high quality', 13),
#  (u'photo', 13),
#  (u'star', 13),
#  (u'screen', 13),
#  (u'case', 13),
#  (u'usb port', 13),
#  (u'signal', 13),
#  (u'sound', 12),
#  (u'system', 12),
#  (u'job', 12),
#  (u'room', 11),
#  (u'feature', 11),
#  (u'memory', 11),
#  (u'hdmi cable', 11),
#  (u'drive', 11),
#  (u'store', 11),
#  (u'movie', 11),
#  (u'camera', 11),
#  (u'light', 11),
#  (u'software', 11),
#  (u'transfer', 11),
#  (u'end', 10),
#  (u'adapter', 10),
#  (u'battery', 10),
#  (u'audio', 10),
#  (u'setup', 9),
#  (u'service', 9),
#  (u'amazon', 9),
#  (u'everything', 9),
#  (u'usb cable', 9),
#  (u'card', 9),
#  (u'charger', 9),
#  (u'difference', 9),
#  (u'foot', 9),
#  (u'purchase cable', 9),
#  (u'tablet', 9),
#  (u'buy cable', 9),
#  (u'hdmi', 9),
#  (u'length', 9),
#  (u'hard drive', 9),
#  (u'cell phone', 8),
#  (u'network', 8),
#  (u'cable quality', 8),
#  (u'life', 8),
#  (u'cheap cable', 8),
#  (u'charge', 8),
#  (u'ray player', 8),
#  (u'design', 8),
#  (u'home', 8),
#  (u'picture quality', 8),
#  (u'write speed', 8),
#  (u'ray', 7),
#  (u'receiver', 7),
#  (u'plug', 7),
#  (u'support', 7),
#  (u'memory card', 7),
#  (u'flash', 7),
#  (u'minute', 7),
#  (u'connector', 7),
#  (u'sd', 7),
#  (u'internet', 7),
#  (u'installation', 7),
#  (u'blu player', 7),
#  (u'high cable', 7),
#  (u'week', 7),
#  (u'model', 7),
#  (u'wifi', 7),
#  (u'disk', 7),
#  (u'hour', 7),
#  (u'button', 7),
#  (u'sound quality', 7),
#  (u'amazon cable', 7),
#  (u'sd card', 7),
#  (u'transfer file', 7),
#  (u'buy card', 6),
#  (u'medium', 6),
#  (u'wireless', 6),
#  (u'battery life', 6),
#  (u'price cable', 6),
#  (u'monster cable', 6),
#  (u'usb drive', 6),
#  (u'set', 6),
#  (u'transfer speed', 6),
#  (u'ipad', 6),
#  (u'class', 6),
#  (u'wire', 6),
#  (u'wall', 6),
#  (u'expensive cable', 6),
#  (u'headphone', 6),
#  (u'sound picture', 5),
#  (u'sandisk', 5),
#  (u'machine', 5),
#  (u'content', 5),
#  (u'sandisk product', 5),
#  (u'high speed', 5),
#  (u'amazonbasics cable', 5),
#  (u'charge phone', 5),
#  (u'deal', 5),
#  (u'apple tv', 5),
#  (u'flash card', 5),
#  (u'car', 5),
#  (u'window', 5),
#  (u'router', 5),
#  (u'performance', 5),
#  (u'color', 5),
#  (u'side', 5),
#  (u'video picture', 5),
#  (u'remote', 5),
#  (u'version', 5),
#  (u'come cable', 5),
#  (u'house', 5),
#  (u'build quality', 5),
#  (u'price quality', 5),
#  (u'brand cable', 5),
#  (u'windows', 5),
#  (u'connect cable', 5),
#  (u'audio video', 5),
#  (u'range', 5),
#  (u'roku', 5),
#  (u'app', 5),
#  (u'customer', 5),
#  (u'control', 5),
#  (u'purchase card', 5),
#  (u'digital camera', 5),
#  (u'ear', 5),
#  (u'android', 5),
#  (u'cable box', 5),
#  (u'usb charger', 5),
#  (u'apps', 5),
#  (u'buy', 5),
#  (u'volume', 5),
#  (u'watch movie', 4),
#  (u'fit', 4),
#  (u'tablet phone', 4),
#  (u'reader', 4),
#  (u'amazon video', 4),
#  (u'microsd card', 4),
#  (u'protection', 4),
#  (u'external drive', 4),
#  (u'mouse', 4),
#  (u'trip', 4),
#  (u'cost', 4),
#  (u'iphone', 4),
#  (u'blue light', 4),
#  (u'plastic', 4),
#  (u'channel', 4),
#  (u'shot', 4),
#  (u'hdd', 4),
#  (u'desktop', 4),
#  (u'backup', 4),
#  (u'image', 4),
#  (u'company', 4),
#  (u'charge device', 4),
#  (u'hdmi quality', 4),
#  (u'cable end', 4),
#  (u'sandisk card', 4),
#  (u'bass', 4),
#  (u'micro card', 4),
#  (u'option', 4),
#  (u'micro sd', 4),
#  (u'flash drive', 4),
#  (u'streaming', 4),
#  (u'class card', 4),
#  (u'thumb drive', 4),
#  (u'stream video', 4),
#  (u'apple', 4),
#  (u'sdhc card', 4),
#  (u'dvd player', 4),
#  (u'buy drive', 4),
#  (u'blu ray', 4),
#  (u'gb card', 4),
#  (u'smart tv', 4),
#  (u'packaging', 4),
#  (u'listen music', 4),
#  (u'noise', 4),
#  (u'car charger', 3),
#  (u'wd drive', 3),
#  (u'hdtv', 3),
#  (u'second', 3),
#  (u'glass', 3),
#  (u'sata', 3),
#  (u'camera card', 3),
#  (u'keyboard', 3),
#  (u'strength', 3),
#  (u'firmware', 3),
#  (u'macbook', 3),
#  (u'metal', 3),
#  (u'long cable', 3),
#  (u'bag', 3),
#  (u'finger', 3),
#  (u'customer service', 3),
#  (u'air', 3),
#  (u'low price', 3),
#  (u'tv show', 3),
#  (u'phone card', 3),
#  (u'digital', 3),
#  (u'cable speed', 3),
#  (u'small drive', 3),
#  (u'apple product', 3),
#  (u'cap', 3),
#  (u'nice cable', 3),
#  (u'android phone', 3),
#  (u'mac', 3),
#  (u'32gb card', 3),
#  (u'thumb', 3),
#  (u'video camera', 3),
#  (u'ear bud', 3),
#  (u'watch video', 3),
#  (u'buy charger', 3),
#  (u'hulu', 3),
#  (u'ring', 3),
#  (u'wireless router', 3),
#  (u'pair', 3),
#  (u'show', 3),
#  (u'slot', 3),
#  (u'outlet', 3),
#  (u'ssd', 3),
#  (u'big box', 3),
#  (u'western digital', 3),
#  (u'touch', 3),
#  (u'backup drive', 3),
#  (u'hd video', 3),
#  (u'name brand', 3),
#  (u'antenna', 3),
#  (u'tb', 3),
#  (u'earbuds', 3),
#  (u'stick', 3),
#  (u'read review', 3),
#  (u'wireless mouse', 3),
#  (u'watch tv', 3),
#  (u'stream content', 3),
#  (u'instruction', 3),
#  (u'kindle', 3),
#  (u'signal strength', 3),
#  (u'cover', 3),
#  (u'box store', 3),
#  (u'interface', 3),
#  (u'protector', 3),
#  (u'fast drive', 3),
#  (u'hdmi speed', 3),
#  (u'charge charger', 3),
#  (u'pack', 3),
#  (u'kindle fire', 3),
#  (u'large file', 3),
#  (u'dslr', 3),
#  (u'netflix', 3),
#  (u'application', 3),
#  (u'gp', 3),
#  (u'big store', 3),
#  (u'3d', 3),
#  (u'fast charge', 3),
#  (u'32gb', 3),
#  (u'ipod', 3),
#  (u'instal drive', 3),
#  (u'fast card', 3),
#  (u'usb device', 3),
#  (u'logitech', 3),
#  (u'hdmi cord', 3),
#  (u'usb plug', 3),
#  (u'canon camera', 3),
#  (u'key', 3),
#  (u'piece', 3),
#  (u'old drive', 3),
#  (u'kingston', 3),
#  (u'controller', 3),
#  (u'value', 3),
#  (u'speaker', 3),
#  (u'flash memory', 3),
#  (u'microsd', 3),
#  (u'desk', 3),
#  (u'replacement', 3),
#  (u'micro usb', 3),
#  (u'charge cable', 3),
#  (u'bud', 3),
#  (u'hand', 3),
#  (u'best buy', 3),
#  (u'book', 3),
#  (u'tv screen', 2),
#  (u'jack', 2),
#  (u'monster', 2),
#  (u'digital signal', 2),
#  (u'remote control', 2),
#  (u'charge port', 2),
#  (u'hole', 2),
#  (u'install', 2),
#  (u'card reader', 2),
#  (u'buy kindle', 2),
#  (u'mediabridge cable', 2),
#  (u'purchase', 2),
#  (u'tb drive', 2),
#  (u'fail drive', 2),
#  (u'usb power', 2),
#  (u'logitech keyboard', 2),
#  (u'gb drive', 2),
#  (u'cable modem', 2),
#  (u'ram', 2),
#  (u'cable tv', 2),
#  (u'wireless network', 2),
#  (u'tech', 2),
#  (u'radio', 2),
#  (u'bar', 2),
#  (u'wd', 2),
#  (u'wireless keyboard', 2),
#  (u'flash usb', 2),
#  (u'left button', 2),
#  (u'ear phone', 2),
#  (u'amazon netflix', 2),
#  (u'digital cable', 2),
#  (u'charge usb', 2),
#  (u'reasonable price', 2),
#  (u'bottom', 2),
#  (u'replace cable', 2),
#  (u'call', 2),
#  (u'roku device', 2),
#  (u'update', 2),
#  (u'phone charger', 2),
#  (u'level', 2),
#  (u'ssd drive', 2),
#  (u'replace drive', 2),
#  (u'card class', 2),
#  (u'address', 2),
#  (u'time boot', 2),
#  (u'full charge', 2),
#  (u'earphone', 2),
#  (u'solid drive', 2),
#  (u'free channel', 2),
#  (u'excellent quality', 2),
#  (u'hd. fire', 2),
#  (u'headphone jack', 2),
#  (u'easy setup', 2),
#  (u'sensor', 2),
#  (u'place', 2),
#  (u'fit case', 2),
#  (u'pro', 2),
#  (u'external power', 2),
#  (u'apple device', 2),
#  (u'upgrade', 2),
#  (u'buy roku', 2),
#  (u'high capacity', 2),
#  (u'reading', 2),
#  (u'internal drive', 2),
#  (u'50mm lens', 2),
#  (u'show movie', 2),
#  (u'power adapter', 2),
#  (u'mount', 2),
#  (u'canon', 2),
#  (u'roku player', 2),
#  (u'play music', 2),
#  (u'buy pair', 2),
#  (u'mediabridge product', 2),
#  (u'hdmi port', 2),
#  (u'small ear', 2),
#  (u'modem', 2),
#  (u'amp', 2),
#  (u'part', 2),
#  (u'state drive', 2),
#  (u'save money', 2),
#  (u'rubber', 2),
#  (u'reception', 2),
#  (u'ssds', 2),
#  (u'program', 2),
#  (u'song', 2),
#  (u'link', 2),
#  (u'last battery', 2),
#  (u'ago year', 2),
#  (u'tv movie', 2),
#  (u'pad', 2),
#  (u'strong signal', 2),
#  (u'fast speed', 2),
#  (u'sound system', 2),
#  (u'kingston product', 2),
#  (u'base', 2),
#  (u'instant video', 2),
#  (u'usb cord', 2),
#  (u'macbook pro', 2),
#  (u'foot cable', 2),
#  (u'oem cable', 2),
#  (u'small size', 2),
#  (u'microsdhc card', 2),
#  (u'button click', 2),
#  (u'fire', 2),
#  (u'roku channel', 2),
#  (u'user', 2),
#  (u'ear fit', 2),
#  (u'sdhc class', 2),
#  (u'input', 2),
#  (u'sd adapter', 2),
#  (u'vehicle', 2),
#  (u'lens', 2),
#  (u'dvd', 2),
#  (u'youtube', 2),
#  (u'5 iphone', 2),
#  (u'scratch', 2),
#  (u'click', 2),
#  (u'access', 2),
#  (u'mp3 player', 2),
#  (u'extension cable', 2),
#  (u'account', 2),
#  (u'smart phone', 2),
#  (u'wall charger', 2),
#  (u'big screen', 2),
#  (u'pocket', 2),
#  (u'element', 2),
#  (u'camera lens', 2),
#  (u'mode', 2),
#  (u'canon lens', 2),
#  (u'hdmi buy', 2),
#  (u'roku box', 2),
#  (u'prong', 2),
#  (u'mbps', 2),
#  (u'usb stick', 2),
#  (u'buy lens', 2),
#  (u'kindle hd', 2),
#  (u'usb receiver', 2),
#  (u'fire hd', 2),
#  (u'reader card', 2),
#  (u'email', 2),
#  (u'monitor', 2),
#  (u'cd', 2),
#  (u'amazon product', 2),
#  (u'card speed', 2),
#  (u'ball', 2),
#  (u'cruzer', 2),
#  (u'web', 2),
#  (u'motorola', 2),
#  (u'glare', 2),
#  (u'blue ray', 2),
#  (u'socket', 2),
#  (u'shipping', 2),
#  (u'warranty', 2),
#  (u'come mount', 2),
#  (u'boot drive', 2),
#  (u'old laptop', 2),
#  (u'boot', 2),
#  (u'data transfer', 2),
#  (u'samsung', 2),
#  (u'd battery', 1),
#  (u'white side', 1),
#  (u'dual port', 1),
#  (u'50mm', 1),
#  (u'portable drive', 1),
#  (u'old speaker', 1),
#  (u'kit lens', 1),
#  (u'short cable', 1),
#  (u'car stereo', 1),
#  (u'charge hd', 1),
#  (u'drive data', 1),
#  (u'galaxy tab', 1),
#  (u'fit cable', 1),
#  (u'garmin unit', 1),
#  (u'move part', 1),
#  (u'add channel', 1),
#  (u'nikon camera', 1),
#  (u'follow instruction', 1),
#  (u'extend cable', 1),
#  (u'itunes', 1),
#  (u'backup software', 1),
#  (u'light lens', 1),
#  (u'sound speaker', 1),
#  (u'fit cover', 1),
#  (u'bluetooth device', 1),
#  (u'lightning end', 1),
#  (u'm4', 1),
#  (u'comcast', 1),
#  (u'passport', 1),
#  (u'purchase battery', 1),
#  (u'wireless signal', 1),
#  (u'stream device', 1),
#  (u'indoor antenna', 1),
#  (u'price mount', 1),
#  (u'scratch lens', 1),
#  (u'power outlet', 1),
#  (u'original kindle', 1),
#  (u'modem fee', 1),
#  (u'charging', 1),
#  (u'gp unit', 1),
#  (u'low light', 1),
#  (u'bean bag', 1),
#  (u'ethernet', 1),
#  (u'office', 1),
#  (u'windshield', 1),
#  (u'ultra sandisk', 1),
#  (u'bluetooth headset', 1),
#  (u'jbuds', 1),
#  (u'original charger', 1),
#  (u'ios device', 1),
#  (u'rental car', 1),
#  (u'lens protection', 1),
#  (u'tiffen filter', 1),
#  (u'usb adapter', 1),
#  (u'band', 1),
#  (u'chrome tab', 1),
#  (u'lease modem', 1),
#  (u'rental', 1),
#  (u'turn cover', 1),
#  (u'turn volume', 1),
#  (u'wire version', 1),
#  (u'amazon cover', 1),
#  (u'cover lens', 1),
#  (u'arrow', 1),
#  (u'bluerigger cable', 1),
#  (u'aaa aa', 1),
#  (u'wireless card', 1),
#  (u'logo', 1),
#  (u'light situation', 1),
#  (u'youtube video', 1),
#  (u'crucial', 1),
#  (u'itunes library', 1),
#  (u'end usb', 1),
#  (u'kingston drive', 1),
#  (u'isp', 1),
#  (u'extra length', 1),
#  (u'filter', 1),
#  (u'perfect fit', 1),
#  (u'puck', 1),
#  (u'phone screen', 1),
#  (u'thumb ball', 1),
#  (u'solid metal', 1),
#  (u'usb sata', 1),
#  (u'surge protector', 1),
#  (u'plug device', 1),
#  (u'shoot video', 1),
#  (u'usb hub', 1),
#  (u'bokeh', 1),
#  (u'touch pad', 1),
#  (u'small key', 1),
#  (u'buy keyboard', 1),
#  (u'bottom screw', 1),
#  (u'rapid rate', 1),
#  (u'switch cable', 1),
#  (u'mini', 1),
#  (u'rapid charger', 1),
#  (u'uv filter', 1),
#  (u'track ball', 1),
#  (u'wall stud', 1),
#  (u'ip address', 1),
#  (u'cordless phone', 1),
#  (u'metal casing', 1),
#  (u'htpc keyboard', 1),
#  (u'tv port', 1),
#  (u'bracket', 1),
#  (u'test speed', 1),
#  (u'point access', 1),
#  (u'lightning usb', 1),
#  (u'phone protector', 1),
#  (u'scroll wheel', 1),
#  (u'docsis', 1),
#  (u'hdmi tv', 1),
#  (u'menu', 1),
#  (u'hotel room', 1),
#  (u'solid cable', 1),
#  (u'folder', 1),
#  (u'portable mount', 1),
#  (u'print finger', 1),
#  (u'samsung drive', 1),
#  (u'surround system', 1),
#  (u'format card', 1),
#  (u'windshield mark', 1),
#  (u'sound headphone', 1),
#  (u'kindle leather', 1),
#  (u'retail packaging', 1),
#  (u'extension cord', 1),
#  (u'subject', 1),
#  (u'cheetah mount', 1),
#  (u'satellite speaker', 1),
#  (u'regular mouse', 1),
#  (u'seagate drive', 1),
#  (u'crucial drive', 1),
#  (u'mount wall', 1),
#  (u'screen protector', 1),
#  (u'prime video', 1),
#  (u'old router', 1),
#  (u'perfectly kindle', 1),
#  (u'customer support', 1),
#  (u'outdoor antenna', 1),
#  (u'tone', 1),
#  (u'chrome', 1),
#  (u'mediabridge hdmi', 1),
#  (u'car usb', 1),
#  (u'medialink router', 1),
#  (u'buy battery', 1),
#  (u'dashboard', 1),
#  (u'voice', 1),
#  (u'garmin gp', 1),
#  (u'ip', 1),
#  (u'multi touch', 1),
#  (u'motorola charger', 1),
#  (u'add weight', 1),
#  (u'charge iphone', 1),
#  (u'wheel', 1),
#  (u'satellite', 1),
#  (u'raid', 1),
#  (u'rabbit ear', 1),
#  (u'kit', 1),
#  (u'cycle', 1),
#  (u'linksys', 1),
#  (u'acoustics', 1),
#  (u'background', 1),
#  (u'read speed', 1),
#  (u'nuvi', 1),
#  (u'mount friction', 1),
#  (u'mount dash', 1),
#  (u'video photo', 1),
#  (u'photographer', 1),
#  (u'turn tv', 1),
#  (u'rent modem', 1),
#  (u'plasma', 1),
#  (u'netgear router', 1),
#  (u'lcd', 1),
#  (u'logitech software', 1),
#  (u'cheap apple', 1),
#  (u'lightning connector', 1),
#  (u'zoom', 1),
#  (u'xbox', 1),
#  (u'old antenna', 1),
#  (u'power device', 1),
#  (u'n wireless', 1),
#  (u'm570', 1),
#  (u'tp link', 1),
#  (u'move mouse', 1),
#  (u'self discharge', 1),
#  (u'reflection', 1),
#  (u'purchase router', 1),
#  (u'bolt', 1),
#  (u'htpc', 1),
#  (u'drop connection', 1),
#  (u'micro charger', 1),
#  (u'mouse button', 1),
#  (u'excellent cable', 1),
#  (u'kindle cover', 1),
#  (u'canon 50mm', 1),
#  (u'appletv', 1),
#  (u'cost cable', 1),
#  (u'buy ssd', 1),
#  (u'rental fee', 1),
#  (u'failure', 1),
#  (u'cool light', 1),
#  (u'plastic cap', 1),
#  (u'price range', 1),
#  (u'rend modem', 1),
#  (u'mohu leaf', 1),
#  (u'privacy screen', 1),
#  (u'kindle fit', 1),
#  (u'optical audio', 1),
#  (u'floor', 1),
#  (u'kindle charger', 1),
#  (u'setting', 1),
#  (u'amazon hdmi', 1),
#  (u'test', 1),
#  (u'power button', 1),
#  (u'put filter', 1),
#  (u'discharge', 1),
#  (u'rechargeables', 1),
#  (u'barracuda', 1),
#  (u'soundbar', 1),
#  (u'chain', 1),
#  (u'focus', 1),
#  (u'switcher', 1),
#  (u'phone case', 1),
#  (u'mile', 1),
#  (u'card adapter', 1),
#  (u'tilt', 1),
#  (u'tv input', 1),
#  (u'left mouse', 1),
#  (u'different size', 1),
#  (u'hdmi output', 1),
#  (u'purchase kindle', 1),
#  (u'price filter', 1),
#  (u'mechanical drive', 1),
#  (u'apple price', 1),
#  (u'magnet', 1),
#  (u'droid', 1),
#  (u'solid state', 1),
#  (u'buy antenna', 1),
#  (u'mount dashboard', 1),
#  (u'wall plug', 1),
#  (u'headset', 1),
#  (u'movie show', 1),
#  (u'recommend lens', 1),
#  (u'led tv', 1),
#  (u'apple charge', 1),
#  (u'buck', 1),
#  (u'lightning cable', 1),
#  (u'shift', 1),
#  (u'sb6121', 1),
#  (u'home theater', 1),
#  (u'clear sound', 1),
#  (u'ear piece', 1),
#  (u'mohu antenna', 1),
#  (u'audio cable', 1),
#  (u'aaa battery', 1),
#  (u'nice cover', 1),
#  (u'price lens', 1),
#  (u'old battery', 1),
#  (u'ir remote', 1),
#  (u'long charge', 1),
#  (u'chip', 1),
#  (u'iphone screen', 1),
#  (u'anti glare', 1),
#  (u'inch tv', 1),
#  (u's4', 1),
#  (u'roku xs', 1),
#  (u'flat screen', 1),
#  (u'clone', 1),
#  (u'spot', 1),
#  (u'storage drive', 1),
#  (u'mah', 1),
#  (u'neck', 1),
#  (u'switch', 1),
#  (u'scan channel', 1),
#  (u'travel', 1),
#  (u'fold prong', 1),
#  (u'auto focus', 1),
#  (u'nimh', 1),
#  (u'wifi adapter', 1),
#  (u'sub woofer', 1),
#  (u'black side', 1),
#  (u'full size', 1),
#  (u'name', 1),
#  (u'prime lens', 1),
#  (u'screen scratch', 1),
#  (u'mount gp', 1),
#  (u'xbox controller', 1),
#  (u'fit paperwhite', 1),
#  (u'windshield mount', 1),
#  (u'outside noise', 1),
#  (u'clear protector', 1),
#  (u'provide protection', 1),
#  (u'eneloops', 1),
#  (u'flare', 1),
#  (u'tiffen', 1),
#  (u'turn', 1),
#  (u'sansa', 1),
#  (u'power supply', 1),
#  (u'quality lens', 1),
#  (u'play video', 1),
#  (u'xx', 1),
#  (u'city', 1),
#  (u'mini cd', 1),
#  (u'tv mount', 1),
#  (u'drill hole', 1),
#  (u'typing', 1),
#  (u'chromecast app', 1),
#  (u'hub', 1),
#  (u'broadcast', 1),
#  (u'quality cable', 1),
#  (u'passport drive', 1),
#  (u'sound surround', 1),
#  (u'holder', 1),
#  (u'include software', 1),
#  (u'elements drive', 1),
#  (u'galaxy note', 1),
#  (u'browser', 1),
#  (u'dash', 1),
#  (u'stick drive', 1),
#  (u'bass volume', 1),
#  (u'fit lens', 1),
#  (u'note', 1),
#  (u'laptop keyboard', 1),
#  (u'wide aperture', 1),
#  (u'switching', 1),
#  (u'printer', 1),
#  (u'pain', 1),
#  (u'protect lens', 1),
#  (u'price sound', 1),
#  (u'old adapter', 1),
#  (u'friction', 1),
#  (u'wi fi', 1),
#  (u'phone call', 1),
#  (u'bubble level', 1),
#  (u'air bubble', 1),
#  (u'hdmi input', 1),
#  (u'hoya', 1),
#  (u'include level', 1),
#  (u'iphone charge', 1),
#  (u'aluminum', 1),
#  (u'leather', 1),
#  (u'link adapter', 1),
#  (u'purchase lens', 1),
#  (u'hd channel', 1),
#  (u'seat', 1),
#  (u'support apps', 1),
#  (u'sandisk drive', 1),
#  (u'push button', 1),
#  (u'noise reduction', 1),
#  (u'tech armor', 1),
#  (u'cheap filter', 1),
#  (u'living room', 1),
#  (u'come level', 1),
#  (u'usb charge', 1),
#  (u'phone cable', 1),
#  (u'hold tv', 1),
#  (u'plug outlet', 1),
#  (u'pod', 1),
#  (u'mark', 1),
#  (u'quality product', 1),
#  (u'windows boot', 1),
#  (u'try antenna', 1),
#  (u'external', 1),
#  (u'situation', 1),
#  (u'old modem', 1),
#  (u'eneloop battery', 1),
#  (u'toslink cable', 1),
#  (u'original fire', 1),
#  (u'mouse keyboard', 1),
#  (u'document', 1),
#  (u'finish', 1),
#  (u'power source', 1),
#  (u'driver', 1),
#  (u'credit card', 1),
#  (u'key arrow', 1),
#  (u'key chain', 1),
#  (u'front element', 1),
#  (u'time modem', 1),
#  (u'hdmi switch', 1),
#  (u'cheap lens', 1),
#  (u'own modem', 1),
#  (u'nas', 1),
#  (u'iphones', 1),
#  (u'suction cup', 1),
#  (u'touchpad', 1),
#  (u'oem charger', 1),
#  (u'apple cord', 1),
#  (u'server', 1),
#  (u'loop', 1),
#  (u'original cable', 1),
#  (u'tower', 1),
#  (u'surge protection', 1),
#  (u'apple cable', 1),
#  (u'buy speaker', 1),
#  (u'galaxy s3', 1),
#  (u'galaxy s4', 1),
#  (u'replace router', 1),
#  (u'surge outlet', 1),
#  (u'wireless trackball', 1),
#  (u'provider', 1),
#  (u'comcast service', 1),
#  (u'front lens', 1),
#  (u'alkaline battery', 1),
#  (u'optical cable', 1),
#  (u'small speaker', 1),
#  (u'package', 1),
#  (u'usb protector', 1),
#  (u'transfer data', 1),
#  (u'strip', 1),
#  (u'protect element', 1),
#  (u'mini protector', 1),
#  (u'weight', 1),
#  (u'3tb', 1),
#  (u'hdmi device', 1),
#  (u'theater system', 1),
#  (u'bubble', 1),
#  (u'hdmi switcher', 1),
#  (u'nikon lens', 1),
#  (u'replace battery', 1),
#  (u'aa', 1),
#  (u'fold cover', 1),
#  (u'ad', 1),
#  (u'lint', 1),
#  (u'local station', 1),
#  (u'film', 1),
#  (u'field', 1),
#  (u'internet provider', 1),
#  (u'photo video', 1),
#  (u'purchase modem', 1),
#  (u'logitech product', 1),
#  (u'wife', 1),
#  (u'comcast modem', 1),
#  (u'keep charge', 1),
#  (u'dollar', 1),
#  (u'mp3', 1),
#  (u'come bud', 1),
#  (u'sansa clip', 1),
#  (u'mount bracket', 1),
#  (u'leather cover', 1),
#  (u'come battery', 1),
#  (u'car charge', 1),
#  (u'sony', 1),
#  (u'buy set', 1),
#  (u'dongle', 1),
#  (u'rca antenna', 1),
#  (u'long trip', 1),
#  (u'long battery', 1),
#  (u'drop signal', 1),
#  (u'rate', 1),
#  (u'magician software', 1),
#  (u'optic cable', 1),
#  (u'sub', 1),
#  (u'movement', 1),
#  (u'garmin mount', 1),
#  (u'eneloop', 1),
#  (u'experience', 1),
#  (u'function key', 1),
#  (u'camcorder', 1),
#  (u'shuffle', 1),
#  (u'n router', 1),
#  (u'usb speed', 1),
#  (u'internet service', 1),
#  (u'aperture', 1),
#  (u'k400', 1),
#  (u'internet cable', 1),
#  (u'rental modem', 1),
#  (u'price card', 1),
#  (u'transcend', 1),
#  (u'wd passport', 1),
#  (u'key shift', 1),
#  (u'year trackball', 1),
#  (u'migration software', 1),
#  (u'fi', 1),
#  (u'netflix prime', 1),
#  (u'zoom lens', 1),
#  (u'forward button', 1),
#  (u'recommend cable', 1),
#  (u'micro connector', 1),
#  (u'paper', 1),
#  (u'second boot', 1),
#  (u'user interface', 1),
#  (u'coat filter', 1),
#  (u'pay modem', 1),
#  (u'old camera', 1),
#  (u'ear size', 1),
#  (u'apple version', 1),
#  (u'read book', 1),
#  (u'nimh battery', 1),
#  (u'l lens', 1),
#  (u'brand charger', 1),
#  (u'car gp', 1),
#  (u'amplify antenna', 1),
#  (u'full keyboard', 1),
#  (u'road trip', 1),
#  (u'sound bar', 1),
#  (u'music player', 1),
#  (u'roku tv', 1),
#  (u'cancel noise', 1),
#  (u'fiber', 1),
#  (u'reason', 1),
#  (u'wireless version', 1),
#  (u'auto switch', 1),
#  (u'tv wall', 1),
#  (u'tiny drive', 1),
#  (u'save lens', 1),
#  (u'number', 1),
#  (u'kindle plug', 1),
#  (u'lens element', 1),
#  (u'year battery', 1),
#  (u'receive channel', 1),
#  (u'station', 1),
#  (u'hotel', 1),
#  (u'optical', 1),
#  (u'surfboard', 1),
#  (u'google play', 1),
#  (u'aaa', 1),
#  (u'mount cup', 1),
#  (u'computer speaker', 1),
#  (u'track pad', 1),
#  (u'keyboard size', 1),
#  (u'iphone cable', 1),
#  (u'download', 1),
#  (u'small keyboard', 1),
#  (u'old linksys', 1),
#  (u'uv protection', 1),
#  ...]

# %%
bigram_aspects = []

for key in asin_dict:
    for aspect, freq in asin_dict[key]['sorted_aspects']:
        if len(aspect.split(" ")) == 2:
            bigram_aspects.append(aspect)
        
bigram_aspects_cnt = Counter(bigram_aspects)

# %%
bigram_aspects_cnt.most_common()
# Out:
# [(u'usb port', 13),
#  (u'high quality', 13),
#  (u'hdmi cable', 11),
#  (u'hard drive', 9),
#  (u'usb cable', 9),
#  (u'purchase cable', 9),
#  (u'buy cable', 9),
#  (u'cell phone', 8),
#  (u'ray player', 8),
#  (u'cable quality', 8),
#  (u'picture quality', 8),
#  (u'write speed', 8),
#  (u'cheap cable', 8),
#  (u'sd card', 7),
#  (u'transfer file', 7),
#  (u'blu player', 7),
#  (u'sound quality', 7),
#  (u'high cable', 7),
#  (u'amazon cable', 7),
#  (u'memory card', 7),
#  (u'usb drive', 6),
#  (u'transfer speed', 6),
#  (u'battery life', 6),
#  (u'price cable', 6),
#  (u'buy card', 6),
#  (u'monster cable', 6),
#  (u'expensive cable', 6),
#  (u'apple tv', 5),
#  (u'sound picture', 5),
#  (u'flash card', 5),
#  (u'come cable', 5),
#  (u'build quality', 5),
#  (u'purchase card', 5),
#  (u'sandisk product', 5),
#  (u'price quality', 5),
#  (u'digital camera', 5),
#  (u'brand cable', 5),
#  (u'high speed', 5),
#  (u'amazonbasics cable', 5),
#  (u'charge phone', 5),
#  (u'connect cable', 5),
#  (u'cable box', 5),
#  (u'audio video', 5),
#  (u'usb charger', 5),
#  (u'video picture', 5),
#  (u'class card', 4),
#  (u'thumb drive', 4),
#  (u'watch movie', 4),
#  (u'stream video', 4),
#  (u'charge device', 4),
#  (u'hdmi quality', 4),
#  (u'microsd card', 4),
#  (u'cable end', 4),
#  (u'sdhc card', 4),
#  (u'tablet phone', 4),
#  (u'sandisk card', 4),
#  (u'dvd player', 4),
#  (u'micro card', 4),
#  (u'amazon video', 4),
#  (u'buy drive', 4),
#  (u'blu ray', 4),
#  (u'gb card', 4),
#  (u'micro sd', 4),
#  (u'blue light', 4),
#  (u'smart tv', 4),
#  (u'external drive', 4),
#  (u'flash drive', 4),
#  (u'listen music', 4),
#  (u'car charger', 3),
#  (u'wd drive', 3),
#  (u'big store', 3),
#  (u'cable speed', 3),
#  (u'apple product', 3),
#  (u'small drive', 3),
#  (u'fast charge', 3),
#  (u'android phone', 3),
#  (u'camera card', 3),
#  (u'hdmi speed', 3),
#  (u'kindle fire', 3),
#  (u'read review', 3),
#  (u'nice cable', 3),
#  (u'ear bud', 3),
#  (u'buy charger', 3),
#  (u'hd video', 3),
#  (u'wireless mouse', 3),
#  (u'instal drive', 3),
#  (u'watch tv', 3),
#  (u'stream content', 3),
#  (u'fast card', 3),
#  (u'wireless router', 3),
#  (u'usb device', 3),
#  (u'signal strength', 3),
#  (u'hdmi cord', 3),
#  (u'usb plug', 3),
#  (u'canon camera', 3),
#  (u'long cable', 3),
#  (u'low price', 3),
#  (u'box store', 3),
#  (u'32gb card', 3),
#  (u'customer service', 3),
#  (u'old drive', 3),
#  (u'fast drive', 3),
#  (u'big box', 3),
#  (u'large file', 3),
#  (u'western digital', 3),
#  (u'video camera', 3),
#  (u'tv show', 3),
#  (u'phone card', 3),
#  (u'micro usb', 3),
#  (u'flash memory', 3),
#  (u'charge cable', 3),
#  (u'name brand', 3),
#  (u'backup drive', 3),
#  (u'best buy', 3),
#  (u'watch video', 3),
#  (u'charge charger', 3),
#  (u'old laptop', 2),
#  (u'tv screen', 2),
#  (u'ssd drive', 2),
#  (u'replace drive', 2),
#  (u'card class', 2),
#  (u'digital signal', 2),
#  (u'remote control', 2),
#  (u'mp3 player', 2),
#  (u'time boot', 2),
#  (u'charge port', 2),
#  (u'extension cable', 2),
#  (u'full charge', 2),
#  (u'ear phone', 2),
#  (u'last battery', 2),
#  (u'ago year', 2),
#  (u'card reader', 2),
#  (u'smart phone', 2),
#  (u'headphone jack', 2),
#  (u'solid drive', 2),
#  (u'wall charger', 2),
#  (u'big screen', 2),
#  (u'buy kindle', 2),
#  (u'mediabridge cable', 2),
#  (u'free channel', 2),
#  (u'excellent quality', 2),
#  (u'hd. fire', 2),
#  (u'tv movie', 2),
#  (u'camera lens', 2),
#  (u'tb drive', 2),
#  (u'mediabridge product', 2),
#  (u'strong signal', 2),
#  (u'easy setup', 2),
#  (u'canon lens', 2),
#  (u'fast speed', 2),
#  (u'reader card', 2),
#  (u'hdmi buy', 2),
#  (u'sound system', 2),
#  (u'kingston product', 2),
#  (u'reasonable price', 2),
#  (u'usb power', 2),
#  (u'logitech keyboard', 2),
#  (u'gb drive', 2),
#  (u'fit case', 2),
#  (u'cable modem', 2),
#  (u'instant video', 2),
#  (u'usb stick', 2),
#  (u'usb cord', 2),
#  (u'macbook pro', 2),
#  (u'cable tv', 2),
#  (u'wireless network', 2),
#  (u'buy lens', 2),
#  (u'foot cable', 2),
#  (u'kindle hd', 2),
#  (u'external power', 2),
#  (u'apple device', 2),
#  (u'oem cable', 2),
#  (u'small size', 2),
#  (u'5 iphone', 2),
#  (u'usb receiver', 2),
#  (u'fire hd', 2),
#  (u'buy roku', 2),
#  (u'wireless keyboard', 2),
#  (u'high capacity', 2),
#  (u'flash usb', 2),
#  (u'microsdhc card', 2),
#  (u'left button', 2),
#  (u'internal drive', 2),
#  (u'button click', 2),
#  (u'50mm lens', 2),
#  (u'amazon product', 2),
#  (u'show movie', 2),
#  (u'card speed', 2),
#  (u'power adapter', 2),
#  (u'roku player', 2),
#  (u'play music', 2),
#  (u'amazon netflix', 2),
#  (u'come mount', 2),
#  (u'buy pair', 2),
#  (u'roku channel', 2),
#  (u'digital cable', 2),
#  (u'hdmi port', 2),
#  (u'small ear', 2),
#  (u'ear fit', 2),
#  (u'sdhc class', 2),
#  (u'charge usb', 2),
#  (u'blue ray', 2),
#  (u'sd adapter', 2),
#  (u'replace cable', 2),
#  (u'state drive', 2),
#  (u'roku box', 2),
#  (u'save money', 2),
#  (u'boot drive', 2),
#  (u'roku device', 2),
#  (u'data transfer', 2),
#  (u'fail drive', 2),
#  (u'phone charger', 2),
#  (u'point access', 1),
#  (u'ir sensor', 1),
#  (u'keep charge', 1),
#  (u'front cover', 1),
#  (u'phone case', 1),
#  (u'high end', 1),
#  (u'2tb drive', 1),
#  (u'old trackball', 1),
#  (u'come bud', 1),
#  (u'card adapter', 1),
#  (u'basic cable', 1),
#  (u'tv input', 1),
#  (u'sansa clip', 1),
#  (u'mount bracket', 1),
#  (u'dual port', 1),
#  (u'leather cover', 1),
#  (u'different size', 1),
#  (u'come battery', 1),
#  (u'car charge', 1),
#  (u'living room', 1),
#  (u'prime video', 1),
#  (u'hdmi output', 1),
#  (u'western drive', 1),
#  (u'hold battery', 1),
#  (u'purchase kindle', 1),
#  (u'old speaker', 1),
#  (u'kit lens', 1),
#  (u'mechanical drive', 1),
#  (u'order cable', 1),
#  (u'short cable', 1),
#  (u'apple price', 1),
#  (u'buy set', 1),
#  (u'bass sound', 1),
#  (u'music player', 1),
#  (u'car stereo', 1),
#  (u'outside noise', 1),
#  (u'rca antenna', 1),
#  (u'charge hd', 1),
#  (u'long trip', 1),
#  (u'long battery', 1),
#  (u'lens picture', 1),
#  (u'low profile', 1),
#  (u'fit cable', 1),
#  (u'kindle paperwhite', 1),
#  (u'portable friction', 1),
#  (u'solid state', 1),
#  (u'buy antenna', 1),
#  (u'cable company', 1),
#  (u'garmin unit', 1),
#  (u'mount dashboard', 1),
#  (u'iphone protector', 1),
#  (u'magician software', 1),
#  (u'usb extension', 1),
#  (u'wall plug', 1),
#  (u'power strip', 1),
#  (u'optic cable', 1),
#  (u'gps unit', 1),
#  (u'put protector', 1),
#  (u'clear protector', 1),
#  (u'kindle touch', 1),
#  (u'move part', 1),
#  (u'power source', 1),
#  (u'tech support', 1),
#  (u'add channel', 1),
#  (u'movie show', 1),
#  (u'nikon camera', 1),
#  (u'self discharge', 1),
#  (u'hold charge', 1),
#  (u'image quality', 1),
#  (u'otterbox case', 1),
#  (u'hulu netflix', 1),
#  (u'follow instruction', 1),
#  (u'bluetooth headphone', 1),
#  (u'd battery', 1),
#  (u'extend cable', 1),
#  (u'led tv', 1),
#  (u'hdtv antenna', 1),
#  (u'apple charge', 1),
#  (u'buy filter', 1),
#  (u'hold cover', 1),
#  (u'garmin mount', 1),
#  (u'lightning cable', 1),
#  (u'lens filter', 1),
#  (u'external usb', 1),
#  (u'function key', 1),
#  (u'garmin gp', 1),
#  (u'price speaker', 1),
#  (u'light lens', 1),
#  (u'mouse pad', 1),
#  (u'sound speaker', 1),
#  (u'internet connection', 1),
#  (u'time battery', 1),
#  (u'mount gp', 1),
#  (u'plug outlet', 1),
#  (u'key chain', 1),
#  (u'clear sound', 1),
#  (u'bluetooth device', 1),
#  (u'dual charger', 1),
#  (u'long charge', 1),
#  (u'mount screw', 1),
#  (u'usb speed', 1),
#  (u'lightning end', 1),
#  (u'connect device', 1),
#  (u'internet service', 1),
#  (u'ear piece', 1),
#  (u'mohu antenna', 1),
#  (u'thick cable', 1),
#  (u'bubble level', 1),
#  (u'audio cable', 1),
#  (u'backup software', 1),
#  (u'aaa battery', 1),
#  (u'end usb', 1),
#  (u'player ray', 1),
#  (u'internet cable', 1),
#  (u'nice cover', 1),
#  (u'chromecast device', 1),
#  (u'purchase battery', 1),
#  (u'price lens', 1),
#  (u'old battery', 1),
#  (u'field depth', 1),
#  (u'replace router', 1),
#  (u'wireless signal', 1),
#  (u'bass control', 1),
#  (u'rental modem', 1),
#  (u'price card', 1),
#  (u'cheap charger', 1),
#  (u'stream device', 1),
#  (u'ir remote', 1),
#  (u'indoor antenna', 1),
#  (u'wd passport', 1),
#  (u'3tb drive', 1),
#  (u'ipad charge', 1),
#  (u'cable cost', 1),
#  (u'top button', 1),
#  (u'iphone screen', 1),
#  (u'scratch lens', 1),
#  (u'anti glare', 1),
#  (u'key shift', 1),
#  (u'cable fiber', 1),
#  (u'windows boot', 1),
#  (u'year trackball', 1),
#  (u'medium center', 1),
#  (u'power outlet', 1),
#  (u'usb slot', 1),
#  (u'original kindle', 1),
#  (u'video quality', 1),
#  (u'modem fee', 1),
#  (u'home system', 1),
#  (u'migration software', 1),
#  (u'swivel plug', 1),
#  (u'storage drive', 1),
#  (u'low light', 1),
#  (u'netflix prime', 1),
#  (u'leaf antenna', 1),
#  (u'suction window', 1),
#  (u'zoom lens', 1),
#  (u'forward button', 1),
#  (u'inch tv', 1),
#  (u'scan channel', 1),
#  (u'recommend cable', 1),
#  (u'docsis modem', 1),
#  (u'support apps', 1),
#  (u'phone call', 1),
#  (u'price filter', 1),
#  (u'paperwhite case', 1),
#  (u'read book', 1),
#  (u'seem cable', 1),
#  (u'fold prong', 1),
#  (u'auto focus', 1),
#  (u'bluetooth headset', 1),
#  (u'cover screen', 1),
#  (u'second boot', 1),
#  (u'original charger', 1),
#  (u'key arrow', 1),
#  (u'user interface', 1),
#  (u'ios device', 1),
#  (u'wifi adapter', 1),
#  (u'logitech mouse', 1),
#  (u'lens protection', 1),
#  (u'major network', 1),
#  (u'nice leather', 1),
#  (u'plat gold', 1),
#  (u'tiffen filter', 1),
#  (u'pay modem', 1),
#  (u'crucial m4', 1),
#  (u'sub woofer', 1),
#  (u'save lens', 1),
#  (u'old camera', 1),
#  (u'ear size', 1),
#  (u'usb adapter', 1),
#  (u'kindle case', 1),
#  (u'angry bird', 1),
#  (u'thumb ball', 1),
#  (u'suction mount', 1),
#  (u'chrome tab', 1),
#  (u'lease modem', 1),
#  (u'apple version', 1),
#  (u'come charger', 1),
#  (u'micro charger', 1),
#  (u'turn cover', 1),
#  (u'roku xs', 1),
#  (u'turn volume', 1),
#  (u'wire version', 1),
#  (u'amazon cover', 1),
#  (u'prime lens', 1),
#  (u'cover lens', 1),
#  (u'tilt mount', 1),
#  (u'l lens', 1),
#  (u'bluerigger cable', 1),
#  (u'brand charger', 1),
#  (u'screen scratch', 1),
#  (u'aaa aa', 1),
#  (u'car gp', 1),
#  (u'roku remote', 1),
#  (u'amplify antenna', 1),
#  (u'full keyboard', 1),
#  (u'road trip', 1),
#  (u'gp unit', 1),
#  (u'light situation', 1),
#  (u'left click', 1),
#  (u'sound bar', 1),
#  (u'usb outlet', 1),
#  (u'touchpad keyboard', 1),
#  (u'cable service', 1),
#  (u'roku tv', 1),
#  (u'flat screen', 1),
#  (u'cancel noise', 1),
#  (u'excellent cable', 1),
#  (u'fit paperwhite', 1),
#  (u'windshield mount', 1),
#  (u'surge protector', 1),
#  (u'itunes library', 1),
#  (u'portable drive', 1),
#  (u'plug device', 1),
#  (u'enough outlet', 1),
#  (u'provide protection', 1),
#  (u'drive data', 1),
#  (u'kingston drive', 1),
#  (u'wall bracket', 1),
#  (u'price mount', 1),
#  (u'wireless version', 1),
#  (u'extra length', 1),
#  (u'auto switch', 1),
#  (u'tv wall', 1),
#  (u'drop signal', 1),
#  (u'perfect fit', 1),
#  (u'tiny drive', 1),
#  (u'sandisk cruzer', 1),
#  (u'come protector', 1),
#  (u'phone screen', 1),
#  (u'quality lens', 1),
#  (u'solid metal', 1),
#  (u'usb sata', 1),
#  (u'kindle plug', 1),
#  (u'screen protector', 1),
#  (u'tv mount', 1),
#  (u'usb hub', 1),
#  (u'mini cd', 1),
#  (u'pick channel', 1),
#  (u'year battery', 1),
#  (u'receive channel', 1),
#  (u'power battery', 1),
#  (u'instal driver', 1),
#  (u'wireless adapter', 1),
#  (u'touch pad', 1),
#  (u'small key', 1),
#  (u'drill hole', 1),
#  (u'windshield mark', 1),
#  (u'chromecast app', 1),
#  (u'track ball', 1),
#  (u'index finger', 1),
#  (u'quality cable', 1),
#  (u'long cord', 1),
#  (u'passport drive', 1),
#  (u'ir receiver', 1),
#  (u'quality build', 1),
#  (u'include software', 1),
#  (u'elements drive', 1),
#  (u'bean bag', 1),
#  (u'mount cup', 1),
#  (u'tp link', 1),
#  (u'bottom screw', 1),
#  (u'rapid rate', 1),
#  (u'galaxy note', 1),
#  (u'switch cable', 1),
#  (u'computer speaker', 1),
#  (u'install driver', 1),
#  (u'rapid charger', 1),
#  (u'keyboard size', 1),
#  (u'iphone cable', 1),
#  (u'fm radio', 1),
#  (u'medialink router', 1),
#  (u'small keyboard', 1),
#  (u'stick drive', 1),
#  (u'm4 ssd', 1),
#  (u'window mount', 1),
#  (u'bass volume', 1),
#  (u'tv antenna', 1),
#  (u'fit lens', 1),
#  (u'laptop keyboard', 1),
#  (u'charge hour', 1),
#  (u'wide aperture', 1),
#  (u'switch device', 1),
#  (u'usb connector', 1),
#  (u'old linksys', 1),
#  (u'g router', 1),
#  (u'ip address', 1),
#  (u'rechargeable battery', 1),
#  (u'replace modem', 1),
#  (u'wireless card', 1),
#  (u'rotate plug', 1),
#  (u'cordless phone', 1),
#  (u'come software', 1),
#  (u'metal casing', 1),
#  (u'volume control', 1),
#  (u'htpc keyboard', 1),
#  (u'tv port', 1),
#  (u'price sound', 1),
#  (u'test speed', 1),
#  (u'old adapter', 1),
#  (u'cool light', 1),
#  (u'lightning usb', 1),
#  (u'left mouse', 1),
#  (u'phone protector', 1),
#  (u'wi fi', 1),
#  (u'n router', 1),
#  (u'garmin friction', 1),
#  (u'scroll wheel', 1),
#  (u'hdmi tv', 1),
#  (u'audio book', 1),
#  (u'read speed', 1),
#  (u'hotel room', 1),
#  (u'push button', 1),
#  (u'bright light', 1),
#  (u'samsung note', 1),
#  (u'air bubble', 1),
#  (u'lag bolt', 1),
#  (u'linksys router', 1),
#  (u'remote jack', 1),
#  (u'quality price', 1),
#  (u'google play', 1),
#  (u'windshield cup', 1),
#  (u'portable mount', 1),
#  (u'fast charger', 1),
#  (u'print finger', 1),
#  (u'include level', 1),
#  (u'garmin gps', 1),
#  (u'cable provider', 1),
#  (u'digital audio', 1),
#  (u'iphone charge', 1),
#  (u'samsung drive', 1),
#  (u'crucial ssd', 1),
#  (u'rental car', 1),
#  (u'tv bracket', 1),
#  (u'cheap filter', 1),
#  (u'protection filter', 1),
#  (u'link adapter', 1),
#  (u'surround system', 1),
#  (u'digital drive', 1),
#  (u'purchase lens', 1),
#  (u'monthly fee', 1),
#  (u'record video', 1),
#  (u'hd channel', 1),
#  (u'format card', 1),
#  (u'fall windshield', 1),
#  (u'high card', 1),
#  (u'sound headphone', 1),
#  (u'kindle leather', 1),
#  (u'sound surround', 1),
#  (u'music video', 1),
#  (u'retail packaging', 1),
#  (u'extension cord', 1),
#  (u'local channel', 1),
#  (u'sandisk drive', 1),
#  (u'iphone case', 1),
#  (u'galaxy tab', 1),
#  (u'cheetah mount', 1),
#  (u'apply protector', 1),
#  (u'old desktop', 1),
#  (u'mount friction', 1),
#  (u'satellite speaker', 1),
#  (u'micro connector', 1),
#  (u'buy keyboard', 1),
#  (u'lens cap', 1),
#  (u'wall stud', 1),
#  (u'noise reduction', 1),
#  (u'tech armor', 1),
#  (u'long life', 1),
#  (u'comcast call', 1),
#  (u'increase speed', 1),
#  (u'comcast internet', 1),
#  (u'focal length', 1),
#  (u'original apple', 1),
#  (u'remote headphone', 1),
#  (u'come level', 1),
#  (u'seagate drive', 1),
#  (u'crucial drive', 1),
#  (u'kindle charge', 1),
#  (u'mount dash', 1),
#  (u'clone drive', 1),
#  (u'buy router', 1),
#  (u'usb charge', 1),
#  (u'barracuda drive', 1),
#  (u'mount wall', 1),
#  (u'phone cable', 1),
#  (u'cable brand', 1),
#  (u'reduce noise', 1),
#  (u'cheap headphone', 1),
#  (u'mac address', 1),
#  (u'samsung software', 1),
#  (u'recommend card', 1),
#  (u'old router', 1),
#  (u'perfectly kindle', 1),
#  (u'firmware update', 1),
#  (u'kingston card', 1),
#  (u'customer support', 1),
#  (u'upload speed', 1),
#  (u'hold tv', 1),
#  (u'uv lens', 1),
#  (u'screen quality', 1),
#  (u'outdoor antenna', 1),
#  (u'pad mouse', 1),
#  (u'connect modem', 1),
#  (u'fold cover', 1),
#  (u'oem charger', 1),
#  (u'expensive lens', 1),
#  (u'original cable', 1),
#  (u'sturdy cable', 1),
#  (u'stream youtube', 1),
#  (u'lifeproof case', 1),
#  (u'end cap', 1),
#  (u'dual band', 1),
#  (u'track pad', 1),
#  (u'longer charge', 1),
#  (u'quality product', 1),
#  (u'ear headphone', 1),
#  (u'coat filter', 1),
#  (u'try antenna', 1),
#  (u'mediabridge hdmi', 1),
#  (u'one apple', 1),
#  (u'keep lens', 1),
#  (u'car usb', 1),
#  (u'kindle fit', 1),
#  (u'time warner', 1),
#  (u'buy battery', 1),
#  (u'android tablet', 1),
#  (u'white side', 1),
#  (u'charge ipad', 1),
#  (u'download driver', 1),
#  (u'armor protector', 1),
#  (u'ac outlet', 1),
#  (u'old modem', 1),
#  (u'protect kindle', 1),
#  (u'eneloop battery', 1),
#  (u'toslink cable', 1),
#  (u'motorola modem', 1),
#  (u'uv filter', 1),
#  (u'multi touch', 1),
#  (u'sharp turn', 1),
#  (u'regular mouse', 1),
#  (u'motorola charger', 1),
#  (u'switch remote', 1),
#  (u'add weight', 1),
#  (u'original fire', 1),
#  (u'key ring', 1),
#  (u'dslr camera', 1),
#  (u'internet speed', 1),
#  (u'regular battery', 1),
#  (u'format drive', 1),
#  (u'mouse keyboard', 1),
#  (u'charge iphone', 1),
#  (u'wireless band', 1),
#  (u'fine cable', 1),
#  (u'shoot video', 1),
#  (u'black side', 1),
#  (u'rabbit ear', 1),
#  (u'tighten screw', 1),
#  (u'credit card', 1),
#  (u'fast boot', 1),
#  (u'indoor hdtv', 1),
#  (u'home theater', 1),
#  (u'portrait lens', 1),
#  (u'apple brand', 1),
#  (u'front element', 1),
#  (u'time modem', 1),
#  (u'easy mount', 1),
#  (u'wall outlet', 1),
#  (u'itunes movie', 1),
#  (u'hdmi switch', 1),
#  (u'download speed', 1),
#  (u'solid cable', 1),
#  (u'cheap lens', 1),
#  (u'safety screw', 1),
#  (u'samsung galaxy', 1),
#  (u'own modem', 1),
#  (u'uv protection', 1),
#  (u'purchase drive', 1),
#  (u'iphone 5s', 1),
#  (u'lens glass', 1),
#  (u'full size', 1),
#  (u'video photo', 1),
#  (u'unifying receiver', 1),
#  (u'dual usb', 1),
#  (u'turn tv', 1),
#  (u'dust bubble', 1),
#  (u'activate modem', 1),
#  (u'rent modem', 1),
#  (u'audio quality', 1),
#  (u'matte finish', 1),
#  (u'hdmi power', 1),
#  (u'suction windshield', 1),
#  (u'netgear router', 1),
#  (u'camera flash', 1),
#  (u'suction cup', 1),
#  (u'lens element', 1),
#  (u'samsung ssd', 1),
#  (u'logitech software', 1),
#  (u'come lens', 1),
#  (u'cheap apple', 1),
#  (u'64gb card', 1),
#  (u'female end', 1),
#  (u'lightning connector', 1),
#  (u'charge fire', 1),
#  (u'fit cover', 1),
#  (u'chrome browser', 1),
#  (u'nimh battery', 1),
#  (u'protect screen', 1),
#  (u'apple cord', 1),
#  (u'perfect cover', 1),
#  (u'adapter card', 1),
#  (u'transcend card', 1),
#  (u'garmin nuvi', 1),
#  (u'remote app', 1),
#  (u'surge protection', 1),
#  (u'product quality', 1),
#  (u'kindle cover', 1),
#  (u'power device', 1),
#  (u'apple cable', 1),
#  (u'n wireless', 1),
#  (u'lens protector', 1),
#  (u'manual focus', 1),
#  (u'buy speaker', 1),
#  (u'cast tab', 1),
#  (u'galaxy s3', 1),
#  (u'galaxy s4', 1),
#  (u'pod control', 1),
#  (u'surge outlet', 1),
#  (u'include cable', 1),
#  (u'power surge', 1),
#  (u'buy hdmi', 1),
#  (u'protect filter', 1),
#  (u'move mouse', 1),
#  (u'extreme sandisk', 1),
#  (u'wireless trackball', 1),
#  (u'cruzer fit', 1),
#  (u'battery charger', 1),
#  (u'wire trackball', 1),
#  (u'comcast service', 1),
#  (u'front lens', 1),
#  (u'power supply', 1),
#  (u'recommend lens', 1),
#  (u'nuvi mount', 1),
#  (u'purchase router', 1),
#  (u'hdmi input', 1),
#  (u'optical cable', 1),
#  (u'small speaker', 1),
#  (u'galaxy phone', 1),
#  (u'leave mark', 1),
#  (u'metal case', 1),
#  (u'class transcend', 1),
#  (u'away foot', 1),
#  (u'charge battery', 1),
#  (u'keyboard mouse', 1),
#  (u'usb protector', 1),
#  (u'protect glass', 1),
#  (u'transfer data', 1),
#  (u'add bulk', 1),
#  (u'drop connection', 1),
#  (u'fast lens', 1),
#  (u'headphone pair', 1),
#  (u'extreme card', 1),
#  (u'switch input', 1),
#  (u'build level', 1),
#  (u'protect element', 1),
#  (u'mouse button', 1),
#  (u'mini protector', 1),
#  (u'purchase filter', 1),
#  (u'old antenna', 1),
#  (u'hang tv', 1),
#  (u'hdmi device', 1),
#  (u'canon 50mm', 1),
#  (u'play video', 1),
#  (u'cost cable', 1),
#  (u'usb car', 1),
#  (u'pick signal', 1),
#  (u'theater system', 1),
#  (u'money cable', 1),
#  (u'easy router', 1),
#  (u'buy ssd', 1),
#  (u'include charger', 1),
#  (u'stream movie', 1),
#  (u'buy mount', 1),
#  (u'rental fee', 1),
#  (u'hdmi switcher', 1),
#  (u'red ball', 1),
#  (u'plastic cap', 1),
#  (u'nikon lens', 1),
#  (u'price range', 1),
#  (u'rend modem', 1),
#  (u'replace battery', 1),
#  (u'sharp lens', 1),
#  (u'samsung evo', 1),
#  (u'turn device', 1),
#  (u'watch youtube', 1),
#  (u'mohu leaf', 1),
#  (u'last charge', 1),
#  (u'set router', 1),
#  (u'trackman wheel', 1),
#  (u'quality filter', 1),
#  (u'privacy screen', 1),
#  (u'protect lens', 1),
#  (u'battery pack', 1),
#  (u'local station', 1),
#  (u'paperwhite cover', 1),
#  (u'hard wd', 1),
#  (u'optical audio', 1),
#  (u'trackball mouse', 1),
#  (u'ultra sandisk', 1),
#  (u'samsung s3', 1),
#  (u'samsung s4', 1),
#  (u'kindle charger', 1),
#  (u'alkaline battery', 1),
#  (u'internet provider', 1),
#  (u'amazon hdmi', 1),
#  (u'power button', 1),
#  (u'motorola logo', 1),
#  (u'old roku', 1),
#  (u'put filter', 1),
#  (u'photo video', 1),
#  (u'fine card', 1),
#  (u'purchase modem', 1),
#  (u'logitech trackball', 1),
#  (u'away mile', 1),
#  (u'aa battery', 1),
#  (u'buy modem', 1),
#  (u'logitech product', 1),
#  (u'netflix youtube', 1),
#  (u'speaker system', 1),
#  (u'micro cable', 1),
#  (u'youtube video', 1),
#  (u'usb dongle', 1),
#  (u'volume knob', 1),
#  (u'comcast modem', 1),
#  (u'speaker set', 1),
#  (u'sanyo battery', 1),
#  (u'micro end', 1),
#  (u'focus ring', 1),
#  (u'xbox controller', 1)]

# %%
adjectives = []

for key in asin_dict:
    for aspect in asin_dict[key]['aspect_dict']:
        for adj in asin_dict[key]['aspect_dict'][aspect]['adjectives']:
            if adj.isalpha():
                adjectives.append(adj)
        
adjectives_cnt = Counter(adjectives)

# %%
adjectives_cnt.most_common()
# Out:
# [(u'great', 10142),
#  (u'other', 8345),
#  (u'good', 7915),
#  (u'new', 5429),
#  (u'old', 3909),
#  (u'high', 3243),
#  (u'hard', 2684),
#  (u'more', 2656),
#  (u'many', 2360),
#  (u'little', 2352),
#  (u'small', 2181),
#  (u'same', 2164),
#  (u'best', 2108),
#  (u'nice', 2054),
#  (u'cheap', 1935),
#  (u'better', 1754),
#  (u'different', 1646),
#  (u'few', 1634),
#  (u'low', 1606),
#  (u'several', 1578),
#  (u'external', 1577),
#  (u'big', 1569),
#  (u'excellent', 1561),
#  (u'large', 1548),
#  (u'expensive', 1458),
#  (u'first', 1352),
#  (u'extra', 1337),
#  (u'wireless', 1227),
#  (u'fast', 1227),
#  (u'micro', 1201),
#  (u'original', 1166),
#  (u'most', 1154),
#  (u'digital', 1120),
#  (u'full', 1072),
#  (u'second', 1057),
#  (u'free', 1009),
#  (u'only', 978),
#  (u'local', 894),
#  (u'standard', 883),
#  (u'regular', 873),
#  (u'sound', 857),
#  (u'last', 839),
#  (u'right', 834),
#  (u'available', 776),
#  (u'much', 755),
#  (u'long', 752),
#  (u'decent', 747),
#  (u'previous', 737),
#  (u'perfect', 716),
#  (u'solid', 714),
#  (u'smart', 711),
#  (u'enough', 651),
#  (u'portable', 609),
#  (u'own', 601),
#  (u'blue', 595),
#  (u'single', 589),
#  (u'multiple', 575),
#  (u'simple', 571),
#  (u'internal', 553),
#  (u'audio', 540),
#  (u'similar', 538),
#  (u'bad', 535),
#  (u'additional', 532),
#  (u'awesome', 514),
#  (u'main', 500),
#  (u'basic', 499),
#  (u'amazing', 480),
#  (u'tiny', 472),
#  (u'inexpensive', 466),
#  (u'clear', 465),
#  (u'reasonable', 455),
#  (u'short', 444),
#  (u'rechargeable', 436),
#  (u'stream', 433),
#  (u'reliable', 416),
#  (u'top', 414),
#  (u'easy', 405),
#  (u'remote', 395),
#  (u'price', 393),
#  (u'optical', 385),
#  (u'include', 380),
#  (u'various', 367),
#  (u'normal', 363),
#  (u'real', 348),
#  (u'left', 346),
#  (u'actual', 341),
#  (u'super', 337),
#  (u'less', 333),
#  (u'slow', 330),
#  (u'build', 328),
#  (u'past', 327),
#  (u'mobile', 320),
#  (u'major', 316),
#  (u'fantastic', 309),
#  (u'favorite', 307),
#  (u'such', 301),
#  (u'black', 299),
#  (u'wire', 299),
#  (u'flat', 291),
#  (u'sturdy', 282),
#  (u'hdmi', 278),
#  (u'suction', 276),
#  (u'strong', 276),
#  (u'light', 272),
#  (u'key', 271),
#  (u'retail', 269),
#  (u'backup', 265),
#  (u'whole', 265),
#  (u'current', 262),
#  (u'sized', 262),
#  (u'overall', 262),
#  (u'poor', 261),
#  (u'quick', 260),
#  (u'particular', 260),
#  (u'entire', 259),
#  (u'separate', 258),
#  (u'electronic', 257),
#  (u'huge', 257),
#  (u'compact', 256),
#  (u'western', 251),
#  (u'usb', 249),
#  (u'dual', 248),
#  (u'affordable', 244),
#  (u'cool', 242),
#  (u'prime', 241),
#  (u'next', 240),
#  (u'late', 238),
#  (u'white', 237),
#  (u'make', 228),
#  (u'fine', 227),
#  (u'thick', 226),
#  (u'generic', 217),
#  (u'positive', 215),
#  (u'third', 215),
#  (u'indoor', 214),
#  (u'wonderful', 213),
#  (u'heavy', 209),
#  (u'charge', 206),
#  (u'traditional', 203),
#  (u'primary', 196),
#  (u'longer', 194),
#  (u'exist', 193),
#  (u'non', 188),
#  (u'front', 186),
#  (u'sharp', 184),
#  (u'back', 182),
#  (u'thin', 181),
#  (u'mechanical', 176),
#  (u'certain', 172),
#  (u'average', 169),
#  (u'clean', 165),
#  (u'compatible', 164),
#  (u'write', 163),
#  (u'plastic', 158),
#  (u'mini', 157),
#  (u'faster', 157),
#  (u'defective', 154),
#  (u'exact', 152),
#  (u'online', 150),
#  (u'negative', 148),
#  (u'important', 147),
#  (u'rental', 146),
#  (u'brand', 146),
#  (u'spare', 144),
#  (u'personal', 142),
#  (u'comfortable', 142),
#  (u'bright', 141),
#  (u'official', 140),
#  (u'mount', 138),
#  (u'specific', 137),
#  (u'beautiful', 137),
#  (u'protective', 136),
#  (u'typical', 136),
#  (u'limited', 135),
#  (u'streaming', 135),
#  (u'overpriced', 134),
#  (u'read', 134),
#  (u'outstanding', 131),
#  (u'initial', 130),
#  (u'open', 130),
#  (u'outside', 129),
#  (u'download', 125),
#  (u'base', 124),
#  (u'fair', 122),
#  (u'fancy', 120),
#  (u'durable', 120),
#  (u'useful', 119),
#  (u'handy', 119),
#  (u'bluetooth', 119),
#  (u'special', 119),
#  (u'genuine', 118),
#  (u'physical', 117),
#  (u'desktop', 117),
#  (u'direct', 115),
#  (u'superior', 115),
#  (u'close', 114),
#  (u'live', 113),
#  (u'true', 111),
#  (u'private', 111),
#  (u'numerous', 110),
#  (u'weak', 109),
#  (u'living', 108),
#  (u'wired', 108),
#  (u'add', 107),
#  (u'common', 106),
#  (u'instant', 106),
#  (u'anti', 104),
#  (u'supply', 104),
#  (u'due', 103),
#  (u'recent', 102),
#  (u'crisp', 102),
#  (u'correct', 101),
#  (u'universal', 99),
#  (u'wide', 98),
#  (u'crucial', 98),
#  (u'rapid', 97),
#  (u'minor', 96),
#  (u'dedicated', 95),
#  (u'comparable', 95),
#  (u'red', 94),
#  (u'monthly', 94),
#  (u'power', 93),
#  (u'tight', 93),
#  (u'up', 93),
#  (u'incredible', 93),
#  (u'work', 91),
#  (u'usable', 89),
#  (u'maximum', 87),
#  (u'android', 86),
#  (u'soft', 86),
#  (u'possible', 85),
#  (u'wifi', 85),
#  (u'technical', 85),
#  (u'looking', 84),
#  (u'worth', 84),
#  (u'modern', 82),
#  (u'rat', 82),
#  (u'angry', 82),
#  (u'manual', 81),
#  (u'secondary', 81),
#  (u'off', 81),
#  (u'mid', 81),
#  (u'crappy', 80),
#  (u'proper', 80),
#  (u'dead', 78),
#  (u'annoying', 78),
#  (u'loud', 77),
#  (u'wrong', 76),
#  (u'raw', 76),
#  (u'convenient', 76),
#  (u'earlier', 75),
#  (u'fix', 75),
#  (u'consistent', 74),
#  (u'samsung', 74),
#  (u'eneloop', 73),
#  (u'half', 73),
#  (u'deep', 73),
#  (u'use', 72),
#  (u'usual', 72),
#  (u'functional', 72),
#  (u'design', 71),
#  (u'slim', 71),
#  (u'native', 71),
#  (u'powerful', 71),
#  (u'pay', 70),
#  (u'outdoor', 70),
#  (u'bulky', 70),
#  (u'magnetic', 69),
#  (u'total', 69),
#  (u'fail', 69),
#  (u'capable', 69),
#  (u'amplify', 69),
#  (u'advertised', 69),
#  (u'fresh', 68),
#  (u'stable', 68),
#  (u'roku', 68),
#  (u'secure', 67),
#  (u'green', 67),
#  (u'popular', 67),
#  (u'logitech', 67),
#  (u'neat', 66),
#  (u'terrible', 66),
#  (u'laptop', 65),
#  (u'alkaline', 65),
#  (u'professional', 65),
#  (u'conventional', 65),
#  (u'look', 65),
#  (u'faulty', 64),
#  (u'adequate', 64),
#  (u'support', 64),
#  (u'plain', 64),
#  (u'set', 64),
#  (u'superb', 64),
#  (u'powered', 64),
#  (u'bottom', 63),
#  (u'electrical', 63),
#  (u'flexible', 62),
#  (u'recommend', 61),
#  (u'happy', 61),
#  (u'middle', 61),
#  (u'occasional', 61),
#  (u'need', 61),
#  (u'necessary', 61),
#  (u'smooth', 61),
#  (u'serious', 60),
#  (u'horrible', 60),
#  (u'multi', 60),
#  (u'provide', 59),
#  (u'purchase', 59),
#  (u'unifying', 59),
#  (u'plat', 59),
#  (u'active', 58),
#  (u'noticeable', 58),
#  (u'double', 58),
#  (u'ios', 58),
#  (u'operate', 57),
#  (u'terrific', 57),
#  (u'connect', 57),
#  (u'know', 57),
#  (u'automatic', 56),
#  (u'quiet', 56),
#  (u'flimsy', 56),
#  (u'sleek', 55),
#  (u'size', 55),
#  (u'future', 55),
#  (u'complete', 55),
#  (u'removable', 55),
#  (u'slight', 55),
#  (u'rich', 54),
#  (u'ok', 54),
#  (u'bare', 54),
#  (u'sweet', 53),
#  (u'minimal', 53),
#  (u'constant', 53),
#  (u'exceptional', 53),
#  (u'ultra', 52),
#  (u'out', 51),
#  (u'effective', 50),
#  (u'random', 50),
#  (u'medium', 50),
#  (u'ideal', 50),
#  (u'loose', 50),
#  (u'useless', 50),
#  (u'included', 49),
#  (u'fourth', 49),
#  (u'lead', 49),
#  (u'gold', 48),
#  (u'appropriate', 48),
#  (u'connected', 48),
#  (u'lightweight', 48),
#  (u'tech', 47),
#  (u'instal', 47),
#  (u'inferior', 47),
#  (u'impressive', 46),
#  (u'very', 46),
#  (u'known', 46),
#  (u'extreme', 46),
#  (u'dumb', 46),
#  (u'composite', 45),
#  (u'weird', 45),
#  (u'pro', 45),
#  (u'stupid', 45),
#  (u'chromecast', 45),
#  (u'shallow', 45),
#  (u'female', 45),
#  (u'aux', 44),
#  (u'disposable', 44),
#  (u'ridiculous', 44),
#  (u'general', 44),
#  (u'approve', 44),
#  (u'corrupt', 44),
#  (u'attractive', 44),
#  (u'record', 44),
#  (u'upload', 43),
#  (u'fake', 43),
#  (u'improved', 43),
#  (u'rave', 43),
#  (u'proprietary', 43),
#  (u'attach', 43),
#  (u'leave', 42),
#  (u'acceptable', 42),
#  (u'individual', 42),
#  (u'competitive', 42),
#  (u'call', 41),
#  (u'critical', 41),
#  (u'male', 41),
#  (u'dark', 41),
#  (u'break', 40),
#  (u'amazon', 40),
#  (u'update', 40),
#  (u'potential', 40),
#  (u'dependable', 40),
#  (u'valuable', 40),
#  (u'age', 40),
#  (u'wd', 40),
#  (u'crazy', 40),
#  (u'permanent', 40),
#  (u'stereo', 40),
#  (u'identical', 40),
#  (u'virtual', 40),
#  (u'sticky', 39),
#  (u'continuous', 39),
#  (u'ethernet', 39),
#  (u'certify', 39),
#  (u'everyday', 39),
#  (u'sensitive', 39),
#  (u'focal', 39),
#  (u'friendly', 39),
#  (u'sufficient', 39),
#  (u'lose', 39),
#  (u'prior', 38),
#  (u'surround', 38),
#  (u'kindle', 38),
#  (u'pretty', 38),
#  (u'ready', 38),
#  (u'precious', 38),
#  (u'hot', 37),
#  (u'purple', 37),
#  (u'equivalent', 37),
#  (u'significant', 37),
#  (u'serial', 37),
#  (u'sd', 37),
#  (u'ordinary', 36),
#  (u'snug', 36),
#  (u'remain', 36),
#  (u'minimum', 36),
#  (u'expandable', 36),
#  (u'static', 36),
#  (u'face', 36),
#  (u'absolute', 35),
#  (u'flawless', 35),
#  (u'cord', 35),
#  (u'rear', 35),
#  (u'public', 35),
#  (u'like', 35),
#  (u'able', 35),
#  (u'massive', 34),
#  (u'rent', 34),
#  (u'bootable', 34),
#  (u'chinese', 34),
#  (u'pricey', 34),
#  (u'sandisk', 33),
#  (u'daily', 33),
#  (u'intermittent', 33),
#  (u'macro', 33),
#  (u'rechargable', 33),
#  (u'miss', 33),
#  (u'empty', 33),
#  (u'cheapo', 33),
#  (u'battery', 33),
#  (u'quality', 33),
#  (u'above', 32),
#  (u'infrared', 32),
#  (u'integrate', 32),
#  (u'near', 32),
#  (u'sequential', 32),
#  (u'ergonomic', 32),
#  (u'hi', 32),
#  (u'equal', 32),
#  (u'lost', 32),
#  (u'stellar', 32),
#  (u'versatile', 32),
#  (u'compete', 32),
#  (u'speedy', 31),
#  (u'cold', 31),
#  (u'interesting', 31),
#  (u'sure', 31),
#  (u'dish', 31),
#  (u'premium', 31),
#  (u'construct', 31),
#  (u'lease', 31),
#  (u'ugly', 30),
#  (u'firmware', 30),
#  (u'onboard', 30),
#  (u'inside', 30),
#  (u'cast', 30),
#  (u'zero', 30),
#  (u'narrow', 30),
#  (u'glowing', 30),
#  (u'intuitive', 30),
#  (u'itunes', 29),
#  (u'adjacent', 29),
#  (u'directional', 29),
#  (u'perform', 29),
#  (u'increase', 29),
#  (u'refurbish', 29),
#  (u'coat', 29),
#  (u'reduce', 29),
#  (u'least', 29),
#  (u'load', 29),
#  (u'costly', 29),
#  (u'move', 29),
#  (u'visible', 28),
#  (u'slr', 28),
#  (u'mediocre', 28),
#  (u'countless', 28),
#  (u'temporary', 28),
#  (u'amplified', 28),
#  (u'unbeatable', 28),
#  (u'audible', 28),
#  (u'responsive', 27),
#  (u'fitting', 27),
#  (u'tough', 27),
#  (u'natural', 27),
#  (u'upgrade', 27),
#  (u'extended', 27),
#  (u'slick', 27),
#  (u'upstairs', 27),
#  (u'robust', 27),
#  (u'youtube', 27),
#  (u'programmable', 27),
#  (u'auxiliary', 27),
#  (u'sounding', 26),
#  (u'corded', 26),
#  (u'glow', 26),
#  (u'matte', 26),
#  (u'rugged', 26),
#  (u'vertical', 26),
#  (u'enable', 26),
#  (u'tinny', 26),
#  (u'video', 26),
#  (u'odd', 26),
#  (u'comcast', 25),
#  (u'vary', 25),
#  (u'amateur', 25),
#  (u'solar', 25),
#  (u'cyber', 25),
#  (u'pure', 25),
#  (u'optimal', 25),
#  (u'steady', 25),
#  (u'further', 25),
#  (u'authentic', 25),
#  (u'nifty', 25),
#  (u'relate', 25),
#  (u'giant', 25),
#  (u'knock', 25),
#  (u'obvious', 25),
#  (u'ipad', 25),
#  (u'ample', 25),
#  (u're', 24),
#  (u'refurbished', 24),
#  (u'creative', 24),
#  (u'round', 24),
#  (u'unbelievable', 24),
#  (u'package', 24),
#  (u'list', 24),
#  (u'select', 24),
#  (u'lousy', 24),
#  (u'buffering', 24),
#  (u'classic', 24),
#  (u'stiff', 24),
#  (u'final', 24),
#  (u'helpful', 24),
#  (u'rural', 24),
#  (u'ip', 23),
#  (u'avid', 23),
#  (u'reputable', 23),
#  (u'cordless', 23),
#  (u'excess', 23),
#  (u'horizontal', 23),
#  (u'store', 23),
#  (u'run', 23),
#  (u'limit', 23),
#  (u'straight', 22),
#  (u'suitable', 22),
#  (u'advertise', 22),
#  (u'upper', 22),
#  (u'iphone', 22),
#  (u'glossy', 22),
#  (u'fat', 22),
#  (u'unused', 22),
#  (u'international', 22),
#  (u'hide', 21),
#  (u'advanced', 21),
#  (u'unnecessary', 21),
#  (u'max', 21),
#  (u'drop', 21),
#  (u'fifth', 21),
#  (u'lighten', 21),
#  (u'early', 21),
#  (u'follow', 21),
#  (u'outrageous', 21),
#  (u'substantial', 21),
#  (u'electric', 21),
#  (u'used', 21),
#  (u'accelerate', 21),
#  (u'strange', 21),
#  (u'ground', 20),
#  (u'braid', 20),
#  (u'nearby', 20),
#  (u'detailed', 20),
#  (u'handheld', 20),
#  (u'multimedia', 20),
#  (u'lock', 20),
#  (u'earbud', 20),
#  (u'optional', 20),
#  (u'accurate', 20),
#  (u'increased', 20),
#  (u'net', 19),
#  (u'cute', 19),
#  (u'require', 19),
#  (u'ultimate', 19),
#  (u'moderate', 19),
#  (u'broken', 19),
#  (u'former', 19),
#  (u'format', 19),
#  (u'app', 19),
#  (u'rough', 19),
#  (u'tremendous', 19),
#  (u'difficult', 19),
#  (u'accessible', 19),
#  (u'classical', 19),
#  (u'economical', 19),
#  (u'headphone', 19),
#  (u'integrated', 18),
#  (u'safe', 18),
#  (u'silly', 18),
#  (u'preferred', 18),
#  (u'unique', 18),
#  (u'opposite', 18),
#  (u'dropped', 18),
#  (u'plus', 18),
#  (u'down', 18),
#  (u'brown', 18),
#  (u'adjustable', 18),
#  (u'frequent', 18),
#  (u'relative', 18),
#  (u'mod', 18),
#  (u'expect', 18),
#  (u'okay', 18),
#  (u'useable', 18),
#  (u'priced', 18),
#  (u'concrete', 18),
#  (u'control', 18),
#  (u'replacement', 18),
#  (u'flush', 18),
#  (u'transfer', 18),
#  (u'inner', 18),
#  (u'bundle', 18),
#  (u'yellow', 17),
#  (u'mediabridge', 17),
#  (u'dry', 17),
#  (u'clunky', 17),
#  (u'downloaded', 17),
#  (u'instructional', 17),
#  (u'incremental', 17),
#  (u'unwanted', 17),
#  (u'bumpy', 17),
#  (u'pricy', 17),
#  (u'mixed', 17),
#  (u'intensive', 17),
#  (u'funny', 17),
#  (u'alternative', 17),
#  (u'essential', 17),
#  (u'overprice', 17),
#  (u'coil', 17),
#  (u'impressed', 17),
#  (u'visual', 17),
#  (u'counterfeit', 17),
#  (u'aforementioned', 17),
#  (u'stunning', 17),
#  (u'swivel', 16),
#  (u'spanish', 16),
#  (u'backlit', 16),
#  (u'protect', 16),
#  (u'save', 16),
#  (u'plated', 16),
#  (u'handed', 16),
#  (u'incoming', 16),
#  (u'pink', 16),
#  (u'accelerated', 16),
#  (u'damage', 16),
#  (u'nimh', 16),
#  (u'molded', 16),
#  (u'buffer', 16),
#  (u'hungry', 16),
#  (u'cancel', 16),
#  (u'extensive', 16),
#  (u'awful', 16),
#  (u'share', 16),
#  (u'foreign', 16),
#  (u'unify', 16),
#  (u'unlimited', 16),
#  (u'signal', 16),
#  (u'forward', 16),
#  (u'crop', 16),
#  (u'proof', 16),
#  (u'legit', 16),
#  (u'blurry', 16),
#  (u'coated', 16),
#  (u'flip', 16),
#  (u'cheetah', 15),
#  (u'improve', 15),
#  (u'lovely', 15),
#  (u'passive', 15),
#  (u'phenomenal', 15),
#  (u'drive', 15),
#  (u'variable', 15),
#  (u'change', 15),
#  (u'brilliant', 15),
#  (u'unobtrusive', 15),
#  (u'shield', 15),
#  (u'name', 15),
#  (u'blu', 15),
#  (u'lighted', 15),
#  (u'color', 15),
#  (u'colored', 15),
#  (u'blank', 15),
#  (u'analog', 15),
#  (u'missing', 15),
#  (u'd', 15),
#  (u'stylish', 15),
#  (u'manufacture', 15),
#  (u'waterproof', 15),
#  (u'curved', 15),
#  (u'recess', 15),
#  (u'pc', 15),
#  (u'tired', 14),
#  (u'yet', 14),
#  (u'balanced', 14),
#  (u'expose', 14),
#  (u'label', 14),
#  (u'practical', 14),
#  (u'underwater', 14),
#  (u'candid', 14),
#  (u'favorable', 14),
#  (u'worthless', 14),
#  (u'shape', 14),
#  (u'alternate', 14),
#  (u'newer', 14),
#  (u'cellular', 14),
#  (u'ancient', 14),
#  (u'unknown', 14),
#  (u'urdrive', 14),
#  (u'bluray', 14),
#  (u'national', 14),
#  (u'bulk', 14),
#  (u'present', 14),
#  (u'distant', 14),
#  (u'retractable', 14),
#  (u'noisy', 14),
#  (u'updated', 13),
#  (u'elegant', 13),
#  (u'satisfied', 13),
#  (u'networked', 13),
#  (u'content', 13),
#  (u'extend', 13),
#  (u'metropolitan', 13),
#  (u'stand', 13),
#  (u'delete', 13),
#  (u'flash', 13),
#  (u'dim', 13),
#  (u'blink', 13),
#  (u'netflix', 13),
#  (u'blurred', 13),
#  (u'unreliable', 13),
#  (u'casual', 13),
#  (u'damn', 13),
#  (u'excelent', 13),
#  (u'commercial', 13),
#  (u'sore', 13),
#  (u'mute', 13),
#  (u'mention', 13),
#  (u'ipod', 13),
#  (u'offset', 13),
#  (u'beefy', 13),
#  (u'paperwhite', 13),
#  (u'microsd', 13),
#  (u'rare', 13),
#  (u'mere', 13),
#  (u'microsdhc', 13),
#  (u'fabulous', 12),
#  (u'textured', 12),
#  (u'outdated', 12),
#  (u'give', 12),
#  (u'enormous', 12),
#  (u'picky', 12),
#  (u'watch', 12),
#  (u'diminutive', 12),
#  (u'wi', 12),
#  (u'beloved', 12),
#  (u'unified', 12),
#  (u'desire', 12),
#  (u'remarkable', 12),
#  (u'apparent', 12),
#  (u'router', 12),
#  (u'efficient', 12),
#  (u'burst', 12),
#  (u'dedicate', 12),
#  (u'trackball', 12),
#  (u'compliant', 12),
#  (u'plex', 12),
#  (u'pleasing', 12),
#  (u'rotate', 12),
#  (u'spinning', 12),
#  (u'pleasant', 12),
#  (u'sell', 12),
#  (u'built', 12),
#  (u'disappointing', 12),
#  (u'shiny', 12),
#  (u'scratch', 12),
#  (u'try', 12),
#  (u'orange', 12),
#  (u'slide', 12),
#  (u'fixed', 12),
#  (u'excessive', 12),
#  (u'buy', 12),
#  (u'crummy', 12),
#  (u'hold', 11),
#  (u'complicated', 11),
#  (u'innovative', 11),
#  (u'fit', 11),
#  (u'independent', 11),
#  (u'silent', 11),
#  (u'result', 11),
#  (u'optimum', 11),
#  (u'wear', 11),
#  (u'trusted', 11),
#  (u'spotty', 11),
#  (u'questionable', 11),
#  (u'focus', 11),
#  (u'droid', 11),
#  (u'smallish', 11),
#  (u'rotational', 11),
#  (u'copy', 11),
#  (u'ssd', 11),
#  (u'subsequent', 11),
#  (u'hybrid', 11),
#  (u'discernible', 11),
#  (u'amp', 11),
#  (u'reduced', 11),
#  (u'booming', 11),
#  (u'operating', 11),
#  (u'miniature', 11),
#  (u'chunky', 11),
#  (u'preloaded', 11),
#  (u'def', 11),
#  (u'exorbitant', 11),
#  (u'really', 11),
#  (u'weighted', 11),
#  (u'mirror', 11),
#  (u'worthwhile', 11),
#  (u'led', 11),
#  (u'amazonbasics', 11),
#  (u'educational', 11),
#  (u'intelligent', 11),
#  (u'adhesive', 11),
#  (u'chargeable', 11),
#  (u'steep', 11),
#  (u'pleased', 11),
#  (u'wise', 11),
#  (u'dynamic', 10),
#  (u'writing', 10),
#  (u'silver', 10),
#  (u'pesky', 10),
#  (u'subtle', 10),
#  (u'replaceable', 10),
#  (u'loaded', 10),
#  (u'complex', 10),
#  (u'just', 10),
#  (u'everything', 10),
#  (u'core', 10),
#  (u'plug', 10),
#  (u'fashioned', 10),
#  (u'lengthy', 10),
#  (u'hefty', 10),
#  (u'interior', 10),
#  (u'surprising', 10),
#  (u'precise', 10),
#  (u'equipped', 10),
#  (u'get', 10),
#  (u'seal', 10),
#  (u'come', 10),
#  (u'harsh', 10),
#  (u'coaxial', 10),
#  (u'dirty', 10),
#  (u'embed', 10),
#  (u'ac', 10),
#  (u'religious', 10),
#  (u'go', 10),
#  (u'compressed', 10),
#  (u'glad', 10),
#  (u'htc', 10),
#  (u'formatted', 10),
#  (u'fun', 10),
#  (u'seperate', 10),
#  (u'ur', 10),
#  (u'minimalist', 10),
#  (u'mbps', 10),
#  (u'enhanced', 10),
#  (u'worthy', 10),
#  (u'else', 10),
#  (u'likely', 9),
#  (u'wart', 9),
#  (u'end', 9),
#  (u'incompatible', 9),
#  (u'gigantic', 9),
#  (u'sdhc', 9),
#  (u'successful', 9),
#  (u'loyal', 9),
#  (u'fragile', 9),
#  (u'marvelous', 9),
#  (u'honest', 9),
#  (u'hardwired', 9),
#  (u'uneven', 9),
#  (u'lightning', 9),
#  (u'central', 9),
#  (u'wife', 9),
#  (u'cable', 9),
#  (u'gorgeous', 9),
#  (u'trusty', 9),
#  (u'telltale', 9),
#  (u'comfy', 9),
#  (u'immediate', 9),
#  (u'famous', 9),
#  (u'hype', 9),
#  (u'firm', 9),
#  (u'triple', 9),
#  (u'gopro', 9),
#  (u'choppy', 9),
#  (u'uncomfortable', 9),
#  (u'clever', 9),
#  (u'insane', 9),
#  (u'legitimate', 9),
#  (u'endless', 9),
#  (u'point', 9),
#  (u'vibrant', 9),
#  (u'recognize', 9),
#  (u'boot', 9),
#  (u'seagate', 9),
#  (u'pointing', 8),
#  (u'ergo', 8),
#  (u'phone', 8),
#  (u'warm', 8),
#  (u'order', 8),
#  (u'hidden', 8),
#  (u'mean', 8),
#  (u'urban', 8),
#  (u'do', 8),
#  (u'earn', 8),
#  (u'steam', 8),
#  (u'received', 8),
#  (u'resistant', 8),
#  (u'respectable', 8),
#  (u'class', 8),
#  (u'sustained', 8),
#  (u'crystal', 8),
#  (u'spindle', 8),
#  (u'o', 8),
#  (u'produce', 8),
#  (u'square', 8),
#  (u'turn', 8),
#  (u'sheer', 8),
#  (u'floppy', 8),
#  (u'sad', 8),
#  (u'say', 8),
#  (u'uninterrupted', 8),
#  (u'naked', 8),
#  (u'review', 8),
#  (u'mirroring', 8),
#  (u'unusual', 8),
#  (u'considerable', 8),
#  (u'muffled', 8),
#  (u'drain', 8),
#  (u'weekly', 8),
#  (u'onscreen', 8),
#  (u'discontinue', 8),
#  (u'finicky', 8),
#  (u'curvy', 8),
#  (u'scan', 8),
#  (u'awkward', 8),
#  (u'obscure', 8),
#  (u'replaced', 8),
#  (u'anymore', 8),
#  (u'throwaway', 8),
#  (u'google', 8),
#  (u'stationary', 8),
#  (u'accidental', 8),
#  (u'far', 8),
#  (u'mainstream', 8),
#  (u'click', 8),
#  (u'access', 8),
#  (u'sexy', 8),
#  (u'illegal', 8),
#  (u'seamless', 8),
#  (u'rubberized', 8),
#  (u'lame', 8),
#  (u'redundant', 8),
#  (u'enclose', 8),
#  (u'illuminate', 8),
#  (u'orginal', 8),
#  (u'lightening', 8),
#  (u'tidy', 8),
#  (u'powerfast', 8),
#  (u'bought', 8),
#  (u'lg', 8),
#  (u'relevant', 8),
#  (u'garmin', 8),
#  (u'mega', 8),
#  (u'rectangular', 8),
#  ...]

# %%
print_sentence_frag_multiprod(asin_dict, 'speed', adjective=None)
# Out:
# ------------------------------------------------------------
# speed
# ------------------------------------------------------------
#
# --------------------------------------------------
# B004G6002M
# --------------------------------------------------
#
# 12 	high
# ----------------------------------------
# 0 I know there is a higher speed one so if you need to have the data move
# 1 The card isn't meant for high-speed transfers and all that jazz, but it's great
# 2 but then again i didn't use it for high speed use
# 3 sure if sandisk even makes 16GB cards at a higher speed rating by the way.
# 4 phone, they are not know for needing the highest speed, it was the cheapest i could find and it
# 5 I'm going to try a higher speed (and higher priced) version to see if that
# 6 and I copy photos to the NaS at a higher speed.
# 7 the player may not work as well with the higher speed rating, since music files don't need a higher
# 8 rating, since music files don't need a higher speed card to work.
# 9 it is HC (high capacity) and not high speed but it keeps up with any of the high speed
# 10 speed but it keeps up with any of the high speed cards I have when i run it through testing software
# 11 If high speed access time is not particularly important that I would definitely
#
# 4 	good
# ----------------------------------------
# 0 Good read/write speeds, etc, etc.
# 1 Great quality and perfectly good speed.
# 2 These are REALLY, REALLY good speeds for a class 4 card, I cannot stress
# 3 1000 songs and keeps on trucking along with very good speed.
#
# 3 	write
# ----------------------------------------
# 0 getting an amazing read speed of 40+Mbps and a write speed of ~6Mbps.
# 1 'class-10', it must maintain a MINIMUM write speed of 10MB/s.
# 2 qualify since it cannot even achieve a MAXIMUM write speed of 10MB/s.
#
# 3 	read
# ----------------------------------------
# 0 Read speed is decent, around 20MB/s, but write speed is
# 1 Read speeds are as fast as PNY class 10, write speeds
# 2 4096kb, and now I'm getting an amazing read speed of 40+Mbps and a write speed of ~6Mbps.
#
# 3 	great
# ----------------------------------------
# 0 great speed and does what it says.
# 1 It provides great speed with no failures so far in my Coby Kyros tablets
# 2 Great speed as well.
#
# 2 	fast
# ----------------------------------------
# 0 I'll get a bigger memory card with a faster speed, they seem to get less expensive all the time
# 1 proven fact that Class 4 cards have a faster read/write speed on small files.
#
# 2 	faster
# ----------------------------------------
# 0 The higher class rated cards have faster file transfer speeds, but very sluggish with small random read/writes - the
# 1 Maybe I'd like a slightly faster writting speed, but every Solid State memory it's kinda slow
#
# 1 	fantastic
# ----------------------------------------
# 0 This microSD card works fantastic and great speed.
#
# 1 	random
# ----------------------------------------
# 0 Memory Toolkit v2.0', which measures the random read/write speed of files between 1MB and 15MB. The other one is
#
# 1 	advertised
# ----------------------------------------
# 0 Amazon!The advertised speed of Class 4 was not
#
# 1 	close
# ----------------------------------------
# 0 I seem to get read speeds close to 20MBps.
#
# 1 	perfect
# ----------------------------------------
# 0 quality is superb,space it perfect,and read/write speed is very fast as well compare to my old sd
#
# 1 	slow
# ----------------------------------------
# 0 Slow transfer speeds.
#
# 1 	descent
# ----------------------------------------
# 0 for only being class 4 memory it is a descent speed for accessing the data.
#
# 1 	transfer
# ----------------------------------------
# 0 Transfer speed i very
#
# 1 	enough
# ----------------------------------------
# 0 plays them back with enough speed to play flawlessly without any skips or anything.
#
# 1 	amazing
# ----------------------------------------
# 0 4096kb, and now I'm getting an amazing read speed of 40+Mbps and a write speed of ~6Mbps.
#
# 1 	sequential
# ----------------------------------------
# 0 'H2testw v1.4', which measures the sequential read/write speed using 1GB files.
#
# 1 	low
# ----------------------------------------
# 0 On most devices, this lowest-speed SanDisk card (class 4) is more than fast
#
# 1 	writting
# ----------------------------------------
# 0 Maybe I'd like a slightly faster writting speed, but every Solid State memory it's kinda slow
#
# 1 	maximum
# ----------------------------------------
# 0 18MB/S (this number may be limited by the maximum speed of my card reader used)What the above shows
#
# 1 	decent
# ----------------------------------------
# 0 have used this for rides on my motorcycle at decent speeds and over some pretty good bumps.
#
# 1 	quick
# ----------------------------------------
# 0 Works well, very reliably, quick read/write speeds, and was a great price at Amazon.
#
# --------------------------------------------------
# B006W8U2MU
# --------------------------------------------------
#
# 7 	write
# ----------------------------------------
# 0 it functions well enuf... but loading it [write speed] is very slow.
# 1 I know that the write speed is not the greatest but since i bought for a
# 2 as it's at the slow end of read write speed.
# 3 According to CrystalDiskMark Read speed was 18.5 MB/s and Write speed was 7.7 MB/s.
# 4 Write speeds are pretty slow: 5.5 MB/s.
# 5 Write speeds were about 2 MB/second.
# 6 , this drive's performance lowers further, the write speed dropped to 2.3-2.6MB/s sustained.
#
# 7 	read
# ----------------------------------------
# 0 Read speed is OK.
# 1 The read speed was much more consistent, and varied between 17 MB/s
# 2 For read speeds, I averaged 16.1 MB/s (ranged from 10 MB/s
# 3 In terms of speed ATTO Disk Benchmark shows maximum read speed of 20 megabytes per second and maximum write speed of
# 4 Read speeds are decent, write speeds are really slow.
# 5 The read speeds stayed in the 10-15 MB/s range and the
# 6 The read speed could be faster, but still pretty good.
#
# 6 	high
# ----------------------------------------
# 0 from my computer to save space, so ultra high speed performance is not as necessary as the accuracy of both
# 1 2.0 USB.  If you are NOT looking for HIGH speed read/write and just need a sturdy overall everyday flash,
# 2 is of the essence, then look for a high speed drive that can read/write 30 MB/s or faster.
# 3 out that this flash disk is coupled with a high speed memory cache which makes the read/write speeds look far better
# 4 I should note that these are definitely not high-speed drives.
# 5 the computers you need to use it with and high speed isn't a concern, it's a great little
#
# 5 	decent
# ----------------------------------------
# 0 Decent speeds.
# 1 It's got decent speed, but I bought this primarily for its design and
# 2 very reasonable price, it transfers data at a decent speed, and it just looks nice.
# 3 for a key-chain), and with decent speeds, USB 3.0 would be great for future iterations.
# 4 loop for keychain or lanyard, inner diameter 8.4mm- Decent speed, but not blazing fast: Large file writes 8MB/s
#
# 4 	slow
# ----------------------------------------
# 0 I was seeing speeds as slow as 4mbs as I neared the full 16gb
# 1 get it for less and don't mind the slower speeds.
# 2 The slow speed isn't worth the look of it.
# 3 at 7-11) and that cost is slower speed.
#
# 4 	average
# ----------------------------------------
# 0 These are considered to be AVERAGE speeds for usb flash drives.
# 1 The average speeds are 18 MB/s for reading and 12 MB/s for writing
# 2 2 gigabyte file to this flash memory yields an average speed of less than 7 megabyte per second although at the
# 3 Average read/write speeds at a great price.
#
# 3 	great
# ----------------------------------------
# 0 great size,great style,great speed.
# 1 Works great good speed.
# 2 very small, very keychain friendly USB drive with great speeds.
#
# 2 	fast
# ----------------------------------------
# 0 3.0, really starting to get use to these faster speeds, but I can't fault it a star for
# 1 If you want fast speed , get a portable hard drive!!
#
# 2 	nice
# ----------------------------------------
# 0 it with 2 programwith 2.0 port and 3.0 portreally nice speed in 3.0
# 1 it plugs in very easy, pretty nice read/write speeds, i was getting an average 3 to 4mbps write
#
# 2 	good
# ----------------------------------------
# 0 It has good read/write speeds for a USB 2.0 drive.
# 1 Works great good speed.
#
# 2 	typical
# ----------------------------------------
# 0 Typical speeds and temperature specs; overall an excellent thumb drive for
# 1 I had no problems with it, typical read/write speed, huge capacity.
#
# 1 	full
# ----------------------------------------
# 0 drives and SDHC cards in adapters that run at full speed on those ports.
#
# 1 	usb
# ----------------------------------------
# 0 USB 3 speeds will make them even better than they already are.
#
# 1 	tx
# ----------------------------------------
# 0 1gb+ size, transfers take much longer, and tx speed goes well below the usb2.0 transfer speed one would expect.but
#
# 1 	top
# ----------------------------------------
# 0 If I wanted top speed, I would get a 3.0 stick.
#
# 1 	amazing
# ----------------------------------------
# 0 u have4- the speed amazing for 2.05- best price for the quality  "
#
# 1 	other
# ----------------------------------------
# 0 About half the speed it seems, other than that the the product is
#
# 1 	black
# ----------------------------------------
# 0 the flash drive, I ran the Black Magic disk speed test (Mac, Mac app store) on it
#
# 1 	easy
# ----------------------------------------
# 0 it plugs in very easy, pretty nice read/write speeds, i was getting an average 3 to 4mbps write
#
# 1 	much
# ----------------------------------------
# 0 The other reviewers expect too much speed from a flash drive.
#
# 1 	disappointing
# ----------------------------------------
# 0 But it has disappointing speed.
#
# 1 	magic
# ----------------------------------------
# 0 the flash drive, I ran the Black Magic disk speed test (Mac, Mac app store) on it
#
# 1 	maximum
# ----------------------------------------
# 0 In terms of speed ATTO Disk Benchmark shows maximum read speed of 20 megabytes per second and maximum write speed of
#
# 1 	miraculous
# ----------------------------------------
# 0 speedy enough for most tasks; if you require miraculous speed, look to USB 3.0 and expect to pay a
#
# 1 	reasonable
# ----------------------------------------
# 0 32GB drive works just fine and seems to have reasonable speed for USB2.
#
# --------------------------------------------------
# B002QEBMAK
# --------------------------------------------------
#
# 3 	transfer
# ----------------------------------------
# 0 Perfect!My experiences and thoughts:- Transfer speed is quite good for a USB 2.0 external HDD that
# 1 Transfer speed is good, but the really impressive thing is that
# 2 Transfer speed is limited to USB 2.0 capacity, and it can
#
# 3 	good
# ----------------------------------------
# 0 Seriously, it's unbelievably quiet, has good speed, the size of the space on the drive is
# 1 of days, it works beautifully, has pretty good speed for 2.0, is a good size, and runs
# 2 source for backups and data storage, with good write speed.
#
# 3 	read
# ----------------------------------------
# 0 Its read speed is higher, but I don't exactly know the
# 1 Read speeds are reasonable for USB, although USB's not particularly
# 2 Sequential read speed = 100MB/s.
#
# 2 	high
# ----------------------------------------
# 0 It can be a bit noisy during high write speeds, but otherwise nearly silent.
# 1 Charcoal)You do pay more, but you do get high speeds even better than or equal to E-SATA speeds
#
# 2 	fast
# ----------------------------------------
# 0 it's ease of use and it's relatively fast speed for USB 2.0.
# 1 USB 2.0, so the much faster USB 3.0 transfer speeds will never be achieved.tl;dr: Would buy again.
#
# 2 	write
# ----------------------------------------
# 0 source for backups and data storage, with good write speed.
# 1 Write speeds are fast for small files,
#
# 2 	rotational
# ----------------------------------------
# 0 WD does not disclose the drive's actual rotational speed on any of their public spec sheets as it is
# 1 The rotational speed of 5400 RPM does not really matter for a USB
#
# 2 	average
# ----------------------------------------
# 0 I don't know about the average speed but it took me few hours to move everything which
# 1 , with the little Passport even doing better on average speed, the Elements drive feels faster during actual use.
#
# 1 	full
# ----------------------------------------
# 0 The drives spin up to full speed within seconds upon the first data request made to them
#
# 1 	same
# ----------------------------------------
# 0 It runs at the same speed as your average notebook drive, so filling up a
#
# 1 	download
# ----------------------------------------
# 0 Download speed is a little slow but more memory is even better
#
# 1 	spindle
# ----------------------------------------
# 0 marketing blurb) which basically does a balance between spindle speed, transfer rate, and caching algorithms, In reality
#
# 1 	best
# ----------------------------------------
# 0 20-30 Mb/s was the best speed I managed to get.
#
# 1 	compact
# ----------------------------------------
# 0 Pros:- sleek black compact quasi-rugged casing- decent write speeds of 40-50 MBps (megabytes per second)
#
# 1 	slow
# ----------------------------------------
# 0 I can live with the inherent slow speed of the drive and the green power.
#
# 1 	tremendous
# ----------------------------------------
# 0 great...but...With the caveat of the tremendous speed of USB 2.0 (insert sarcasm here), but
#
# 1 	sequential
# ----------------------------------------
# 0 Sequential read speed = 100MB/s.
#
# 1 	various
# ----------------------------------------
# 0 has a single subtle white LED that flashes at various speeds to indicate if it is reading/writing data or if the
#
# 1 	low
# ----------------------------------------
# 0 or as an auxiliary storage device for relatively low-speed requirements.
#
# 1 	black
# ----------------------------------------
# 0 Pros:- sleek black compact quasi-rugged casing- decent write speeds of 40-50 MBps (megabytes per second)
#
# 1 	comparable
# ----------------------------------------
# 0 far, the product has performed great and with comparable speed to my other drives.
#
# 1 	increased
# ----------------------------------------
# 0 Two tips for increased speed of the drive for copy/backup use...
#
# 1 	performance
# ----------------------------------------
# 0 PERFORMANCE: speed is pretty standard for USB 2.0, so acceptable.
#
# 1 	variable
# ----------------------------------------
# 0 the internal drive in this uses the same variable-speed technology as in the WD Green drives
#
# 1 	actual
# ----------------------------------------
# 0 WD does not disclose the drive's actual rotational speed on any of their public spec sheets as it is
#
# 1 	copy
# ----------------------------------------
# 0 it into four drives in hopes of improving the copy speed.
#
# 1 	true
# ----------------------------------------
# 0 directly, so I can't attest to the true speed of this hard drive...
#
# 1 	sleek
# ----------------------------------------
# 0 Pros:- sleek black compact quasi-rugged casing- decent write speeds of 40-50 MBps (megabytes per second)
#
# 1 	great
# ----------------------------------------
# 0 Great read/write speed.
#
# 1 	rugged
# ----------------------------------------
# 0 Pros:- sleek black compact quasi-rugged casing- decent write speeds of 40-50 MBps (megabytes per second)
#
# 1 	mbps
# ----------------------------------------
# 0 all the computers, it is giving about 10 mbps speed
#
# 1 	quiet
# ----------------------------------------
# 0 What I like of this drive, quiet, reasonably speed and looks neat.
#
# 1 	inherent
# ----------------------------------------
# 0 I can live with the inherent slow speed of the drive and the green power.
#
# --------------------------------------------------
# B002SZEOLG
# --------------------------------------------------
#
# 18 	high
# ----------------------------------------
# 0 this USB adapter cannot keep up with your high speed internet.
# 1 Don't hesitate if you're looking for higher wireless speeds but keep in mind that you will also need a
# 2 No issues whatsoever yet  I get high speeds with my dell hybrid PC.  This was to replace
# 3 users who demand better throughput to take advantage of high speed internet connections.
# 4 She can't get high speed internet at her house, but she has a neighbor
# 5 a Netgear WN111 v2 adapter & hardly ever got a speed higher than 30 Mbps.
# 6 a router and now this card that both have high speeds and individual transmit/receive antennae, absolutely no noticeable loss of
# 7 , I'm taking full advantage of the high-speed internet access and getting 4 out of 5 bars consistently
# 8 However for high speeds,I would start looking at more other items.
# 9 you need a larger device to hold the high-speed hardware and this one is nice and tiny.
# 10 very perfect sized equipment , high speed data transferring ,recommended for people need to install a
# 11 , but never received a strong radio signal or high speeds as a result of being both inside the desktop case
# 12 After shopping for a high speed adapter, I selected this TP-Link.
# 13 -in adapter, adding to the pleasure of high speed service.
# 14 need an easy setup and likely do not have high speed demands.
# 15 router for a while, and have enjoyed the higher speeds on a couple devices and wireless bridge that support N.
# 16 a LAN speed test to a server connected via high speed cable connection directly to the router.
# 17 the computer using the adapter to connect at the higher speed.
#
# 16 	download
# ----------------------------------------
# 0 following results:with TP-Link adapter:25.06, 5.12 ( download speed, upload speed)18.53, 5.3227.55, 5.2229.32, 5.3025.86,
# 1 Warner account "speed test" gauged my download connection speed at a pitiful 10 Mbps, and my upload speed
# 2 internet connection which may also have contributed to the download speed and unfortunately is too slow for streaming video.
# 3 Using this adapter I get download speeds of 1.5 Mb on an almost useless network before using
# 4 it connects as 144Mbs and gives at best 39Mbs downloading speed.
# 5 conditions it gives 300Mbs connection speed and ~170Mbs effective downloading speed.
# 6 test and was getting between 1-2 Mbps download speed on my ultrabook.
# 7 using the same server) and I got my download speed to increase to 15 Mbps!
# 8 Increased my download speed from around 2 Mbps to 15 Mbps.
# 9 just over 6 Mbps to over 60 Mbpd on download speed.
# 10 to work very well after restart the PC. The download speed and signal gain are very good.
# 11 not really that useful if you want to boost download speeds.
# 12 I'm only gettong 50K download speed with this thing
# 13 The download speed varies between 8Mb-12Mb - it probably hits 12mb because of
# 14 The download speed is almost as good as I can get by plugging
# 15 would recommend it to someone needing more range and download speed.
#
# 11 	fast
# ----------------------------------------
# 0 router homepage, and you will be getting the fastest speed out of your connection possible, along with the least
# 1 Very fast speed for the price.
# 2 standard for it's better signal strength and potentially faster speeds.
# 3 , it's a more stable connection and obviously faster speed for them.
# 4 Presto, fast speeds again.
# 5 I'm sure it would get much faster speeds on the LAN, but I don't care --
# 6 a good chance we'll all be using a faster speed anyway.
# 7 to make it wifi ready and allow for the fastest speed available with n standard and 5GHZ.
# 8 Blazing fast speed.
# 9 on wireless g and hoped I could get faster download speeds with this adapter.
# 10 It downloads and uploads with faster speed.
#
# 9 	good
# ----------------------------------------
# 0 tried to do any streaming but it was getting good speeds and wasn't randomly disconnecting me.
# 1 This one works *awesome*. Great reception, good speed.
# 2 brands), I cannot get a good enough speed to the office.
# 3 I get good speed from this accessory.
# 4 computer, which faces my router, I get fantastic speeds with excellent consistency and low latency, as good as
# 5 Good speed.
# 6 for my use of it, it has a good speed, has a nice style, and will hold up
# 7 is perfect, but I did not get very good speed, so streaming video,even youtube, may be
# 8 1 foot antenna10 dBi 2.4GHz WIFI AntennaI get very good speeds but like the other ones I had owned in the
#
# 8 	slow
# ----------------------------------------
# 0 has lost signals at times and loaded websites at slow speed.
# 1 than I was happy with due to the sorry slow speed of our Time Warner connection, despite having an account
# 2 not receiving packets, and  had a slow connection speed for media streaming.
# 3 So I connected to the 2.4GHz network instead (slower speed, but better than nothing.)
# 4 Can you imagine a speed slower than a T1 between devices in your home?
# 5 that the best I could hope for was mediocre connection speeds, slow enough that I do have some minor issues
# 6 My previous wireless adapter was suffering from annoyingly slow speeds and low signal strength connections.
# 7 but the only change in actual speed was a slower speed since it's just another device to pull from my
#
# 7 	full
# ----------------------------------------
# 0 USB2 and therefore wouldn't be able to pull full speed on this adapter.
# 1 Most users will never achieve the full 300 Mbps speeds but you have to account for what type of router
# 2 if you want an adapter that just connects at full speed and stays connected for a good price then this might
# 3 the Advanced adapter settings to make it work at full speed.
# 4 with the utility it can be set to the full speed and 5Ghz band but with standard Windows 8 capabilities you
# 5 15mbps internet, but i was able to get full speed through this adapter on the second floor (my router
# 6 Running at full speed (300mbps) always.
#
# 6 	wireless
# ----------------------------------------
# 0 is "Plug 'n Play" with a wireless speed up to 150Mbps.
# 1 Upgrader (TEW-637AP)), and doubled the wireless speed.
# 2 my router and my wife's laptop has excellent wireless speed.
# 3 I'm now connected at wireless N speed as well.
# 4 've read it has a better penetration/range and wireless N speeds are not really a concern for me.
# 5 The wireless strength improved but somehow the wireless speed still remain low at 1mbps when is just 2 wall
#
# 5 	same
# ----------------------------------------
# 0 3.0 it is able to deliver the same 87 mbps speed and not lag at all during my games.
# 1 I'm getting the same speed that I get via wire (about 42 Mbps down
# 2 That's the same speed I get when I bring my ultrabook down to the
# 3 them, and found that it is about the same speed as the other two.
# 4 issues with our TP-LINK router of the same speed (regardless of which PC we plug it into)Nothing major
#
# 5 	great
# ----------------------------------------
# 0 its connection without fail, and I am achieving greater speeds than I ever did with the old adapter.
# 1 I'm getting great download speeds.
# 2 all my neighbors wifi's and I get great download speeds.
# 3 on my Windows 7 machine, I got great download speeds and never lost connection, however I did have a
# 4 He gets on average 150-200kbs greater speeds than I do, and also has far less trouble
#
# 3 	upload
# ----------------------------------------
# 0 such non-ideal situation, I got a upload speed of 20Mbps for copying file in local network.
# 1 speed at a pitiful 10 Mbps, and my upload speed at an incredibly embarrassing and slow as molasses speed of
# 2 other people's signal space :P - but the upload speed has been really constant at 1.7Mb or so since I
#
# 3 	much
# ----------------------------------------
# 0 Don't spect much speed, this thing it's not
# 1 have had great luck with this unit without loosing much speed compared to other units.
# 2 I feel like I just added so much speed to my computer.
#
# 3 	faster
# ----------------------------------------
# 0 used for that, and you will be getting faster speeds with n. (N has far better throughput reliability,
# 1 router--and you most likely will be getting faster speeds with that band too.
# 2 have pre-N systems who want/need a bit faster speed or range.
#
# 3 	maximum
# ----------------------------------------
# 0 -64PRO. I was never able to get teh maximum speed advertised, but was able to pull around 150mbps from
# 1 In the same network, I saw a maximum connection speed of 300 Mbps, but that was one instance and
# 2 Excellent" all the time, with the maximum 54Mbps speed.
#
# 2 	low
# ----------------------------------------
# 0 it would randomly disconnect and then reconnect at a lower speed.
# 1 But for lower speeds it will work just fine.
#
# 2 	average
# ----------------------------------------
# 0 faster than mine (i.e. >10x improvement in average connection speed in our experience).
# 1 lucky, and i mean very lucky, my average speed is 65 kb/s.i have a laptop with a G series
#
# 2 	nice
# ----------------------------------------
# 0 works perfectly, providing a good N connection and nice speeds.
# 1 router with no problems and I instantly saw a nice speed increase on my Laptop, it now rivals my iPhone
#
# 1 	available
# ----------------------------------------
# 0 to make it wifi ready and allow for the fastest speed available with n standard and 5GHZ.
#
# 1 	fantastic
# ----------------------------------------
# 0 computer, which faces my router, I get fantastic speeds with excellent consistency and low latency, as good as
#
# 1 	constant
# ----------------------------------------
# 0 ** I get constant download speeds of 12Mbps+, which is close the the max of
#
# 1 	extra
# ----------------------------------------
# 0 off yet) and lets you get both some extra speed and range out of your WIFI connection.
#
# 1 	adequate
# ----------------------------------------
# 0 and it worked well until it no longer ran adequate speeds.
#
# 1 	direct
# ----------------------------------------
# 0 it did deliver my 87 mbps speed (direct ethernet speeds) it would lag when I played League of Legends
#
# 1 	promise
# ----------------------------------------
# 0 giving Time Warner a hard time over not providing promised speeds until they pushed me on troubleshooting MY equipment.
#
# 1 	advertised
# ----------------------------------------
# 0 My advertised speed is 35/25 with Fios, but with this wireless,
#
# 1 	close
# ----------------------------------------
# 0 I was getting a burst speed close to 55mbps down and constant speeds in the 30
#
# 1 	mediocre
# ----------------------------------------
# 0 that the best I could hope for was mediocre connection speeds, slow enough that I do have some minor issues
#
# 1 	best
# ----------------------------------------
# 0 Best speed I was able to get at connection of 300Mbs was
#
# 1 	different
# ----------------------------------------
# 0 connections to the same router, each connecting at different speeds.
#
# 1 	decent
# ----------------------------------------
# 0 However, you will get decent speeds of anywhere from 35 - 75 Mbps over Wireless N
#
# 1 	burst
# ----------------------------------------
# 0 I was getting a burst speed close to 55mbps down and constant speeds in the 30
#
# 1 	dsl
# ----------------------------------------
# 0 install, get connected and most of all I DSL speed is as fast as if the Ethernet cable was plugged
#
# 1 	better
# ----------------------------------------
# 0 It gets much better speed than most of my other older 2.4Ghz devices.
#
# 1 	amazing
# ----------------------------------------
# 0 Installs without issues, great signal and amazing speed of 105 Mbps(the signal of the N300 High Gain is
#
# 1 	sorry
# ----------------------------------------
# 0 than I was happy with due to the sorry slow speed of our Time Warner connection, despite having an account
#
# 1 	more
# ----------------------------------------
# 0 wish I would have gotten one that allowed more connection speed.
#
# 1 	poor
# ----------------------------------------
# 0 Poor connection speeds compared to other high gain usb wireless antennas I've
#
# 1 	snail
# ----------------------------------------
# 0 i have and no luck it still runs at snail speed, so i am actually quite frustrated at this point
#
# 1 	gettong
# ----------------------------------------
# 0 I'm only gettong 50K download speed with this thing
#
# 1 	lower
# ----------------------------------------
# 0 to 300Mbps for maximum throughput and automatically adjusts to lower speeds due to distance or other operating limitations- USB 2.0 interface-
#
# 1 	immediate
# ----------------------------------------
# 0 It's only anecdotal, but I noticed an immediate speed up in my internet connection with this newer adapter,
#
# 1 	excellent
# ----------------------------------------
# 0 my router and my wife's laptop has excellent wireless speed.
#
# 1 	potential
# ----------------------------------------
# 0 does NOT connect at the advertised "150Mbps" potential speed when it's configured to do so, but I
#
# 1 	actual
# ----------------------------------------
# 0 with the adapter, but the only change in actual speed was a slower speed since it's just another device
#
# 1 	effective
# ----------------------------------------
# 0 conditions it gives 300Mbs connection speed and ~170Mbs effective downloading speed.
#
# 1 	up
# ----------------------------------------
# 0 Yes thats right; the up and down speeds not only INCREASED, but they are nearly equal.
#
# 1 	steady
# ----------------------------------------
# 0 I get speeds of up to 100mb, steady speeds at 60mb+. I rarely get an interruption due to the
#
# 1 	advertized
# ----------------------------------------
# 0 Major downside of the 2.4ghz not getting the advertized 300megabit speed is that 5ghz range tends to be shorter than 2.4ghz
#
# 1 	due
# ----------------------------------------
# 0 to 300Mbps for maximum throughput and automatically adjusts to lower speeds due to distance or other operating limitations- USB 2.0 interface-
#
# 1 	quick
# ----------------------------------------
# 0 -15&#34; from the wall resulted in pretty quick speeds.
#
# 1 	ethernet
# ----------------------------------------
# 0 it did deliver my 87 mbps speed (direct ethernet speeds) it would lag when I played League of Legends
#
# 1 	mbps
# ----------------------------------------
# 0 You get 150 Mbps speed - you can get a LOT faster, but these
#
# 1 	typical
# ----------------------------------------
# 0 laptops within my home gave transfer speeds affording typical 802.11n speeds.
#
# --------------------------------------------------
# B000VX6XL6
# --------------------------------------------------
#
# 8 	write
# ----------------------------------------
# 0 Has the write speed expected of a class 4, love Kingston and would
# 1 Write speed is fast and read speed is also good.
# 2 Write speeds are great for a 4GB card and this card has
# 3 The write speed is a tad slow, but the read speed is
# 4 class-4' card means it must sustain a MINIMUM write speed of 4MB/s; a 'class-10' means 10MB/s,
# 5 of 1MB to 15MB, this card can achieve write speed between 6.5MB/s and 10MB/s- For huge file size of 1GB
# 6 For huge file size of 1GB each, its write speed is 9.4MB/s- The read speed is consistently high at ~16MB/s
# 7 I tested this card and got a write speed of 4 and a read speed of 6 - 7
#
# 7 	high
# ----------------------------------------
# 0 If you intend to use your card for high speed data transfers or video recording I'd recommend a higher
# 1 for audio and look forward to the price of higher speed high capacity cards coming down in price in coming months
# 2 for a gps or devices that do not need high speed.
# 3 mp3 players that can't use more expensive, high speed flash cards.
# 4 Would not suggest using on any high speed devices like cameras.
# 5 Good buy for devices that don't need high speed storage.
# 6 I would only use a higher speed card if I needed one for a camera or videorecorder
#
# 7 	read
# ----------------------------------------
# 0 this and popping into my computer the right and read speeds seem okay not really fast and not really so ca
# 1 I get read speeds of 3.0 MS/s and write speeds of 3.6 to 4.4
# 2 For read speeds, it's around 20 MB with the default 128
# 3 write speed is a tad slow, but the read speed is fast enough to stream music and video.
# 4 1GB each, its write speed is 9.4MB/s- The read speed is consistently high at ~16MB/s, regardless of file sizeThat
# 5 Read speed was 20MB/sec.
# 6 and got a write speed of 4 and a read speed of 6 - 7, so it is likely legit
#
# 6 	good
# ----------------------------------------
# 0 It does all that at a good speed.
# 1 Good speed and never had an issue with reading files or saving
# 2 Excellent quality, good speed.
# 3 good price, excellent quality (Kinstone) and good speed (Class 4), which gives you a data
# 4 Good speed and adequate space for music playing on an MP3 player
# 5 Very good data, good speed.
#
# 4 	decent
# ----------------------------------------
# 0 Decent speed and very good price.
# 1 4' means, it seems to work a decent speed though, no complaints just "not sure."Edited Jan 1,2009Works
# 2 rsync through the terminal still gave decent write speeds, though.
# 3 Pretty decent speed.
#
# 4 	fast
# ----------------------------------------
# 0 Series Class 10 40MB/s UHS-1 32GB MicroSD Cardat a faster speed and bigger size, had issues.
# 1 up to 8 gig and didn't need the faster speed of some other cards, I got this one.
# 2 class 4 memory card so don't expect the fastest speeds.
# 3 phone, I really have no need to blazing fast speed.
#
# 2 	slow
# ----------------------------------------
# 0 I bought this as a lower class thinking the slower speeds will at least keep the life longer.
# 1 so avoid in latest cameras and cell phones (slow speed) .
#
# 2 	reasonable
# ----------------------------------------
# 0 the non-pro like me who just wants reasonable speed at a great price.
# 1 Reasonable read/write speeds.
#
# 1 	extra
# ----------------------------------------
# 0 Class 10 card, but did not need the extra speed for this use.
#
# 1 	varying
# ----------------------------------------
# 0 and its not blazing fast but USB 2 has varying speeds no matter how fast your card is supposed to be
#
# 1 	medium
# ----------------------------------------
# 0 I  would say it is about medium speed when copying
#
# 1 	file
# ----------------------------------------
# 0 File transfer speed was fast.
#
# 1 	advertised
# ----------------------------------------
# 0 We ordered 6 of these. 3 met the advertised speeds, three did not.
#
# 1 	much
# ----------------------------------------
# 0 is average, but you don't need that much speed when taking pictures or filming video, or while listening
#
# 1 	expected
# ----------------------------------------
# 0 transferred quickly and easily to my computer at an expected speed.
#
# 1 	tolerable
# ----------------------------------------
# 0 Not a super fast card, but performs at tolerable speeds.
#
# 1 	excellent
# ----------------------------------------
# 0 Excellent speed and data transfer either direct or through the provided adapter
#
# 1 	true
# ----------------------------------------
# 0 CrystalDiskMark and everything came out clear with true class 4 speed (4mb/s) a tested capacity of 7.4GB. I plugged
#
# 1 	class
# ----------------------------------------
# 0 The class 4 doublesthe speed of the original memory card in the reader.
#
# 1 	transfer
# ----------------------------------------
# 0 Transfer speed is very good, not super fast but not too
#
# --------------------------------------------------
# B0041Q38NU
# --------------------------------------------------
#
# 9 	high
# ----------------------------------------
# 0 is actually rated at but for a claimed "high speed drive" it did not reach my expectation.
# 1 Not as high-speed at copying many small files as the Patriot Xporter but
# 2 conscious of the fact that it wasn't a high speed memory.
# 3 Can't speak for how high speed it is but in loading my music seems fast enough
# 4 there are flash drives out there that use higher-speed memory chips, but cost more.
# 5 , theTranscend 16 GB JetFlash 500was able to achieve higher speed of 6.8MB/s (for 1MB file) to 11.3MB/s (
# 6 I don't need high speed because I use it for DVD player from my camera
# 7 release because most people don't have a high-speed internet connection that can handle a 4GB download or they
# 8 You just have to know it is not real high speed so not great for more intensive copying of files.
#
# 8 	good
# ----------------------------------------
# 0 I am getting pretty good speeds of about 13 MB/sec reading and 8 MB/sec writing my
# 1 Good speed in download or upload and good relatively small size.
# 2 Good speed, has held up well including a trip through the
# 3 The Kingston is a fine drive with good speed (The Amazon Tech Specs say it is a 5MB/s
# 4 no matter what I plug it into.it's got good speed, and doesn't hesitate.
# 5 Great flash drive, with good access speeds (or at least sufficiently fast that I don't
# 6 Good speed.
# 7 Good speeds, good reliability, and handy cap that can't
#
# 7 	fast
# ----------------------------------------
# 0 holds a ton of data, has a pretty fast speed when copying larger files, and it is pretty compact
# 1 Excellent performance, fast read/write speed, no complaints.
# 2 This thing has such a fast write/transfer speed compared to all my other Flash Drives.
# 3 Quality build, fast speeds, doesn't hurt that it looks good too.
# 4 The drive is not that fast but speed is comparable to most USB drives in this size.
# 5 Fast speed compared to other USB 2.0 products I've purchased.
# 6 erased it and it still works well at a fast speed in my XP environment.
#
# 7 	write
# ----------------------------------------
# 0 4-stars because the write speed doesn't seem particularly fast.
# 1 They can barely maintain a 3MBPS write speed...
# 2 warned that, for the 8GB version, the write speed is really just 5MB / second.
# 3 simple:pros:cheap, very large, neat design, sturdycons:Slow Write speed.
# 4 for smaller files of 1-5MB, the write speed is only 5.7 - 6.2MB/s (see the Customer Image
# 5 The write speed is about 2/3 of what they claim (about 3.5
# 6 to the device took about an hour; the write speed was only 2.6MB/sec.
#
# 5 	read
# ----------------------------------------
# 0 As stated above the read speeds are sufficient for this application.
# 1 pentium) in VLC Media Player, so the read speed is at least enough for high def video.
# 2 The read speed is excellent, consistent with what the manufacturer claims (
# 3 Read speed is good and since my application is to play mp3
# 4 I wanted something short/small with reasonable read speeds and at a good price point.
#
# 3 	download
# ----------------------------------------
# 0 Download speed seemed more than adequate but I didn't download a
# 1 Good usb worth for the price but download speed is really slow lol takes around 30 minutes for 12
# 2 However if download speed for large chunks of data is a consideration, then
#
# 3 	slow
# ----------------------------------------
# 0 the drive and all had the same outcome of slow speeds on larger files.
# 1 , when occasionally does, runs at a very slow speed.
# 2 The slow speed is a killer.
#
# 3 	hi
# ----------------------------------------
# 0 The Kingston Digital 16 GB USB hi-Speed Datatraveler Flash Drive is an excellent, compact device for
# 1 This product shows as hi speed.
# 2 This really is a hi-speed datatraveller.
#
# 3 	reasonable
# ----------------------------------------
# 0 They are affordable, reliable, transfer data at reasonable speeds, and are designed well.
# 1 You just need one that is a reasonable speed so you aren't hanging around all afternoon.
# 2 I wanted something short/small with reasonable read speeds and at a good price point.
#
# 2 	great
# ----------------------------------------
# 0 metal cover - fires right up and has great read/write speed.
# 1 an option to attach it with you).Great product, great speeds - happy with this purchase.
#
# 2 	decent
# ----------------------------------------
# 0 it transfers at a decent speed and for only a 10 odd bucks, its definitely
# 1 weight of this flash drive and it gets decent read/write speeds too.
#
# 1 	right
# ----------------------------------------
# 0 be any happier this is worth every penny!Read and right speeds seem to vary overall best speeds where on a windows
#
# 1 	rated
# ----------------------------------------
# 0 This is over twice as fast as its rated speed, which claims just 5MB/s write and 10MB/s read.
#
# 1 	extra
# ----------------------------------------
# 0 which is more important to me than a little extra speed.
#
# 1 	medium
# ----------------------------------------
# 0 Slow-medium speed.
#
# 1 	same
# ----------------------------------------
# 0 It seems to have the same speed as the 32gb which is pretty decent.
#
# 1 	best
# ----------------------------------------
# 0 every penny!Read and right speeds seem to vary overall best speeds where on a windows 8 laptop!
#
# 1 	little
# ----------------------------------------
# 0 which is more important to me than a little extra speed.
#
# 1 	transfer
# ----------------------------------------
# 0 Transfer speed is pretty fast.
#
# 1 	writing
# ----------------------------------------
# 0 , the Reading speed is 10MB/sec, while the Writing speed is 5MB/sec.
#
# 1 	amazing
# ----------------------------------------
# 0 saidRecommendations:This product certainly works, but don't expect amazing speeds.
#
# 1 	nominal
# ----------------------------------------
# 0 but my other pen drives work at nominal USB 2.0 speed
#
# 1 	low
# ----------------------------------------
# 0 Obviously due to the low speeds I really feel the drive is a back up device
#
# 1 	test
# ----------------------------------------
# 0 Test speed and it about 25MB/s read and about 10MB/s write
#
# 1 	totransfer
# ----------------------------------------
# 0 works well does what it is supposed totransfer speed is 4.5 mb/snice and small, very portable.
#
# 1 	adequate
# ----------------------------------------
# 0 Adequate speed and capacity.
#
# 1 	theoretical
# ----------------------------------------
# 0 does not come close to the theoretical 60MB/sec max I/O speed that the USB 2.0 specification allows.- Installs itself and does
#
# 1 	nice
# ----------------------------------------
# 0 Very good drive with nice speed for the price.
#
# 1 	real
# ----------------------------------------
# 0 You just have to know it is not real high speed so not great for more intensive copying of files.
#
# 1 	comparable
# ----------------------------------------
# 0 Speed comparable to other USB 2 devices.
#
# 1 	install
# ----------------------------------------
# 0 $40 for a freaking flash drive!!!!!!BTW ... the install
#
# 1 	stellar
# ----------------------------------------
# 0 It's USB 2.0, so don't expect stellar speed, but they read/write is still faster than most other
#
# 1 	excellent
# ----------------------------------------
# 0 It has excellent speed, handles HD video well and its memory is pretty
#
# 1 	exact
# ----------------------------------------
# 0 I don't know what the exact speed was, but it was similarly priced.
#
# 1 	faster
# ----------------------------------------
# 0 speeds, but then again, if you want faster speeds, you're probably not looking at a $6
#
# 1 	wifi
# ----------------------------------------
# 0 Slower than a HALF of my wifi network speed from a fiberoptic cable.
#
# 1 	list
# ----------------------------------------
# 0 Definitely top of the line and exceeds the listed read/write speeds.
#
# 1 	limit
# ----------------------------------------
# 0 drives besides their being USB 2.0 and their limited read/write speeds, but then again, if you want faster speeds
#
# --------------------------------------------------
# B004XC6GJ0
# --------------------------------------------------
#
# 36 	high
# ----------------------------------------
# 0 This particular model is capable of upgrades to the higher speeds if and when that is needed, which means another
# 1 This cable modem detected this higher speed capability.
# 2 became available in our area and we subscribed to higher speeds, our ISP provided us a cable modem/router gateway combo
# 3 fast good connection, resets quickly works with TWC high speed.
# 4 Work great with my high speed connection package on TW.
# 5 Instead of starting off at high speeds and tapering down, they start and finish at about
# 6 was spending a fortune every month to get the highest speed of service.
# 7 too old and was not able to handle the higher speeds.
# 8 I added a high speed router from Netgear and I now have the best connection
# 9 I recently switched my ISP from Comcast to RCN high speed (up to 110 MBPS down/15MBPS up) and purchased
# 10 this modem because my cable internet provider Comcast offers higher speeds than previously so a docsis 3.0 modem is a must
# 11 , since the SB5120 simply refused to function at higher speeds than it was already operating at.
# 12 Surprise was that I am getting high speed only when connecting computer via Ethernet.
# 13 Love the higher speeds, just wish we had less issues with Comcast!
# 14 My next purchase will be a high speed router to match.
# 15 The modem puts out very high speeds, I've never had issues with lag or loss
# 16 and I purchased to upgrade all my computers to high speed.
# 17 Very high speed (10-20% faster than the rental one
# 18 connection speed to demand a higher payment for "high speed" access.
# 19 I use it for high speed data work at home, but didn't needthe fastest
# 20 works great with Comcast, and I frequently even get speeds higher than my connection is rated to get.
# 21 since it's already DOCSIS 3.0 and can support higher speeds if I upgrade my bandwidth.
# 22 am able to upgrade Time Warner internet to ultra high speed in the future.
# 23 as the DOCSIS 2.0 modem cannot handle very high speeds, and this is where the DOCSIS 3.0 comes in
# 24 connection down even though you are paying for a high speed connection.
# 25 using a 2.0 modem and are paying for a high speed cable connection, the newer 3.0 modem will be what
# 26 I believe if you're not getting the much higher speeds you expected it's probably a, the cable plan
# 27 ) to be an excellent handler of the high-speed signals of Cable, Satellite, and HDTV signals.
# 28 If you need a DOCSIS 3 modem to utilize higher speeds from your cable provider, look no further than the
# 29 Cable companies bombard the TV claiming high speed availability for everyone.
# 30 I've also seen the higher speeds with this modem vs the one suddenlink provided (smc
# 31 Maxes out my TWC 'high speed' connection limits on up and down runs without issues
# 32 spectacular, but I'm not paying for the higher speed tiers)So, there is a nice bump in speed.
# 33 for Internet and they are Verizon DSL w/ a Highest speed purchased of 3.0Mbs download & 0.756Mbs upload speed @ a
# 34 So far I got this to work with charter high speed called them to activate it and once activated There have
# 35 Comcast) that my area (finally) had higher speed access avaialble.
#
# 24 	download
# ----------------------------------------
# 0 My download speed went from a ridiculously slow 2 Mbps to over 30
# 1 First impressions are that I am getting faster download speed from the Motorola, vice the TWC supplied modem.
# 2 with Cox.net cox communicationsat 25MB down i am getting download speed of 3.2MB/S and 6.4MB/S it works great buy it
# 3 indicate that Cox has me throttled down to 20Mbps download speed, and that doesn't come anywhere near the claimed
# 4 Download speed via ethernet from the SB6121  to the mac mini
# 5 DOCSIS 3.0 (new modem)brought me up to the download speed I was actually paying for...plus an additional 1
# 6 I pay for 15 mbps download speed from Mediacom.
# 7 the Surfboard, ping latency dropped to 11ms, download speed is now 25+ often as high as 30Mbps and upload
# 8 docsis 2 to this, docsis 3, my download speed went from 15 gig to 55 gig.
# 9 Download speed doubled.
# 10 download speed stayed the samefrom older modem.
# 11 This modem performs within 3% of my max download speed.
# 12 After installing the SB 6121, download speed improved to 35 Mbps.
# 13 stay productive (I was limited to 3 MB/s download speed with my DSL provider, while the cable modem offered
# 14 The speed test showed our download speed was now 68.28mbps and upload speed now 24.93.So I believe
# 15 the modem activated, I noticed immediately that the download speed never got above 14.46Mbps and the download seemed to struggle
# 16 speed ($10/month increase); download speed went from 17 to 35+ mbps, upload speed went
# 17 1.2mbs upload speed at the modem and about 1.6mbs download speed behind my 10/100 T base standard switches.
# 18 When I installed it, my download speed went from 13 mbps to 30 mbps.
# 19 (With the E1000 router in line, the download speed is only 12 Mbits/sec and there's no PowerBoost to
# ...
#
# 2 	low
# ----------------------------------------
# 0 The laptop fan was running at low speed once awhile.
# 1 The laptop cooling fan is running at low speed and the system RAM is warm again.
#
# 2 	average
# ----------------------------------------
# 0 score also jumped from 5.9 to 7.4 and average read speed went from 103MB/s to 217MB/s (not forgetting that the
# 1 Per HD Tune Pro, average read speed increased from 90.2 MB/s to 202.3 MB/s, access time
#
# 1 	insane
# ----------------------------------------
# 0 to my Retina MBPro where I saw some insane copy speeds (about 450MB/sec).
#
# 1 	extra
# ----------------------------------------
# 0 MacBook Pro i5, but I did want the extra speed.
#
# 1 	true
# ----------------------------------------
# 0 the same as a result these drives deliver the true speed advertised unlike most other products that do not delivery in
#
# 1 	consistent
# ----------------------------------------
# 0 on capacity, but after you've tasted the consistent speed they provide, it is almost impossible to go back
#
# 1 	hard
# ----------------------------------------
# 0 Windows Experience Index being held back by your hard drive speed?
#
# 1 	crackle
# ----------------------------------------
# 0 But the pop and crackle speed of the SSD, however, makes you more productive
#
# 1 	maximum
# ----------------------------------------
# 0 run some command in terminal to put the maximum fan speed on a certain number.
#
# 1 	rat
# ----------------------------------------
# 0 Marvell no problem as it won't approach the rated speed anyway.
#
# 1 	promised
# ----------------------------------------
# 0 still a bit pricey, they do deliver the promised speed.
#
# 1 	shutdown
# ----------------------------------------
# 0 Shutdown speed is almost instant (5 seconds) and programs load
#
# 1 	advertise
# ----------------------------------------
# 0 to (or slightly better than) the advertised Read/Write speeds using ATTO. AS SSD doesn't run very well on
#
# 1 	best
# ----------------------------------------
# 0 I know it won't work at the best speeds, but I now can transfer the SDD to a
#
# 1 	access
# ----------------------------------------
# 0 will eventually require a low level reformat to maintain access speed, but for the average user this will be long
#
# 1 	slow
# ----------------------------------------
# 0 SATA II connections so I'm stuck with slightly slower speeds than this drive is capable of, but I'm
#
# 1 	incredible
# ----------------------------------------
# 0 Loads large files at incredible speed.
#
# 1 	much
# ----------------------------------------
# 0 understand that the drive didn't add all that much speed, but will be a more reliable storage device.
#
# 1 	boot
# ----------------------------------------
# 0 The boot up speed is so much better now and it uses less power
#
# 1 	blaze
# ----------------------------------------
# 0 Blazing speeds and great for the price.
#
# 1 	pure
# ----------------------------------------
# 0 SSD, I now get the awestruck feeling of pure SPEED when I use my Macbook.
#
# 1 	lighten
# ----------------------------------------
# 0 Of course, one would be excited to see lightening speed of SSD.
#
# 1 	overall
# ----------------------------------------
# 0 energy efficiency of the unit as well as the overall speed and reduced HDD use.
#
# 1 	immediate
# ----------------------------------------
# 0 Was very surprised at the immediate speed increase I noticed.
#
# 1 	subjective
# ----------------------------------------
# 0 My subjective drive speed increase from stock is about 250%.
#
# 1 	regular
# ----------------------------------------
# 0 :)I had a regular 5400 speed hard drive and this thing seems to be at least
#
# 1 	fan
# ----------------------------------------
# 0 run some command in terminal to put the maximum fan speed on a certain number.
#
# 1 	imac
# ----------------------------------------
# 0 party hhd fan control software to keep the imac fan speeds from going full speed.
#
# 1 	same
# ----------------------------------------
# 0 large files back up over the network at the same speed they always did.
#
# 1 	ssd
# ----------------------------------------
# 0 be working perfect.7) Download any benchmark to test ssd speed and you can easily get reading speeds of 1 to
#
# 1 	super
# ----------------------------------------
# 0 Silent, really long MTBF, and super speed are the reasons why I got an SSD and it
#
# 1 	faster
# ----------------------------------------
# 0 test software and I am getting about 10% faster speeds than even the fastest speeds advertised for the m4 SATA
#
# 1 	actual
# ----------------------------------------
# 0 The actual read / write speeds are about 515MB/s and 261MB/s, which are even higher
#
# 1 	light
# ----------------------------------------
# 0 boots up in 7 seconds and apps opening a light speed,there is no need of hibernation which seems to
#
# 1 	drive
# ----------------------------------------
# 0 experience is much improved, even in browsers the drive speed makes a difference now that pages snap up faster.
#
# 1 	random
# ----------------------------------------
# 0 Oddly enough, sequential write vs random write speed do not vary very much and ranges within 2-
#
# 1 	blistering
# ----------------------------------------
# 0 The drive reads data at blistering speeds.
#
# 1 	unreal
# ----------------------------------------
# 0 stripe them in a raid 0 config and get unreal speeds that we in I.T. could only dream about a few
#
# 1 	reasonable
# ----------------------------------------
# 0 They cater more towards reading speed and reasonable write speed.
#
# 1 	decent
# ----------------------------------------
# 0 The Buffalo Mini-Station offered outstanding reliability and decent speed.)
#
# --------------------------------------------------
# B0044YU60M
# --------------------------------------------------
#
# 13 	high
# ----------------------------------------
# 0 room-mate claims that he has a super high speed, both for downloading and for uploading, from his
# 1 I get higher speeds with the old Linksys with a stable connection.
# 2 a wireless N router to take advantage of the higher speeds it offers.
# 3 suggestion for a great router that can do high-speeds of 100Mbps + ??Very disappointed, I thought this would
# 4 fortune 500 companies and our ISP is a major high speed internet provider.
# 5 Recently I upgraded, not just to higher speed, but to their new Quantum BS. I saw no
# 6 the wireless speed since for the uses that require higher speed I use a wired connection, so there may or
# 7 the glowing reviews- maybe this thing does have higher wireless speeds but I didn't test and that isn't an
# 8 I upgraded my internet connection to a higher speed, and therefore needed a gigabit connection and a higher
# 9 , and therefore needed a gigabit connection and a higher speed 300mbps router.
# 10 So if you have a higher speed internet plan - such as the Comcast Blast at 50mbps
# 11 It reaches ALL my rooms at super high speeds and my computer which was in the opposite living room
# 12 Perhaps others have achieved the higher speed.
#
# 11 	wireless
# ----------------------------------------
# 0 Wireless speeds are staying consistently fast no matter how overloaded it gets
# 1 N router and allows laptops connected with wireless N top speeds at up to 150 Mbps.
# 2 was connected at 54 Mbps, which is Wireless G speed.
# 3 (with ethernet cable) and was worried my wireless speeds would hurt my gameplay.
# 4 Now my wireless speed is faster than what I see via Ethernet!
# 5 But the wireless speed comparison was like night and day.
# 6 I did not test the wireless speed since for the uses that require higher speed I use
# 7 the glowing reviews- maybe this thing does have higher wireless speeds but I didn't test and that isn't an
# 8 ( Belkin , TP-Link) dropped the wireless speed by almost 60%.
# 9 still both Belkin and TP-LINK always dropped wireless speed by 60%I tried this MediaLink.
# 10 Oh and by the way, my wireless download speed increased on my 40mb/s connection from less than 500k/sec (
#
# 10 	download
# ----------------------------------------
# 0 Download speeds are easily twice as fast as the best speeds I
# 1 upload speed is about 3 times higher than the download speed, something that has been observed it two computers in
# 2 bang for the buck while it lasted and handled download speeds to my wireless laptop as fast as my ethernet wired
# 3 , which I noticed also gives me a faster download speed.
# 4 Range seems OK but video download speed seemed to drop off precipitously with distance inside my house
# 5 Interestingly download speeds remain the same as the Netgear but the time between
# 6 full 5 bars in the next room and the download speed is much better.
# 7 I have a cable modem that varies in download speed between 10 or 11 mbps (usually) and 30
# 8 It allows you to set maximum download speed, which I did, and this router doesn't
# 9 exactly the same physical location, with the same download speed and exact same router settings and was shocked by the
#
# 6 	good
# ----------------------------------------
# 0 It gave good speeds on speakeasy (~12mbps download, 4mpbs upload) even
# 1 and anything else across computer from nearly anywhere at good speeds.
# 2 , easy to set up, and looks like good speed and range.
# 3 I now get good speed in the living room and everywhere else, presumably due
# 4 In addition to having good network speeds, booting up the router takes very little time -
# 5 Good speeds and very pleased with the purchase.
#
# 6 	great
# ----------------------------------------
# 0 Great speed and very happy with performance.
# 1 The router has great speed and coverage, and the price is great too.
# 2 is essential to you then look elsewhere, otherwise great speeds when relatively close.
# 3 it delivers great speed across all our connected devices, which is usually my
# 4 Worked quickly and at great speeds at first.
# 5 It does a solid job and has great speed.
#
# 4 	fast
# ----------------------------------------
# 0 signal, I am very happy with the super fast speeds  of wireless N. And I got faster speeds in
# 1 fast speeds  of wireless N. And I got faster speeds in the process of setting all this up.
# 2 Works great and has fast speeds
# 3 money, secure, quick, easy setup-fast speed, small footprint.
#
# 3 	full
# ----------------------------------------
# 0 I can stream Netflix or whatever from anywhere at full speed.
# 1 I attached the media link it was Boom, full speed connection.
# 2 Full Speed from my ISP in under 1 minute.
#
# 3 	best
# ----------------------------------------
# 0 Download speeds are easily twice as fast as the best speeds I had gotten with the previous router.
# 1 Before the router switch the best download speeds on my MacBook Air downstairs from my router was about
# 2 after three routers, this one is rating the best speed, and I don't fault any of them for
#
# 3 	super
# ----------------------------------------
# 0 room-mate claims that he has a super high speed, both for downloading and for uploading, from his
# 1 signal, I am very happy with the super fast speeds  of wireless N. And I got faster speeds in
# 2 It reaches ALL my rooms at super high speeds and my computer which was in the opposite living room
#
# 3 	average
# ----------------------------------------
# 0 My average speeds with my iPhone upload 16.00 and 18.00 download (speedtest.net
# 1 net I learned the average speed on the PC was 15 download and 8 upload.
# 2 On the laptop my average speed is 30 download and 27 upload.
#
# 2 	slow
# ----------------------------------------
# 0 good, but soon started dropping connections and delivering slow speeds.
# 1 else was logged in and didn't notice any slow speed.
#
# 2 	maximum
# ----------------------------------------
# 0 router transmits on a single band, so that maximum speed is 150Mb/second.
# 1 It allows you to set maximum download speed, which I did, and this router doesn't
#
# 2 	more
# ----------------------------------------
# 0 I wanted more speed and mostly better range in my home.
# 1 so can't say that the router is causing more speeds but definitely not causing any less for sure.
#
# 2 	increased
# ----------------------------------------
# 0 I wanted an N router for a bit of increased speed but I really didn't notice much of a difference
# 1 Everyone has noticed the increased internet speed.
#
# 2 	upload
# ----------------------------------------
# 0 it is a bit bizarre though is that the upload speed is about 3 times higher than the download speed,
# 1 am getting up to 40-45  in upload speed wirelessly
#
# 2 	faster
# ----------------------------------------
# 0 , which I noticed also gives me a faster download speed.
# 1 about the same price) and the linksys displayed faster speeds.
#
# 1 	crazy
# ----------------------------------------
# 0 You won't see crazy 100mbps+ speeds.
#
# 1 	old
# ----------------------------------------
# 0 My up speed is faster than my old down speed!
#
# 1 	secure
# ----------------------------------------
# 0 money, secure, quick, easy setup-fast speed, small footprint.
#
# 1 	outstanding
# ----------------------------------------
# 0 (about 10' away) and she gets outstanding speed, so there it is.. I am being honest
#
# 1 	consistent
# ----------------------------------------
# 0 visit, it always accepts everyone smoothly and keeps consistent speeds.
#
# 1 	fantastic
# ----------------------------------------
# 0 Pros: fantastic speed, easy to setupCons: limited range
#
# 1 	down
# ----------------------------------------
# 0 My up speed is faster than my old down speed!
#
# 1 	appropriate
# ----------------------------------------
# 0 It handles everything with appropriate speed.
#
# 1 	video
# ----------------------------------------
# 0 Range seems OK but video download speed seemed to drop off precipitously with distance inside my house
#
# 1 	same
# ----------------------------------------
# 0 exactly the same physical location, with the same download speed and exact same router settings and was shocked by the
#
# 1 	claimed
# ----------------------------------------
# 0 between a wall and my bed).I'm not seeing the claimed speeds, but it's still way faster than my old
#
# 1 	previous
# ----------------------------------------
# 0 Previous wireless speeds at best were around 11mbs.
#
# 1 	wan
# ----------------------------------------
# 0 They are VERY coy about the WAN port speed.
#
# 1 	decent
# ----------------------------------------
# 0 brick walls away and still had two bars and decent speeds.
#
# 1 	top
# ----------------------------------------
# 0 a coincidence, but my wired connection yielded a top speed of about 1.8MB/second and with the wireless it got up
#
# 1 	ideal
# ----------------------------------------
# 0 believe that 150 is a "laboratory technical ideal" speed that isn't going to happen in the real world
#
# 1 	easy
# ----------------------------------------
# 0 money, secure, quick, easy setup-fast speed, small footprint.
#
# 1 	local
# ----------------------------------------
# 0 Local network speed feels like it is able the same as having everything
#
# 1 	poor
# ----------------------------------------
# 0 Had to call Customer Service to fix very poor wireless speeds.
#
# 1 	bandwidth
# ----------------------------------------
# 0 Bandwidth speeds are fast as are internal transfer rates from machine to
#
# 1 	regular
# ----------------------------------------
# 0 Speed test showed it didn't slow my regular speed at all.
#
# 1 	game
# ----------------------------------------
# 0 company, and even "upgrading" to their gamer speed, I was unable to use HuluPlus or Netflix,
#
# 1 	significant
# ----------------------------------------
# 0 I don't notice any significant speed increase over a wireless G router, but very few
#
# 1 	actual
# ----------------------------------------
# 0 my 40mb/s connection from less than 500k/sec (actual download speeds) up to 35mb/sec.
#
# 1 	up
# ----------------------------------------
# 0 My up speed is faster than my old down speed!
#
# 1 	n
# ----------------------------------------
# 0 would have a better range since it is a N speed router.
#
# 1 	bad
# ----------------------------------------
# 0 will give you very poor coverage at really bad bandwith speeds.
#
# 1 	hi
# ----------------------------------------
# 0 my 3G service for my cell phone to a hi speed with wifi.i would recommend this router to all my friends

# %% [markdown]
# ##### Test Code

# %%
reviews = df[df.asin == 'B00007E7JU'].reviewText.tolist()

# %%
corpus = ReviewSents(reviews)
# Out:
# parser for review #312 failed
# parser for review #602 failed
# parser for review #643 failed

# %%
unigrams = candidate_unigrams(corpus)

# %%
bigrams, bigram_words = candidate_bigrams(corpus)

# %%
results = extract_aspects(corpus, unigrams, bigrams, bigram_words)

# %%
sort_aspect_frequency(results)
# Out:
# [[u'lens', 630],
#  [u'picture', 169],
#  [u'shot', 166],
#  [u'light', 161],
#  [u'low light', 114],
#  [u'photo', 102],
#  [u'aperture', 96],
#  [u'price', 91],
#  [u'photographer', 86],
#  [u'review', 81],
#  [u'image', 79],
#  [u'field depth', 76],
#  [u'prime lens', 74],
#  [u'bokeh', 70],
#  [u'focus', 67],
#  [u'quality', 65],
#  [u'50mm lens', 63],
#  [u'price lens', 59],
#  [u'camera', 57],
#  [u'canon lens', 57],
#  [u'portrait lens', 57],
#  [u'focal length', 52],
#  [u'portrait', 47],
#  [u'photography', 44],
#  [u'light situation', 42],
#  [u'length', 40],
#  [u'image quality', 32],
#  [u'focus ring', 31],
#  [u'background', 31],
#  [u'quality build', 28],
#  [u'body', 28],
#  [u'buy lens', 27],
#  [u'lens picture', 26],
#  [u'bit', 25],
#  [u'50mm', 24],
#  [u'quality lens', 24],
#  [u'glass', 24],
#  [u'money', 24],
#  [u'plastic', 23],
#  [u'sensor', 23],
#  [u'kit lens', 23],
#  [u'issue', 22],
#  [u'fast lens', 22],
#  [u'zoom lens', 22],
#  [u'cheap lens', 21],
#  [u'color', 21],
#  [u'situation', 21],
#  [u'zoom', 20],
#  [u'light lens', 20],
#  [u'manual focus', 19],
#  [u'sharp lens', 18],
#  [u'year', 18],
#  [u'auto focus', 17],
#  [u'depth', 17],
#  [u'wide aperture', 16],
#  [u'ring', 16],
#  [u'build', 15],
#  [u'picture quality', 15],
#  [u'subject', 14],
#  [u'problem', 14],
#  [u'dslr', 13],
#  [u'purchase lens', 13],
#  [u'come lens', 11],
#  [u'field', 9],
#  [u'camera lens', 9],
#  [u'l lens', 9],
#  [u'bag', 8],
#  [u'canon', 7],
#  [u'flash', 6],
#  [u'canon 50mm', 4]]

# %%
print_sentence_frag(corpus, results, 'aperture')
# Out:
# ----------------------------------------
# aperture
# ----------------------------------------
#
# 29 	wide
# ----------------------------------------
# 0 I love this because of the f/1.8 wide aperture.
# 1 Just an aside about the wide aperture, it's very tough to focus on a close
# 2 With the wide aperture, you can get some really nice depth of field
# 3 you'll be forced to rely on a very wide aperture, with the consequent lack of sharpness discussed above.
# 4 This lens has a very wide aperture, but surprisingly considering the price even out at f/1.8
# 5 , but still performs well since it can reach wide apertures.
# 6 depending on zoom, so this provides a much wider aperture for me to play with.
# 7 Also focus is hunting at wide f1.8 aperture sometimes and lens makes annoying noise.
# 8 Its very wide Aperture lets me shoot beautiful portraits and good shots in low
# 9 It doesn't have nearly as wide an aperture as this, but it will be great for outdoors
# 10 like a 27.2-136.The lenses that have BOTH wide aperture and zoom are at least $1000.
# 11 The wider aperture is what I bought it for and it definitely takes
# 12 Because of its wide aperture, you can really blur the background, even indoors
# 13 bluish tinge when using this lens, even at wide aperture.
# 14 follow the advice to not shoot at super-wide aperture unless it's the right situation for it, anyone
# 15 to shoot in Aperture priority and this lens' wide aperture makes my portraits really stand out.
# 16 So it is great to have this wide aperture as a very versatile lens for portraits, street photography
# 17 can shoot at faster shutter speeds because of the wider aperture.
# 18 I can shoot 800 or 1600 ISO with a wide aperture and still stop the motion of the dancers.
# 19 shallower depth-of-field afforded by the wider aperture.
# 20 The wide aperture helps greatly in low light situations; however it is
# 21 it would be at f/2.8, which is the widest aperture on any zoom lens.
# 22 I had never owned a lens with an aperture wider than f/2.8, so I pleasantly surprised at the
# 23 bokehWith an even wider aperture than the f/1.8, the f/1.4 will produce better bokeh
# 24 Using Av and a wide aperture worked very well for low-light nighttime shots,
# 25 The wide aperture means candles can be excellent lights for portraits.
# 26 Because of the wide aperture of 1.8, this means its good for parties and
# 27 Surely its capable of creating it easily with its wide aperture, but its very "nervous" looking both in
# 28 The wide aperture also gives the background a nice professional looking soft-
#
# 26 	large
# ----------------------------------------
# 0 for the 1.8 full stop which gives you a larger aperture.
# 1 Low-light performance is excellent, with the large aperture (still incredibly sharp wide open) allowing wonderful low
# 2 love this one, because the focal length and large aperture are perfect for the sort of photography I've just
# 3 on my 1.6 crop camera, and for its large aperture.
# 4 This lens works great, provides a large aperture for the price, and has very fast focal lock
# 5 perfect for night shots due to it's large f/1.8 aperture and it's amazing for portrait shots due to it
# 6 all troubled by the lack of sharpness delivered at large apertures, and street shooters or photojournalists who want an inexpensive
# 7 In particular, I wanted a reasonably large aperture that would allow me to get the intimacy of close
# 8 the narrow depth of field at close range with large aperture softens the foreground and background detail to turn a "
# 9 you have the kit lens or similar with larger minimum aperture, this a great fast lens to add on the
# 10 The large maximum aperture proves very useful in low light, though you will
# 11 to get the sharp photo that I want at larger apertures.
# 12 The large aperture also makes it great for shooting in low light or
# 13 The 50/1.4 lenses are typically a little sharper at large apertures.
# 14 With the large aperture, you can shoot easily indoors, but you consequently
# 15 It has a nice large aperture that blurs out your background.
# 16 That's because this lens offers such larger aperture at f/1.8, and it creates such wonderful blur or
# 17 Although I LOVE the bit larger aperture of the lens, I was pretty happy with f/1.8
# 18 good in low light in general due to the large aperture.
# 19 but that is not a big deal and the large aperture is great!Beware that you have to get used to the
# 20 -200mm) were not fast enough (large enough aperture) to freeze-frame a judo throw.
# 21 large aperture.
# 22 take some getting use to in regards to the large apertures (compared with my standard lens) and the narrow
# 23 this is very cheap for the great feature of large apertures.
# 24 price, primarily allows you to play around with large apertures.
# 25 The sharpness is very sensitive to larger apertures, I'd rate it as follows,1.8 - Very Soft
#
# 10 	maximum
# ----------------------------------------
# 0 But you'd have the benefit of a f/1.8 maximum aperture.
# 1 ultra compact and lightweight lens that offers a great maximum aperture at an incredibly low price.
# 2 The large maximum aperture proves very useful in low light, though you will
# 3 of the kit lenses that are available have a maximum aperture of 4 and the difference between 2.8 and 4 is
# 4 50(ish) mm "standard" lens with a maximum aperture of somewhere in the f 1.4-2.0 range.
# 5 This has a maximum aperture generally in the f 4.0-5.6 range.
# 6 than most L series lenses due to the f1.8 maximum aperture.
# 7 With a maximum aperture of f/2, it will help you take "no
# 8 're close eenough to the stage), the maximum aperture of f/1.8 is very helpful at freezing action without cranking
# 9 much brighter, and that's due to the maximum aperture.
#
# 9 	fast
# ----------------------------------------
# 0 I have taken so many great images with this fast aperture lens, and they have turned out universally well (
# 1 of having just one focal length for an ultra fast aperture and sharp images will win you over!
# 2 so sought after in potrait shots and a super fast aperture rating of 1.8.
# 3 Canon DSLR.  Impeccable clarity, superb bokeh, fast aperture, right price.
# 4 is a great prime lens with a big, fast aperture.
# 5 development have brought us a lens that has a fast aperture of 1.8 - far faster than any consumer zoom lens
# 6 (80mm equivalent), especially indoors where the fast aperture is most useful, the quality of the pictures are
# 7 initially wanted it just to play around with the fast aperture, but the sharpness of the photos it takes is
# 8 If you're on a budget and need a fast aperture lens, then this is THE lens to get!It does
#
# 7 	low
# ----------------------------------------
# 0 Great beginner low-aperture, low-cost lens.
# 1 -55) but it wasn't fitting my low aperture needs.
# 2 The low aperture setting makes for some beautiful bokeh and fantastic looking shots
# 3 and video with it and I love the super low aperture on stills.
# 4 It has some fringing problems at the lower apertures but for the price it's got to be in
# 5 If you need something inexpensive but with a low aperture, just get this lens.
# 6 With the low aperture f-stop you can also get tons of light
#
# 7 	small
# ----------------------------------------
# 0 , unfixable halo if you're trying for a small aperture.
# 1 lens) the larger the number, the smaller the aperture.
# 2 when it is a better idea to use a smaller aperture.
# 3 conditions the loss of extra light caused by using smaller apertures will require compensation via a higher ISO and/or a slower
# 4 The results are noticeable at apertures as small as f/4.
# 5 At smaller apertures it's a tie.
# 6 acceptable (better than kit-lens) in smaller apertures.
#
# 6 	big
# ----------------------------------------
# 0 With a bigger aperture it will gather more light, so you will be
# 1 With an aperture this big, you will be able to create the
# 2 great in low light situations (due to the big aperture) and is perfect for portraits.
# 3 is a great prime lens with a big, fast aperture.
# 4 The fast lens with a big aperture provides lot of flexibility when it comes to variable lighting
# 5 got some really nice shots of Euro using the biggest aperture (1.8)Pros:-Dirt cheap lens, the least expensive in my
#
# 4 	high
# ----------------------------------------
# 0 along with lower light situations when you need a higher aperture.
# 1 to use the autofocus on my camera with the highest aperture, which is another reason I don't use 1.8
# 2 Using it at a high aperture (low f-stop) produces the best results
# 3 to the center of the lens (at the higher apertures) if you can.
#
# 3 	huge
# ----------------------------------------
# 0 slow focus can be a problem, since the huge aperture and generally short distance to the subject makes for a
# 1 Lens has a huge aperture, phenomenal opening.
# 2 The huge aperture is the best thing about this lens, it lets
#
# 2 	nice
# ----------------------------------------
# 0 It has a nice large aperture that blurs out your background.
# 1 really nice aperture, great image quality . and its only 100$
#
# 2 	great
# ----------------------------------------
# 0 quality considering it is grey market- super light weight- Great aperture for the price- It's only $100...
# 1 ultra compact and lightweight lens that offers a great maximum aperture at an incredibly low price.
#
# 1 	constant
# ----------------------------------------
# 0 and also the fact that it has a constant f2.8 aperture), I always find myself increasing the sharpness of
#
# 1 	relative
# ----------------------------------------
# 0 The relative aperture of 1.8 is far lower than the one of my
#
# 1 	minimum
# ----------------------------------------
# 0 you have the kit lens or similar with larger minimum aperture, this a great fast lens to add on the
#
# 1 	same
# ----------------------------------------
# 0 you want to take that shot with the same f/1.8 aperture, you'd
#
# 1 	sharp
# ----------------------------------------
# 0 The images are sharp and clear at all apertures.
#
# 1 	open
# ----------------------------------------
# 0 , and given the narrow depth of field at open apertures I also prefer manual focus.
#
# 1 	less
# ----------------------------------------
# 0 is very high (perhaps a little less a full aperture) and it's unbotrusive, meaning you can take
#
# 1 	enough
# ----------------------------------------
# 0 -200mm) were not fast enough (large enough aperture) to freeze-frame a judo throw.
#
# 1 	increase
# ----------------------------------------
# 0 It is great for taking night shots with the increased aperture, snaps onto focus very well, and all around
#
# 1 	tight
# ----------------------------------------
# 0 Similarly, at very tight apertures (f/22) this same effect can intrude on your
#
# 1 	other
# ----------------------------------------
# 0 bokeh(out of focus area) is a bit rough at apertures other than f/1.8.
#
# 1 	comparable
# ----------------------------------------
# 0 my Tamron 17-50 is definitely sharper at comparable apertures and it focuses faster (though louder!).
#
# 1 	full
# ----------------------------------------
# 0 is very high (perhaps a little less a full aperture) and it's unbotrusive, meaning you can take
#
# 1 	wonderful
# ----------------------------------------
# 0 lens while limiting as a fixed, has a wonderful aperture for the price and I have been able to get
#
# 1 	most
# ----------------------------------------
# 0 on body* On-axis picture contrast at most apertures is quite close to the 50/1.4 and 50/1.2, costing
#
# 1 	such
# ----------------------------------------
# 0 That's because this lens offers such larger aperture at f/1.8, and it creates such wonderful blur or
#
# 1 	super
# ----------------------------------------
# 0 and video with it and I love the super low aperture on stills.
#
# 1 	narrow
# ----------------------------------------
# 0 In fact in using this lens, even with narrower aperture you suddenly realize how much IS really helps in those
#
# 1 	light
# ----------------------------------------
# 0 quality considering it is grey market- super light weight- Great aperture for the price- It's only $100...
#
# 1 	grey
# ----------------------------------------
# 0 quality considering it is grey market- super light weight- Great aperture for the price- It's only $100...
#
# 1 	tiny
# ----------------------------------------
# 0 For the price, that tiny aperture just can't be beat.
#
# 1 	ultra
# ----------------------------------------
# 0 of having just one focal length for an ultra fast aperture and sharp images will win you over!
#
# 1 	fix
# ----------------------------------------
# 0 With a fixed aperture all you have to do is focus and just worry
