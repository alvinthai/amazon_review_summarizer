# %%
from __future__ import division
from bs4 import BeautifulSoup
from collections import Counter, defaultdict
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from pprint import pprint
from spacy.en import English
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import os
import re
import requests
import string

parser = English()

# %%
# list of dependencies not likely to be words found in features
com_dep = set(['det', 'aux', 'cc', 'punct', 'mark', '', 'neg', 'nummod',
               'prt', 'auxpass', 'case', 'expl', 'preconj', 'intj',
               'predet', 'meta', 'quantmod', 'agent'])

# list of POS tags not likely to be words found in features
com_tag = set(['IN', 'PRP', 'PRP$', 'DT', 'HYPH', 'TO', ',', '.', 'CC',
               'SP', 'CD', 'MD', 'WDT', 'RP', 'WRB', '-LRB-', '-RRB-',
               ':', 'WP', 'POS', '``', "''", 'SYM', 'EX', 'PDT', 'UH',
               'NFP', 'XX'])

# list of POS tag belonging to nouns
noun_tag = set(['NN', 'NNP', 'NNS'])

# %%
# Loosely adopted from Nic Scharding
# https://nicschrading.com/project/Intro-to-NLP-with-spaCy/

# A custom stoplist
STOPLIST = set(stopwords.words('english') +
               ["n't", "'s", "'m", "ca", "'re"] +
               list(ENGLISH_STOP_WORDS))

# List of symbols we don't care about
SYMBOLS = " ".join(string.punctuation).split(" ")
SYMBOLS += ["-----", "---", "...", "“", "”", "'ve", ""]

# Full set of stops
STOPS = STOPLIST ^ set(SYMBOLS)

# %%
# stopword aspects to filter out
nonaspects = set(['product', 'price', 'problem', 'device', 'review',
                 'item', 'amazon', 'everything', 'company', 'brand',
                 'buy', 'purchase', 'cost'])

# stopword adjectives to filter out
nonadj = set(['other', 'first', 'second', 'third', 'much'])

# %% [markdown]
# ##### Scraping functions

# %%
def get_id(url):
    '''
    INPUT: str
    OUTPUT: str
    
    gets asin identifer for amazon product from a url
    '''
    
    # url format: https://www.amazon.com/.../.../id/...
    regex = re.compile(r'(?<=/)[^/]*')
    asin = regex.findall(url)[-2]

    if len(asin) != 10:
        # url format https://www.amazon.com/.../id
        asin = regex.findall(url)[-1][:10]

    return asin


def extract(asin):
    '''
    INPUT: str
    OUTPUT: list(int), list(str)
    
    extracts the star rating and review text from directory of
    amazon html files
    '''
    ratings = []
    reviews = []

    path = 'reviews/com/{}/'.format(asin)
    pages = [file_ for file_ in os.listdir(path) if file_[-5:] == '.html']

    for page in pages:
        html = open(path + page, 'r')
        soup = BeautifulSoup(html, 'html.parser')
        tags = soup.findAll("div", {"class": "a-section review"})

        if not tags:
            break

        for tag in tags:
            rating = int(tag.find('i').text[0])
            review = tag.findAll("span",
                                 {"class": "a-size-base review-text"})[0].text
            ratings.append(rating)
            reviews.append(review)

    return ratings, reviews

# %%
class Loader(object):
    '''
    class for scraping a review site on Amazon
    '''

    def __init__(self, freq_thresh=5, aspect_thresh=8):
        '''
        INPUT: int, int
        OUTPUT: None
        
        freq_thresh = num of reviews aspect has to appear in product
        aspect_thresh = how strict to filter a word from aspect consideration
        '''
        self.aspect_thresh = aspect_thresh
        self.freq_thresh = freq_thresh

    def scrape(self, n_reviews=100):
        '''
        INPUT: int
        OUTPUT: None
        
        scrapes n most helpful amazon reviews and extracts reviews
        if already scraped, extracts reviews
        '''
        url = raw_input('url of amazon product: ')
        asin = get_id(url)
        doc1.asin = asin
        
        folder = os.getcwd() + '/reviews/com/' + asin
        
        if not os.path.isdir(folder):
            # Run Amazon scraper
            # Credit to Andrea Esuli
            # https://github.com/aesuli/amadown2py
            os.system('python amazon_crawler.py '
                      '-d com {} -m {} -o reviews'.format(asin, n_reviews))

        ratings, reviews = extract(asin)
        
        self.ratings = ratings
        self.reviews = reviews

# %% [markdown]
# ##### Code for classing review objects

# %%
class SentCustomProperties(object):
    '''
    adds properties to spacy sentence that tracks:
        index of review where sentence originated
        spacy Span object
        index of sentence within review corpus
        index of first token in sentence within review
        num of words in sentences
    '''
    
    def __init__(self, review_idx, rating, sent_idx, sent):
        '''
        INPUT: int, int, spacy sentence (spacy.tokens.span.Span)
        OUTPUT: None
        '''
        self.review_idx = review_idx
        self.review_rate = rating
        self.sent = sent
        self.sent_idx = sent_idx
        self.start_idx = sent[0].i
        self.words = len(sent)

# %%
class ReviewSents(object):
    '''
    Takes a list of unicode reviews and stores the sentences
    (with additional properties) in the returned object
    '''
    
    def __init__(self, product):
        '''
        INPUT: Loader
        OUTPUT: None
        '''
        self.ratings = product.ratings
        self.reviews = product.reviews
        self.n_reviews, self.n_sent, self.sentences = self._parse_sentences()
        
    def _parse_sentences(self):
        '''
        INPUT: None
        OUTPUT: int, int, list(SentCustomProperties)
        
        Uses spacy to parse and split the sentences
        Return number of reviews, sentences, and list of spacy objects
        '''
        n_sent, n_reviews = 0, 0
        sentences = []
        
        for i, review in enumerate(self.reviews):
            try:
                review = parser(review)
                n_reviews += 1
            except AssertionError:
                print 'parser for review #{} failed'.format(i)
                continue
            
            for sent in review.sents:
                if sent.string:
                    sentences.append(SentCustomProperties(i, self.ratings[i], n_sent, sent))
                    n_sent += 1
                
        return n_reviews, n_sent, sentences

# %% [markdown]
# ### Hu and Liu Workflow

# %%
doc1 = Loader()
doc1.scrape(1000)
# Out:
# url of amazon product: https://www.amazon.com/Samsung-UN40J5200-40-Inch-1080p-Smart/dp/B00WR292JE/ref=sr_1_6?ie=UTF8&qid=1470191366&sr=8-6&keywords=television+samsung

# %%
corpus = ReviewSents(doc1)
# Out:
# parser for review #304 failed

# %% [markdown]
# 3.1 POS Tagging

# %%
### No script needed, just use the token.tag_ attribute in spaCy after parsing sentence

# %% [markdown]
# 3.2 Frequent Feature Identification

# %%
def _iter_nps(sent):
    '''
    INPUT: spacy sentence (spacy.tokens.span.Span)
    OUTPUT: set
    
    Iterates through each token of spacy sentence and collects
    lemmas of all nouns into a set
    
    this function requires parser to be defined as:
        from spacy.en import English
        parser = English()
    '''
    wordset = set()
    
    for token in sent:
        root = parser.vocab[token.lemma].prob
        # filter to only consider nouns
        if token.tag_ in noun_tag and (root < -7.5 and
                                       token.lemma_ not in nonaspects):
            wordset.add(token.lemma_)
    
    return " ".join(wordset)

def candidate_unigrams(corpus, min_pct=0.01):
    '''
    INPUT: ReviewSents, float
    OUTPUT: set
    
    obtains a set of candidate unigrams
    each candidate unigram must be a noun and must appear in at least
        a percentage of the sentences specified by min_pct
    '''
    count_X = []

    for sent in corpus.sentences:
        count_X.append(_iter_nps(sent.sent))
        
    cnt_vec = CountVectorizer()
    freq = cnt_vec.fit_transform(count_X)
    
    total_count = freq.toarray().sum(axis=0)
    filter_ = total_count >= min_pct * corpus.n_sent

    features = np.array(cnt_vec.get_feature_names())
    return set(features[filter_])

# %%
unigrams = candidate_unigrams(corpus)

# %% [markdown]
# ##### Associative mining with compactness pruning

# %%
def _get_compactness_feat(corpus):
    '''
    INPUT: ReviewSents
    OUTPUT: generator(tuples(unicode))
    
    outputs generator of tuples consisting of:
        at least one noun
        a second word within +/- 3 words of noun
    excludes dependencies and tags not likely to be a feature word
    
    this function requires parser to be defined as:
        from spacy.en import English
        parser = English()
    '''

    for sent in corpus.sentences:
        output = set()

        for i, token in enumerate(sent.sent):
            # one word in bigram must be noun
            if token.tag_ not in noun_tag or token.lemma_ in nonaspects:
                continue
            else:
                arr = sent.sent[max(0, i-3):min(i+4, sent.words)]
                arr = np.array(arr)
                arr = arr[arr != token]

                for item in arr:
                    root = parser.vocab[item.lemma].prob
                    # filter out unlikely features
                    if root > -7.5 or (item.dep_ in com_dep or
                                       item.tag_ in com_tag or
                                       item.lemma_ in nonaspects):
                        continue
                    else:
                        tup = tuple(sorted([item.lemma_, token.lemma_]))
                        output.add(tup)

        if output:
            for element in output:
                yield element
                            
def candidate_bigrams(corpus, min_pct=0.005):
    '''
    INPUT: ReviewSents, float
    OUTPUT: set(tuples), set(str)
    
    outputs set of tuples and set of words within tuples from 
        _get_compactness_feat function appearing at least 
        min_cnt times
    '''
    bigrams = set()
    bigram_words = set()
    
    feats = Counter(_get_compactness_feat(corpus))
    
    for (key, val) in feats.iteritems():
        if val >= max(2, min_pct * corpus.n_sent):
            bigrams.add(key)
            bigram_words.update(set(key))
            
    return bigrams, bigram_words

# %%
bigrams, bigram_words = candidate_bigrams(corpus)

# %% [markdown]
# 3.3 Opinion Word Extraction

# %%
def _check_bigram(adj, token, sent, bigrams, bigram_words):
    '''
    INPUT: spacy token (spacy.tokens.token.Token),
           spacy token (spacy.tokens.token.Token),
           SentCustomProperties,
           set(tuples),
           set(str)
    OUTPUT: generator(tuples)
    
    Given an adjective token, dependency word token, a sentence, and 
        token index within sentence, check if the token has any 
        associated bigram within +/- 3 words and yield all bigrams. 
    
    If no bigrams, yield unigram.
    '''
    yielded = False
    seen_words = []
    t_idx = token.i - sent.start_idx
    a_idx = adj.i - sent.start_idx
    
    arr = sent.sent[max(0, t_idx-3):min(t_idx+4, sent.words)]
    
    for item in arr:
        if item == token or (item.lemma_ in seen_words or
                             item.lemma_ in nonaspects):
            continue
        elif item.lemma_ in bigram_words:
            tup = tuple(sorted([item.lemma_, token.lemma_]))
            adjectives = [adj]
            
            if adj.lemma_ in tup:
                # try finding first adjective around aspect if
                #     bigram includes adjective
                # return nothing if no other adjectives found
                left = max(0, min(a_idx-3, t_idx-3))
                right = min(sent.words, max(a_idx+4, t_idx+4))
                bi_arr = sent.sent[left:right]

                adjectives = [word for word in bi_arr 
                              if word.tag_ in ['JJ', 'JJR', 'JJS']
                              and word.lemma_ not in tup
                              and word.lemma_ not in nonadj]
                
            if tup in bigrams and adjectives:
                yielded = True
                seen_words.append(item.lemma_)
                # for checking which word in bigram is likely to appear first
                ordering = [1, 0] if item.lemma_ == tup[0] else [0, 1]
                a_idx = adjectives[0].i - sent.start_idx
                
                yield (adjectives[0].lemma_, tup, 
                       np.array(ordering), t_idx, a_idx)
                
    if not yielded:
        yield (adj.lemma_, token.lemma_, np.array([1, 0]), t_idx, a_idx)

def extract_aspects(corpus, unigrams, bigrams, bigram_words):
    '''
    INPUT: ReviewSents, set(str), set(tuple), set(str)
    OUTPUT: dictionary
    
    Extracts all aspects modified by an 'amod' dependency and returns
    dictionary of all aspects within candidate unigram and bigram aspects
    
    relation_from: list of words that aspect has dependency relation from
    relation_dep: list of dependencies types aspect has relationship from
    
    adjectives: word modifying the aspect
    adj_idx: list of where adjective can be found within sentence
    aspect_idx: list of where aspect can be found within sentence
    ordering: if bigram, count of which word appears first
    review_idx: list of which reviews contain aspct
    sentence_idx: list of which sentences contain aspect
    
    amod_pct: percentage of time aspect has 'amod' dependency relation
    review_count: how many reviews aspects are found in
    sentence_count: how many sentences aspects are found in
    '''
    props = defaultdict(lambda:
                    {'adjectives': [],
                     'adj_idx': [],
                     'aspect_idx': [],
                     'ordering': np.array([0, 0]),
                     'relation_from': [],
                     'relation_dep': [],
                     'review_idx': [],
                     'sentence_idx': []})
    
    for sent in corpus.sentences:
        
        for token in sent.sent:
            # code to check frequency of adjective for aspect
            if token.head.lemma_ in unigrams:
                props[token.head.lemma_]['relation_from'].append(token.lemma_)
                props[token.head.lemma_]['relation_dep'].append(token.dep_)
            
            if token.head.lemma_ not in unigrams or token.lemma_ in nonadj:
                continue
            
            elif token.dep_ == 'amod':
                aspects = _check_bigram(token, token.head, sent, 
                                        bigrams, bigram_words)
                
                for adj, aspect, ordering, asp_i, adj_i in aspects:
                    props[aspect]['adjectives'].append(adj)
                    props[aspect]['adj_idx'].append(adj_i)
                    props[aspect]['aspect_idx'].append(asp_i)
                    props[aspect]['review_idx'].append(sent.review_idx)
                    props[aspect]['sentence_idx'].append(sent.sent_idx)
                    props[aspect]['ordering'] += ordering
    
    for key in props:
        props[key]['review_count'] = len(set(props[key]['review_idx']))
        props[key]['sent_count'] = len(set(props[key]['sentence_idx']))
        
        if isinstance(key, unicode):
            arr = np.array(props[key]['relation_dep']) == 'amod'
            props[key]['amod_pct'] = np.sum(arr)/len(arr)
    
    # determining bigram amod percentage requires knowing unigram amod
    for key in props:        
        if isinstance(key, tuple):
            reverse = props[key]['ordering'][1] > props[key]['ordering'][0]
            word1 = key[reverse]
            word2_key = key[not reverse]
            
            arr = np.array(props[word2_key]['relation_from']) == word1
            props[key]['amod_pct'] = np.sum(arr)/len(arr)
        
    return props

# %%
def sort_aspect_frequency(aspect_dict, n=3, thresh=0.075):
    '''
    INPUT: dict, int, float
    OUTPUT: list([aspect, freq])
    
    Outputs a list of the most common aspect occuring at least n times with 
        a minimum amod value in descending order.
    Dictionary returned from extract_aspects is the input of this function.
    '''
    counts = []

    for key in aspect_dict:

        freq = aspect_dict[key]['review_count']
        amod = round(aspect_dict[key]['amod_pct'], 3)

        if freq < n or amod < thresh:
            continue

        if isinstance(key, tuple):
            # check which word of bigram appears first more often
            reverse = aspect_dict[key]['ordering'][1] > aspect_dict[key]['ordering'][0]
            ordered_key = " ".join(sorted(key, reverse=reverse))
            counts.append([ordered_key, freq, amod])
        else:
            counts.append([key, freq, amod])

    return sorted(counts, key=lambda x: x[1], reverse=True)

# %%
def print_aspect_by_review(corpus, aspect_dict, aspect):
    '''
    INPUT: ReviewSents, dict, string
    OUTPUT: None
    
    Script that prints out sentences in review containing aspect 
        and polarity score of sentence.
    
    Dictionary returned from extract_aspects is the second input 
        of this function.
    '''
    prev_sent = -1
    overall_rating = []
    good, neutral, bad = 0, 0, 0
    
    print '-'*40
    print aspect
    print '-'*40
    print

    aspect_list = aspect.split(" ")
    
    if len(aspect_list) == 2:
        aspect = tuple(sorted(aspect_list))
    
    adj_idx = aspect_dict[aspect]['adj_idx']
    review_idx = aspect_dict[aspect]['review_idx']
    sent_idx = aspect_dict[aspect]['sentence_idx']
    
    review_dict = defaultdict(lambda: {'rating': 0, 'sentences': ""})
    
    for r, s in zip(review_idx, sent_idx):
        if s == prev_sent:
            continue
        else:
            review_dict[r]['sentences'] += corpus.sentences[s].sent.string
            review_dict[r]['rating'] = corpus.sentences[s].review_rate
            overall_rating.append(corpus.sentences[s].review_rate)
            prev_sent = s
        
    for review in review_dict:
        polarity = round(TextBlob(review_dict[review]['sentences']).sentiment.polarity, 2)
        if polarity > 0 and review_dict[review]['rating'] > 3:
            good += 1
        elif polarity < 0 and review_dict[review]['rating'] < 3:
            bad += 1
        elif polarity >= 0.5 and review_dict[review]['rating'] == 3:
            good += 1
        elif polarity <= -0.5 and review_dict[review]['rating'] == 3:
            bad += 1
        else:
            neutral += 1
        
        print 'review #{} \trating: {}'.format(review, 
                                               review_dict[review]['rating'])
        print '-'*28
        print review_dict[review]['sentences']
        print '\tpolarity: {}'.format(polarity)
        print
    
    print 'average rating:', np.mean(overall_rating)
    print 'good:', good/len(overall_rating)
    print 'neutral:', neutral/len(overall_rating)
    print 'bad:', bad/len(overall_rating)

# %%
from textblob import TextBlob

def print_sentence_full(corpus, aspect_dict, aspect, adjective=None):
    '''
    INPUT: ReviewSents, dict, string, str(optional)
    OUTPUT: None
    
    Script that prints out sentence containing adjective describing specified
        aspect and polarity score of sentence.
    
    Dictionary returned from extract_aspects is the second input 
        of this function.
    
    If no adjective specified, prints all adjectives in descending
        order of occurance.
    '''
    print '-'*40
    print aspect
    print '-'*40
    print

    aspect_list = aspect.split(" ")
    
    if len(aspect_list) == 2:
        aspect = tuple(sorted(aspect_list))
    
    if not adjective:
        adjectives = Counter(aspect_dict[aspect]['adjectives']).most_common()
        
        for (word, freq) in adjectives:
            # toss out adjectives that with non-alphabetic characters
            if not word.isalpha():
                continue
            
            print 'matches:', freq, '\tword:', word
            print
            print '# \trating \tpolarity'
            print '-'*40
            
            mask = np.array(aspect_dict[aspect]['adjectives']) == word
            aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
            sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]
            
            for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
                rating = corpus.sentences[s_idx].review_rate
                sent = corpus.sentences[s_idx]
                score = round(TextBlob(sent.sent.string).sentiment.polarity, 2)
                
#                 try:
#                     prev_sent = corpus.sentences[s_idx-1]
#                     if sent.review_idx == prev_sent.review_idx:
#                         prev_score = round(TextBlob(prev_sent.sent.string).sentiment.polarity, 2)
#                 except:
#                     prev_score = None
                    
#                 try:
#                     next_sent = corpus.sentences[s_idx+1]
#                     if sent.review_idx == next_sent.review_idx:
#                         next_score = round(TextBlob(next_sent.sent.string).sentiment.polarity, 2)
#                 except:
#                     next_score = None                    
                
                print i, '\t', rating, '\t', score #, '\t', prev_score, '\t', next_score
                print sent.sent.string
                print
                
            print
            
    else:
        print 'word:', adjective
        print
        print '# \trating \tpolar \tsentence fragment'
        print '-'*40

        mask = np.array(aspect_dict[aspect]['adjectives']) == adjective
        aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
        sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]

        for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
            rating = corpus.sentences[s_idx].review_rate
            sent = corpus.sentences[s_idx]
            score = round(TextBlob(sent.sent.string).sentiment.polarity, 2)
            
            frag = sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)].string
            if len(frag) > 72:
                frag = frag[0:72] + '...'

            print i, '\t', rating, '\t', score, '\t', frag

        print

# %%
def print_sentence_frag(corpus, aspect_dict, aspect, adjective=None):
    '''
    INPUT: ReviewSents, dict, string, str(optional)
    OUTPUT: None
    
    Script that prints out sentence fragment containing adjective
        describing specified aspect.
    
    Dictionary returned from extract_aspects is the second input 
        of this function.
    
    If no adjective specified, prints all adjectives in descending
        order of occurance.
    '''
    print '-'*40
    print aspect
    print '-'*40
    print

    aspect_list = aspect.split(" ")
    
    if len(aspect_list) == 2:
        aspect = tuple(sorted(aspect_list))
    
    if not adjective:
        adjectives = Counter(aspect_dict[aspect]['adjectives']).most_common()
        
        for (word, freq) in adjectives:
            # toss out adjectives that with non-alphabetic characters
            if not word.isalpha():
                continue
            
            print freq, '\t', word
            print '-'*40
            
            mask = np.array(aspect_dict[aspect]['adjectives']) == word
            aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
            sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]
            
            for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
                rating = corpus.sentences[s_idx].review_rate
                sent = corpus.sentences[s_idx]
                
                frag = sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)].string
                if len(frag) > 72:
                    frag = frag[0:72] + '...'
                    
                print i, '\t', rating, '\t', frag
                
            print
            
    else:
        print adjective
        print '-'*40

        mask = np.array(aspect_dict[aspect]['adjectives']) == adjective
        aspect_idx = np.array(aspect_dict[aspect]['aspect_idx'])[mask]
        sent_idx = np.array(aspect_dict[aspect]['sentence_idx'])[mask]

        for i, (a_idx, s_idx) in enumerate(zip(aspect_idx, sent_idx)):
            rating = corpus.sentences[s_idx].review_rate
            sent = corpus.sentences[s_idx]
            
            frag = sent.sent[max(0, a_idx-10):min(a_idx+11, sent.words)].string
            if len(frag) > 72:
                frag = frag[0:72] + '...'

            print i, '\t', rating, '\t', frag

        print

# %%
results = extract_aspects(corpus, unigrams, bigrams, bigram_words)

# %%
sort_aspect_frequency(results)
# Out:
# [[u'tv', 235, 0.148],
#  [u'picture', 134, 0.256],
#  [u'quality', 54, 0.213],
#  [u'screen', 51, 0.236],
#  [u'picture quality', 41, 0.218],
#  [u'size', 39, 0.25],
#  [u'issue', 39, 0.205],
#  [u'feature', 36, 0.18],
#  [u'apps', 31, 0.208],
#  [u'speaker', 31, 0.294],
#  [u'hub', 31, 0.224],
#  [u'model', 30, 0.23],
#  [u'sound', 29, 0.159],
#  [u'sound quality', 25, 0.08],
#  [u'color', 25, 0.262],
#  [u'room', 24, 0.144],
#  [u'minute', 22, 0.139],
#  [u'smart feature', 20, 0.165],
#  [u'service', 20, 0.209],
#  [u'box', 18, 0.099],
#  [u'television', 18, 0.168],
#  [u'remote', 18, 0.092],
#  [u'connection', 17, 0.147],
#  [u'stand', 17, 0.086],
#  [u'button', 16, 0.094],
#  [u'samsung', 13, 0.1],
#  [u'year', 11, 0.143],
#  [u'network', 11, 0.188],
#  [u'smart hub', 11, 0.458],
#  [u'second', 9, 0.084],
#  [u'wifi', 9, 0.119],
#  [u'movie', 8, 0.13],
#  [u'internet', 8, 0.108],
#  [u'bedroom', 6, 0.089],
#  [u'video', 6, 0.077],
#  [u'wall', 4, 0.131],
#  [u'smart', 4, 0.085]]

# %%
print_aspect_by_review(corpus, results, 'picture quality')
# Out:
# ----------------------------------------
# picture quality
# ----------------------------------------
#
# review #641 	rating: 1
# ----------------------------
# Its a high cost for a tv with such poor picture quality.
# 	polarity: -0.08
#
# review #2 	rating: 5
# ----------------------------
# With this replacement tv, I didn't have any volume issues at all and that same movie has much better picture quality than the first tv.
# 	polarity: 0.25
#
# review #3 	rating: 2
# ----------------------------
# This one has the same good picture quality as my previous units, but I must say that it is the least satisfying TV that I have ever owned.
# 	polarity: 0.15
#
# review #263 	rating: 3
# ----------------------------
# But the great picture quality is overshadowed by slow, sometimes non-responsive operating system.
# 	polarity: 0.25
#
# review #776 	rating: 2
# ----------------------------
# Picture quality's okay...
# 	polarity: 0.5
#
# review #778 	rating: 3
# ----------------------------
# I bought it because of picture and sound quality and it was less expensive than the "not smart" TV!!!
# 	polarity: -0.12
#
# review #11 	rating: 5
# ----------------------------
# It arrived within 3 days, took less than a half hour to hook up and hang on the wall, and the picture and sound quality is EXCELLENT!
# 	polarity: 0.27
#
# review #270 	rating: 3
# ----------------------------
# The picture and sound quality are very good, and overall it is an attractive unit.
# 	polarity: 0.53
#
# review #840 	rating: 5
# ----------------------------
# Great TV, So many features, great picture quality.
# 	polarity: 0.7
#
# review #915 	rating: 5
# ----------------------------
# Great picture quality only gripe is the amount of time its smarthub needs to boot up.
# 	polarity: 0.4
#
# review #794 	rating: 4
# ----------------------------
# I really like this T.V. Nice picture quality and other features.
# 	polarity: 0.23
#
# review #539 	rating: 5
# ----------------------------
# Has a great picture quality as well.
# 	polarity: 0.8
#
# review #158 	rating: 5
# ----------------------------
# I love my new Samsung tv picture quality is great!
# 	polarity: 0.55
#
# review #312 	rating: 5
# ----------------------------
# The picture and sound quality and Smart Hub features takes you to a better way to watch TV.
# 	polarity: 0.37
#
# review #554 	rating: 5
# ----------------------------
# Good picture quality for the price.
# 	polarity: 0.7
#
# review #684 	rating: 5
# ----------------------------
# Great picture quality, easy to use.
# 	polarity: 0.62
#
# review #813 	rating: 5
# ----------------------------
# Easy set-up, quality picture.
# 	polarity: 0.43
#
# review #321 	rating: 3
# ----------------------------
# Pretty low cost smart TV with really good picture quality.
# 	polarity: 0.29
#
# review #49 	rating: 3
# ----------------------------
# Pros:Excellent picture quality, viewing angle, and sound.
# 	polarity: 0.4
#
# review #56 	rating: 1
# ----------------------------
# The Good: Nice size, good picture quality, easy to set up.
# 	polarity: 0.61
#
# review #700 	rating: 5
# ----------------------------
# Good picture quality and I love the screen mirroring feature.
# 	polarity: 0.6
#
# review #65 	rating: 3
# ----------------------------
# Pros: Lightweight, Ease of install, simple setup, Moderate picture quality, Wifi good range.
# 	polarity: 0.23
#
# review #267 	rating: 4
# ----------------------------
# Streaming through the smart tv capabilities gives a lower quality picture.
# 	polarity: 0.21
#
# review #583 	rating: 5
# ----------------------------
# I loved the tv, good quality picture and sound.
# 	polarity: 0.6
#
# review #584 	rating: 5
# ----------------------------
# Awesome budget TV. Great quality picture, which is pretty standard for Samsung.
# 	polarity: 0.51
#
# review #331 	rating: 3
# ----------------------------
# The TV itself is great, very nice picture and quality.
# 	polarity: 0.79
#
# review #462 	rating: 3
# ----------------------------
# Great picture quality, but the smart features are pretty lackluster.
# 	polarity: 0.42
#
# review #591 	rating: 5
# ----------------------------
# Great picture and sound quality.
# 	polarity: 0.6
#
# review #80 	rating: 4
# ----------------------------
# Top quality picture, the price is a bargain.
# 	polarity: 0.5
#
# review #209 	rating: 5
# ----------------------------
# It got that good picture quality you feel me.
# 	polarity: 0.7
#
# review #722 	rating: 5
# ----------------------------
# great picture quality, everything I expected from this brand of TV and more!!!  have no problems recommending this set to others.
# 	polarity: 0.56
#
# review #467 	rating: 2
# ----------------------------
# I also have a 24" Samsung that has perfect picture quality.
# 	polarity: 1.0
#
# review #603 	rating: 4
# ----------------------------
# This TV meets my particular needs very well and I'm very satisfied with the high-refresh picture quality and the sound (not great but good for built-in TV speakers).
# 	polarity: 0.29
#
# review #863 	rating: 4
# ----------------------------
# Amazing picture quality
# 	polarity: 0.6
#
# review #99 	rating: 4
# ----------------------------
# This TV meets my particular needs very well and I'm very satisfied with the high-refresh picture quality and the sound (not great but good for built-in TV speakers).
# 	polarity: 0.29
#
# review #743 	rating: 5
# ----------------------------
# Awesome no damages tv is perfect awesome quality picture is perfect and super fast delivery would buy agein
# 	polarity: 0.76
#
# review #239 	rating: 5
# ----------------------------
# The Time Warner app is another great bonus, I can watch everything in great picture quality and sound without the need of having another cable box.
# 	polarity: 0.67
#
# review #371 	rating: 5
# ----------------------------
# Simple to operate and decent quality picture.
# 	polarity: 0.08
#
# review #124 	rating: 5
# ----------------------------
# Amazing picture quality loaded with lots of features - poor on-screen instructions for accessing both Amazon and setting up a Samsung account.
# 	polarity: 0.1
#
# review #382 	rating: 5
# ----------------------------
# Easy set up and Excellent picture quality!
# 	polarity: 0.72
#
# review #639 	rating: 5
# ----------------------------
# Excellent picture quality.
# 	polarity: 1.0
#
# average rating: 4.0487804878
# good: 0.731707317073
# neutral: 0.243902439024
# bad: 0.0243902439024

# %%
print_sentence_full(corpus, results, 'movie')
# Out:
# ----------------------------------------
# movie
# ----------------------------------------
#
# matches: 35 	word: good
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.7
# Josh Trank claims he made a good movie we'll never see, and it was all the studio's fault for interfering.
#
# 1 	3 	0.52
# Anyway, on it's own this is a pretty good movie.
#
# 2 	1 	0.7
# Will there ever be a really good movie for them.
#
# 3 	2 	-0.2
# It is not a very good movie compared to the other Marvel movie that have been made.
#
# 4 	4 	0.7
# This was a good movie.
#
# 5 	4 	0.55
# The movie was good, but it was like watching a really good science fiction movie, not so much a comic book based movie.
#
# 6 	4 	0.23
# It takes a different approach to thr origins of each character than is traditional but nonetheless it was still a good movie.
#
# 7 	2 	0.7
# Looked like the start of a good movie...
#
# 8 	3 	0.28
# A complete reboot that although I thought it was a good movie  in general, I just didn't connect with it like I thought I would have).
#
# 9 	3 	-0.35
# It's not a good movie.
#
# 10 	3 	0.7
# Not even really a good movie.
#
# 11 	3 	0.45
# It was a good Sci-fi movie, but didn't really like this version of the 4.
#
# 12 	4 	0.35
# The different view is what makes this a good movie.
#
# 13 	5 	0.6
# We can't understand why so many people are saying that this isn't a good movie.
#
# 14 	4 	0.6
# better than i was told it would be , good movie
#
# 15 	4 	0.7
# Good movie and ends in a spot for squeals.
#
# 16 	4 	0.25
# Fun movie...good for the whole family
#
# 17 	4 	0.18
# I bought it on amazon video although I saw a lot of negative comments and I must say it was pretty good movie at least it was way better than the first one with Jessica alba
#
# 18 	3 	0.15
# good movie, but very slow...
#
# 19 	3 	0.7
# Good movie.
#
# 20 	4 	0.7
# good movie
#
# 21 	4 	0.7
# good movie
#
# 22 	4 	0.7
# Good movie
#
# 23 	4 	0.91
# Very good movie.
#
# 24 	4 	0.7
# It's a good movie.
#
# 25 	2 	0.6
# I wanted this to be a good movie,it was OK
#
# 26 	2 	-0.27
# This was not a very good movie.
#
# 27 	1 	-0.35
# Not a good movie.
#
# 28 	4 	0.7
# good movie
#
# 29 	4 	0.5
# It's a good B movie, maybe not what the creators intended, but fun nonetheless.
#
# 30 	4 	0.28
# If you're just looking for a good sci-fi movie and don't care that it's not exactly like the comic book then rent on it is worth it.
#
# 31 	4 	0.7
# Good movie.
#
# 32 	4 	0.7
# Good movie.
#
# 33 	1 	-0.35
# This is not a good movie.
#
# 34 	2 	-0.35
# Not a good movie at all.
#
#
# matches: 26 	word: bad
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.02
# I have a fondness for bad movies; I've watched the first half of "Sphere" about 300 times, because it's a good cure for my insomnia.
#
# 1 	3 	-0.2
# Most bad movies are worse than this one, because they have ultra low-budgets.
#
# 2 	1 	-0.19
# I think it's a shame that today Fox has made so many bad movies that people can't take the team seriously, and believe it or not this one may in fact be worse than the last two.
#
# 3 	1 	-0.7
# Not just a bad superhero movie, but a bad movie.
#
# 4 	2 	0.08
# While it wasn't the worst movie I saw (the Last Airbender deserved it better in my opinion), I wasn't all that great either.
#
# 5 	1 	-0.7
# Another, Humans are bad movie.
#
# 6 	2 	0.02
# Ok, this was a pretty bad movie but I can give you the reason why.
#
# 7 	3 	0.24
# I like the other cast better but not a bad movie.
#
# 8 	1 	-0.27
# When it comes to bad movies, there are four main types:a)
#
# 9 	1 	-0.75
# This is probably the worst movie of 2015, but I was so bored that I didn't even care.
#
# 10 	1 	-0.25
# Really is the bad movie everyone says it is.
#
# 11 	1 	-1.0
# This is the worst movie I've seen years.
#
# 12 	1 	-0.28
# The worst movie I've seen in a long time, disappointing in that Marvel usually ensures highly entertaining products.
#
# 13 	3 	-1.0
# I have seen worst movies.
#
# 14 	3 	0.35
# Not a bad movie, just seems out of step with the rest Of the MCU.
#
# 15 	3 	0.4
# Not bad movie but I'm so glad we did go movies & paid  full price.
#
# 16 	1 	-1.0
# Downright the worst movie I have seen in my life, and I never say that.
#
# 17 	2 	-1.0
# One of the worst movies of all time.
#
# 18 	1 	-0.7
# Is a bad movie every one know that, but the 3D version Is no here.
#
# 19 	1 	-0.3
# This is the worst movie of all the Fantastic four films.
#
# 20 	3 	0.35
# Not a bad movie.
#
# 21 	1 	-0.26
# Not worth your time, I like comic books, I like bad movies, but this is so bad I want my time back.
#
# 22 	4 	-0.7
# Frankly it wasn t a movie so bad everyone says .
#
# 23 	4 	-0.32
# This really isn't a bad movie, at all, so I'm not really sure what the 1-star reviewers look for in an adventure/action movie, especially from a superhero film.
#
# 24 	1 	-0.7
# It's just a bad movie.
#
# 25 	1 	-0.53
# Was one of the worst movies I'd seen in a very long time.
#
#
# matches: 11 	word: great
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.8
# In this day and age i cant see why they cant make a great movie out of F4.
#
# 1 	4 	1.0
# Great movie from beginning to end!
#
# 2 	1 	0.8
# So PC you screwed up another great movie.
#
# 3 	3 	-0.4
# So, not a great movie.
#
# 4 	4 	0.8
# Great movie.. two thumbs up👍👍
#
# 5 	1 	0.57
# The reason Deadpool was a great movie was it was so true to the comics and the character.
#
# 6 	5 	1.0
# Great movie!!
#
# 7 	5 	0.8
# great movie...Doesn't
#
# 8 	2 	0.8
# With Josh Trank blaming Fox that he couldn't make the great movie he intended to make.
#
# 9 	5 	0.8
# I think this was a great movie and if there were no plans to make another after silver surfer... Than this was a great movie to start off the 4 and another should be made.
#
# 10 	5 	0.8
# I think this was a great movie and if there were no plans to make another after silver surfer... Than this was a great movie to start off the 4 and another should be made.
#
#
# matches: 11 	word: terrible
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	-1.0
# Terrible movie.
#
# 1 	1 	-1.0
# Terrible movie.
#
# 2 	3 	-0.25
# The reason I got this movie is because I love terrible movies.
#
# 3 	1 	-0.5
# Terrible movie,  strike three,  give the rights back to marvel.
#
# 4 	1 	-1.0
# Terrible movie.
#
# 5 	1 	-1.0
# it's a terrible, terrible movie.
#
# 6 	1 	-1.0
# it's a terrible, terrible movie.
#
# 7 	1 	-0.44
# what a terrible movie, do not waste your time!
#
# 8 	1 	-0.15
# Good actors - but terrible movie.
#
# 9 	1 	-1.0
# Terrible movie
#
# 10 	3 	-0.4
# I was expecting a terrible movie since it had so many bad reviews when it went to theater.
#
#
# matches: 8 	word: original
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.38
# This reboot, unlike the original 2 movies, failed miserably.
#
# 1 	1 	0.13
# .... if this was supposed to be better than the original 2 movies, it was a fail.
#
# 2 	3 	0.29
# I don’t mind the darker version that was attempted here as I thought the original FF movie was a bit campy but the movie I think missed the mark on being a darker action filled FF movie.
#
# 3 	3 	0.54
# not as good as the original movie.
#
# 4 	1 	0.26
# No where near the fun that the original movie had.
#
# 5 	2 	0.14
# Totally different from the original movie made not too long before that I didn't spend 90% of the movie thinking this is SO not like the first.
#
# 6 	3 	0.49
# Yes, the two original movies with Chris Evans is better, but there are things about this movie that I liked.
#
# 7 	1 	0.38
# It makes the original F4 movies look like academy award winners.
#
#
# matches: 7 	word: entire
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.14
# Dr. Doom actually feels like a threat in this movie as compared to the sad excuse for a villain we got in the previous 2 films, hell that guy spent the entire movie trying to figure out what sort of accent his character was supposed to have - just pick one and go with it!
#
# 1 	2 	-0.08
# Suzan Storm - Kate Mara was bland and uninteresting throughout the entire movie.
#
# 2 	2 	0.04
# While the plot of teleporting to a mysterious dimension is interesting (and I couldn't help wondering if the realm is the Negative Zone), the entire movie is plagued by a flat tone from which it never emerges.
#
# 3 	2 	0.28
# The movie went on too long without any real action and there wasn't even a scene you could call a best part in the entire movie.
#
# 4 	2 	0.18
# A good half of the entire movie is devoted to this set-up and pre-origin stuff.
#
# 5 	2 	0.03
# Not to mention, Doctor Doom only spends about ten minutes in the entire movie (in his new, powered up form).
#
# 6 	1 	-0.16
# This is really a poor movie with a really poor plot............... it seems that the director thought by simply using up to date visual effects would carry the entire movie.
#
#
# matches: 6 	word: best
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.4
# Michael B. Jordan killed me in "Fruitvale Station", one of the best movies of 2013.
#
# 1 	1 	1.0
# Miles Teller starred in "Whiplash", one of the best movies of 2014.
#
# 2 	4 	0.62
# Not the best movie.. The remakes are rarely as good as the original but I did enjoy it.
#
# 3 	1 	0.47
# Best movie i seen in a long time but the movie sucked
#
# 4 	3 	0.51
# This wasn't the best movie I have seen and some things i felt could have been better, but since i don't have much of background knowledge on Fantastic Four comic life, I thought it was good.
#
# 5 	3 	0.44
# not mind blowing best movie in the world, but i liked it better than the old ones. especially the cast!!!!
#
#
# matches: 6 	word: last
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.19
# Since the last two FF movies weren't stellar box office winners, the fan boys were hoping 20th CF would just skip a movie and let the rights revert to Marvel where, they hoped, it would get a much better film treatment.
#
# 1 	1 	0.0
# No reason to change up the characters from the last movies.
#
# 2 	3 	0.2
# The last movies from qute a few years ago was much better and put together much better with a stronger story line.
#
# 3 	2 	0.25
# While the last movies are not the greatest, not sure why they have to change origin stories.
#
# 4 	4 	0.33
# I thought this was equally as entertaining as the Wolverine movies and better than the last Avengers movie.
#
# 5 	1 	0.25
# what a junk movie,  the last two movies were better than this trash ,you need to have j.j.
#
#
# matches: 5 	word: comic
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.38
# and I love comic movies.
#
# 1 	2 	0.01
# I think we have been spoiled with other comic movies, which by comparison, makes this movie seem terrible, but for the most part, I did not hate this movie like everyone else I have spoken to.
#
# 2 	1 	0.02
# To show that comic movies can handle diversity, Johnny is now black rather than the blonde haired teen of the comics.
#
# 3 	4 	-0.28
# Some of those people are Marvel Studios fanboys who simply hate any comic movie that isn't made by Marvel Studios.
#
# 4 	2 	0.28
# I enjoy comic movies, but this one is very skippable.
#
#
# matches: 5 	word: horrible
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.15
# A Movie that was so rotten, you can only enjoy it when you want to see it with the mind set of why this is such a horrible movie.
#
# 1 	1 	-1.0
# horrible movie.... but i collect marvel movies, so i had to add this one to my collection.
#
# 2 	2 	-1.0
# Had to purchase for my marvel Blu ray collection...... horrible movie
#
# 3 	1 	-1.0
# Horrible movie
#
# 4 	4 	-0.45
# I was expecting to see a horrible movie but I was pleasantly surprised.
#
#
# matches: 4 	word: fantastic
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	0.09
# This movie appears to have low ratings (as well as the other fantastic 4 movies),
#
# 1 	2 	0.4
# This movie will keep you on the edge of your seat but not because it is a fantastic movie because you can't believe what they did to the fantastic four.
#
# 2 	3 	0.25
# If you convince yourself it's not a Fantastic 4 movie it's pretty good
#
# 3 	1 	0.09
# At least in the first Gen fantastic 4 movie we actually got to see them fight with there powers instead of 5 min at end of movie
#
#
# matches: 4 	word: enjoyable
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.38
# But still, that also only serves to point out that the FF could have been shot and edited into a much more enjoyable movie, making better use of both the time and resources available to the writers and director.
#
# 1 	4 	0.65
# Very enjoyable movie.
#
# 2 	4 	0.07
# I've heard various negative comments about the movie, but I thought it was an enjoyable Sci-Fi movie.
#
# 3 	4 	0.5
# Enjoyable movie.
#
#
# matches: 4 	word: decent
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	-0.02
# It could've been a decent movie with a few adjustments.
#
# 1 	2 	0.17
# I thought that it would be a decent movie because it is Marvel.
#
# 2 	3 	0.38
# What I'm saying to all is you have to see it for yourselves and you might find yourselves enjoying a decent science fiction movie with a few thrills, some fine actors giving it their best, and moments.
#
# 3 	3 	0.17
# It was a decent movie.
#
#
# matches: 4 	word: whole
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.31
# The story-line in this movie is more deeply entertaining and more well planned, but again the whole movie pretty much lacks action scenes throughout the whole film.
#
# 1 	3 	0.2
# The whole movie I think lacks a purpose.
#
# 2 	2 	0.35
# While the movie is rife with stunning graphics (what isn't these days?), the graphics are not the whole movie.
#
# 3 	1 	-0.1
# And was poor visibility throughout the whole movie.
#
#
# matches: 3 	word: same
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.0
# I stopped it after about 10 minutes and then ordered the same movie in 1080p from vudu.
#
# 1 	3 	0.35
# The movie itself was good but the fans did not want another remake of the same movie now three times.
#
# 2 	3 	-0.31
# I am disappointed in the movie company they just made this movie because the movie rights was about to expire this is unfair to the fans this is the 3rd remake of the same movie.
#
#
# matches: 3 	word: previous
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	0.13
# As someone tht doesn't Particularly enjoy the Fantastic Four, never felt the need to read any of the comics and enjoy any of the previous movies, animated or live action,  I really enjoy this I saw this movie about a year after it came out because of all the harshly negative reviews I expected to be more of what I did not like turns out that it was a very new, modern take on what became a very monotonous or stale.
#
# 1 	2 	0.17
# The only thing worthy of it was the things character had a better look to it than the previous movies.
#
# 2 	2 	0.17
# The previous movies are so much better.
#
#
# matches: 3 	word: prior
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	0.0
# None of these things were explained in prior movies about their relationships.
#
# 1 	5 	0.08
# The outfits in this movie was more sleek than prior movies and the Thing seem big the way I imagined him to be from the comic books instead of the small Thing in prior movies.
#
# 2 	5 	0.08
# The outfits in this movie was more sleek than prior movies and the Thing seem big the way I imagined him to be from the comic books instead of the small Thing in prior movies.
#
#
# matches: 3 	word: next
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	0.25
# I enjoyed this origin movie, and I felt like it sets up the next movie pretty well.
#
# 1 	3 	0.25
# Perhaps the next movie will be better
#
# 2 	4 	0.02
# is it beleaveable when the first Human Torche is black and in the next movie he is white???
#
#
# matches: 3 	word: overall
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.28
# Doom seemed more insane than evil and the lack of action made the overall movie a tad on the dull side.
#
# 1 	1 	0.23
# The failed 2005 Fantastic Four movie was epically an better overall movie (better cast and better story) then this attempt to cash in on the Marvel movie bandwagon.
#
# 2 	1 	-0.24
# Just saw it this morning and everything said about it is true; no chemistry among the actors; zero character development; boring, drawn out with minimal action; horrendous dialogue; clearly a cash grab movie by Fox and co. that feel they can put out any type of crappy movie and the public are dumb enough to see it; a movie shouldn't make you feel like crap at the end of it, this one did; just an overall sorry movie with poor execution; very disappointing, half a star goes to the actors who were good but given nothing to work with and partial stardust goes to the CGI for The Thing which was good; The villain looked like a burnt crash test dummy and was lame;  it's not entertaining bad just bad boring bad; a pure waste of time,
#
#
# matches: 3 	word: awful
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.9
# I do not know if it is because I hate myself or if I find amusement in absolutely awful movies.
#
# 1 	1 	-0.17
# I saw the 2005 version and it was ten times better than this awful movie.
#
# 2 	1 	-1.0
# Awful movie.
#
#
# matches: 3 	word: many
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.19
# I think it's a shame that today Fox has made so many bad movies that people can't take the team seriously, and believe it or not this one may in fact be worse than the last two.
#
# 1 	5 	0.63
# This was great superhero movie, with a good cast that should have been the start of many more movies.
#
# 2 	2 	0.33
# In the many movies I've seen, I can't recall the last time I heard so many boo's from the audience.
#
#
# matches: 2 	word: awesome
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	1.0
# Awesome movie!
#
# 1 	3 	0.3
# I admit that I had low expectations based on all of the reviews that I've read here and elsewhere and refused to go see it in the theater as I was hoping that it would bomb and the rights would go back to Marvel to make a truly awesome FF movie, but I have to say that I mostly enjoyed the movie and would actually go to the theater to see a sequel, if one is ever made.
#
#
# matches: 2 	word: own
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.35
# As its own movie, this FF does manage to get some things right- the characters are, for the most part, consistent, the story (up until the last third) is easy to follow, doing a good job of establishing this world.
#
# 1 	5 	0.28
# I feel like if the director hadn't been such a whiner baby and publicly dissed his own movie, it would have been received much better by the audience.
#
#
# matches: 2 	word: old
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.36
# I was very excited for this movie as I loved the old movies and I was interested in seeing it with better technology and a new perspective.
#
# 1 	1 	0.01
# I suppose that if you like the actors and really love the Fantastic Four, watch this, but seriously, this movie will make you want your money back because it is so bad that it makes the older F4 movies look like masterpieces.
#
#
# matches: 2 	word: better
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.23
# The failed 2005 Fantastic Four movie was epically an better overall movie (better cast and better story) then this attempt to cash in on the Marvel movie bandwagon.
#
# 1 	2 	0.06
# It's made a profit at the box office and the sequel is supposedly coming out in 2017 but it's a sad state of affairs when the two previous Fantastic Four movies aimed squarely at kids were actually better movies than this.
#
#
# matches: 2 	word: low
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.33
# Low budget movies are better than this one and have a better story.
#
# 1 	1 	0.0
# Low energy movie.
#
#
# matches: 2 	word: etch
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.1
# Did they really hijack the script and worked it like it was an etch-a-sketch?This movie is a darker take than its predecessors, and it maybe would've worked if only it also weren't so drab and dour.
#
# 1 	2 	0.1
# Did they really hijack the script and worked it like it was an etch-a-sketch?This movie is a darker take than its predecessors, and it maybe would've worked if only it also weren't so drab and dour.
#
#
# matches: 2 	word: excellent
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	1.0
# Excellent movie!!!
#
# 1 	3 	1.0
# In fact, from all the footage released this seemed to resemble something along the lines of Singer's excellent X-Men movies
#
#
# matches: 2 	word: ok
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.5
# It was an ok movie.
#
# 1 	4 	0.5
# It is an ok movie.
#
#
# matches: 2 	word: earlier
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.16
# The earlier movies may not have been very cool by current standards, but at least they were colorful and tried to match the adventurous spirit of the comics.
#
# 1 	4 	0.23
# I enjoyed this movie as much as I did the earlier FF movies.
#
#
# matches: 2 	word: most
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.2
# Most bad movies are worse than this one, because they have ultra low-budgets.
#
# 1 	3 	0.51
# For the most part the actors where good and the sets and special effects were on par with most movies.
#
#
# matches: 2 	word: worthy
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.17
# This would be a movie worthy of such a disgraceful rating!
#
# 1 	1 	0.18
# Fox has wasted a fortune and an opportunity to produce and present a movie worthy of its own title.
#
#
# matches: 2 	word: actual
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.27
# The behind-the-scenes drama of this film would make a fine documentary and it would undoubtedly be much more interesting, fun and full of action than the actual movie.
#
# 1 	1 	-0.31
# There was barely anything in the trailer in the actual movie, VERY disappointed
#
#
# matches: 1 	word: followup
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.04
# Doom should have been left for a followup movie and someone like Klaw, Blastar, or number one choice Annihilus and the Negative Zone been the main villian.
#
#
# matches: 1 	word: set
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	0.02
# Also, it does seem like the entire thing was very much a set-up movie which can leave you feeling a little unsatisfied.
#
#
# matches: 1 	word: pack
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.4
# I was anticipating an action packed movie with a good story line but was dissapointed.
#
#
# matches: 1 	word: do
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.0
# Not a well done movie.
#
#
# matches: 1 	word: particular
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.07
# The reason for hating this particular DVD Video is because ALL Copies of this particular Movie are 100% Blank when it comes to this Movie; the ONLY thing that you end up seeing is the  "  20th  Century  Fox  Video  " Sign of which is Out of Hollywood, California!
#
#
# matches: 1 	word: horible
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.0
# Horible movie.
#
#
# matches: 1 	word: malign
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.25
# But instead of focusing on superheroics and coming together as a team, which even the much-maligned 2005 movie showed, this movie is mostly about them working together through their differences and trying to achieve a scientific breakthrough by creating a portal to an alternate dimension on Earth.
#
#
# matches: 1 	word: proper
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.0
# Getting entangled in the ongoing story of the infinity gems... tangling with SHIELD... Or just getting a proper movie and sequel that hews closely to what the characters should be.
#
#
# matches: 1 	word: poor
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.16
# This is really a poor movie with a really poor plot............... it seems that the director thought by simply using up to date visual effects would carry the entire movie.
#
#
# matches: 1 	word: slow
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.05
# Bet that works better than a really slow uninspired movie :)
#
#
# matches: 1 	word: precede
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	-0.2
# While missing the camp or the superficial sense of the preceding movies, this one was still missing something.
#
#
# matches: 1 	word: only
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.0
# This is the only movie I've seen that I'd rather melt then through into the trash!
#
#
# matches: 1 	word: stupid
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.2
# Why can't this stupid movie just be free on Netflix....
#
#
# matches: 1 	word: underground
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.0
# Whoever does it next has to go with the Mole man and the underground monster invasion movie that should have started it to begin with.
#
#
# matches: 1 	word: new
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.27
# When 20th CF announced the new movie, they immediately hated it before it was ever made or released since that meant there would be no Marvel produced FF for at least another 7 years.
#
#
# matches: 1 	word: fill
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.29
# I don’t mind the darker version that was attempted here as I thought the original FF movie was a bit campy but the movie I think missed the mark on being a darker action filled FF movie.
#
#
# matches: 1 	word: crummy
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.07
# This is another crummy re-origin movie that does not live up to what Marvel Fans come to expect from a Marvel film.
#
#
# matches: 1 	word: real
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.37
# I mean a real horror movie and it's shocking.
#
#
# matches: 1 	word: fun
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.3
# Now that was a fun nerd movie.
#
#
# matches: 1 	word: okay
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.63
# It's just a okay movie, wait for it to go prime!
#
#
# matches: 1 	word: spectacular
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.4
# Marvel has historically done a better job of making sure their properties are well transitioned to the silver screen and some of the results have been spectacular movies.
#
#
# matches: 1 	word: separate
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	0.0
# Man, I wish I could see the two different versions of this movie that were mashed into one as separate movies.
#
#
# matches: 1 	word: successful
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.75
# Fox knew they had to make a successful movie and this decision which caused a uproar was foolish.
#
#
# matches: 1 	word: big
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	0.0
# All I figure is it wasn't a big budget movie with big name actors so people want to complain.
#
#
# matches: 1 	word: dark
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.03
# It's a dark movie, but not because of the story or feel of the movie, but because CGI in the dark is literally ten times cheaper than CGI in day light.
#
#
# matches: 1 	word: uninspired
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.05
# Bet that works better than a really slow uninspired movie :)
#
#
# matches: 1 	word: ff
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.15
# at least it was better than the first FF movie
#
#
# matches: 1 	word: passable
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.4
# If you had never heard of the Fantastic Four, and you knew nothing of Marvel comics, then this would be a passable movie.
#
#
# matches: 1 	word: spin
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.12
# Just saw this on regular version and I have to say that even though the special effects are neat it's way off point compared to the first version done a few years back and the writing was way better back then so I don't know why they made a new version of the film with younger actors when the first one sufficed but I  want to know where the spin off movie is at for THE SILVER SURFER after they filmed the first Fantastic Four movie a few years back.
#
#
# matches: 1 	word: sorry
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.24
# Just saw it this morning and everything said about it is true; no chemistry among the actors; zero character development; boring, drawn out with minimal action; horrendous dialogue; clearly a cash grab movie by Fox and co. that feel they can put out any type of crappy movie and the public are dumb enough to see it; a movie shouldn't make you feel like crap at the end of it, this one did; just an overall sorry movie with poor execution; very disappointing, half a star goes to the actors who were good but given nothing to work with and partial stardust goes to the CGI for The Thing which was good; The villain looked like a burnt crash test dummy and was lame;  it's not entertaining bad just bad boring bad; a pure waste of time,
#
#
# matches: 1 	word: bleak
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	0.13
# But, he also share's the blame because he departed so far from the source material, character dynamics that made the Fantastic Four such a great read many years ago have been deleted and replaced with the feel of a bleak, David Cronenberg movie.
#
#
# matches: 1 	word: epic
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.37
# It was ok - but felt more like a TV episode than an epic movie.
#
#
# matches: 1 	word: longer
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.21
# I would have even been better with a longer movie if it meant the second half was better.
#
#
# matches: 1 	word: cruddy
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	-0.05
# This was great compared to those cruddy movies from 2005, 2007.
#
#
# matches: 1 	word: favorite
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	-0.02
# I find it hard to believe that this is entirely Josh Tranks fault, I mean this is the same guy who gave us CHRONICLE, one of my favorite movies.
#
#
# matches: 1 	word: foreign
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	2 	0.13
# Imagine somebody bought the rights to a foreign movie, dubbed it in English, and renamed the characters to fit a well-known comic book team.
#
#
# matches: 1 	word: lousy
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	1 	-0.04
# They took some fine actors and created a lousy movie.
#
#
# matches: 1 	word: serious
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.14
# Anyone who reads these reviews should know first that many of them are by marvel fans who don't know a serious movie from a cartoon.
#
#
# matches: 1 	word: quick
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.3
# The first thing I noticed in the reviews was the uniform dislike by the fan boys, mostly based on the idea that 20th CF was just going to make a quick and cheap movie so they could retain the movie rights to FF.
#
#
# matches: 1 	word: frustrating
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	-0.4
# It's a frustrating movie.
#
#
# matches: 1 	word: entertaining
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	3 	0.17
# It was an entertaining movie,  yet slightly unsatisfying by the time it was over.
#
#
# matches: 1 	word: more
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	5 	0.63
# This was great superhero movie, with a good cast that should have been the start of many more movies.
#
#
# matches: 1 	word: chonenberge
#
# # 	rating 	polarity
# ----------------------------------------
# 0 	4 	0.5
# The fact that this movie turns into one of those chonenberge body horror type movies is refreshing and something knee.

# %% [markdown]
# 3.4 Orientation Identification for Opinion
# Words

# %% [markdown]
# ### Code for analysis of SpaCy attributes

# %%
# code to test how words rank within spacy's prob attribute

output = set()

for sent in corpus.sentences:
    for token in sent.sent:
        output.add((token.prob*-1, token.string.strip()))
            
sorted(output)
# Out:
# [(3.0678977966308594, u'.'),
#  (3.4549596309661865, u','),
#  (3.528766632080078, u'the'),
#  (3.791565179824829, u'I'),
#  (3.8560216426849365, u'to'),
#  (3.92978835105896, u'a'),
#  (4.113108158111572, u'and'),
#  (4.27587366104126, u'of'),
#  (4.373791217803955, u'you'),
#  (4.388050079345703, u'it'),
#  (4.457748889923096, u'is'),
#  (4.464504718780518, u'that'),
#  (4.619071960449219, u'in'),
#  (4.830559253692627, u"'s"),
#  (4.859938621520996, u"n't"),
#  (4.8801093101501465, u'for'),
#  (5.02677583694458, u'"'),
#  (5.05924654006958, u'?'),
#  (5.129165172576904, u''),
#  (5.156484603881836, u'have'),
#  (5.172736167907715, u'on'),
#  (5.1977410316467285, u'*'),
#  (5.197994232177734, u')'),
#  (5.225094318389893, u'be'),
#  (5.243249893188477, u'with'),
#  (5.246996879577637, u'do'),
#  (9.521262168884277, u'key'),
#  (9.522706985473633, u'cover'),
#  (9.524518013000488, u'further'),
#  (9.526593208312988, u'calling'),
#  (9.526923179626465, u'regular'),
#  (9.527807235717773, u'wall'),
#  (9.528594017028809, u'possibly'),
#  (9.528669357299805, u'risk'),
#  (9.528985023498535, u'total'),
#  ...]

# %%
dep = []

for sent in corpus.sentences:
    for token in sent.sent:
        dep.append(token.dep_)
            
Counter(dep).most_common()
# Out:
# [(u'punct', 10489),
#  (u'nsubj', 9127),
#  (u'det', 8660),
#  (u'prep', 6693),
#  (u'pobj', 6067),
#  (u'advmod', 6025),
#  (u'ROOT', 5793),
#  (u'dobj', 5340),
#  (u'amod', 4712),
#  (u'aux', 4504),
#  (u'conj', 3917),
#  (u'cc', 3483),
#  (u'compound', 3390),
#  (u'acomp', 2010),
#  (u'advcl', 1844),
#  (u'', 1550),
#  (u'ccomp', 1535),
#  (u'xcomp', 1477),
#  (u'neg', 1436),
#  (u'mark', 1396),
#  (u'poss', 1311),
#  (u'nummod', 1058),
#  (u'attr', 961),
#  (u'relcl', 916),
#  (u'prt', 823),
#  (u'npadvmod', 573),
#  (u'pcomp', 493),
#  (u'auxpass', 398),
#  (u'appos', 332),
#  (u'nsubjpass', 320),
#  (u'nmod', 304),
#  (u'acl', 302),
#  (u'quantmod', 176),
#  (u'dep', 170),
#  (u'case', 157),
#  (u'expl', 152),
#  (u'intj', 125),
#  (u'csubj', 106),
#  (u'dative', 91),
#  (u'predet', 89),
#  (u'oprd', 80),
#  (u'parataxis', 79),
#  (u'preconj', 41),
#  (u'agent', 38),
#  (u'meta', 24),
#  (u'csubjpass', 1)]

# %%
pos = []

for sent in corpus.sentences:
    for token in sent.sent:
        pos.append(token.tag_)
            
Counter(pos).most_common()
# Out:
# [(u'NN', 13468),
#  (u'DT', 9520),
#  (u'IN', 8485),
#  (u'JJ', 6883),
#  (u'RB', 6707),
#  (u'PRP', 6480),
#  (u'.', 5446),
#  (u'VB', 4429),
#  (u'VBZ', 3537),
#  (u'CC', 3511),
#  (u'NNP', 3454),
#  (u',', 2956),
#  (u'NNS', 2800),
#  (u'VBD', 2717),
#  (u'VBP', 2533),
#  (u'TO', 1818),
#  (u'VBG', 1628),
#  (u'SP', 1550),
#  (u'CD', 1366),
#  (u'VBN', 1354),
#  (u'MD', 1268),
#  (u'PRP$', 1220),
#  (u'RP', 793),
#  (u'WDT', 443),
#  (u'JJR', 442),
#  (u'WRB', 370),
#  (u'-LRB-', 361),
#  (u'``', 347),
#  (u'-RRB-', 343),
#  (u':', 341),
#  (u"''", 279),
#  (u'HYPH', 277),
#  (u'WP', 202),
#  (u'JJS', 152),
#  (u'EX', 151),
#  (u'POS', 150),
#  (u'UH', 150),
#  (u'RBR', 122),
#  (u'NFP', 108),
#  (u'PDT', 101),
#  (u'$', 75),
#  (u'FW', 60),
#  (u'SYM', 53),
#  (u'RBS', 38),
#  (u'XX', 33),
#  (u'LS', 17),
#  (u'NNPS', 14),
#  (u'ADD', 10),
#  (u'AFX', 6)]
