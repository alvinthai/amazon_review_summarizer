# %%
from bs4 import BeautifulSoup
from pprint import pprint
import pandas as pd

import datetime
import time
import requests

# %% [markdown]
# ### Custom Functions

# %%
from wordsets import *
from scraper import *

# %%
from __future__ import division
from collections import Counter, defaultdict
from sklearn.feature_extraction.text import CountVectorizer
from spacy.en import English
from textblob import TextBlob
from wordsets import com_dep, com_tag, noun_tag, nonaspects
import numpy as np
import re

parser = English()


class SentCustomProperties(object):
    '''
    adds properties to spacy sentence that tracks:
        index of review where sentence originated
        customer review rating
        spacy Span object
        index of sentence within review corpus
        index of first token in sentence within review
        num of words in sentences
    '''

    def __init__(self, review_idx, rating, sent_idx, sent):
        '''
        INPUT: int, int, spacy sentence (spacy.tokens.span.Span)
        OUTPUT: None
        '''
        self.review_idx = review_idx
        self.review_rate = rating
        self.sent = sent
        self.sent_idx = sent_idx
        self.start_idx = sent[0].i
        self.words = len(sent)


class ReviewSents(object):
    '''
    Takes a list of unicode reviews and stores the sentences
    (with additional properties) in the returned object
    '''

    def __init__(self, product):
        '''
        INPUT: Loader
        OUTPUT: None
        '''
        self.ratings = product.ratings
        self.reviews = product.reviews
        self.n_reviews, self.n_sent, self.sentences = self._parse_sentences()

    def _parse_sentences(self):
        '''
        INPUT: None
        OUTPUT: int, int, list(SentCustomProperties)

        Uses spacy to parse and split the sentences
        Return number of reviews, sentences, and list of spacy objects
        '''
        regex = re.compile(r'\.\.\.\.+')

        n_sent, n_reviews = 0, 0
        sentences = []

        for i, review in enumerate(self.reviews):
            try:
                review = regex.sub(u'...', review)
                review = parser(review)
                n_reviews += 1
            except AssertionError:
                print 'parser for review #{} failed'.format(i)
                continue

            for sent in review.sents:
                if sent.string:
                    sentences.append(SentCustomProperties(i, self.ratings[i],
                                                          n_sent, sent))
                    n_sent += 1

        return n_reviews, n_sent, sentences


class Unigramer(object):
    '''
    Class of functions for extracting Unigrams
    '''

    def __init__(self):
        self.dep_dict = defaultdict(list)
        self.cnt_dict = defaultdict(int)
        self.pol_dict = defaultdict(list)
        self.rev_dict = defaultdict(set)
        self.sent_dict = defaultdict(set)
        self.word_pos_dict = defaultdict(list)

    def _iter_nouns(self, sent):
        '''
        INPUT: SentCustomProperties
        OUTPUT: set

        Iterates through each token of spacy sentence and collects
            lemmas of all nouns into a set.
        '''
        wordset = set()

        for token in sent.sent:
            self.cnt_dict[token.lemma_] += 1
            self.dep_dict[token.head.lemma_].append(token.dep_)
            root = parser.vocab[token.lemma].prob

            # filter to only consider nouns, valid aspects, and uncommon words
            if token.tag_ in noun_tag and (root < -7.5 and
                                           token.lemma_ not in nonaspects):
                wordset.add(token.lemma_)
                self.rev_dict[token.lemma_].add(sent.review_idx)

                if sent.sent_idx not in self.sent_dict[token.lemma_]:
                    self.word_pos_dict[token.lemma_].append(token.i)
                    self.sent_dict[token.lemma_].add(sent.sent_idx)

            if token.dep_ == 'amod':
                pol = abs(TextBlob(token.string).sentiment.polarity) > 0
                self.pol_dict[token.head.lemma_].append(pol)

        return " ".join(wordset)

    def candidate_unigrams(self, corpus, min_pct=0.01, amod_pct=0.075):
        '''
        INPUT: ReviewSents, float, float
        OUTPUT: set, dict

        obtains a set of candidate unigrams

        each candidate unigram must be a noun and must appear in at least
            a percentage of the sentences specified by min_pct with the unigram
            being modified by an amod dependency at least amod_pct of the time
        '''
        count_X = []

        for sent in corpus.sentences:
            count_X.append(self._iter_nouns(sent))

        cnt_vec = CountVectorizer()
        freq = cnt_vec.fit_transform(count_X)

        total_count = freq.toarray().sum(axis=0)
        filter_ = total_count >= min_pct * corpus.n_sent

        # filter for aspect appearing in min_pct of sentences
        features = np.array(cnt_vec.get_feature_names())
        unigrams = set(features[filter_])

        # filter for percentage of time aspect is modified by amod
        for word in unigrams.copy():
            arr = np.array(self.dep_dict[word]) == 'amod'

            if np.mean(arr) < amod_pct:
                unigrams.remove(word)

        return unigrams, self.cnt_dict


class Bigramer(object):
    '''
    Class of functions for extracting Bigrams
    '''
    def __init__(self):
        self.avg_dist = defaultdict(float)
        self.distances = defaultdict(list)
        self.ordering = defaultdict(lambda: [0, 0])
        self.pmi = defaultdict(float)
        self.rev_dict = defaultdict(set)
        self.sent_dict = defaultdict(set)
        self.word_pos_dict = defaultdict(list)

    def _reverse_key(self, key, new_key):
        '''
        INPUT: string(two words seperated by space)
        OUTPUT: None

        Reverses the word order for the key in the class dictionaries
        '''
        self.avg_dist[new_key] = self.avg_dist.pop(key)
        self.distances[new_key] = self.distances.pop(key)
        self.ordering[new_key] = self.ordering.pop(key)
        self.pmi[new_key] = self.pmi.pop(key)
        self.rev_dict[new_key] = self.rev_dict.pop(key)
        self.sent_dict[new_key] = self.sent_dict.pop(key)
        self.word_pos_dict[new_key] = self.word_pos_dict.pop(key)

    def _get_compactness_feat(self, corpus):
        '''
        INPUT: ReviewSents
        OUTPUT: generator(tuples(unicode))

        outputs generator of tuples (in alphabetical order) consisting of:
            at least one noun
            a second word within +/- 3 words of noun
        excludes dependencies and tags not likely to be a feature word
        '''

        for sent in corpus.sentences:
            output = set()

            for i, token in enumerate(sent.sent):
                # one word in bigram must be noun
                if token.tag_ in noun_tag and token.lemma_ not in nonaspects:
                    arr = sent.sent[max(0, i - 3):min(i + 4, sent.words)]
                    arr = np.array(arr)
                    arr = arr[arr != token]

                    for item in arr:
                        root = parser.vocab[item.lemma].prob
                        # filter out unlikely features
                        if root < -7.5 and (item.dep_ not in com_dep and
                                            item.tag_ not in com_tag and
                                            item.lemma_ not in nonaspects):
                            bigrm = " ".join(sorted([item.lemma_,
                                                     token.lemma_]))
                            dist = item.i - token.i
                            word_sort = item.lemma_ < token.lemma_

                            self.distances[bigrm].append(abs(dist))
                            self.rev_dict[bigrm].add(sent.review_idx)
                            self.ordering[bigrm][word_sort == (dist > 0)] += 1

                            if sent.sent_idx not in self.sent_dict[bigrm]:
                                self.word_pos_dict[bigrm].append(token.i)
                                self.sent_dict[bigrm].add(sent.sent_idx)

                            output.add(bigrm)

            if output:
                for element in output:
                    yield element

    def candidate_bigrams(self, corpus, cnt_dict, min_pct=0.005,
                          pmi_pct=0.0, max_avg_dist=2):
        '''
        INPUT: ReviewSents, cnt_dict, float
        OUTPUT: set(tuples), set(str)

        outputs set of tuples and set of words within tuples from
            _get_compactness_feat function appearing at least
            min_cnt times

        cnt_dict output from candidate_unigrams is the input for the second
            argument of this function
        '''
        bigrams = set()
        bigram_words = set()

        feats = Counter(self._get_compactness_feat(corpus))

        for (key, val) in feats.iteritems():
            order = sorted(key.split(" "),
                           reverse=self.ordering[key][1] >
                           self.ordering[key][0])
            new_key = " ".join(order)

            pmi = round(val / (cnt_dict[order[0]] * cnt_dict[order[1]]), 4)
            avg_dist = round(np.mean(self.distances[key]), 2)

            if pmi >= pmi_pct and (avg_dist < max_avg_dist and
                                   val >= max(2, min_pct * corpus.n_sent)):
                self.avg_dist[key] = avg_dist
                self.pmi[key] = pmi

                bigrams.add(new_key)
                bigram_words.update(set(key))

                if key != new_key:
                    self._reverse_key(key, new_key)

        return bigrams, bigram_words

# %% [markdown]
# # My Code

# %%
class DFloader(object):
    '''
    INPUT: df
    OUTPUT: None
    
    Extracts the ratings and reviews from a canned amazon dataset
        parsed into pandas.
    '''
    
    def __init__(self, df, name=None):
        self.name = name
        self.ratings = df.overall.tolist()
        self.reviews = df.reviewText.tolist()

def pipeline(df, asin_list, product_names=None):
    '''
    INPUT: df, list(str), dict
    OUTPUT: dict
    
    runs pipeline specified in functions above for list of asin
        on loaded data frame containing reviews
    outputs asin callable dictionary
    '''
    print 'start time:', datetime.datetime.now().time().isoformat()
    print
    
    asin_dict = defaultdict(dict)
    
    for asin in asin_list:
        print 'working on ASIN {}'.format(asin)
        print '-'*40
        
        if product_names:
            asin_dict[asin]['name'] = product_names.get(asin, None)
        
        product = DFloader(df[df.asin == asin])    
        corpus = ReviewSents(product)
        
        unigramer = Unigramer()
        unigrams, cnt_dict = unigramer.candidate_unigrams(corpus, min_pct=0.01, amod_pct=0.094)
        
        bigramer = Bigramer()
        bigrams, bigram_words = bigramer.candidate_bigrams(corpus, cnt_dict, 
                                                           min_pct=0.005, pmi_pct=1/2500)
        
        asin_dict[asin]['corpus'] = corpus
        asin_dict[asin]['unigrams'] = unigrams
        asin_dict[asin]['dep_dict'] = unigramer.dep_dict
        asin_dict[asin]['cnt_dict'] = unigramer.cnt_dict
        asin_dict[asin]['pol_dict'] = unigramer.pol_dict
        asin_dict[asin]['uni_rev_dict'] = unigramer.rev_dict
        asin_dict[asin]['uni_sent_dict'] = unigramer.sent_dict
        asin_dict[asin]['uni_word_pos_dict'] = unigramer.word_pos_dict
        asin_dict[asin]['bigrams'] = bigrams
        asin_dict[asin]['bigram_words'] = bigram_words
        asin_dict[asin]['bigram_avg_dist'] = bigramer.avg_dist
        asin_dict[asin]['bigram_ordering'] = bigramer.ordering
        asin_dict[asin]['bigram_pmi'] = bigramer.pmi
        asin_dict[asin]['big_rev_dict'] = bigramer.rev_dict
        asin_dict[asin]['big_sent_dict'] = bigramer.sent_dict
        asin_dict[asin]['big_word_pos_dict'] = bigramer.word_pos_dict
        
        print '-'*40
        print
    
    print 'end time:', datetime.datetime.now().time().isoformat()
    return asin_dict

# %%
def get_item_name(asin_list):
    '''
    INPUT: list
    OUTPUT: dict
    
    Script that returns a list of product names given an ASIN list
    '''
    output = dict()
    
    for asin in asin_list:
        url = 'https://www.amazon.com/dp/{}/'.format(asin)
        user_agent = ['Mozilla/5.0 (X11; Linux i686) AppleWebKit/534.30',
                      '(KHTML, like Gecko) Ubuntu/11.04',
                      'Chromium/12.0.742.91 Chrome/12.0.742.91',
                      'Safari/534.30']
        headers = {'User-Agent': np.random.choice(user_agent)}
        html = requests.get(url, headers=headers).content
        soup = BeautifulSoup(html, 'html.parser')
        try:
            name = soup.select('#productTitle')[0].text.strip()
        except IndexError:
            name = ''
            
        output[asin] = name
        time.sleep(5 + np.random.random()*10)
    
    return output

# %% [markdown]
# # Amazon Electronics Review Corpus

# %%
cd ~/repos/amazon_review_summarizer/
# Out:
# /Users/Alvin/Repos/amazon_review_summarizer

# %%
with open('reviews/Electronics_5-2.json', 'r') as f:
    data = f.readlines()

# %%
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"

# %%
df = pd.read_json(data_json_str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689188 entries, 0 to 1689187
# Data columns (total 9 columns):
# asin              1689188 non-null object
# helpful           1689188 non-null object
# overall           1689188 non-null int64
# reviewText        1689188 non-null object
# reviewTime        1689188 non-null object
# reviewerID        1689188 non-null object
# reviewerName      1664458 non-null object
# summary           1689188 non-null object
# unixReviewTime    1689188 non-null int64
# dtypes: int64(2), object(7)
# memory usage: 128.9+ MB

# %%
group = df.groupby('asin').size()

# %%
len(group[df.groupby('asin').size() >= 1000])
# Out:
# 52

# %%
asin_1000 = group[df.groupby('asin').size() >= 1000].index.tolist()
asin_1000
# Out:
# [u'B00004ZCJE',
#  u'B00007E7JU',
#  u'B0002L5R78',
#  u'B000BQ7GW8',
#  u'B000I68BD4',
#  u'B000LRMS66',
#  u'B000QUUFRW',
#  u'B000S5Q9CA',
#  u'B000VX6XL6',
#  u'B0012S4APK',
#  u'B0015DYMVO',
#  u'B0019EHU8G',
#  u'B001TH7GSW',
#  u'B001TH7GUU',
#  u'B001XURP7W',
#  u'B0027VT6V4',
#  u'B002MAPRYU',
#  u'B002QEBMAK',
#  u'B002SZEOLG',
#  u'B002V88HFE',
#  u'B002WE6D44',
#  u'B00316263Y',
#  u'B003ELYQGG',
#  u'B003ES5ZUU',
#  u'B0041Q38NU',
#  u'B0043T7FXE',
#  u'B0044YU60M',
#  u'B004G6002M',
#  u'B004GF8TIK',
#  u'B004QK7HI8',
#  u'B004W2JKWG',
#  u'B004XC6GJ0',
#  u'B0052SCU8U',
#  u'B005CLPP84',
#  u'B005CT56F8',
#  u'B005DKZTMG',
#  u'B005FYNSPK',
#  u'B005HMKKH4',
#  u'B00622AG6S',
#  u'B006GWO5WK',
#  u'B006W8U2MU',
#  u'B0074BW614',
#  u'B007I5JT4S',
#  u'B007R5YDYA',
#  u'B007WTAJTO',
#  u'B008OHNZI0',
#  u'B009A5204K',
#  u'B009SYZ8OC',
#  u'B00B46XUQU',
#  u'B00BGGDVOO',
#  u'B00DR0PDNE',
#  u'B00E3W15P0']

# %%
# product_names = get_item_name(asin_1000)

# %%
product_names = {u'B00004ZCJE': u'Tiffen 46mm UV Protection Filter',
 u'B00007E7JU': u'Canon EF 50mm f/1.8 II Camera Lens - Fixed (Discontinued by Manufacturer)',
 u'B0002L5R78': u"DVI Gear HDMI-2M 2M/6' HDMI Cable",
 u'B000BQ7GW8': u'SanDisk 2GB Class 4 SD Flash Memory Card- SDSDB-002G-B35 (Label May Change)',
 u'B000I68BD4': u'JLab Audio JBuds Hi-Fi Noise-Reducing Ear Buds, GUARANTEED FOR LIFE - White',
 u'B000LRMS66': u'Garmin Portable Friction Mount',
 u'B000QUUFRW': u'SanDisk 4GB Extreme SDHC Class 10 Memory Card',
 u'B000S5Q9CA': u'Motorola Vehicle Power Adapter micro-USB Charger',
 u'B000VX6XL6': u'Kingston 4 GB microSDHC Class 4 Flash Memory Card SDC4/4GBET',
 u'B0012S4APK': u'Cheetah Mounts APTMM2B TV Wall Mount for 20-75-Inch TVs Bundle with 10-feet Braided HDMI Cable and a 6-Inch 3-Axis Magnetic Bubble',
 u'B0015DYMVO': u'Belkin Mini 5W 3-Outlet Swivel Travel Charger with Dual USB Ports',
 u'B0019EHU8G': u'Mediabridge ULTRA Series HDMI Cable (6 Foot) - High-Speed Supports Ethernet, 3D and Audio Return [Newest Standard]',
 u'B001TH7GSW': u'AmazonBasics Digital Optical Audio Toslink Cable - 6 Feet (1.8 Meters)',
 u'B001TH7GUU': u'AmazonBasics USB 2.0 Extension Cable - A-Male to A-Female - 9.8 Feet (3 Meters)',
 u'B001XURP7W': u'SanDisk Cruzer 4GB USB 2.0 Flash Drive- SDCZ36-004G-B35',
 u'B0027VT6V4': u'Cyber Acoustics 30 Watt Powered Speakers with Subwoofer for PC and Gaming Systems in Standard Packaging, (CA-3602a)',
 u'B002MAPRYU': u'SanDisk Sansa Clip+ 4 GB MP3 Player (Red) (Discontinued by Manufacturer)',
 u'B002QEBMAK': u'WD Elements 500 GB USB 2.0 Desktop External Hard Drive',
 u'B002SZEOLG': u'TP-LINK TL-WN722N Wireless N150 High Gain USB Adapter, 150Mbps, 4dBi External Antenna, WPS Button, Support Windows XP/Vista/7/8',
 u'B002V88HFE': u'eneloop SEC-CSPACER4PK C Size Spacers for use with AA battery cells',
 u'B002WE6D44': u'Transcend 8GB Class 10 SDHC Card (TS8GSDHC10)',
 u'B00316263Y': u'BlueRigger High Speed HDMI Cable with Ethernet 6.6 Feet (2m) - Supports 3D and Audio Return [Latest Version]',
 u'B003ELYQGG': u'Panasonic ErgoFit Best in Class In-Ear Earbud Headphones RP-HJE120-D (Orange) Dynamic Crystal Clear Sound, Ergonomic Comfort-Fit, iPhone, Android Compatible, Noise Isolating Headphones',
 u'B003ES5ZUU': u'AmazonBasics High-Speed HDMI Cable with Ethernet - Braided 6.5 feet/2.0 meters (Discontinued by Manufacturer)',
 u'B0041Q38NU': u'Kingston Datatraveler 101 Gen 2 With urDrive 8GB USB 2.0 (Red)',
 u'B0043T7FXE': u'Logitech M570 Wireless Trackball, Computer Wireless Mouse, Long Range Wireless Mouse',
 u'B0044YU60M': u'Wireless Router w/ WiFi Range Extender Mode (300 Mbps) by Medialink - Easy YouTube Setup Video (Part# MWNWAPR300N )',
 u'B004G6002M': u'SanDisk 16GB Mobile MicroSDHC Class 4 Flash Memory Card- SDSDQM-016G-B35N',
 u'B004GF8TIK': u'Mediabridge USB 2.0 - Micro-USB to USB Cable (6 Feet) - High-Speed A Male to Micro B - (Part# 30-004-06B )',
 u'B004QK7HI8': u'Mohu Leaf 30 TV Antenna, Indoor, 30 Mile Range, Original Paper-thin, Reversible, Paintable, 4K-Ready HDTV, 10 Foot Detachable Cable, Premium Materials for Performance, USA Made, MH-110598',
 u'B004W2JKWG': u'Crucial m4 64GB 2.5-Inch (9.5mm) SATA 6Gb/s Solid State Drive CT064M4SSD2',
 u'B004XC6GJ0': u'ARRIS SURFboard SB6121 DOCSIS 3.0 Cable Modem  (Black,Retail Packaging)',
 u'B0052SCU8U': u'AmazonBasics High-Speed HDMI Cable 2-Pack - 6.5 Feet (2 Meters) Supports Ethernet, 3D, 4K and Audio Return',
 u'B005CLPP84': u'Roku 2 XS 1080p Streaming Player (Old Model)',
 u'B005CT56F8': u'Seagate 320GB HDD SATA 6Gb/s 64MB Cache 3.5-Inch Internal Bare Drive (ST320DM000)',
 u'B005DKZTMG': u'Logitech Wireless Touch Keyboard K400 with Built-In Multi-Touch Touchpad, Black',
 u'B005FYNSPK': u'SanDisk Cruzer Fit 4GB USB 2.0 Low-Profile Flash Drive- SDCZ33-004G-B35',
 u'B005HMKKH4': u'WD My Passport 2TB Portable External USB 3.0 Hard Drive Storage Black (WDBY8L0020BBK-NESN)',
 u'B00622AG6S': u'PowerGen 2.4Amps / 12W Dual USB Car charger Designed for Apple and Android Devices - White',
 u'B006GWO5WK': u'Amazon Kindle 9W PowerFast Adapter for Accelerated Charging',
 u'B006W8U2MU': u'Kingston Digital DataTraveler SE9 8GB USB 2.0 DTSE9H/8GBZ',
 u'B0074BW614': u'Kindle Fire HD 7", Dolby Audio, Dual-Band Wi-Fi, 16 GB (Previous Generation - 2nd),-R',
 u'B007I5JT4S': '',
 u'B007R5YDYA': u'Amazon Kindle Paperwhite Case - Lightest and Thinnest Protective Genuine Leather Cover with Auto Wake/Sleep for Amazon Kindle Paperwhite, Saddle Tan',
 u'B007WTAJTO': u'SanDisk Ultra 64GB MicroSDXC Class 10 UHS Memory Card Speed Up To 30MB/s With Adapter - SDSDQUA-064G-U46A [Old Version]',
 u'B008OHNZI0': u'Tech Armor Ultimate 4-Way 360 Degree Privacy Screen Protector for Apple New iPhone 5, Latest Generation, 1-Pack',
 u'B009A5204K': u'LG Tone HBS-730 Wireless Stereo Headset - Black',
 u'B009SYZ8OC': u'AmazonBasics Apple Certified Lightning to USB Cable - 3 Feet (0.9 Meters) - Black',
 u'B00B46XUQU': u'PORTTA PET0301S 3x1 Port HDMI Switch/Switcher 1080P Supports 3D with IR Wireless Remote Ultra High...',
 u'B00BGGDVOO': u'Roku 3 Streaming Media Player (2014 model)',
 u'B00DR0PDNE': '',
 u'B00E3W15P0': u'[DISCONTINUED] Samsung 840 EVO 120GB 2.5-Inch SATA III Internal SSD (MZ-7TE120BW)'}

# %%
group[df.groupby('asin').size() >= 1000].sum()
# Out:
# 89054

# %%
asin_dict = pipeline(df, asin_1000, product_names)
# Out:
# start time: 21:17:33.204446
#
# working on ASIN B00004ZCJE
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00007E7JU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0002L5R78
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000BQ7GW8
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000I68BD4
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000LRMS66
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000QUUFRW
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000S5Q9CA
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B000VX6XL6
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0012S4APK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0015DYMVO
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0019EHU8G
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B001TH7GSW
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B001TH7GUU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B001XURP7W
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0027VT6V4
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002MAPRYU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002QEBMAK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002SZEOLG
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002V88HFE
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B002WE6D44
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00316263Y
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B003ELYQGG
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B003ES5ZUU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0041Q38NU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0043T7FXE
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0044YU60M
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004G6002M
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004GF8TIK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004QK7HI8
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004W2JKWG
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B004XC6GJ0
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0052SCU8U
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B005CLPP84
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B005CT56F8
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B005DKZTMG
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B005FYNSPK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B005HMKKH4
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00622AG6S
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B006GWO5WK
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B006W8U2MU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B0074BW614
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B007I5JT4S
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B007R5YDYA
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B007WTAJTO
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B008OHNZI0
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B009A5204K
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B009SYZ8OC
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00B46XUQU
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00BGGDVOO
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00DR0PDNE
# ----------------------------------------
# ----------------------------------------
#
# working on ASIN B00E3W15P0
# ----------------------------------------
# ----------------------------------------
#
# end time: 21:36:15.908151

# %%
all_unigrams = []
all_bigrams = []

def is_amod(dep_list):
    '''
    INPUT: list of spacy dependency strings
    OUTPUT: float
    
    Calculates the percentage of time the unigram was used as an amod
    '''
    amod = np.array(asin_dict[asin]['dep_dict'][dep_list]) == 'amod'
    return round(np.mean(amod), 3)

for asin in asin_dict:
    name = asin_dict[asin]['name']
    
    print asin
    print name
    print '-' * 40, '\n'
    
    uni_rev_dict = asin_dict[asin]['uni_rev_dict']
    big_dist_dict = asin_dict[asin]['bigram_avg_dist']
    big_pmi_dict = asin_dict[asin]['bigram_pmi']
    big_rev_dict = asin_dict[asin]['big_rev_dict']
    
    unigrams = list(asin_dict[asin]['unigrams'])
    unigrams_amod = map(is_amod, unigrams)
    unigrams_amod_pol = [round(np.mean(asin_dict[asin]['pol_dict'][unigram]), 2)
                         for unigram in unigrams]
    unigrams_rev_f = [len(uni_rev_dict[unigram]) for unigram in unigrams]
    
    top_unigrams = sorted(zip(unigrams, unigrams_amod, unigrams_amod_pol, 
                              unigrams_rev_f),
                          key=lambda x: x[3], reverse=True)[0:20]
    all_unigrams.extend([[name, asin, x[0], x[1], x[2], x[3]] for x in top_unigrams])
    
    bigrams = list(asin_dict[asin]['bigrams'])
    bigrams_dist = [big_dist_dict[bigram] for bigram in bigrams]
    bigrams_pmi = [big_pmi_dict[bigram] for bigram in bigrams]
    bigrams_rev_f = [len(big_rev_dict[bigram]) for bigram in bigrams]
    
    top_bigrams = sorted(zip(bigrams, bigrams_dist, bigrams_pmi,
                            bigrams_rev_f),
                        key=lambda x: x[3], reverse=True)[0:20]
    all_bigrams.extend([[name, asin, x[0], x[1], x[2], x[3]]
                        for x in top_bigrams])
    
    pprint(top_unigrams)
    print
    pprint(top_bigrams)
    print
# Out:
# B00007E7JU
# Canon EF 50mm f/1.8 II Camera Lens - Fixed (Discontinued by Manufacturer)
# ----------------------------------------
#
# [(u'lens', 0.202, 0.62, 1171),
#  (u'picture', 0.337, 0.78, 367),
#  (u'quality', 0.148, 0.7, 360),
#  (u'camera', 0.114, 0.57, 349),
#  (u'light', 0.458, 0.24, 339),
#  (u'portrait', 0.247, 0.7, 291),
#  (u'shot', 0.326, 0.71, 276),
#  (u'focus', 0.116, 0.35, 255),
#  (u'photo', 0.291, 0.75, 247),
#  (u'image', 0.319, 0.72, 242),
#  (u'plastic', 0.178, 0.68, 187),
#  (u'aperture', 0.353, 0.5, 179),
#  (u'photography', 0.374, 0.52, 172),
#  (u'money', 0.146, 0.48, 164),
#  (u'bokeh', 0.281, 0.81, 159),
#  (u'field', 0.203, 0.6, 154),
#  (u'photographer', 0.301, 0.74, 153),
#  (u'depth', 0.251, 0.92, 153),
#  (u'bit', 0.121, 0.79, 121),
#  (u'dslr', 0.138, 0.87, 106)]
#
# [(u'low light', 1.28, 0.0008, 208),
#  (u'build quality', 1.07, 0.0011, 124),
#  (u'focal length', 1.02, 0.0065, 81),
#  (u'image quality', 1.19, 0.0005, 79),
#  (u'auto focus', 1.33, 0.0011, 75),
#  (u'manual focus', 1.08, 0.0009, 66),
#  (u'focus ring', 1.08, 0.0009, 62),
#  (u'background blur', 1.63, 0.0049, 50),
#  (u'canon rebel', 1.29, 0.0005, 44),
#  (u'wide aperture', 1.39, 0.001, 44),
#  (u'light situation', 1.25, 0.0007, 43),
#  (u'crop sensor', 1.18, 0.0042, 43),
#  (u'full frame', 1.23, 0.0067, 38),
#  (u'50mm f/1.8', 1.05, 0.0005, 36)]
#
# B0027VT6V4
# Cyber Acoustics 30 Watt Powered Speakers with Subwoofer for PC and Gaming Systems in Standard Packaging, (CA-3602a)
# ----------------------------------------
#
# [(u'speaker', 0.202, 0.59, 823),
#  (u'sound', 0.125, 0.77, 653),
#  (u'bass', 0.234, 0.66, 477),
#  (u'volume', 0.194, 0.6, 439),
#  (u'system', 0.195, 0.72, 395),
#  (u'quality', 0.393, 0.85, 326),
#  (u'control', 0.096, 0.52, 314),
#  (u'music', 0.163, 0.54, 235),
#  (u'set', 0.104, 0.72, 225),
#  (u'room', 0.269, 0.6, 137),
#  (u'money', 0.188, 0.76, 127),
#  (u'jack', 0.097, 0.22, 112),
#  (u'range', 0.253, 0.41, 108),
#  (u'bit', 0.117, 0.84, 97),
#  (u'base', 0.19, 0.66, 88),
#  (u'level', 0.238, 0.51, 84),
#  (u'satellite', 0.109, 0.57, 83),
#  (u'input', 0.268, 0.15, 79),
#  (u'audio', 0.194, 0.68, 79),
#  (u'power', 0.116, 0.82, 78)]
#
# [(u'volume control', 1.32, 0.0005, 195),
#  (u'headphone jack', 1.18, 0.0023, 70),
#  (u'cyber acoustics', 1.01, 0.0079, 62),
#  (u'sub woofer', 1.52, 0.0025, 46),
#  (u'control pod', 1.14, 0.001, 43),
#  (u'play music', 1.48, 0.001, 43),
#  (u'volume knob', 1.37, 0.0007, 40),
#  (u'high end', 1.42, 0.0017, 40)]
#
# B004G6002M
# SanDisk 16GB Mobile MicroSDHC Class 4 Flash Memory Card- SDSDQM-016G-B35N
# ----------------------------------------
#
# [(u'card', 0.126, 0.44, 649),
#  (u'memory', 0.293, 0.45, 383),
#  (u'sd', 0.236, 0.15, 193),
#  (u'storage', 0.284, 0.29, 180),
#  (u'space', 0.367, 0.48, 147),
#  (u'speed', 0.252, 0.39, 127),
#  (u'data', 0.126, 0.64, 106),
#  (u'camera', 0.164, 0.34, 103),
#  (u'file', 0.227, 0.8, 77),
#  (u'quality', 0.283, 0.75, 75),
#  (u'android', 0.108, 1.0, 73),
#  (u'movie', 0.101, 0.67, 66),
#  (u'packaging', 0.404, 0.32, 64),
#  (u'capacity', 0.182, 0.73, 62),
#  (u'size', 0.19, 0.55, 55),
#  (u'deal', 0.27, 0.92, 47)]
#
# [(u'sd card', 1.09, 0.0005, 148),
#  (u'samsung galaxy', 1.0, 0.0033, 96),
#  (u'micro sd', 1.07, 0.0022, 79),
#  (u'micro card', 1.95, 0.0005, 78),
#  (u'flash memory', 1.03, 0.0013, 66),
#  (u'flash card', 1.71, 0.0005, 65),
#  (u'galaxy tab', 1.04, 0.004, 48),
#  (u'microsd card', 1.26, 0.0005, 44),
#  (u'cell phone', 1.0, 0.0015, 43),
#  (u'android phone', 1.38, 0.0007, 37),
#  (u'mp3 player', 1.0, 0.0094, 37),
#  (u'galaxy s3', 1.03, 0.0045, 35),
#  (u'microsdhc card', 1.87, 0.0004, 33),
#  (u'samsung tab', 1.8, 0.0028, 32),
#  (u'smart phone', 1.08, 0.0013, 30),
#  (u'store music', 1.62, 0.0009, 29),
#  (u'retail packaging', 1.15, 0.0052, 28),
#  (u'write speed', 1.16, 0.0022, 23),
#  (u'android tablet', 1.17, 0.0008, 23),
#  (u'microsdhc flash', 1.45, 0.0034, 23)]
#
# B001TH7GSW
# AmazonBasics Digital Optical Audio Toslink Cable - 6 Feet (1.8 Meters)
# ----------------------------------------
#
# [(u'cable', 0.24, 0.36, 800),
#  (u'quality', 0.382, 0.88, 338),
#  (u'sound', 0.163, 0.67, 276),
#  (u'audio', 0.199, 0.21, 182),
#  (u'end', 0.142, 0.58, 141),
#  (u'system', 0.186, 0.76, 129),
#  (u'amazonbasics', 0.357, 0.2, 85),
#  (u'bar', 0.154, 0.92, 81),
#  (u'connection', 0.308, 0.34, 76),
#  (u'plastic', 0.273, 0.56, 74),
#  (u'home', 0.125, 1.0, 67),
#  (u'store', 0.304, 0.06, 65),
#  (u'job', 0.144, 0.77, 65),
#  (u'box', 0.136, 0.25, 62),
#  (u'money', 0.185, 0.7, 60),
#  (u'connector', 0.17, 0.25, 59),
#  (u'speaker', 0.158, 0.27, 57),
#  (u'optical', 0.098, 0.5, 57),
#  (u'cap', 0.347, 0.38, 56),
#  (u'difference', 0.118, 0.59, 52)]
#
# [(u'optical cable', 1.43, 0.0004, 217),
#  (u'sound bar', 1.06, 0.0017, 80),
#  (u'toslink cable', 1.24, 0.0004, 78),
#  (u'sound quality', 1.27, 0.0004, 78),
#  (u'optical audio', 1.04, 0.0007, 77),
#  (u'digital audio', 1.53, 0.0012, 69),
#  (u'high quality', 1.12, 0.0014, 64),
#  (u'sound system', 1.19, 0.0008, 58),
#  (u'surround sound', 1.12, 0.0012, 58),
#  (u'home theater', 1.0, 0.0107, 46),
#  (u'digital optical', 1.25, 0.0006, 42),
#  (u'surround system', 1.63, 0.0023, 31),
#  (u'audio toslink', 1.48, 0.0008, 27),
#  (u'build quality', 1.2, 0.0011, 26),
#  (u'home system', 1.97, 0.0025, 26),
#  (u'plastic cap', 1.15, 0.0034, 25),
#  (u'fiber optic', 1.02, 0.0145, 24),
#  (u'theater system', 1.04, 0.0028, 21),
#  (u'plastic cover', 1.19, 0.0032, 21),
#  (u'quality excellent', 1.76, 0.0008, 20)]
#
# B006W8U2MU
# Kingston Digital DataTraveler SE9 8GB USB 2.0 DTSE9H/8GBZ
# ----------------------------------------
#
# [(u'drive', 0.171, 0.66, 634),
#  (u'usb', 0.141, 0.57, 487),
#  (u'key', 0.118, 0.58, 321),
#  (u'metal', 0.225, 0.15, 240),
#  (u'size', 0.232, 0.61, 191),
#  (u'file', 0.317, 0.54, 187),
#  (u'chain', 0.32, 0.02, 185),
#  (u'speed', 0.296, 0.48, 181),
#  (u'ring', 0.287, 0.08, 171),
#  (u'design', 0.22, 0.55, 159),
#  (u'data', 0.204, 0.68, 135),
#  (u'kingston', 0.109, 0.8, 129),
#  (u'computer', 0.155, 0.56, 120),
#  (u'case', 0.143, 0.54, 91),
#  (u'storage', 0.222, 0.29, 89),
#  (u'thumb', 0.483, 0.64, 83),
#  (u'stick', 0.109, 0.74, 83),
#  (u'memory', 0.232, 0.62, 73),
#  (u'quality', 0.241, 0.81, 69),
#  (u'capacity', 0.358, 0.78, 68)]
#
# [(u'flash drive', 1.0, 0.0007, 316),
#  (u'key chain', 1.07, 0.0017, 177),
#  (u'key ring', 1.11, 0.0013, 133),
#  (u'usb port', 1.13, 0.0009, 115),
#  (u'thumb drive', 1.04, 0.0007, 79),
#  (u'transfer file', 1.46, 0.001, 46),
#  (u'usb stick', 1.14, 0.0005, 45),
#  (u'solid metal', 1.73, 0.0011, 38),
#  (u'transfer speed', 1.09, 0.0008, 35),
#  (u'metal casing', 1.09, 0.002, 34),
#  (u'metal case', 1.31, 0.0011, 32),
#  (u'move part', 1.07, 0.0068, 30),
#  (u'data transfer', 1.12, 0.0009, 28),
#  (u'large file', 1.16, 0.0009, 27),
#  (u'write speed', 1.12, 0.0014, 26)]
#
# B009SYZ8OC
# AmazonBasics Apple Certified Lightning to USB Cable - 3 Feet (0.9 Meters) - Black
# ----------------------------------------
#
# [(u'cable', 0.185, 0.51, 1644),
#  (u'quality', 0.35, 0.86, 453),
#  (u'cord', 0.18, 0.46, 405),
#  (u'connector', 0.116, 0.34, 339),
#  (u'charger', 0.149, 0.43, 271),
#  (u'length', 0.261, 0.37, 264),
#  (u'usb', 0.097, 0.33, 221),
#  (u'amazonbasics', 0.129, 0.25, 175),
#  (u'plastic', 0.122, 0.55, 125),
#  (u'version', 0.13, 0.33, 124),
#  (u'wire', 0.191, 0.42, 112),
#  (u'money', 0.237, 0.5, 103),
#  (u'connection', 0.19, 0.33, 93),
#  (u'port', 0.109, 0.24, 87)]
#
# [(u'lightning end', 1.3, 0.0004, 120),
#  (u'lightning connector', 1.12, 0.0004, 114),
#  (u'iphone 5s', 1.07, 0.0008, 88),
#  (u'high quality', 1.03, 0.0015, 84),
#  (u'ipad mini', 1.06, 0.0024, 76),
#  (u'official apple', 1.14, 0.0004, 54),
#  (u'car charger', 1.27, 0.0005, 50),
#  (u'lifeproof case', 1.27, 0.0008, 46),
#  (u'otterbox case', 1.8, 0.0005, 42)]
#
# B001TH7GUU
# AmazonBasics USB 2.0 Extension Cable - A-Male to A-Female - 9.8 Feet (3 Meters)
# ----------------------------------------
#
# [(u'cable', 0.155, 0.53, 666),
#  (u'usb', 0.103, 0.3, 443),
#  (u'extension', 0.106, 0.47, 335),
#  (u'quality', 0.332, 0.92, 245),
#  (u'cord', 0.161, 0.45, 193),
#  (u'length', 0.283, 0.48, 112),
#  (u'foot', 0.133, 0.36, 96),
#  (u'end', 0.222, 0.26, 84),
#  (u'amazonbasics', 0.107, 0.33, 81),
#  (u'connection', 0.243, 0.5, 81),
#  (u'connector', 0.336, 0.4, 67),
#  (u'keyboard', 0.126, 0.21, 57),
#  (u'job', 0.138, 1.0, 57),
#  (u'room', 0.156, 0.6, 57),
#  (u'drive', 0.264, 0.48, 45),
#  (u'camera', 0.108, 0.25, 39),
#  (u'signal', 0.254, 0.6, 39),
#  (u'controller', 0.155, 0.15, 38),
#  (u'box', 0.182, 0.45, 37),
#  (u'tv', 0.109, 0.67, 36)]
#
# [(u'extension cable', 1.05, 0.0004, 175),
#  (u'usb extension', 1.29, 0.0005, 142),
#  (u'usb port', 1.09, 0.0009, 58),
#  (u'extension cord', 1.06, 0.0004, 50),
#  (u'high quality', 1.06, 0.0024, 42),
#  (u'usb hub', 1.11, 0.0008, 33),
#  (u'phone charger', 1.3, 0.002, 23),
#  (u'charge phone', 1.88, 0.001, 23),
#  (u'build quality', 1.11, 0.001, 22),
#  (u'hard drive', 1.07, 0.0068, 19),
#  (u'female end', 1.28, 0.0028, 18)]
#
# B006GWO5WK
# Amazon Kindle 9W PowerFast Adapter for Accelerated Charging
# ----------------------------------------
#
# [(u'charger', 0.196, 0.56, 834),
#  (u'usb', 0.165, 0.23, 357),
#  (u'hour', 0.094, 0.62, 209),
#  (u'power', 0.103, 0.64, 160),
#  (u'adapter', 0.143, 0.57, 159),
#  (u'cord', 0.119, 0.28, 142),
#  (u'cable', 0.118, 0.27, 141),
#  (u'wall', 0.141, 0.44, 129),
#  (u'prong', 0.099, 0.06, 111),
#  (u'battery', 0.138, 0.45, 110),
#  (u'job', 0.208, 0.81, 93),
#  (u'charging', 0.403, 0.38, 92),
#  (u'outlet', 0.147, 0.26, 79),
#  (u'unit', 0.169, 0.33, 72),
#  (u'kindles', 0.153, 0.57, 69),
#  (u'money', 0.284, 0.68, 65)]
#
# [(u'fire hd', 1.07, 0.0008, 296),
#  (u'usb cable', 1.13, 0.0009, 89),
#  (u'usb port', 1.02, 0.0015, 84),
#  (u'prong fold', 1.35, 0.0053, 71),
#  (u'kindle hd.', 1.83, 0.0004, 64),
#  (u'cell phone', 1.0, 0.0043, 62),
#  (u'fire hd.', 1.03, 0.0008, 61),
#  (u'usb cord', 1.12, 0.0007, 56),
#  (u'long time', 1.23, 0.0008, 39),
#  (u'micro usb', 1.58, 0.0017, 34)]
#
# B002QEBMAK
# WD Elements 500 GB USB 2.0 Desktop External Hard Drive
# ----------------------------------------
#
# [(u'drive', 0.288, 0.56, 765),
#  (u'wd', 0.12, 0.35, 304),
#  (u'computer', 0.108, 0.39, 242),
#  (u'backup', 0.147, 0.27, 235),
#  (u'file', 0.183, 0.52, 224),
#  (u'digital', 0.16, 0.09, 177),
#  (u'storage', 0.311, 0.32, 163),
#  (u'data', 0.158, 0.5, 162),
#  (u'space', 0.37, 0.64, 138),
#  (u'software', 0.232, 0.32, 135),
#  (u'unit', 0.131, 0.47, 104),
#  (u'light', 0.203, 0.34, 97),
#  (u'speed', 0.239, 0.31, 94),
#  (u'hd', 0.238, 0.29, 90),
#  (u'case', 0.22, 0.47, 86),
#  (u'size', 0.196, 0.47, 85),
#  (u'system', 0.179, 0.28, 84),
#  (u'disk', 0.315, 0.69, 74),
#  (u'box', 0.132, 0.67, 73),
#  (u'cable', 0.104, 0.2, 68)]
#
# [(u'western digital', 1.0, 0.0034, 172),
#  (u'time machine', 1.04, 0.0015, 47),
#  (u'usb port', 1.15, 0.0016, 46),
#  (u'usb cable', 1.13, 0.0012, 42),
#  (u'wd elements', 1.0, 0.001, 35),
#  (u'power supply', 1.06, 0.0027, 32)]
#
# B007I5JT4S
#
# ----------------------------------------
#
# [(u'movie', 0.108, 0.41, 314),
#  (u'screen', 0.24, 0.46, 194),
#  (u'content', 0.234, 0.61, 178),
#  (u'cable', 0.127, 0.25, 175),
#  (u'apps', 0.272, 0.69, 174),
#  (u'app', 0.124, 0.7, 156),
#  (u'feature', 0.224, 0.78, 145),
#  (u'box', 0.243, 0.72, 137),
#  (u'remote', 0.11, 0.31, 134),
#  (u'quality', 0.186, 0.73, 133),
#  (u'interface', 0.171, 0.55, 126),
#  (u'medium', 0.234, 0.31, 113),
#  (u'channel', 0.313, 0.73, 112),
#  (u'library', 0.155, 0.33, 107),
#  (u'picture', 0.156, 0.57, 106),
#  (u'user', 0.115, 0.7, 105),
#  (u'service', 0.312, 0.57, 100),
#  (u'network', 0.151, 0.19, 95),
#  (u'room', 0.159, 0.49, 89),
#  (u'option', 0.25, 0.69, 88)]
#
# [(u'itunes library', 1.17, 0.0008, 61),
#  (u'remote app', 1.32, 0.0006, 45),
#  (u'hbo go', 1.04, 0.0018, 43),
#  (u'blu ray', 1.81, 0.0113, 42),
#  (u'big screen', 1.14, 0.0013, 41),
#  (u'smart tv', 1.17, 0.0004, 39),
#  (u'hdmi cable', 1.12, 0.0013, 36),
#  (u'user interface', 1.05, 0.0017, 35),
#  (u'play music', 1.65, 0.0004, 33),
#  (u'instant video', 1.01, 0.0011, 32),
#  (u'ray player', 1.11, 0.0041, 30),
#  (u'air play', 1.02, 0.0013, 30)]
#
# B002SZEOLG
# TP-LINK TL-WN722N Wireless N150 High Gain USB Adapter, 150Mbps, 4dBi External Antenna, WPS Button, Support Windows XP/Vista/7/8
# ----------------------------------------
#
# [(u'adapter', 0.142, 0.5, 498),
#  (u'wireless', 0.106, 0.33, 328),
#  (u'signal', 0.288, 0.7, 326),
#  (u'driver', 0.131, 0.51, 284),
#  (u'computer', 0.117, 0.56, 255),
#  (u'laptop', 0.126, 0.86, 244),
#  (u'speed', 0.231, 0.49, 243),
#  (u'connection', 0.251, 0.35, 222),
#  (u'wifi', 0.139, 0.14, 216),
#  (u'network', 0.176, 0.3, 203),
#  (u'desktop', 0.155, 0.73, 170),
#  (u'antenna', 0.257, 0.29, 138),
#  (u'software', 0.133, 0.29, 138),
#  (u'range', 0.305, 0.61, 121),
#  (u'card', 0.215, 0.26, 118),
#  (u'cd', 0.178, 0.11, 117),
#  (u'installation', 0.139, 0.31, 112),
#  (u'port', 0.124, 0.24, 110),
#  (u'strength', 0.165, 0.72, 99),
#  (u'pc', 0.15, 0.58, 98)]
#
# [(u'tp link', 1.88, 0.0017, 261),
#  (u'usb port', 1.06, 0.0012, 102),
#  (u'signal strength', 1.03, 0.0017, 87),
#  (u'install driver', 1.93, 0.0005, 75),
#  (u'link tl', 1.01, 0.0011, 71),
#  (u'wireless n', 1.39, 0.0005, 56),
#  (u'strong signal', 1.48, 0.0013, 56),
#  (u'dual band', 1.24, 0.004, 52),
#  (u'wireless card', 1.24, 0.0004, 51),
#  (u'usb cable', 1.51, 0.0005, 48),
#  (u'wi fi', 1.99, 0.0088, 46),
#  (u'usb extension', 1.01, 0.0011, 42),
#  (u'old laptop', 1.42, 0.0005, 41),
#  (u'high gain', 1.13, 0.0065, 40),
#  (u'windows xp', 1.33, 0.0009, 38),
#  (u'mini cd', 1.71, 0.0026, 37),
#  (u'extension cable', 1.0, 0.0031, 33),
#  (u'old desktop', 1.38, 0.0006, 32),
#  (u'access point', 1.0, 0.0062, 31)]
#
# B000S5Q9CA
# Motorola Vehicle Power Adapter micro-USB Charger
# ----------------------------------------
#
# [(u'charger', 0.181, 0.62, 823),
#  (u'light', 0.259, 0.21, 347),
#  (u'motorola', 0.149, 0.73, 331),
#  (u'usb', 0.287, 0.04, 202),
#  (u'quality', 0.302, 0.87, 147),
#  (u'cord', 0.24, 0.57, 140),
#  (u'power', 0.167, 0.44, 133),
#  (u'night', 0.2, 0.67, 103),
#  (u'cable', 0.224, 0.41, 84),
#  (u'adapter', 0.15, 0.55, 83),
#  (u'logo', 0.215, 0.17, 75),
#  (u'vehicle', 0.122, 0.67, 71),
#  (u'store', 0.144, 0.13, 70),
#  (u'job', 0.211, 0.91, 67),
#  (u'oem', 0.105, 1.0, 66),
#  (u'port', 0.195, 0.1, 60),
#  (u'verizon', 0.235, 0.25, 60),
#  (u'rate', 0.248, 0.28, 44)]
#
# [(u'blue light', 1.22, 0.001, 266),
#  (u'micro usb', 1.54, 0.0026, 139),
#  (u'samsung galaxy', 1.02, 0.0036, 65),
#  (u'cell phone', 1.0, 0.0008, 48),
#  (u'rapid charger', 1.78, 0.0004, 41),
#  (u'galaxy s3', 1.0, 0.0054, 39),
#  (u'motorola logo', 1.15, 0.0011, 38),
#  (u'usb port', 1.14, 0.0019, 37),
#  (u'blue glow', 1.11, 0.0006, 37),
#  (u'wall charger', 1.23, 0.0005, 33),
#  (u'high quality', 1.03, 0.0031, 31),
#  (u'long cord', 1.68, 0.0011, 31),
#  (u'blue led', 1.06, 0.0013, 29),
#  (u'power adapter', 1.08, 0.0015, 25),
#  (u'rapid rate', 1.04, 0.0077, 24)]
#
# B000VX6XL6
# Kingston 4 GB microSDHC Class 4 Flash Memory Card SDC4/4GBET
# ----------------------------------------
#
# [(u'card', 0.137, 0.37, 769),
#  (u'phone', 0.104, 0.66, 409),
#  (u'memory', 0.277, 0.49, 359),
#  (u'sd', 0.184, 0.13, 305),
#  (u'adapter', 0.097, 0.15, 286),
#  (u'camera', 0.152, 0.21, 163),
#  (u'storage', 0.245, 0.33, 136),
#  (u'speed', 0.273, 0.44, 115),
#  (u'file', 0.134, 0.59, 95),
#  (u'space', 0.357, 0.51, 82),
#  (u'quality', 0.277, 0.84, 79),
#  (u'data', 0.169, 0.47, 78),
#  (u'size', 0.336, 0.64, 71),
#  (u'samsung', 0.125, 0.0, 67),
#  (u'reader', 0.133, 0.14, 64),
#  (u'microsd', 0.12, 0.67, 60),
#  (u'capacity', 0.283, 0.53, 59),
#  (u'chip', 0.15, 0.41, 35)]
#
# [(u'sd card', 1.13, 0.0004, 228),
#  (u'micro card', 1.87, 0.0004, 148),
#  (u'micro sd', 1.15, 0.0012, 126),
#  (u'flash card', 1.36, 0.0004, 94),
#  (u'cell phone', 1.02, 0.0016, 79),
#  (u'sd adapter', 1.41, 0.0004, 64),
#  (u'flash memory', 1.16, 0.0008, 54),
#  (u'card reader', 1.17, 0.0004, 47),
#  (u'microsd card', 1.13, 0.0005, 46),
#  (u'microsdhc card', 1.48, 0.0004, 46),
#  (u'mp3 player', 1.0, 0.0098, 41),
#  (u'samsung galaxy', 1.0, 0.006, 37),
#  (u'microsdhc flash', 1.86, 0.0025, 36),
#  (u'gb microsdhc', 1.68, 0.003, 35),
#  (u'gb class', 1.74, 0.0013, 31),
#  (u'microsdhc class', 1.45, 0.0016, 29),
#  (u'digital camera', 1.06, 0.0027, 29),
#  (u'smart phone', 1.1, 0.0016, 27),
#  (u'transfer file', 1.33, 0.0016, 22),
#  (u'sdhc card', 1.14, 0.0004, 20)]
#
# B0041Q38NU
# Kingston Datatraveler 101 Gen 2 With urDrive 8GB USB 2.0 (Red)
# ----------------------------------------
#
# [(u'drive', 0.133, 0.66, 906),
#  (u'usb', 0.099, 0.68, 413),
#  (u'file', 0.224, 0.52, 338),
#  (u'data', 0.22, 0.42, 250),
#  (u'computer', 0.13, 0.63, 243),
#  (u'speed', 0.251, 0.5, 227),
#  (u'storage', 0.279, 0.41, 185),
#  (u'cover', 0.168, 0.19, 156),
#  (u'memory', 0.258, 0.47, 129),
#  (u'size', 0.275, 0.44, 126),
#  (u'cap', 0.137, 0.15, 125),
#  (u'design', 0.208, 0.58, 111),
#  (u'space', 0.368, 0.53, 104),
#  (u'capacity', 0.279, 0.59, 101),
#  (u'thumb', 0.263, 0.2, 100),
#  (u'software', 0.252, 0.29, 85),
#  (u'color', 0.325, 0.39, 75),
#  (u'quality', 0.333, 0.94, 75),
#  (u'metal', 0.231, 0.5, 73),
#  (u'pc', 0.167, 0.72, 62)]
#
# [(u'flash drive', 1.01, 0.0005, 505),
#  (u'thumb drive', 1.02, 0.0005, 96),
#  (u'transfer file', 1.55, 0.0005, 84),
#  (u'data transfer', 1.19, 0.0007, 75),
#  (u'usb port', 1.16, 0.0012, 65),
#  (u'large file', 1.2, 0.0008, 61),
#  (u'hard drive', 1.03, 0.0004, 61),
#  (u'transfer speed', 1.19, 0.0005, 51),
#  (u'write speed', 1.22, 0.0011, 35)]
#
# B0002L5R78
# DVI Gear HDMI-2M 2M/6' HDMI Cable
# ----------------------------------------
#
# [(u'cable', 0.157, 0.57, 1956),
#  (u'quality', 0.282, 0.75, 651),
#  (u'picture', 0.203, 0.88, 333),
#  (u'store', 0.304, 0.14, 308),
#  (u'money', 0.195, 0.82, 277),
#  (u'difference', 0.098, 0.39, 260),
#  (u'signal', 0.245, 0.23, 207),
#  (u'shipping', 0.309, 0.89, 192),
#  (u'hd', 0.116, 0.88, 174),
#  (u'job', 0.146, 0.47, 149),
#  (u'dollar', 0.177, 0.91, 140),
#  (u'cord', 0.19, 0.66, 136),
#  (u'buck', 0.17, 0.58, 112),
#  (u'sound', 0.107, 0.59, 110),
#  (u'deal', 0.287, 0.88, 108),
#  (u'length', 0.26, 0.64, 104),
#  (u'gold', 0.146, 0.43, 98),
#  (u'connection', 0.249, 0.46, 98),
#  (u'end', 0.161, 0.74, 93)]
#
# [(u'picture quality', 1.42, 0.0004, 127),
#  (u'blu ray', 1.71, 0.0061, 111),
#  (u'dvd player', 1.05, 0.0024, 100),
#  (u'high quality', 1.07, 0.0004, 80),
#  (u'digital signal', 1.17, 0.0012, 71),
#  (u'ray player', 1.04, 0.0017, 66),
#  (u'waste money', 1.84, 0.0028, 59),
#  (u'gold plat', 1.25, 0.0075, 50)]
#
# B0043T7FXE
# Logitech M570 Wireless Trackball, Computer Wireless Mouse, Long Range Wireless Mouse
# ----------------------------------------
#
# [(u'mouse', 0.201, 0.45, 662),
#  (u'trackball', 0.175, 0.54, 621),
#  (u'ball', 0.145, 0.26, 349),
#  (u'button', 0.26, 0.26, 318),
#  (u'battery', 0.152, 0.66, 249),
#  (u'hand', 0.22, 0.45, 246),
#  (u'usb', 0.234, 0.27, 178),
#  (u'receiver', 0.253, 0.22, 157),
#  (u'version', 0.364, 0.32, 144),
#  (u'finger', 0.156, 0.37, 123),
#  (u'keyboard', 0.223, 0.18, 118),
#  (u'software', 0.121, 0.52, 112),
#  (u'model', 0.361, 0.47, 111),
#  (u'life', 0.215, 0.48, 105),
#  (u'trackman', 0.189, 0.62, 104),
#  (u'space', 0.35, 0.75, 87),
#  (u'movement', 0.245, 0.68, 78),
#  (u'design', 0.128, 0.42, 73),
#  (u'user', 0.187, 0.61, 72),
#  (u'click', 0.166, 0.32, 71)]
#
# [(u'battery life', 1.03, 0.0021, 90),
#  (u'scroll wheel', 1.08, 0.0029, 83),
#  (u'track ball', 1.01, 0.0012, 74),
#  (u'regular mouse', 1.17, 0.0005, 65),
#  (u'usb port', 1.0, 0.0032, 59),
#  (u'battery last', 1.5, 0.0007, 57),
#  (u'long time', 1.18, 0.0008, 56),
#  (u'wire version', 1.06, 0.0011, 49),
#  (u'usb receiver', 1.28, 0.0008, 46),
#  (u'wireless version', 1.21, 0.0004, 44),
#  (u'wireless keyboard', 1.46, 0.0005, 43),
#  (u'left button', 1.98, 0.0009, 41),
#  (u'click button', 1.61, 0.0004, 36),
#  (u'index finger', 1.32, 0.0043, 36),
#  (u'red ball', 1.04, 0.0011, 35),
#  (u'unifying receiver', 1.29, 0.0021, 34),
#  (u'trackman wheel', 1.13, 0.0011, 27)]
#
# B004XC6GJ0
# ARRIS SURFboard SB6121 DOCSIS 3.0 Cable Modem  (Black,Retail Packaging)
# ----------------------------------------
#
# [(u'modem', 0.162, 0.68, 1110),
#  (u'speed', 0.269, 0.46, 518),
#  (u'router', 0.121, 0.42, 306),
#  (u'service', 0.121, 0.51, 280),
#  (u'connection', 0.164, 0.35, 196),
#  (u'fee', 0.319, 0.07, 173),
#  (u'box', 0.13, 0.56, 129),
#  (u'model', 0.255, 0.47, 121),
#  (u'number', 0.131, 0.22, 117),
#  (u'setup', 0.143, 0.62, 107),
#  (u'unit', 0.149, 0.55, 102),
#  (u'customer', 0.127, 0.8, 100),
#  (u'network', 0.142, 0.17, 92),
#  (u'surfboard', 0.217, 0.64, 92),
#  (u'money', 0.247, 0.63, 90),
#  (u'installation', 0.098, 0.25, 82),
#  (u'week', 0.147, 0.55, 80),
#  (u'light', 0.227, 0.2, 75),
#  (u'hour', 0.143, 0.89, 73),
#  (u'signal', 0.127, 0.67, 72)]
#
# [(u'time warner', 1.04, 0.0017, 131),
#  (u'mac address', 1.01, 0.0039, 93),
#  (u'wireless router', 1.35, 0.001, 90),
#  (u'download speed', 1.34, 0.0005, 84),
#  (u'rental fee', 1.07, 0.0023, 83),
#  (u'internet service', 1.06, 0.0004, 77),
#  (u'high speed', 1.22, 0.0006, 74),
#  (u'monthly fee', 1.51, 0.003, 68),
#  (u'cable provider', 1.18, 0.0004, 63),
#  (u'speed test', 1.17, 0.0005, 52),
#  (u'internet provider', 1.23, 0.0005, 48),
#  (u'save money', 1.47, 0.0029, 44),
#  (u'speed increase', 1.79, 0.0006, 43),
#  (u'motorola sb6121', 1.02, 0.0009, 42),
#  (u'upload speed', 1.42, 0.0004, 41)]
#
# B00E3W15P0
# [DISCONTINUED] Samsung 840 EVO 120GB 2.5-Inch SATA III Internal SSD (MZ-7TE120BW)
# ----------------------------------------
#
# [(u'drive', 0.243, 0.7, 760),
#  (u'ssd', 0.114, 0.69, 605),
#  (u'software', 0.126, 0.36, 353),
#  (u'computer', 0.159, 0.77, 326),
#  (u'laptop', 0.154, 0.69, 275),
#  (u'speed', 0.18, 0.35, 275),
#  (u'performance', 0.24, 0.6, 249),
#  (u'system', 0.139, 0.59, 188),
#  (u'data', 0.141, 0.58, 168),
#  (u'hdd', 0.212, 0.6, 139),
#  (u'pc', 0.115, 0.64, 137),
#  (u'program', 0.154, 0.59, 137),
#  (u'disk', 0.247, 0.62, 136),
#  (u'macbook', 0.098, 0.6, 117),
#  (u'difference', 0.18, 0.51, 116),
#  (u'window', 0.18, 0.35, 112),
#  (u'file', 0.225, 0.41, 111),
#  (u'installation', 0.137, 0.39, 111),
#  (u'storage', 0.237, 0.41, 101),
#  (u'ssds', 0.245, 0.56, 97)]
#
# [(u'boot time', 1.36, 0.0004, 126),
#  (u'macbook pro', 1.08, 0.0021, 88),
#  (u'samsung evo', 1.79, 0.0005, 75),
#  (u'samsung magician', 1.11, 0.0008, 75),
#  (u'magician software', 1.2, 0.0008, 72),
#  (u'include software', 1.49, 0.0007, 57),
#  (u'solid state', 1.07, 0.0078, 56),
#  (u'migration software', 1.07, 0.0007, 55),
#  (u'data migration', 1.03, 0.0014, 50),
#  (u'sata cable', 1.74, 0.001, 36)]
#
# B005DKZTMG
# Logitech Wireless Touch Keyboard K400 with Built-In Multi-Touch Touchpad, Black
# ----------------------------------------
#
# [(u'keyboard', 0.21, 0.44, 1122),
#  (u'key', 0.123, 0.37, 514),
#  (u'mouse', 0.15, 0.19, 493),
#  (u'button', 0.172, 0.24, 306),
#  (u'touch', 0.178, 0.42, 305),
#  (u'size', 0.299, 0.75, 285),
#  (u'battery', 0.162, 0.37, 277),
#  (u'usb', 0.167, 0.27, 245),
#  (u'range', 0.294, 0.64, 235),
#  (u'room', 0.151, 0.31, 196),
#  (u'medium', 0.172, 0.2, 167),
#  (u'shift', 0.385, 0.88, 164),
#  (u'finger', 0.118, 0.35, 159),
#  (u'hand', 0.348, 0.52, 148),
#  (u'function', 0.18, 0.51, 145),
#  (u'bit', 0.121, 0.83, 145),
#  (u'click', 0.216, 0.29, 136),
#  (u'receiver', 0.188, 0.2, 134),
#  (u'life', 0.221, 0.55, 123),
#  (u'side', 0.336, 0.52, 122)]
#
# [(u'touch pad', 1.12, 0.0009, 186),
#  (u'shift key', 1.11, 0.0005, 147),
#  (u'battery life', 1.04, 0.0019, 100),
#  (u'living room', 1.02, 0.0041, 95),
#  (u'click button', 1.23, 0.0006, 93),
#  (u'home theater', 1.03, 0.0043, 84),
#  (u'track pad', 1.1, 0.0015, 83),
#  (u'usb port', 1.05, 0.0023, 77),
#  (u'arrow key', 1.15, 0.0004, 75),
#  (u'left click', 1.65, 0.0008, 74),
#  (u'foot away', 1.01, 0.0022, 68),
#  (u'smart tv', 1.12, 0.0011, 64),
#  (u'medium center', 1.05, 0.0023, 61),
#  (u'multi touch', 1.9, 0.0018, 57),
#  (u'full size', 1.23, 0.0009, 54),
#  (u'usb dongle', 1.23, 0.0009, 44),
#  (u'usb receiver', 1.48, 0.0007, 42)]
#
# B003ELYQGG
# Panasonic ErgoFit Best in Class In-Ear Earbud Headphones RP-HJE120-D (Orange) Dynamic Crystal Clear Sound, Ergonomic Comfort-Fit, iPhone, Android Compatible, Noise Isolating Headphones
# ----------------------------------------
#
# [(u'sound', 0.115, 0.79, 1141),
#  (u'headphone', 0.231, 0.74, 997),
#  (u'quality', 0.41, 0.89, 847),
#  (u'pair', 0.185, 0.56, 647),
#  (u'earbuds', 0.195, 0.72, 542),
#  (u'bud', 0.18, 0.61, 509),
#  (u'bass', 0.254, 0.7, 495),
#  (u'music', 0.142, 0.51, 314),
#  (u'earphone', 0.232, 0.7, 287),
#  (u'set', 0.173, 0.56, 282),
#  (u'noise', 0.326, 0.3, 282),
#  (u'size', 0.293, 0.25, 235),
#  (u'color', 0.307, 0.49, 221),
#  (u'cord', 0.199, 0.46, 204),
#  (u'phone', 0.153, 0.65, 196),
#  (u'money', 0.175, 0.97, 178),
#  (u'volume', 0.325, 0.45, 128),
#  (u'wire', 0.183, 0.42, 119),
#  (u'case', 0.121, 0.39, 117),
#  (u'design', 0.139, 0.38, 115)]
#
# [(u'different size', 1.17, 0.0013, 97)]
#
# B0012S4APK
# Cheetah Mounts APTMM2B TV Wall Mount for 20-75-Inch TVs Bundle with 10-feet Braided HDMI Cable and a 6-Inch 3-Axis Magnetic Bubble
# ----------------------------------------
#
# [(u'cable', 0.122, 0.38, 361),
#  (u'level', 0.213, 0.45, 332),
#  (u'hdmi', 0.119, 0.5, 318),
#  (u'screw', 0.119, 0.17, 317),
#  (u'bracket', 0.127, 0.39, 230),
#  (u'instruction', 0.112, 0.65, 197),
#  (u'quality', 0.315, 0.82, 164),
#  (u'part', 0.22, 0.43, 146),
#  (u'bolt', 0.128, 0.28, 146),
#  (u'piece', 0.199, 0.3, 144),
#  (u'cheetah', 0.103, 0.0, 134),
#  (u'hardware', 0.267, 0.12, 129),
#  (u'hole', 0.247, 0.25, 128),
#  (u'bit', 0.132, 0.72, 127),
#  (u'plasma', 0.096, 0.85, 123),
#  (u'installation', 0.193, 0.76, 120),
#  (u'job', 0.137, 0.83, 113),
#  (u'box', 0.195, 0.42, 112),
#  (u'room', 0.252, 0.43, 105),
#  (u'store', 0.287, 0.17, 101)]
#
# [(u'hdmi cable', 1.04, 0.0015, 264),
#  (u'flat screen', 1.01, 0.0063, 70),
#  (u'include hdmi', 1.53, 0.0004, 49),
#  (u'drill hole', 1.95, 0.002, 46),
#  (u'screw driver', 1.0, 0.0012, 42),
#  (u'bubble level', 1.02, 0.0011, 42),
#  (u'lag bolt', 1.02, 0.0025, 40),
#  (u'low profile', 1.15, 0.0054, 37),
#  (u'safety screw', 1.21, 0.0009, 33)]
#
# B00622AG6S
# PowerGen 2.4Amps / 12W Dual USB Car charger Designed for Apple and Android Devices - White
# ----------------------------------------
#
# [(u'charger', 0.182, 0.62, 678),
#  (u'car', 0.095, 0.47, 662),
#  (u'usb', 0.193, 0.13, 423),
#  (u'port', 0.128, 0.31, 368),
#  (u'power', 0.14, 0.5, 194),
#  (u'light', 0.268, 0.26, 178),
#  (u'cable', 0.18, 0.26, 147),
#  (u'trip', 0.261, 0.76, 109),
#  (u'quality', 0.331, 0.86, 98),
#  (u'outlet', 0.15, 0.26, 96),
#  (u'adapter', 0.185, 0.52, 89),
#  (u'socket', 0.17, 0.07, 79),
#  (u'job', 0.198, 0.84, 77),
#  (u'unit', 0.195, 0.45, 73),
#  (u'amp', 0.105, 0.53, 62),
#  (u'cord', 0.176, 0.3, 59),
#  (u'slot', 0.114, 0.2, 57)]
#
# [(u'usb port', 1.13, 0.0005, 168),
#  (u'blue light', 1.18, 0.0017, 126),
#  (u'dual usb', 1.06, 0.0007, 62),
#  (u'usb cable', 1.24, 0.0005, 58),
#  (u'dual port', 1.7, 0.0007, 57),
#  (u'long trip', 1.42, 0.003, 45),
#  (u'android phone', 1.3, 0.0007, 43),
#  (u'road trip', 1.02, 0.0049, 40),
#  (u'cigarette light', 1.05, 0.0022, 38),
#  (u'samsung galaxy', 1.03, 0.0056, 37),
#  (u'cell phone', 1.0, 0.0015, 32),
#  (u'non apple', 1.93, 0.003, 29)]
#
# B005FYNSPK
# SanDisk Cruzer Fit 4GB USB 2.0 Low-Profile Flash Drive- SDCZ33-004G-B35
# ----------------------------------------
#
# [(u'drive', 0.173, 0.56, 945),
#  (u'usb', 0.13, 0.35, 701),
#  (u'size', 0.265, 0.62, 439),
#  (u'music', 0.121, 0.65, 305),
#  (u'storage', 0.409, 0.34, 261),
#  (u'file', 0.235, 0.54, 255),
#  (u'speed', 0.277, 0.35, 214),
#  (u'space', 0.403, 0.54, 144),
#  (u'profile', 0.472, 0.15, 142),
#  (u'data', 0.236, 0.77, 136),
#  (u'lanyard', 0.125, 0.61, 126),
#  (u'loop', 0.17, 0.56, 111),
#  (u'capacity', 0.292, 0.67, 107),
#  (u'memory', 0.308, 0.32, 106),
#  (u'thumb', 0.25, 0.25, 99),
#  (u'system', 0.158, 0.32, 98),
#  (u'bit', 0.13, 0.83, 86),
#  (u'key', 0.134, 0.44, 82),
#  (u'song', 0.179, 0.65, 72),
#  (u'ring', 0.25, 0.35, 71)]
#
# [(u'flash drive', 1.02, 0.0004, 492),
#  (u'usb port', 1.03, 0.0007, 294),
#  (u'car stereo', 1.13, 0.0012, 137),
#  (u'low profile', 1.15, 0.0049, 126),
#  (u'thumb drive', 1.04, 0.0004, 84),
#  (u'cruzer fit', 1.01, 0.0019, 69),
#  (u'file transfer', 1.26, 0.0008, 61),
#  (u'write speed', 1.01, 0.0015, 54),
#  (u'usb slot', 1.08, 0.0006, 54),
#  (u'form factor', 1.04, 0.0131, 48),
#  (u'sandisk cruzer', 1.04, 0.0012, 46),
#  (u'key chain', 1.03, 0.0055, 45),
#  (u'transfer speed', 1.08, 0.0007, 40)]
#
# B000I68BD4
# JLab Audio JBuds Hi-Fi Noise-Reducing Ear Buds, GUARANTEED FOR LIFE - White
# ----------------------------------------
#
# [(u'ear', 0.111, 0.44, 549),
#  (u'sound', 0.128, 0.77, 449),
#  (u'bud', 0.154, 0.57, 389),
#  (u'quality', 0.41, 0.9, 324),
#  (u'noise', 0.287, 0.27, 249),
#  (u'pair', 0.217, 0.58, 232),
#  (u'headphone', 0.247, 0.74, 219),
#  (u'earbuds', 0.197, 0.65, 207),
#  (u'music', 0.146, 0.52, 140),
#  (u'bass', 0.2, 0.74, 126),
#  (u'set', 0.196, 0.54, 119),
#  (u'size', 0.262, 0.15, 112),
#  (u'cord', 0.197, 0.51, 99),
#  (u'earphone', 0.228, 0.79, 95),
#  (u'phone', 0.101, 0.81, 78),
#  (u'money', 0.118, 0.6, 74),
#  (u'volume', 0.243, 0.54, 73),
#  (u'week', 0.168, 0.76, 63),
#  (u'reduction', 0.132, 0.68, 59),
#  (u'piece', 0.2, 0.33, 57)]
#
# [(u'ear bud', 1.09, 0.0006, 268),
#  (u'sound quality', 1.14, 0.0006, 231),
#  (u'noise reduce', 1.43, 0.002, 67),
#  (u'noise reduction', 1.19, 0.0025, 59),
#  (u'mp3 player', 1.0, 0.0097, 55),
#  (u'noise cancel', 1.46, 0.0021, 43),
#  (u'different size', 1.06, 0.0024, 33),
#  (u'ear piece', 1.21, 0.0005, 32),
#  (u'outside noise', 1.06, 0.0013, 30)]
#
# B000BQ7GW8
# SanDisk 2GB Class 4 SD Flash Memory Card- SDSDB-002G-B35 (Label May Change)
# ----------------------------------------
#
# [(u'card', 0.114, 0.48, 770),
#  (u'camera', 0.173, 0.41, 479),
#  (u'memory', 0.269, 0.4, 369),
#  (u'sd', 0.104, 0.25, 241),
#  (u'picture', 0.152, 0.74, 213),
#  (u'video', 0.125, 0.75, 172),
#  (u'photo', 0.117, 0.76, 128),
#  (u'storage', 0.301, 0.22, 117),
#  (u'computer', 0.099, 0.6, 102),
#  (u'space', 0.32, 0.58, 88),
#  (u'quality', 0.319, 0.86, 77),
#  (u'capacity', 0.208, 0.71, 69),
#  (u'speed', 0.331, 0.31, 68),
#  (u'disk', 0.155, 0.31, 65),
#  (u'data', 0.216, 0.5, 60),
#  (u'size', 0.235, 0.5, 53),
#  (u'file', 0.242, 0.44, 48),
#  (u'drive', 0.241, 0.5, 46),
#  (u'hd', 0.222, 1.0, 32)]
#
# [(u'memory card', 1.03, 0.0004, 255),
#  (u'sd card', 1.1, 0.0005, 218),
#  (u'digital camera', 1.16, 0.0009, 74),
#  (u'sdhc card', 1.51, 0.0005, 74),
#  (u'flash memory', 1.0, 0.0012, 57),
#  (u'flash card', 1.74, 0.0004, 55),
#  (u'canon camera', 1.75, 0.0006, 28),
#  (u'hold lot', 1.74, 0.0013, 27),
#  (u'old camera', 1.56, 0.0005, 24),
#  (u'card reader', 1.0, 0.0006, 24),
#  (u'raspberry pi', 1.0, 0.03, 23),
#  (u'hd video', 1.04, 0.0024, 18),
#  (u'high capacity', 1.08, 0.0033, 18)]
#
# B00BGGDVOO
# Roku 3 Streaming Media Player (2014 model)
# ----------------------------------------
#
# [(u'tv', 0.098, 0.75, 904),
#  (u'channel', 0.265, 0.62, 720),
#  (u'remote', 0.105, 0.4, 509),
#  (u'movie', 0.162, 0.73, 451),
#  (u'video', 0.137, 0.43, 403),
#  (u'headphone', 0.167, 0.43, 383),
#  (u'box', 0.18, 0.66, 367),
#  (u'player', 0.134, 0.58, 329),
#  (u'internet', 0.114, 0.43, 276),
#  (u'service', 0.219, 0.51, 269),
#  (u'interface', 0.216, 0.68, 267),
#  (u'quality', 0.206, 0.71, 264),
#  (u'content', 0.273, 0.6, 263),
#  (u'feature', 0.238, 0.73, 260),
#  (u'streaming', 0.196, 0.5, 235),
#  (u'app', 0.124, 0.6, 229),
#  (u'unit', 0.196, 0.56, 227),
#  (u'connection', 0.217, 0.34, 227),
#  (u'medium', 0.364, 0.37, 225),
#  (u'option', 0.231, 0.74, 203)]
#
# [(u'headphone jack', 1.02, 0.0013, 177),
#  (u'smart tv', 1.24, 0.0004, 94),
#  (u'credit card', 1.02, 0.0047, 80),
#  (u'ray player', 1.06, 0.0013, 79),
#  (u'blu ray', 1.67, 0.0063, 78)]
#
# B000QUUFRW
# SanDisk 4GB Extreme SDHC Class 10 Memory Card
# ----------------------------------------
#
# [(u'card', 0.128, 0.6, 1208),
#  (u'camera', 0.136, 0.42, 682),
#  (u'video', 0.125, 0.58, 485),
#  (u'speed', 0.271, 0.41, 423),
#  (u'memory', 0.262, 0.65, 386),
#  (u'sd', 0.113, 0.67, 292),
#  (u'picture', 0.155, 0.59, 261),
#  (u'photo', 0.129, 0.67, 235),
#  (u'hd', 0.18, 1.0, 173),
#  (u'quality', 0.323, 0.77, 150),
#  (u'file', 0.267, 0.75, 117),
#  (u'shot', 0.254, 0.43, 110),
#  (u'image', 0.191, 0.65, 103),
#  (u'storage', 0.437, 0.55, 102),
#  (u'space', 0.282, 0.41, 100),
#  (u'flash', 0.229, 0.75, 99),
#  (u'data', 0.19, 0.67, 94),
#  (u'capacity', 0.28, 0.71, 93),
#  (u'performance', 0.25, 0.65, 85),
#  (u'size', 0.162, 0.68, 83)]
#
# [(u'hd video', 1.17, 0.001, 111),
#  (u'write speed', 1.13, 0.0007, 87),
#  (u'sandisk extreme', 1.1, 0.0007, 84),
#  (u'digital camera', 1.18, 0.0008, 63),
#  (u'flash memory', 1.0, 0.001, 54),
#  (u'record video', 1.79, 0.0005, 44),
#  (u'canon t3i', 1.3, 0.002, 43),
#  (u'high speed', 1.4, 0.0004, 43),
#  (u'dslr camera', 1.17, 0.0004, 41),
#  (u'transfer speed', 1.23, 0.0004, 40),
#  (u'read speed', 1.86, 0.0004, 35),
#  (u'sdhc class', 1.45, 0.0011, 33)]
#
# B008OHNZI0
# Tech Armor Ultimate 4-Way 360 Degree Privacy Screen Protector for Apple New iPhone 5, Latest Generation, 1-Pack
# ----------------------------------------
#
# [(u'screen', 0.117, 0.59, 887),
#  (u'protector', 0.112, 0.67, 733),
#  (u'bubble', 0.1, 0.69, 385),
#  (u'dust', 0.095, 0.68, 212),
#  (u'tech', 0.15, 0.33, 199),
#  (u'glare', 0.241, 0.12, 176),
#  (u'quality', 0.244, 0.88, 169),
#  (u'fingerprint', 0.187, 0.31, 138),
#  (u'instruction', 0.152, 0.86, 127),
#  (u'air', 0.286, 0.0, 110),
#  (u'installation', 0.263, 0.73, 105),
#  (u'finger', 0.095, 0.4, 102),
#  (u'cloth', 0.181, 0.4, 97),
#  (u'tape', 0.167, 0.26, 92),
#  (u'video', 0.186, 0.14, 87),
#  (u'side', 0.196, 0.29, 79),
#  (u'finish', 0.25, 0.25, 76),
#  (u'film', 0.191, 0.44, 73),
#  (u'bit', 0.145, 0.75, 73),
#  (u'edge', 0.106, 0.28, 73)]
#
# [(u'tech armor', 1.01, 0.0031, 202),
#  (u'anti glare', 1.8, 0.003, 104),
#  (u'air bubble', 1.04, 0.0013, 80),
#  (u'matte finish', 1.13, 0.0039, 66),
#  (u'finger print', 1.06, 0.0063, 46),
#  (u'iphone 5s', 1.13, 0.0014, 45),
#  (u'remove dust', 1.56, 0.0007, 37),
#  (u'high quality', 1.09, 0.0027, 32),
#  (u'retina display', 1.0, 0.0122, 31),
#  (u'customer service', 1.06, 0.0106, 31),
#  (u'home button', 1.0, 0.0153, 30)]
#
# B004QK7HI8
# Mohu Leaf 30 TV Antenna, Indoor, 30 Mile Range, Original Paper-thin, Reversible, Paintable, 4K-Ready HDTV, 10 Foot Detachable Cable, Premium Materials for Performance, USA Made, MH-110598
# ----------------------------------------
#
# [(u'antenna', 0.222, 0.41, 1122),
#  (u'channel', 0.217, 0.48, 1036),
#  (u'tv', 0.125, 0.65, 643),
#  (u'cable', 0.13, 0.31, 582),
#  (u'signal', 0.238, 0.64, 457),
#  (u'station', 0.242, 0.41, 438),
#  (u'wall', 0.118, 0.18, 394),
#  (u'reception', 0.406, 0.79, 393),
#  (u'area', 0.169, 0.26, 316),
#  (u'hd', 0.104, 0.79, 270),
#  (u'picture', 0.236, 0.76, 214),
#  (u'location', 0.302, 0.36, 201),
#  (u'ear', 0.127, 0.52, 199),
#  (u'rabbit', 0.125, 0.0, 187),
#  (u'quality', 0.188, 0.74, 179),
#  (u'room', 0.134, 0.29, 167),
#  (u'hdtv', 0.16, 0.43, 162),
#  (u'side', 0.238, 0.48, 159),
#  (u'box', 0.126, 0.37, 143),
#  (u'tower', 0.106, 0.34, 129)]
#
# [(u'rabbit ear', 1.03, 0.003, 177),
#  (u'mohu leaf', 1.05, 0.0004, 156),
#  (u'mile away', 1.03, 0.0011, 92),
#  (u'signal strength', 1.04, 0.0009, 76),
#  (u'crystal clear', 1.04, 0.0029, 72),
#  (u'white side', 1.98, 0.002, 70),
#  (u'side black', 1.98, 0.0025, 66),
#  (u'paper thin', 1.47, 0.0021, 64),
#  (u'cut cable', 1.87, 0.0004, 58),
#  (u'picture quality', 1.28, 0.001, 57),
#  (u'major network', 1.09, 0.0026, 56),
#  (u'indoor hdtv', 1.0, 0.0008, 48),
#  (u'leaf ultimate', 1.02, 0.0007, 48)]
#
# B004GF8TIK
# Mediabridge USB 2.0 - Micro-USB to USB Cable (6 Feet) - High-Speed A Male to Micro B - (Part# 30-004-06B )
# ----------------------------------------
#
# [(u'cable', 0.195, 0.56, 932),
#  (u'usb', 0.213, 0.09, 352),
#  (u'quality', 0.361, 0.89, 346),
#  (u'length', 0.256, 0.44, 157),
#  (u'end', 0.131, 0.2, 153),
#  (u'cord', 0.177, 0.54, 144),
#  (u'connector', 0.257, 0.18, 140),
#  (u'connection', 0.286, 0.47, 138),
#  (u'charger', 0.136, 0.25, 123),
#  (u'port', 0.172, 0.12, 65),
#  (u'wire', 0.236, 0.47, 58),
#  (u'replacement', 0.172, 0.8, 46),
#  (u'customer', 0.444, 1.0, 45),
#  (u'service', 0.189, 0.85, 43)]
#
# [(u'micro usb', 1.38, 0.0011, 175),
#  (u'high quality', 1.09, 0.0016, 99),
#  (u'kindle fire', 1.01, 0.0044, 62),
#  (u'micro end', 1.92, 0.0008, 52),
#  (u'data transfer', 1.08, 0.0057, 50),
#  (u'micro b', 1.84, 0.0023, 41),
#  (u'heavy duty', 1.11, 0.0142, 39),
#  (u'cell phone', 1.0, 0.0016, 37),
#  (u'samsung galaxy', 1.06, 0.0053, 36),
#  (u'build quality', 1.2, 0.0009, 34),
#  (u'customer service', 1.0, 0.0118, 32),
#  (u'gold plat', 1.31, 0.0153, 29),
#  (u'extra length', 1.07, 0.0027, 26),
#  (u'micro connector', 1.89, 0.0005, 22)]
#
# B002WE6D44
# Transcend 8GB Class 10 SDHC Card (TS8GSDHC10)
# ----------------------------------------
#
# [(u'card', 0.112, 0.61, 1700),
#  (u'camera', 0.145, 0.48, 1077),
#  (u'memory', 0.26, 0.51, 719),
#  (u'video', 0.147, 0.46, 574),
#  (u'picture', 0.152, 0.65, 459),
#  (u'speed', 0.266, 0.5, 370),
#  (u'sd', 0.122, 0.45, 355),
#  (u'photo', 0.157, 0.48, 305),
#  (u'storage', 0.264, 0.57, 219),
#  (u'hd', 0.18, 0.75, 202),
#  (u'quality', 0.238, 0.82, 188),
#  (u'capacity', 0.286, 0.76, 172),
#  (u'space', 0.299, 0.51, 170),
#  (u'flash', 0.105, 0.5, 156),
#  (u'nikon', 0.095, 1.0, 140),
#  (u'file', 0.144, 0.58, 120),
#  (u'data', 0.2, 0.53, 115),
#  (u'size', 0.23, 0.61, 113),
#  (u'image', 0.13, 0.45, 97),
#  (u'shot', 0.283, 0.41, 92)]
#
# [(u'digital camera', 1.08, 0.0005, 131),
#  (u'hd video', 1.14, 0.0007, 121),
#  (u'flash memory', 1.0, 0.0006, 102),
#  (u'record video', 1.93, 0.0004, 63),
#  (u'class sdhc', 1.81, 0.0005, 63),
#  (u'write speed', 1.2, 0.0007, 56)]
#
# B00004ZCJE
# Tiffen 46mm UV Protection Filter
# ----------------------------------------
#
# [(u'lens', 0.135, 0.55, 920),
#  (u'filter', 0.138, 0.57, 819),
#  (u'protection', 0.183, 0.64, 264),
#  (u'camera', 0.113, 0.55, 249),
#  (u'quality', 0.271, 0.83, 245),
#  (u'glass', 0.184, 0.58, 189),
#  (u'picture', 0.128, 0.65, 121),
#  (u'job', 0.159, 0.93, 121),
#  (u'photo', 0.143, 0.56, 102),
#  (u'image', 0.13, 0.5, 93),
#  (u'light', 0.273, 0.48, 92),
#  (u'element', 0.314, 0.06, 55),
#  (u'flare', 0.188, 0.5, 55),
#  (u'money', 0.229, 0.38, 53),
#  (u'protector', 0.116, 0.81, 53),
#  (u'reflection', 0.336, 0.38, 51),
#  (u'shot', 0.25, 0.52, 46),
#  (u'glare', 0.149, 0.55, 42),
#  (u'hoya', 0.097, 0.0, 40)]
#
# [(u'uv filter', 1.27, 0.0004, 252),
#  (u'uv protection', 1.13, 0.0006, 80),
#  (u'front element', 1.12, 0.008, 42),
#  (u'lens cap', 1.02, 0.0005, 38),
#  (u'image quality', 1.16, 0.001, 33),
#  (u'high quality', 1.06, 0.0017, 30),
#  (u'light source', 1.26, 0.0055, 28),
#  (u'multi coat', 1.87, 0.0075, 18)]
#
# B00B46XUQU
# PORTTA PET0301S 3x1 Port HDMI Switch/Switcher 1080P Supports 3D with IR Wireless Remote Ultra High...
# ----------------------------------------
#
# [(u'input', 0.105, 0.41, 352),
#  (u'cable', 0.134, 0.32, 348),
#  (u'remote', 0.103, 0.32, 338),
#  (u'port', 0.099, 0.34, 251),
#  (u'unit', 0.16, 0.48, 146),
#  (u'receiver', 0.132, 0.52, 134),
#  (u'signal', 0.122, 0.53, 131),
#  (u'ir', 0.1, 0.0, 122),
#  (u'button', 0.104, 0.44, 121),
#  (u'source', 0.162, 0.28, 113),
#  (u'supply', 0.123, 0.03, 112),
#  (u'switching', 0.157, 0.13, 107),
#  (u'control', 0.377, 0.8, 89),
#  (u'quality', 0.203, 0.74, 87),
#  (u'screen', 0.255, 0.62, 73),
#  (u'light', 0.206, 0.19, 68),
#  (u'connection', 0.16, 0.62, 57),
#  (u'setup', 0.123, 0.5, 53)]
#
# [(u'power supply', 1.0, 0.0011, 109),
#  (u'blu ray', 1.78, 0.004, 108),
#  (u'ray player', 1.06, 0.0016, 106),
#  (u'dvd player', 1.08, 0.0017, 99),
#  (u'cable box', 1.03, 0.0006, 93),
#  (u'remote control', 1.09, 0.0009, 83),
#  (u'apple tv', 1.02, 0.0012, 69),
#  (u'power adapter', 1.03, 0.0006, 63),
#  (u'external power', 1.07, 0.0012, 61),
#  (u'auto switching', 1.47, 0.0024, 47),
#  (u'power source', 1.12, 0.0004, 46),
#  (u'ir receiver', 1.02, 0.0013, 39),
#  (u'blue light', 1.23, 0.0023, 32),
#  (u'blue ray', 1.24, 0.0016, 31),
#  (u'ir sensor', 1.06, 0.0032, 28),
#  (u'bluray player', 1.05, 0.0015, 28)]
#
# B005CLPP84
# Roku 2 XS 1080p Streaming Player (Old Model)
# ----------------------------------------
#
# [(u'tv', 0.105, 0.68, 543),
#  (u'channel', 0.286, 0.57, 450),
#  (u'cable', 0.105, 0.19, 392),
#  (u'movie', 0.163, 0.69, 326),
#  (u'video', 0.129, 0.28, 312),
#  (u'box', 0.177, 0.7, 278),
#  (u'player', 0.118, 0.5, 268),
#  (u'connection', 0.228, 0.27, 232),
#  (u'remote', 0.108, 0.44, 230),
#  (u'content', 0.28, 0.64, 217),
#  (u'quality', 0.179, 0.65, 209),
#  (u'service', 0.196, 0.52, 185),
#  (u'ethernet', 0.157, 0.0, 169),
#  (u'unit', 0.148, 0.53, 165),
#  (u'network', 0.192, 0.28, 163),
#  (u'model', 0.223, 0.63, 163),
#  (u'setup', 0.155, 0.36, 148),
#  (u'streaming', 0.15, 0.5, 145),
#  (u'option', 0.262, 0.7, 142),
#  (u'picture', 0.236, 0.8, 139)]
#
# [(u'angry bird', 1.01, 0.0033, 103),
#  (u'apple tv', 1.04, 0.0005, 97),
#  (u'hdmi cable', 1.06, 0.0005, 95),
#  (u'credit card', 1.01, 0.0034, 91),
#  (u'blu ray', 1.79, 0.0071, 73),
#  (u'ray player', 1.15, 0.0014, 66),
#  (u'play game', 1.53, 0.0004, 64),
#  (u'hulu plus', 1.04, 0.0013, 63),
#  (u'internet connection', 1.07, 0.0006, 62),
#  (u'picture quality', 1.07, 0.0012, 59),
#  (u'remote control', 1.16, 0.0006, 58),
#  (u'instant video', 1.02, 0.0009, 52)]
#
# B005CT56F8
# Seagate 320GB HDD SATA 6Gb/s 64MB Cache 3.5-Inch Internal Bare Drive (ST320DM000)
# ----------------------------------------
#
# [(u'drive', 0.222, 0.7, 983),
#  (u'storage', 0.245, 0.4, 214),
#  (u'computer', 0.134, 0.69, 205),
#  (u'data', 0.14, 0.56, 195),
#  (u'speed', 0.242, 0.38, 168),
#  (u'space', 0.28, 0.57, 132),
#  (u'system', 0.121, 0.63, 128),
#  (u'disk', 0.233, 0.66, 125),
#  (u'performance', 0.3, 0.67, 118),
#  (u'hdd', 0.119, 0.69, 106),
#  (u'backup', 0.13, 0.36, 98),
#  (u'file', 0.214, 0.64, 92),
#  (u'box', 0.18, 0.39, 85),
#  (u'capacity', 0.256, 0.72, 84),
#  (u'2tb', 0.144, 0.46, 74),
#  (u'failure', 0.182, 0.46, 73),
#  (u'3tb', 0.113, 0.58, 72),
#  (u'week', 0.175, 0.76, 72),
#  (u'digital', 0.162, 0.06, 70),
#  (u'noise', 0.311, 0.66, 66)]
#
# [(u'western digital', 1.0, 0.0076, 67),
#  (u'seagate barracuda', 1.16, 0.0007, 57),
#  (u'raid array', 1.42, 0.0031, 35)]
#
# B0052SCU8U
# AmazonBasics High-Speed HDMI Cable 2-Pack - 6.5 Feet (2 Meters) Supports Ethernet, 3D, 4K and Audio Return
# ----------------------------------------
#
# [(u'cable', 0.192, 0.56, 1079),
#  (u'quality', 0.34, 0.85, 418),
#  (u'store', 0.296, 0.19, 148),
#  (u'color', 0.263, 0.2, 120),
#  (u'box', 0.172, 0.31, 116),
#  (u'money', 0.263, 0.73, 115),
#  (u'picture', 0.196, 0.8, 115),
#  (u'end', 0.164, 0.79, 92),
#  (u'video', 0.096, 0.64, 89),
#  (u'signal', 0.213, 0.31, 86),
#  (u'length', 0.268, 0.69, 83),
#  (u'job', 0.173, 0.79, 71),
#  (u'monster', 0.1, 0.75, 68),
#  (u'deal', 0.341, 0.92, 63),
#  (u'cord', 0.161, 0.54, 59),
#  (u'value', 0.306, 0.98, 59),
#  (u'connection', 0.177, 0.47, 54),
#  (u'packaging', 0.385, 0.65, 48),
#  (u'set', 0.108, 0.55, 47),
#  (u'receiver', 0.094, 0.73, 45)]
#
# [(u'high quality', 1.12, 0.0008, 90),
#  (u'blu ray', 1.79, 0.0114, 54),
#  (u'ray player', 1.04, 0.0055, 49),
#  (u'color coded', 1.0, 0.0075, 44),
#  (u'big box', 1.0, 0.005, 44),
#  (u'picture quality', 1.52, 0.0007, 43),
#  (u'box store', 1.13, 0.0019, 40),
#  (u'waste money', 1.74, 0.0078, 31),
#  (u'high speed', 1.36, 0.0032, 29),
#  (u'high end', 1.31, 0.001, 24),
#  (u'hdmi cord', 1.11, 0.0004, 24)]
#
# B00316263Y
# BlueRigger High Speed HDMI Cable with Ethernet 6.6 Feet (2m) - Supports 3D and Audio Return [Latest Version]
# ----------------------------------------
#
# [(u'cable', 0.163, 0.6, 1098),
#  (u'quality', 0.285, 0.79, 460),
#  (u'picture', 0.202, 0.83, 192),
#  (u'store', 0.309, 0.17, 145),
#  (u'money', 0.143, 0.67, 104),
#  (u'box', 0.147, 0.33, 103),
#  (u'video', 0.113, 0.64, 100),
#  (u'length', 0.249, 0.58, 85),
#  (u'audio', 0.1, 0.57, 85),
#  (u'end', 0.138, 0.71, 78),
#  (u'sound', 0.118, 0.7, 74),
#  (u'connection', 0.305, 0.47, 72),
#  (u'difference', 0.146, 0.61, 71),
#  (u'signal', 0.189, 0.32, 71),
#  (u'job', 0.19, 0.68, 68),
#  (u'cord', 0.145, 0.65, 64),
#  (u'connector', 0.193, 0.32, 61),
#  (u'value', 0.343, 0.93, 58),
#  (u'speed', 0.326, 0.96, 55),
#  (u'monster', 0.214, 0.67, 55)]
#
# [(u'picture quality', 1.56, 0.0007, 89),
#  (u'blu ray', 1.63, 0.0075, 83),
#  (u'ray player', 1.1, 0.0042, 77),
#  (u'high quality', 1.23, 0.0007, 75),
#  (u'bluerigger hdmi', 1.95, 0.0004, 60),
#  (u'high speed', 1.07, 0.0042, 49),
#  (u'audio return', 1.0, 0.0047, 38),
#  (u'speed hdmi', 1.02, 0.0007, 36),
#  (u'box store', 1.09, 0.0017, 34),
#  (u'build quality', 1.09, 0.0007, 33),
#  (u'big box', 1.05, 0.0035, 33),
#  (u'dvd player', 1.06, 0.0044, 31),
#  (u'sound quality', 1.96, 0.0005, 31),
#  (u'blue rigger', 1.0, 0.0143, 30),
#  (u'waste money', 1.88, 0.0071, 29),
#  (u'heavy duty', 1.07, 0.0217, 27)]
#
# B007WTAJTO
# SanDisk Ultra 64GB MicroSDXC Class 10 UHS Memory Card Speed Up To 30MB/s With Adapter - SDSDQUA-064G-U46A [Old Version]
# ----------------------------------------
#
# [(u'card', 0.139, 0.5, 2519),
#  (u'memory', 0.294, 0.4, 1046),
#  (u'sd', 0.239, 0.15, 838),
#  (u'speed', 0.259, 0.4, 684),
#  (u'storage', 0.34, 0.38, 661),
#  (u'camera', 0.112, 0.31, 517),
#  (u'adapter', 0.104, 0.16, 452),
#  (u'space', 0.332, 0.48, 421),
#  (u'file', 0.219, 0.45, 381),
#  (u'data', 0.165, 0.73, 329),
#  (u'quality', 0.3, 0.88, 245),
#  (u'microsd', 0.129, 0.58, 245),
#  (u'capacity', 0.25, 0.6, 239),
#  (u'size', 0.274, 0.6, 209),
#  (u'android', 0.096, 0.56, 192),
#  (u'hd', 0.097, 0.9, 158)]
#
# [(u'samsung galaxy', 1.0, 0.0006, 464),
#  (u'micro sd', 1.12, 0.0005, 326),
#  (u'galaxy note', 1.05, 0.0005, 252),
#  (u'galaxy s3', 1.02, 0.0007, 215),
#  (u'samsung note', 1.77, 0.0004, 166),
#  (u'galaxy s4', 1.03, 0.0006, 165),
#  (u'samsung s3', 1.91, 0.0004, 113),
#  (u'sandisk ultra', 1.08, 0.0004, 111),
#  (u'samsung s4', 1.78, 0.0004, 98),
#  (u'cell phone', 1.0, 0.0004, 92)]
#
# B0019EHU8G
# Mediabridge ULTRA Series HDMI Cable (6 Foot) - High-Speed Supports Ethernet, 3D and Audio Return [Newest Standard]
# ----------------------------------------
#
# [(u'cable', 0.155, 0.58, 2765),
#  (u'quality', 0.284, 0.86, 1333),
#  (u'picture', 0.196, 0.86, 523),
#  (u'box', 0.164, 0.36, 286),
#  (u'video', 0.118, 0.59, 280),
#  (u'money', 0.165, 0.67, 262),
#  (u'signal', 0.21, 0.38, 245),
#  (u'length', 0.243, 0.43, 236),
#  (u'store', 0.282, 0.12, 229),
#  (u'hd', 0.128, 0.91, 205),
#  (u'connection', 0.192, 0.55, 181),
#  (u'end', 0.163, 0.76, 179),
#  (u'speed', 0.288, 0.87, 164),
#  (u'connector', 0.249, 0.35, 155),
#  (u'job', 0.155, 0.78, 145),
#  (u'system', 0.139, 0.71, 144),
#  (u'cord', 0.181, 0.68, 137),
#  (u'screen', 0.313, 0.69, 130),
#  (u'hdtv', 0.105, 0.57, 121)]
#
# [(u'blu ray', 1.75, 0.0025, 238),
#  (u'ray player', 1.09, 0.0014, 199),
#  (u'high speed', 1.13, 0.0012, 132),
#  (u'home theater', 1.01, 0.0044, 101),
#  (u'ultra series', 1.03, 0.005, 94),
#  (u'mediabridge ultra', 1.07, 0.0006, 89),
#  (u'dvd player', 1.04, 0.0013, 79),
#  (u'mediabridge series', 1.99, 0.0005, 76),
#  (u'blue ray', 1.34, 0.0023, 67),
#  (u'customer service', 1.0, 0.0042, 58)]
#
# B002MAPRYU
# SanDisk Sansa Clip+ 4 GB MP3 Player (Red) (Discontinued by Manufacturer)
# ----------------------------------------
#
# [(u'player', 0.18, 0.7, 771),
#  (u'mp3', 0.115, 0.75, 550),
#  (u'music', 0.146, 0.45, 533),
#  (u'sansa', 0.102, 0.67, 357),
#  (u'battery', 0.15, 0.26, 352),
#  (u'sound', 0.128, 0.87, 317),
#  (u'card', 0.152, 0.08, 303),
#  (u'quality', 0.393, 0.9, 300),
#  (u'song', 0.175, 0.47, 260),
#  (u'life', 0.201, 0.46, 235),
#  (u'ipod', 0.099, 0.6, 215),
#  (u'file', 0.127, 0.33, 195),
#  (u'screen', 0.178, 0.4, 193),
#  (u'size', 0.166, 0.7, 187),
#  (u'sd', 0.308, 0.06, 186),
#  (u'memory', 0.355, 0.24, 181),
#  (u'button', 0.161, 0.45, 181),
#  (u'feature', 0.24, 0.67, 158),
#  (u'unit', 0.188, 0.56, 157),
#  (u'headphone', 0.214, 0.42, 148)]
#
# [(u'mp3 player', 1.01, 0.0004, 447),
#  (u'battery life', 1.01, 0.0014, 204),
#  (u'sound quality', 1.15, 0.0008, 198),
#  (u'sd card', 1.06, 0.0013, 140),
#  (u'micro sd', 1.1, 0.0027, 117),
#  (u'fm radio', 1.03, 0.0019, 94),
#  (u'audio book', 1.02, 0.0018, 83),
#  (u'sansa clip+', 1.04, 0.0005, 70),
#  (u'ear bud', 1.13, 0.0049, 64),
#  (u'microsd card', 1.04, 0.0013, 61),
#  (u'media player', 1.06, 0.0004, 53),
#  (u'memory card', 1.27, 0.0005, 49)]
#
# B0015DYMVO
# Belkin Mini 5W 3-Outlet Swivel Travel Charger with Dual USB Ports
# ----------------------------------------
#
# [(u'usb', 0.109, 0.3, 694),
#  (u'outlet', 0.199, 0.38, 554),
#  (u'surge', 0.19, 0.57, 383),
#  (u'power', 0.152, 0.34, 275),
#  (u'charger', 0.147, 0.36, 274),
#  (u'unit', 0.135, 0.46, 157),
#  (u'room', 0.121, 0.59, 133),
#  (u'hotel', 0.106, 1.0, 108),
#  (u'cable', 0.147, 0.26, 108),
#  (u'adapter', 0.151, 0.4, 98),
#  (u'protection', 0.094, 0.31, 90),
#  (u'size', 0.22, 0.61, 87),
#  (u'cell', 0.154, 0.0, 81),
#  (u'space', 0.26, 0.81, 79),
#  (u'electronics', 0.264, 0.68, 78),
#  (u'design', 0.125, 0.67, 74),
#  (u'cord', 0.161, 0.24, 70),
#  (u'socket', 0.2, 0.33, 70),
#  (u'feature', 0.317, 0.72, 66),
#  (u'place', 0.149, 0.64, 62)]
#
# [(u'usb port', 1.16, 0.0007, 380),
#  (u'surge protector', 1.01, 0.0014, 300),
#  (u'cell phone', 1.0, 0.0022, 79),
#  (u'surge protection', 1.09, 0.0011, 68),
#  (u'usb cable', 1.23, 0.0004, 60),
#  (u'plug rotate', 1.59, 0.0004, 56),
#  (u'hotel room', 1.0, 0.0032, 53),
#  (u'power strip', 1.0, 0.0012, 44),
#  (u'mini surge', 1.25, 0.0005, 33)]
#
# B009A5204K
# LG Tone HBS-730 Wireless Stereo Headset - Black
# ----------------------------------------
#
# [(u'headset', 0.18, 0.55, 408),
#  (u'sound', 0.111, 0.74, 386),
#  (u'quality', 0.377, 0.85, 317),
#  (u'battery', 0.148, 0.34, 310),
#  (u'bluetooth', 0.133, 0.82, 285),
#  (u'range', 0.232, 0.64, 224),
#  (u'headphone', 0.2, 0.46, 212),
#  (u'life', 0.197, 0.71, 201),
#  (u'bud', 0.1, 0.47, 164),
#  (u'connection', 0.226, 0.34, 127),
#  (u'voice', 0.239, 0.37, 119),
#  (u'volume', 0.157, 0.35, 110),
#  (u'wire', 0.155, 0.4, 108),
#  (u'bass', 0.289, 0.73, 107),
#  (u'earbuds', 0.187, 0.33, 107),
#  (u'pocket', 0.111, 0.25, 102),
#  (u'noise', 0.193, 0.52, 96),
#  (u'set', 0.113, 0.7, 84),
#  (u'feature', 0.228, 0.62, 81),
#  (u'bit', 0.135, 0.84, 80)]
#
# [(u'sound quality', 1.2, 0.0007, 237),
#  (u'battery life', 1.01, 0.002, 186),
#  (u'ear bud', 1.13, 0.0013, 132),
#  (u'foot away', 1.1, 0.0024, 36),
#  (u'cell phone', 1.0, 0.0008, 31)]
#
# B007R5YDYA
# Amazon Kindle Paperwhite Case - Lightest and Thinnest Protective Genuine Leather Cover with Auto Wake/Sleep for Amazon Kindle Paperwhite, Saddle Tan
# ----------------------------------------
#
# [(u'cover', 0.15, 0.51, 703),
#  (u'case', 0.166, 0.66, 347),
#  (u'leather', 0.225, 0.75, 244),
#  (u'color', 0.253, 0.52, 216),
#  (u'quality', 0.367, 0.94, 151),
#  (u'protection', 0.417, 0.81, 144),
#  (u'weight', 0.296, 0.7, 127),
#  (u'hand', 0.126, 0.69, 126),
#  (u'feature', 0.261, 0.47, 109),
#  (u'book', 0.186, 0.71, 103),
#  (u'bit', 0.12, 0.7, 92),
#  (u'button', 0.117, 0.37, 65),
#  (u'reader', 0.117, 0.62, 62),
#  (u'material', 0.282, 0.57, 61),
#  (u'paper', 0.111, 0.5, 57),
#  (u'bulk', 0.462, 0.81, 57),
#  (u'touch', 0.123, 0.76, 56),
#  (u'reading', 0.463, 0.21, 56),
#  (u'design', 0.135, 0.55, 48)]
#
# [(u'high quality', 1.09, 0.0032, 42),
#  (u'magnetic closure', 1.0, 0.0041, 40),
#  (u'paper white', 1.11, 0.0128, 40),
#  (u'magnetic clasp', 1.03, 0.0034, 36),
#  (u'perfect fit', 1.31, 0.0004, 35),
#  (u'power button', 1.03, 0.0069, 31),
#  (u'kindle keyboard', 1.09, 0.0005, 27)]
#
# B000LRMS66
# Garmin Portable Friction Mount
# ----------------------------------------
#
# [(u'car', 0.148, 0.35, 589),
#  (u'cup', 0.267, 0.09, 446),
#  (u'dashboard', 0.094, 0.42, 444),
#  (u'friction', 0.221, 0.27, 384),
#  (u'vehicle', 0.196, 0.31, 196),
#  (u'turn', 0.207, 0.85, 123),
#  (u'base', 0.137, 0.36, 123),
#  (u'bit', 0.102, 0.84, 123),
#  (u'road', 0.32, 0.36, 120),
#  (u'mark', 0.161, 0.3, 112),
#  (u'bag', 0.16, 0.37, 109),
#  (u'sight', 0.222, 1.0, 103),
#  (u'bottom', 0.096, 0.35, 100),
#  (u'thief', 0.23, 0.14, 96),
#  (u'trip', 0.162, 0.58, 93),
#  (u'surface', 0.33, 0.5, 82),
#  (u'holder', 0.165, 0.52, 79)]
#
# [(u'suction cup', 1.04, 0.0012, 439),
#  (u'portable friction', 1.02, 0.0009, 90),
#  (u'bean bag', 1.1, 0.0066, 72),
#  (u'dash board', 1.04, 0.0008, 63),
#  (u'rental car', 1.12, 0.0009, 59),
#  (u'gps unit', 1.06, 0.0005, 49),
#  (u'sharp turn', 1.04, 0.0032, 44),
#  (u'leave mark', 1.68, 0.0012, 42)]
#
# B003ES5ZUU
# AmazonBasics High-Speed HDMI Cable with Ethernet - Braided 6.5 feet/2.0 meters (Discontinued by Manufacturer)
# ----------------------------------------
#
# [(u'cable', 0.176, 0.56, 3044),
#  (u'quality', 0.315, 0.81, 1190),
#  (u'picture', 0.206, 0.81, 398),
#  (u'store', 0.307, 0.16, 362),
#  (u'money', 0.224, 0.75, 311),
#  (u'box', 0.153, 0.27, 302),
#  (u'length', 0.269, 0.64, 300),
#  (u'cord', 0.185, 0.62, 237),
#  (u'job', 0.134, 0.72, 236),
#  (u'video', 0.125, 0.62, 229),
#  (u'signal', 0.262, 0.33, 186),
#  (u'blu', 0.167, 0.0, 177),
#  (u'end', 0.194, 0.81, 175),
#  (u'connection', 0.226, 0.53, 171),
#  (u'sound', 0.114, 0.83, 171),
#  (u'connector', 0.263, 0.29, 166),
#  (u'hd', 0.175, 0.9, 164),
#  (u'value', 0.351, 0.94, 143),
#  (u'speed', 0.262, 0.92, 134),
#  (u'monitor', 0.109, 0.44, 132)]
#
# [(u'blu ray', 1.72, 0.0039, 180),
#  (u'ray player', 1.06, 0.0021, 159),
#  (u'high speed', 1.54, 0.0013, 114),
#  (u'big box', 1.1, 0.0012, 93),
#  (u'box store', 1.11, 0.0006, 87),
#  (u'apple tv', 1.02, 0.0006, 85)]
#
# B00DR0PDNE
#
# ----------------------------------------
#
# [(u'tv', 0.095, 0.74, 1741),
#  (u'video', 0.129, 0.32, 1083),
#  (u'apps', 0.328, 0.71, 878),
#  (u'screen', 0.282, 0.49, 551),
#  (u'content', 0.235, 0.5, 423),
#  (u'setup', 0.109, 0.53, 409),
#  (u'cable', 0.112, 0.3, 398),
#  (u'network', 0.197, 0.13, 385),
#  (u'wifi', 0.117, 0.33, 357),
#  (u'quality', 0.194, 0.59, 352),
#  (u'internet', 0.104, 0.52, 333),
#  (u'medium', 0.343, 0.3, 323),
#  (u'player', 0.102, 0.55, 287),
#  (u'home', 0.1, 0.43, 263),
#  (u'connection', 0.184, 0.44, 263),
#  (u'streaming', 0.151, 0.59, 260),
#  (u'router', 0.134, 0.45, 257),
#  (u'service', 0.309, 0.6, 252),
#  (u'room', 0.129, 0.21, 252),
#  (u'box', 0.168, 0.55, 248)]
#
# [(u'chrome browser', 1.11, 0.0005, 435),
#  (u'hdmi port', 1.16, 0.0006, 193),
#  (u'usb port', 1.11, 0.0009, 164),
#  (u'big screen', 1.11, 0.0005, 121),
#  (u'hbo go', 1.02, 0.0006, 116),
#  (u'wi fi', 1.99, 0.0051, 82)]
#
# B005HMKKH4
# WD My Passport 2TB Portable External USB 3.0 Hard Drive Storage Black (WDBY8L0020BBK-NESN)
# ----------------------------------------
#
# [(u'drive', 0.308, 0.57, 1019),
#  (u'wd', 0.105, 0.48, 386),
#  (u'file', 0.188, 0.59, 375),
#  (u'computer', 0.14, 0.55, 362),
#  (u'backup', 0.122, 0.35, 308),
#  (u'storage', 0.374, 0.42, 295),
#  (u'software', 0.188, 0.21, 256),
#  (u'data', 0.156, 0.47, 239),
#  (u'size', 0.204, 0.52, 223),
#  (u'speed', 0.189, 0.49, 198),
#  (u'case', 0.153, 0.4, 177),
#  (u'space', 0.354, 0.57, 175),
#  (u'power', 0.111, 0.07, 167),
#  (u'digital', 0.171, 0.0, 156),
#  (u'cable', 0.125, 0.26, 149),
#  (u'capacity', 0.316, 0.53, 124),
#  (u'system', 0.131, 0.35, 112),
#  (u'pc', 0.12, 0.52, 112),
#  (u'machine', 0.096, 0.56, 87),
#  (u'disk', 0.215, 0.53, 86)]
#
# [(u'western digital', 1.0, 0.0036, 152),
#  (u'usb port', 1.43, 0.0007, 117),
#  (u'wd passport', 1.54, 0.0005, 106),
#  (u'transfer file', 1.42, 0.0004, 57),
#  (u'time machine', 1.01, 0.0012, 53),
#  (u'transfer speed', 1.12, 0.0007, 48),
#  (u'data transfer', 1.22, 0.0005, 44)]
#
# B002V88HFE
# eneloop SEC-CSPACER4PK C Size Spacers for use with AA battery cells
# ----------------------------------------
#
# [(u'battery', 0.27, 0.36, 1642),
#  (u'charger', 0.165, 0.62, 437),
#  (u'camera', 0.189, 0.17, 269),
#  (u'eneloops', 0.163, 0.39, 228),
#  (u'power', 0.147, 0.68, 202),
#  (u'set', 0.142, 0.49, 198),
#  (u'pack', 0.106, 0.44, 167),
#  (u'life', 0.263, 0.67, 161),
#  (u'money', 0.215, 0.7, 153),
#  (u'capacity', 0.356, 0.66, 140),
#  (u'rechargeables', 0.246, 0.78, 139),
#  (u'hour', 0.096, 0.59, 134),
#  (u'flashlight', 0.096, 0.46, 116),
#  (u'week', 0.168, 0.61, 116),
#  (u'quality', 0.427, 0.87, 105),
#  (u'phone', 0.115, 0.3, 100),
#  (u'light', 0.182, 0.26, 100),
#  (u'mouse', 0.113, 0.04, 98),
#  (u'cell', 0.225, 0.43, 97),
#  (u'case', 0.16, 0.54, 95)]
#
# [(u'hold charge', 1.99, 0.0004, 353),
#  (u'long time', 1.23, 0.0004, 211),
#  (u'sanyo eneloop', 1.36, 0.0005, 67),
#  (u'camera flash', 1.41, 0.0005, 66),
#  (u'digital camera', 1.01, 0.0022, 63),
#  (u'save money', 1.56, 0.0025, 62),
#  (u'remote control', 1.05, 0.0041, 57),
#  (u'xbox controller', 1.57, 0.0057, 53),
#  (u'cordless phone', 1.1, 0.0055, 52),
#  (u'ni mh', 1.97, 0.0098, 51),
#  (u'self discharge', 1.49, 0.0062, 49),
#  (u'high capacity', 1.14, 0.0013, 48),
#  (u'wireless mouse', 1.5, 0.0035, 46),
#  (u'long life', 1.3, 0.0004, 44)]
#
# B001XURP7W
# SanDisk Cruzer 4GB USB 2.0 Flash Drive- SDCZ36-004G-B35
# ----------------------------------------
#
# [(u'drive', 0.134, 0.62, 754),
#  (u'file', 0.251, 0.62, 311),
#  (u'computer', 0.125, 0.53, 185),
#  (u'storage', 0.332, 0.31, 178),
#  (u'data', 0.173, 0.61, 171),
#  (u'speed', 0.268, 0.36, 153),
#  (u'space', 0.356, 0.49, 107),
#  (u'thumb', 0.14, 0.33, 97),
#  (u'capacity', 0.328, 0.78, 95),
#  (u'memory', 0.237, 0.61, 90),
#  (u'quality', 0.218, 0.93, 82),
#  (u'deal', 0.247, 0.85, 74),
#  (u'size', 0.282, 0.36, 74),
#  (u'software', 0.145, 0.33, 71),
#  (u'laptop', 0.183, 0.93, 69),
#  (u'document', 0.11, 0.36, 59),
#  (u'disk', 0.161, 0.4, 55),
#  (u'backup', 0.099, 0.29, 51),
#  (u'movie', 0.171, 0.67, 48),
#  (u'system', 0.196, 0.41, 44)]
#
# [(u'flash drive', 1.01, 0.0006, 493),
#  (u'thumb drive', 1.06, 0.0006, 86),
#  (u'transfer file', 1.53, 0.0007, 84),
#  (u'sandisk cruzer', 1.01, 0.0011, 69),
#  (u'hard drive', 1.03, 0.0004, 60),
#  (u'usb port', 1.09, 0.0015, 45),
#  (u'large file', 1.4, 0.0007, 40),
#  (u'data transfer', 1.18, 0.0006, 38),
#  (u'write speed', 1.04, 0.0015, 33)]
#
# B004W2JKWG
# Crucial m4 64GB 2.5-Inch (9.5mm) SATA 6Gb/s Solid State Drive CT064M4SSD2
# ----------------------------------------
#
# [(u'drive', 0.228, 0.62, 684),
#  (u'ssd', 0.108, 0.58, 530),
#  (u'computer', 0.139, 0.69, 280),
#  (u'speed', 0.172, 0.33, 227),
#  (u'performance', 0.238, 0.63, 219),
#  (u'system', 0.143, 0.55, 217),
#  (u'laptop', 0.185, 0.72, 211),
#  (u'firmware', 0.189, 0.74, 175),
#  (u'm4', 0.101, 0.21, 161),
#  (u'macbook', 0.156, 0.79, 150),
#  (u'program', 0.201, 0.57, 138),
#  (u'disk', 0.304, 0.61, 127),
#  (u'data', 0.103, 0.56, 118),
#  (u'hdd', 0.192, 0.63, 116),
#  (u'pc', 0.147, 0.67, 111),
#  (u'machine', 0.261, 0.62, 105),
#  (u'difference', 0.177, 0.74, 102),
#  (u'hour', 0.102, 0.63, 101),
#  (u'application', 0.193, 0.56, 95),
#  (u'desktop', 0.118, 0.33, 93)]
#
# [(u'hard drive', 1.07, 0.0004, 214),
#  (u'macbook pro', 1.0, 0.0028, 121),
#  (u'boot time', 1.28, 0.0004, 118),
#  (u'crucial m4', 1.2, 0.0008, 104),
#  (u'firmware update', 1.27, 0.0012, 84),
#  (u'solid state', 1.03, 0.007, 66),
#  (u'late firmware', 1.26, 0.0015, 42)]
#
# B0044YU60M
# Wireless Router w/ WiFi Range Extender Mode (300 Mbps) by Medialink - Easy YouTube Setup Video (Part# MWNWAPR300N )
# ----------------------------------------
#
# [(u'router', 0.175, 0.66, 858),
#  (u'signal', 0.259, 0.53, 267),
#  (u'connection', 0.233, 0.26, 217),
#  (u'setup', 0.14, 0.43, 207),
#  (u'speed', 0.26, 0.58, 177),
#  (u'house', 0.138, 0.53, 169),
#  (u'customer', 0.256, 0.86, 166),
#  (u'linksys', 0.123, 0.84, 161),
#  (u'cable', 0.095, 0.35, 156),
#  (u'range', 0.276, 0.68, 155),
#  (u'service', 0.159, 0.71, 155),
#  (u'instruction', 0.146, 0.38, 154),
#  (u'support', 0.156, 0.36, 152),
#  (u'network', 0.193, 0.29, 151),
#  (u'home', 0.208, 0.69, 113),
#  (u'week', 0.181, 0.53, 109),
#  (u'installation', 0.128, 0.55, 102),
#  (u'setting', 0.167, 0.38, 97),
#  (u'unit', 0.175, 0.55, 90),
#  (u'strength', 0.153, 0.68, 90)]
#
# [(u'customer service', 1.0, 0.0026, 107),
#  (u'signal strength', 1.09, 0.0016, 74),
#  (u'cable modem', 1.21, 0.0012, 68),
#  (u'wireless n', 1.28, 0.0005, 67),
#  (u'strong signal', 1.62, 0.0014, 60),
#  (u'tech support', 1.0, 0.0022, 55),
#  (u'drop connection', 1.59, 0.0008, 51),
#  (u'blue light', 1.23, 0.0049, 44),
#  (u'old linksys', 1.16, 0.0006, 44),
#  (u'drop signal', 1.79, 0.0005, 42),
#  (u'customer support', 1.07, 0.0007, 35),
#  (u'ip address', 1.04, 0.0044, 34)]
#
# B0074BW614
# Kindle Fire HD 7", Dolby Audio, Dual-Band Wi-Fi, 16 GB (Previous Generation - 2nd),-R
# ----------------------------------------
#
# [(u'kindle', 0.125, 0.63, 1303),
#  (u'fire', 0.124, 0.87, 967),
#  (u'book', 0.147, 0.59, 694),
#  (u'tablet', 0.219, 0.71, 605),
#  (u'screen', 0.163, 0.51, 561),
#  (u'apps', 0.244, 0.77, 491),
#  (u'movie', 0.111, 0.49, 422),
#  (u'video', 0.14, 0.35, 353),
#  (u'sound', 0.108, 0.76, 310),
#  (u'quality', 0.196, 0.91, 252),
#  (u'picture', 0.173, 0.78, 244),
#  (u'feature', 0.194, 0.72, 240),
#  (u'reader', 0.152, 0.58, 223),
#  (u'size', 0.173, 0.64, 213),
#  (u'battery', 0.151, 0.5, 208),
#  (u'speaker', 0.254, 0.4, 181),
#  (u'case', 0.112, 0.51, 180),
#  (u'android', 0.214, 0.72, 175),
#  (u'reading', 0.19, 0.48, 173),
#  (u'camera', 0.202, 0.2, 172)]
#
# [(u'watch movie', 1.58, 0.0006, 215),
#  (u'play game', 1.51, 0.0007, 166),
#  (u'battery life', 1.01, 0.0022, 128),
#  (u'wi fi', 1.96, 0.0056, 79),
#  (u'ipad mini', 1.1, 0.0008, 78),
#  (u'customer service', 1.01, 0.0026, 76)]

# %%
# Only run the code if asin_dict was executed with following parameters:
# unigramer.candidate_unigrams(corpus, min_pct=0.01, amod_pct=0.0)
# bigramer.candidate_bigrams(corpus, cnt_dict, min_pct=0.005, pmi_pct=0, max_avg_dist=3)

import csv

with open("labeled_unigrams.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(all_unigrams)

with open("labeled_bigrams.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(all_bigrams)

# %% [markdown]
# ### Evaluation of unigram threshold

# %%
uni_df = pd.read_csv('test.csv')

# %%
from sklearn.metrics import *

# %%
X = uni_df.ix[:, 3].values
y = uni_df.ix[:, 6].values.astype(bool)

# %%
def print_score(X, y, test_values):
    for thresh in test_values:
        acc = round(accuracy_score(y, X > thresh), 3)
        pre = round(precision_score(y, X > thresh), 3)
        rec = round(recall_score(y, X > thresh), 3)
        f1 = round(f1_score(y, X > thresh), 3)
        print thresh, '\t', acc, '\t', pre, '\t', rec, '\t', f1
